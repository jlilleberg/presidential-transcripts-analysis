# %%
# Clean unicode and double nested arrays
import unicodedata
import itertools

# Handle Data
import pandas as pd
import numpy as np
from collections import OrderedDict 
from collections import Counter

# CMU dictionary
from nltk.corpus import cmudict

# Time and Progress Bar
from tqdm import tqdm
import time

# Regular Expressions
import re

from pprint import pprint

# Parallel Processing
from joblib import Parallel, delayed
import math
from spacy.util import minibatch
from functools import partial

# Web scaping
import requests
from bs4 import BeautifulSoup
import pickle

# Handle numbers
from text_to_num import text2num
from text_to_num import alpha2digit
from num2words import num2words

# Spacy
import spacy
from spacy.matcher import Matcher
from spacy.lang.en import English

# Custom Tokenizer
import re
import spacy
from spacy.tokenizer import Tokenizer
from spacy.lang.char_classes import ALPHA, ALPHA_LOWER, ALPHA_UPPER, CONCAT_QUOTES, LIST_ELLIPSES, LIST_ICONS
from spacy.lang.de.punctuation import _quotes
from spacy.util import compile_prefix_regex, compile_infix_regex, compile_suffix_regex
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-813368b777b0> in <module>
#      33
#      34 # Handle numbers
# ---> 35 from text_to_num import text2num
#      36 from text_to_num import alpha2digit
#      37 from num2words import num2words
#
# ModuleNotFoundError: No module named 'text_to_num'

# %% [markdown]
# # 1. Preprocessing Functions

# %% [markdown]
# ## 1.1 Custom Tokenizer <a id='1_1_id'></a>

# %%
# https://stackoverflow.com/questions/57295996/is-it-possible-to-change-the-token-split-rules-for-a-spacy-tokenizer

# Custom tokenizer to not split on hyphens
def custom_tokenizer(nlp):
    infixes = (
        LIST_ELLIPSES
        + LIST_ICONS
        + [
            r"(?<=[{al}])\.(?=[{au}])".format(al=ALPHA_LOWER, au=ALPHA_UPPER),
            r"(?<=[{a}])[,!?](?=[{a}])".format(a=ALPHA),
            r'(?<=[{a}])[:<>=](?=[{a}])'.format(a=ALPHA),
            r"(?<=[{a}]),(?=[{a}])".format(a=ALPHA),
            r"(?<=[{a}])([{q}\]\[])(?=[{a}])".format(a=ALPHA, q=_quotes),
            r"(?<=[{a}])--(?=[{a}])".format(a=ALPHA),
            r"(?<=[0-9])-(?=[0-9])",
        ]
    )

    infix_re = compile_infix_regex(infixes)
    
    updated_tokenizer =  Tokenizer(nlp.vocab, prefix_search=nlp.tokenizer.prefix_search,
                                suffix_search=nlp.tokenizer.suffix_search,
                                infix_finditer=infix_re.finditer,
                                token_match=nlp.tokenizer.token_match,
                                rules=nlp.Defaults.tokenizer_exceptions)
    
    return updated_tokenizer

# %% [markdown]
# ## 1.2 Matchers <a id='1_3_id'></a>

# %%
def pattern_merger(doc):
    """ 
        This will be called on the Doc object in the pipeline 
    """
    matched_spans = []
    matches = matcher(doc)
    for match_id, start, end in matches:
        span = doc[start:end]
        matched_spans.append(span)
    for span in matched_spans:  # merge into one token after collecting all matches
        span.merge()
    return doc

# %% [markdown]
# # 1.3 Pipelines

# %%
def remove_excess_spaces_component(doc):
    """ Removes all excess spaces to a single space """
    filtered_text = ' '.join([token.text for token in doc if not token.is_space])
    return pattern_merger(nlp.make_doc(filtered_text))

# %% [markdown]
# # 2. Helper Functions

# %% [markdown]
# ## 2.1 General Functions <a id='2_1_id'></a>

# %%
def update_dict(dictionary, before_after_values):
    """ 
        Given a list of tuples (before, after), updates dictionary with 'before' as key and 'after' as value 
        if the pair doesn't already exist in the dictionary and returns it
    """
    
    for before, after in before_after_values:
        if before not in dictionary:
            dictionary[before] = after
    return dictionary

# %%
def is_valid_hyphen_word(word):
    """
        Returns True if each word in the hyphenated token is a valid word
    """
    word_tokens = word.split('-')
    words = [is_word(token) is not False for token in word_tokens]
    return sum(words) == len(words)

# %%
def is_all_words(token):
    """
        Returns True if all tokens are valid words
    """
    tokens = token.text.split()
    return sum([token.isalnum() for token in tokens]) == len(tokens)

# %%
def is_word(word):
    """
        Verifies the word is valid if it exists in merriam-wester's database
    """
    
    url = 'https://www.merriam-webster.com/dictionary/' + word
    
    while True:
        try:
            page = requests.get(url).text
            soup = BeautifulSoup(page, 'lxml')
            try:
                if soup.find_all("div", {"id": "definition-wrapper"})[0].find('h1', {'class': 'hword'}):
                    return soup.find_all("div", {"id": "definition-wrapper"})[0].find('h1', {'class': 'hword'}).text
                elif soup.find_all("div", {"id": "definition-wrapper"})[0].find('h1', {'class': 'mispelled-word'}):
                    return False
            except:
                return False
        except:
            # If there is connection failure, wait 2 seconds then retry
            time.sleep(2)
            continue
        break

# %%
def preview_summaries(president):
    """ 
        Prints  all summaries for a given president 
    """
    df = speeches[speeches.President == president].Summary.reset_index()
    for row in df.itertuples(index=False):
        index = row[0]
        summary = row[1]
        if len(summary) > 0:
            print('Index: {}\n{}\n'.format(index, summary))

# %%
def get_presidents(ret = False):
    """ 
        Returns list of presidents in alphabetical order 
    """
    
    presidents = sorted(list(set(speeches.President.values)))
    if ret:
        return presidents
    else:
        for i, president in enumerate(presidents):
            print('{}: {}'.format(i, president))
        return presidents

# %%
def clean_removable_speaker_text(speaker, speakers):
    """
        Given a speaker and a list of all speakers, remove all texts from the speaker f
    """
    texts = []
    
    pattern = '{}[^:]+'.format(speaker)
    patterns = find_pattern(speeches['Transcript'], pattern, 50, -1, verbose = False)
    
    for pattern in patterns:
        pattern_match = []
        for speaker in speakers:
            speaker = speaker.rstrip(':')
            
            # End of pattern matches a speaker, 
            if speaker == pattern[-len(speaker):]:
                pattern_match += [pattern[:-len(speaker)]]
        if not pattern_match:
            texts += [pattern]
        else:
            texts += pattern_match
    return texts

# %%
def text_surrounding_speakers(speakers, single_multiple = 'multiple'):
    """
        Returns all surrounding text around a given speaker
    """
    if single_multiple == 'single':
        speaker = speakers
        print('{}\n| {} |\n{}\n'.format((len(speaker) + 6) * '-', speaker, (len(speaker) + 6) * '-'))

        pattern = '.{,30}' + speaker + '.{,30}'
        pprint(find_pattern(speeches['Transcript'], pattern, 50, -1)[:5])
        print()
    elif single_multiple == 'multiple':
        for i, speaker in enumerate(speakers):
            print('{}\n| {} {} |\n{}\n'.format((len(speaker) + (6 if i < 10 else 7)) * '-', i, speaker, (len(speaker) + (6 if i < 10 else 7)) * '-'))

            pattern = '.{,30}' + speaker + '.{,30}'
            pprint(find_pattern(speeches['Transcript'], pattern, 50, -1)[:5])
            print()

# %%
def is_number(text):
    """ Returns boolean on whether token is a number or not """
    try:
        return text2num(text.lower(), "en")
    except:
        return None

# %%
def is_ordinal(token):
    """ Returns boolean indicating if token is ordinal """
    try:
        ordinal_number = alpha2digit(token, "en")
        ordinal_number_stripped = re.match('[0-9]+', ordinal_number)[0]
        return token == num2words(int(ordinal_number_stripped), to='ordinal')
    except:
        return False

# %%
def is_compound(token, p1, p2, select):
    """
        Returns specified pos/tag for each token of the specified format
        
        p: part of speech
        t: tag
    """
    
    if select == 'pp':
        if token[0].pos_ == p1 and token[1].pos_ == p2:
            return True
    if select == 'pt':
        if token[0].pos_ == p1 and token[1].tag_ == p2:
            return True
    if select == 'tp':
        if token[0].tag_ == p1 and token[1].pos_ == p2:
            return True
    if select == 'tt':
        if token[0].tag_ == p1 and token[1].tag_ == p2:
            return True

# %%
def clean_transcript(doc):
    """
    Given a doc, replaces all quotes with the correct double quotes token. Then merges the tokens in sentences
    with the correct formatting and correct puncuation placement. Finally removes all unncessary text in 
    parenthese 
    """
    
    # Replace quotation tokens
    transcript_quotes = []
    left_quote = True
    for token in doc:
        if token.text == '"':
            if left_quote:
                transcript_quotes += ['“']
                left_quote = False
            else:
                transcript_quotes += ['”']
                left_quote = True
        else:
            transcript_quotes += [token.text]  
    
    transcript_quotes = nlp(' '.join(transcript_quotes))
    
    punctuation_marks = ['.', ',','?','!',':',';', ',']
    
    # Merge tokens into correct placement
    transcript_punctuation = ""
    for i, token in enumerate(transcript_quotes):
        if i < len(transcript_quotes) - 1:
            if transcript_quotes[i+1].text in punctuation_marks:
                transcript_punctuation += token.text
            else:
                transcript_punctuation += token.text + ' '
    transcript_punctuation
    
    # Merge sentences using quotation boundaries 
    new_transcript = transcript_punctuation.replace(' ..', '.')
    new_transcript = new_transcript.split(' “ ')
    new_transcript = ' “'.join(new_transcript)
    new_transcript = new_transcript.split(' ” ')
    new_transcript = '” '.join(new_transcript)
    
    # Removes all unncessary text in  parenthese 
    new_transcript = new_transcript.replace('(Applause.)', '')
    new_transcript = new_transcript.replace('(Laughs.)', '')
    new_transcript = new_transcript.replace('(Laughter.)', '')
    new_transcript = new_transcript.replace('(LAUGHTER)', '')
    new_transcript = new_transcript.replace('(APPLAUSE)', '')
    new_transcript = new_transcript.replace('(laughter.)', '')
    new_transcript = new_transcript.replace('(TRANSLATION) ', '')
    new_transcript = re.sub(' -{2,}', '', new_transcript)

    return new_transcript

# %%
def clean_text_tokens(text, clean_dict):
    """
     Given a dictionary of tokens before and after, cleans the given text
    """
    for token in clean_dict:
        if token in text:
            text = text.replace(token, clean_dict[token])
            
    return text.strip()

# %% [markdown]
# ## 2.2 Parallel Processing Functions <a id='2_3_id'></a>

# %% [markdown]
# ### 2.2.1 Calling Functions <a id='2_3_id'></a>

# %%
def find_pattern(texts, pattern, batch_size, n_jobs, verbose = False):
    """
        Finds all pattern matches in the given texts using parallel processing
    """
    num_of_texts = len(texts)
    num_of_batches = math.ceil(num_of_texts/batch_size) 
    
    # Processing Texts
    mini_batch_pattern('find_pattern', texts, pattern, num_of_texts, batch_size, num_of_batches, n_jobs, verbose)
    
    path = 'pickles/batch_functions/find_pattern/find_pattern'
    return pickles_to_list(path, num_of_batches)

# %%
def get_transcript_tokens(texts, batch_size, n_jobs, verbose = False):
    """
        Finds all tokens in the given texts that are not words or numbers
    """
    
    num_of_texts = len(texts)
    num_of_batches = math.ceil(num_of_texts/batch_size) 
    
    # Processing Texts
    mini_batch('transcript_tokens', texts, num_of_texts, batch_size, num_of_batches, n_jobs, verbose)
    
    path = 'pickles/batch_functions/transcript_tokens/transcript_tokens'
    return pickles_to_list(path, num_of_batches)

# %% [markdown]
# ### 2.2.2 Parallel Processing Functions <a id='2_3_id'></a>

# %%
def mini_batch(method, texts, num_of_texts, batch_size, num_of_batches, n_jobs, verbose):
    """
        Given the function name and texts, executes the specified function using parallel processing
    """
    
    partitions = minibatch(texts, size=batch_size)
    executor = Parallel(n_jobs=n_jobs, backend="multiprocessing", prefer="processes")
    
    path = 'pickles/batch_functions/{}/{}'.format(method, method)
    
    
    if method == 'combine_transcripts':
        do = delayed(partial(combine_transcripts_batch, num_of_texts, num_of_batches, path, verbose))
    if method == 'transcript_tokens':
        do = delayed(partial(transcript_tokens_batch, num_of_texts, num_of_batches, path, verbose))
        
    tasks = (do(i, batch) for i, batch in enumerate(partitions))
    executor(tasks)

# %%
def mini_batch_pattern(method, texts, pattern, num_of_texts, batch_size, num_of_batches, n_jobs, verbose):
    """
        Executes find_pattern using parallel processing
    """
    
    partitions = minibatch(texts, size=batch_size)
    executor = Parallel(n_jobs=n_jobs, backend="multiprocessing", prefer="processes")
    
    path = 'pickles/batch_functions/{}/{}'.format(method, method)
    
    if method == 'find_pattern':
        do = delayed(partial(find_pattern_batch, pattern, num_of_texts, num_of_batches, path, verbose))
        
    tasks = (do(i, batch) for i, batch in enumerate(partitions))
    executor(tasks)

# %% [markdown]
# ### 2.2.3 Called Functions <a id='2_3_id'></a>

# %%
def find_pattern_batch(pattern, num_of_texts, num_of_batches, path, verbose, batch_id, texts):
    if verbose:
        print("Processing batch {}/{}".format(batch_id + 1, num_of_batches))
    
    pattern_matches = []
    for text in texts:
        matches = re.finditer(pattern, text)
        for match in matches:
            pattern_matches += [match[0]]
    output_path = '{}_{}.p'.format(path, batch_id + 1)
    pickle.dump(pattern_matches, open(output_path, "wb" ))

# %%
def combine_transcripts_batch(num_of_texts, num_of_batches, path, verbose, batch_id, texts):
    if verbose:
        print("Processing batch {}/{}".format(batch_id + 1, num_of_batches))
    
    transcripts = []
    for doc in nlp.pipe(texts):
        transcripts += [doc.text]        
    output_path = '{}_{}.p'.format(path, batch_id + 1)
    pickle.dump(transcripts, open(output_path, "wb" ))

# %%
def transcript_tokens_batch(num_of_texts, num_of_batches, path, verbose, batch_id, texts):
    if verbose:
        print("Processing batch {}/{}".format(batch_id + 1, num_of_batches))
        
    docs = list(nlp.pipe(texts))
    tokens = [[token.text for token in doc if not token.is_alpha and not token.like_num and not token.is_punct and not token.is_space] for doc in docs]
    tokens = list(set(itertools.chain.from_iterable(tokens)))
    
    output_path = '{}_{}.p'.format(path, batch_id + 1)
    pickle.dump(tokens, open(output_path, "wb" ))

# %% [markdown]
# ### 2.4 Load Pickles Functions <a id='2_3_id'></a>

# %%
def pickles_to_list(path, num_of_batches):
    pickle_list = []
    for batch in range(1, num_of_batches + 1):
        batch_path = '{}_{}.p'.format(path, batch)
        pickle_list += pickle.load(open(batch_path, 'rb'))
    return list(set(pickle_list))

# %% [markdown]
# # 3. Setup

# %% [markdown]
# ## 3.1 Load Data <a id='3_1_id'></a>

# %%
# Load speeches
speeches = pickle.load(open('pickles/webscrape/raw_speech_data.p', 'rb'))

# Examine speeches
speeches
# Out:
#                    Date                     President  \
# 0    September 25, 2019       Donald Trump Presidency
# 1    September 24, 2019       Donald Trump Presidency
# 2     February 15, 2019       Donald Trump Presidency
# 3     February 05, 2019       Donald Trump Presidency
# 4      January 19, 2019       Donald Trump Presidency
# ..                  ...                           ...
# 987   December 29, 1790  George Washington Presidency
# 988   December 08, 1790  George Washington Presidency
# 989    January 08, 1790  George Washington Presidency
# 990    October 03, 1789  George Washington Presidency
# 991      April 30, 1789  George Washington Presidency
#
#                                           Speech Title  \
# 0                 September 25, 2019: Press Conference
# 1    September 24, 2019: Remarks at the United Nati...
# 2    February 15, 2019: Speech Declaring a National...
# 3         February 5, 2019: State of the Union Address
# 4    January 19, 2019: Remarks about the US Souther...
# ..                                                 ...
# 987  December 29, 1790: Talk to the Chiefs and Coun...
# 988  December 8, 1790: Second Annual Message to Con...
# 989  January 8, 1790: First Annual Message to Congress
# 990         October 3, 1789: Thanksgiving Proclamation
# 991            April 30, 1789: First Inaugural Address
#
#                                                Summary  \
# 0    President Donald Trump holds a press conferenc...
# 1    President Donald Trump speaks to the 74th sess...
# 2    President Donald Trump declares a national eme...
# 3    In his second State of the Union Address, Pres...
# 4    President Donald Trump speaks about what he se...
# ..                                                 ...
# 987  The President reassures the Seneca Nation that...
# 988  Washington focuses on commerce in his second a...
# 989  In a wide-ranging speech, President Washington...
# 990  At the request of Congress, Washington establi...
# 991  Washington calls on Congress to avoid local an...
#
#                                             Transcript  \
# 0    \nTranscript\nPRESIDENT TRUMP:  Thank you very...
# 1    \nTranscript\nPRESIDENT TRUMP:  Thank you very...
# 2    \nTranscript\nTHE PRESIDENT:  Thank you very m...
# 3    \nTranscript\n\nMadam Speaker, Mr. Vice Presid...
# 4    \nTranscript\nTHE PRESIDENT: Just a short time...
# ..                                                 ...
# 987  Transcript I the President of the United State...
# 988  Transcript Fellow citizens of the Senate and H...
# 989  TranscriptFellow Citizens of the Senate and Ho...
# 990  TranscriptWhereas it is the duty of all Nation...
# 991  TranscriptFellow Citizens of the Senate and th...
#
#                                                    URL
# 0    https://millercenter.org/the-presidency/presid...
# 1    https://millercenter.org/the-presidency/presid...
# 2    https://millercenter.org/the-presidency/presid...
# 3    https://millercenter.org/the-presidency/presid...
# 4    https://millercenter.org/the-presidency/presid...
# ..                                                 ...
# 987  https://millercenter.org/the-presidency/presid...
# 988  https://millercenter.org/the-presidency/presid...
# 989  https://millercenter.org/the-presidency/presid...
# 990  https://millercenter.org/the-presidency/presid...
# 991  https://millercenter.org/the-presidency/presid...
#
# [992 rows x 6 columns]

# %% [markdown]
# ## 3.2 Initialize NLP Model <a id='3_2_id'></a>

# %%
# Small English Model
nlp = spacy.load("en_core_web_sm")

# Set tokenizer to the custom tokenizer
nlp.tokenizer = custom_tokenizer(nlp)

# Pipeline
nlp.add_pipe(pattern_merger, first=True)  # add it right after the tokenizer

# Tokens to be cleaned before and after mappings
clean_dict = {}

# %% [markdown]
# ## 3.3 Initialize Matcher <a id='3_3_id'></a>

# %%
# Matcher
matcher = Matcher(nlp.vocab)

# Pattern to match possesion
matcher.add('match_conj_apos_s', None, [{'IS_ALPHA': True}, {'TEXT': '\'s'}])
matcher.add('match_conj_not', None, [{'IS_ALPHA': True}, {'TEXT': 'n\'t'}])
matcher.add('match_conj_apos_d', None, [{'IS_ALPHA': True}, {'TEXT': '\'d'}])
matcher.add('match_conj_apos_ll', None, [{'IS_ALPHA': True}, {'TEXT': '\'ll'}])
matcher.add('match_conj_apos_ll', None, [{'IS_ALPHA': True}, {'TEXT': '\'m'}])
matcher.add('match_conj_apos_re', None, [{'IS_ALPHA': True}, {'TEXT': '\'re'}])
matcher.add('match_conj_apos_ve', None, [{'IS_ALPHA': True}, {'TEXT': '\'ve'}])

# %% [markdown]
#  # 4. Cleaning <a id='6_1_id'></a>

# %% [markdown]
# ## 4.1. Clean Dates <a id='4_1_id'></a>

# %%
# Convert Date type into datetime
speeches['Date'] = pd.to_datetime(speeches['Date'])

# %% [markdown]
# ## 4.2. Clean President Names <a id='4_2_id'></a>

# %%
# Remove 'Presidency' from each president's name
speeches['President'] = [' '.join(president.split()[:-1]) for president in speeches['President']]

# %% [markdown]
# ## 4.3. Clean Speech Titles <a id='4_3_id'></a>

# %%
# Remove date from each speech title
speeches['Speech Title'] = speeches['Speech Title'].apply(lambda x: x.split(':')[-1].strip())

# %% [markdown]
# ## 4.4. Clean Summaries <a id='4_4_id'></a>

# %% [markdown]
# ### 4.4.1 Normalize Unicode <a id='4_4_1_id'></a>

# %%
speeches['Summary'] = speeches['Summary'].apply(lambda x: unicodedata.normalize('NFKD', x))

# %% [markdown]
# ### 4.4.2 Initial preprocessing <a id='4_4_2_id'></a>

# %%
# Clean newlines and different apostrophe symbols
speeches['Summary'] = speeches['Summary'].apply(lambda x: x.replace('\n', ' '))
speeches['Summary'] = speeches['Summary'].apply(lambda x: x.replace('’', '\''))
speeches['Summary'] = speeches['Summary'].apply(lambda x: x.strip())

# %% [markdown]
# ### 4.4.3 Remove unnecessary leading and trailing text from summaries <a id='4_4_3_id'></a>

# %%
# List of all presidents
presidents = get_presidents()
# Out:
# 0: Abraham Lincoln
# 1: Andrew Jackson
# 2: Andrew Johnson
# 3: Barack Obama
# 4: Benjamin Harrison
# 5: Bill Clinton
# 6: Calvin Coolidge
# 7: Chester A. Arthur
# 8: Donald Trump
# 9: Dwight D. Eisenhower
# 10: Franklin D. Roosevelt
# 11: Franklin Pierce
# 12: George H. W. Bush
# 13: George W. Bush
# 14: George Washington
# 15: Gerald Ford
# 16: Grover Cleveland
# 17: Harry S. Truman
# 18: Herbert Hoover
# 19: James A. Garfield
# 20: James Buchanan
# 21: James K. Polk
# 22: James Madison
# 23: James Monroe
# 24: Jimmy Carter
# 25: John Adams
# 26: John F. Kennedy
# 27: John Quincy Adams
# 28: John Tyler
# 29: Lyndon B. Johnson
# 30: Martin Van Buren
# 31: Millard Fillmore
# 32: Richard M. Nixon
# 33: Ronald Reagan
# 34: Rutherford B. Hayes
# 35: Theodore Roosevelt
# 36: Thomas Jefferson
# 37: Ulysses S. Grant
# 38: Warren G. Harding
# 39: William Harrison
# 40: William McKinley
# 41: William Taft
# 42: Woodrow Wilson
# 43: Zachary Taylor

# %% [markdown]
# #### Preview summaries for any unnecessary text at the beginning and end of each summary

# %%
# Preview all summaries for a given president
preview_summaries(presidents[38])
# Out:
# Index: 522
# Victor Recording #35718-B (4:40) On November 12,1921, President Harding convened in Washington the most significant arms limitation conference of the inter-war era. Represented were the major political and military powers including Belgium, China, Great Britain, Italy, France, the Netherlands, Portugal, and Japan. Mindful of Wilson's ill-fated experience and inability to gain consent for the Treaty of Versailles and the League of Nations by the Senate, President Harding elected to welcome and challenge the invited diplomats, and then delegate the negotiations to Secretary of State Charles Evans Hughes. He also ensured that the U.S. delegation contained important Congressional Republicans including Senator Henry Cabot Lodge. After the formalities of the negotiations were completed, leaving nothing to chance, Harding spoke in person to the Senate on February 10, 1922 and submitted the treaties for consent. He noted that he was respectful of the Senate's part in contracting foreign relations, then added “I have come to know the viewpoint and inescapable responsibility of the executive” and then asked for expeditious agreement. The treaties resulted in the only successful limitation and reduction of armament the world had known to that time.
#
# Index: 523
# Victor Recording # 35718-A (5:18) President Harding speaks at Hoboken, New Jersey at a ceremony honoring 5,212 soldiers, sailors, marines, and nurses who were killed defending our country in the World War. He expressed hope for “a nation so righteous as never to make a war of conquest and a nation so powerful in righteousness that none will dare invoke her wrath.” He praises the members of the armed services for their service and assures our mindfulness, our gratitude, and noted that our reverence for them should be in the preservation of the republic for which they died. He also declared, “I would not wish a nation for which men are not willing to fight, and if need be die, but I do wish for a nation where it is not necessary to ask that sacrifice.”
#
# Index: 524
# In this speech given by President-elect Harding early in 1921, he underscored President George Washington's admonition in his 1796 “Farewell Address” to America that we should avoid, when possible, alliances with the Old World. He also noted the importance of U.S. citizens becoming fully integrated into the “melting pot” of American culture. He cautioned to avoid “hyphenated citizenship,” whereby immigrants' loyalties were diluted by being divided between America and their country of origin. It was a popular way of speaking about the millions of immigrants who had poured into the United States beginning in the early 1880's. Until that time most of the growth in the nation's population had come through the American ”multiplication table,” as people described it—the huge size of American families. The new immigration was centering on Eastern Europe, unlike the older immigrants who came from Western Europe. The resumption of new immigration was much on the minds of political leaders as the United States emerged from World War I.
#
# Index: 527
# In this quintessential campaign speech, Harding lamented the nation's lost opportunity for world moral leadership after the World War I, and states his intent to regain it. He also declares that the nation should stay the course and not join the internationalists in their desire to establish membership in the League of Nations.
#
# Index: 528
# Pathé Actuelle #021042-B (3:16) This recording includes excerpts from two different speeches. The first speech, The Republican Party, was given on August 25, 1920. In it, Senator Harding praised the Republicans in Congress for supporting President Wilson in the war effort and affirmed his belief that "politics should stop at the water's edge." In the second speech, A Tribute to Our Disabled Soldiers, given on August 19, 1920, he praised disabled soldiers, including two in the audience from Wyandot County, Ohio, and reminded us of the adage "all politics is local."
#
# Index: 529
# Pathé Actuelle #021042-B (4:48) Harding praised the American men and women who served in World War I. He also notes that services, sacrifices and injuries should be recognized and deficiencies restored. He also expressed appreciation for their help in preserving the orderly process for making our government reflect the hearts and minds of its citizens—“never warlike in peace and never pacifist in war.”
#
# Index: 530
# Nation's Forum (NF 25) 49877 (5:06) As in today's world, violence and terrorism were prominent in post World War I America and Europe. The collapse of the Tsarist Empire in March* and subsequent communist victory in the November Revolution* of 1917 was of concern. But it was the Bolshevists' closure of the democratic Constituent Assembly, the signing of the peace treaty with Germany, the massacre of the Imperial family, attacks on churches, and Red Terror that shocked the western world. The sense of the American people was that democracy was the future of government everywhere; and certainly not the beliefs of the small but vocal group of communists and socialists in the United States. Senator Harding was making that point when he stated that men “must always remember that the rights of freedom impose the obligations which maintain it.” He also speaks of his approval of collective bargaining in labor/management relations but emphasizes the right of every American to seek employment without being forced to accept the conditions of the union shop.
#
# Index: 531
# In this speech, Senator Harding noted that profiteering is a crime of commission, underproduction a crime of omission and called for labor, management and capital to reach an understanding for the benefit of the nation; and then emphasized the supremacy of the human element. After every American war save World War II there has been a period of boom, then bust—often described by the party in power as recession, depression by its rival. After World War I almost everyone-- people and government-- desired freedom from the restrictions of wartime. The Wilson Administration lagged and soon labor and management were at odds with dispute after dispute and group animosity that the senator from Ohio deplored.
#
# Index: 532
# Senator Harding argued that a “covenant of conscience” rather than a written compact—which would surrender freedom of action and give a military alliance the right to proclaim America's duty to the world as in Article 10 of the Covenant of the League of Nations—would be in the best interests of the U.S. The Republican candidate was proposing a separate American peace with the German government, subsequently accomplished by the Treaty of Berlin of 1921. He also hinted of his desire to bring about a reduction of armament and to decrease the possibility of a renewed arms race and the resultant threat to world peace and burden on financial resources, an accomplishment of the Conference on the Limitation of Armament, 1921-22.
#
# Index: 533
# Although he was officially nominated at the Republican National Convention on June 12, Senator Harding was formally notified of his nomination at his home in Marion, Ohio on July 22, 1920. In his acceptance speech he reaffirms his belief in the Republican Party as the best vehicle for restoring tranquility and stability. Harding pledged to restore “balance” to the relationship between Congress and the presidency, noting that the nation cannot and should not be governed by one man. His allusion to the failure of the Versailles Treaty in Congress reinforced this message. Party government, he believed, is essential to the health of the republic.
#
# Index: 534
# Harding accepts the Republican nomination for President.
#
# Index: 535
# Nation's Forum (NF 21) 4985 (4:48) The basis for this recording was an address entitled “Back to Normal” Senator Harding delivered to the Home Market Club of Boston on May 14, 1920. He reminded citizens that all human ills are not curable by legislation (a gentle chiding of the Democrats), and stated that “if we can prove a representative popular government under which the citizenship seeks what it may do for the government and country, rather than what the country may do for individuals, we shall do more to make democracy safe for the world than all armed conflict ever recorded.” The listener can catch the extraordinary ability of the senator with words and the quickness and imagination with which he could speak. The speech is also notable for Harding's phrase “not heroics, but healing, not nostrums, but normalcy.” Critics of the senator would claim that he coined the word “normalcy,” which actually goes back to Elizabethan times.
#
# Index: 536
# Pathé Actuelle Recording # 021042 A (5:03) Address Delivered before the Ohio Society of New York, Waldorf Hotel, New York City The debate over whether the Senate should agree to the Treaty of Versailles with its provision for entry into the League of Nations continued through the fall of 1919 and early months of 1920. On January 10, 2910, Senator Harding spoke to the meeting of the Ohio Society of New York at the Waldorf Hotel in New York City. He cautioned that America should hesitate before surrendering its hard won nationality to the dream of the internationalists--the League of Nations--and to "think of America first." The Senate rejected the treaty by seven votes in March 1920. This transcript is derived from an audio recording made by Harding after the event, and is an excerpt of his public speech. (Transcription by Warren G. Harding, III)
#
# Index: 538
# Nation's Forum (NF 3) 49660 (5:02) Address on the League of Nations in the United States Senate On September 11, 1919, Senator Harding spoke against the recently signed (June 28, 1919) Treaty of Versailles with its provision for establishing the League of Nations. He wanted the Covenant--which President Wilson considered "the heart of the world"--to be modified to free it of portions that could endanger American independence. The Senate rejected the treaty in November 1919, and again in March 1920. Of interest is the senator's use of "Sirs" in addressing the upper chamber of Congress, showing a lack of women. Some states allowed women to vote in 1919, and women had been elected to the House of Representatives, but the 19th Amendment providing woman's suffrage did not become law until 1920. (Transcription by Warren G. Harding, III)
#
# Index: 545
# Then-Senator Harding (R-Ohio) set forth his support for President Wilson's request for a declaration of war against the Imperial German Government. The speech was originally delivered to the U.S. Senate on April 4, 1917. He emphasized that he was not voting for war in the name of democracy, but to maintain American rights and guarantee neutrality, the very preservation of the nation. The unified effort of the American people and government allowed the largely unprepared United States of America to centralize and harness its powerful economy. Within months, ammunition, weapons, and newly-trained recruits were pouring from America's towns and cities onto transport ships and cargo vessels bound for the European war theater. This unprecedented war effort made victory for the Entente Powers almost inevitable. (Transcript by Warren G. Harding III)

# %% [markdown]
# #### Remove unncessary text

# %%
# Obama
speeches.loc[38, 'Summary'] = ' '.join(speeches['Summary'].loc[38].split()[:-10])
speeches.loc[39, 'Summary'] = ' '.join(speeches['Summary'].loc[39].split()[:-10])

#Eisenhower
speeches.loc[408, 'Summary'] = ' '.join(speeches['Summary'].loc[408].split()[:-10])

# Clinton
speeches.loc[117, 'Summary'] = ' '.join(speeches['Summary'].loc[117].split()[11:])

# Kennedy
speeches.loc[376, 'Summary'] = ' '.join(speeches['Summary'].loc[376].split()[:-67])
speeches.loc[377, 'Summary'] = ' '.join(speeches['Summary'].loc[377].split()[:-67])
speeches.loc[378, 'Summary'] = ' '.join(speeches['Summary'].loc[378].split()[:-67])
speeches.loc[380, 'Summary'] = ' '.join(speeches['Summary'].loc[380].split()[:-31])
speeches.loc[381, 'Summary'] = ' '.join(speeches['Summary'].loc[381].split()[:-67])
speeches.loc[384, 'Summary'] = ' '.join(speeches['Summary'].loc[384].split()[:-67])
speeches.loc[385, 'Summary'] = ' '.join(speeches['Summary'].loc[385].split()[:-31])
speeches.loc[387, 'Summary'] = ' '.join(speeches['Summary'].loc[387].split()[:-53])
speeches.loc[388, 'Summary'] = ' '.join(speeches['Summary'].loc[388].split()[:-67])
speeches.loc[393, 'Summary'] = ' '.join(speeches['Summary'].loc[393].split()[:-31])
speeches.loc[394, 'Summary'] = ' '.join(speeches['Summary'].loc[394].split()[:-31])

# Harding
speeches.loc[522, 'Summary'] = ' '.join(speeches['Summary'].loc[522].split()[4:])
speeches.loc[523, 'Summary'] = ' '.join(speeches['Summary'].iloc[523].split()[5:])
speeches.loc[528, 'Summary'] = ' '.join(speeches['Summary'].iloc[528].split()[4:])
speeches.loc[529, 'Summary'] = ' '.join(speeches['Summary'].iloc[529].split()[4:])
speeches.loc[530, 'Summary'] = ' '.join(speeches['Summary'].iloc[530].split()[6:])
speeches.loc[535, 'Summary'] = ' '.join(speeches['Summary'].iloc[535].split()[6:])
speeches.loc[536, 'Summary'] = ' '.join(speeches['Summary'].loc[536].split()[7:-28])
speeches.loc[538, 'Summary'] = ' '.join(speeches['Summary'].loc[538].split()[6:-6])
speeches.loc[545, 'Summary'] = ' '.join(speeches['Summary'].loc[545].split()[:-6])

# %% [markdown]
# ### 4.4.5 Additional Cleaning <a id='4_4_5_id'></a>

# %%
# Get all tokens that are not alphanumeric, numbers, punctuation, or spaces
docs = list(nlp.pipe(speeches.Summary, batch_size = 50, n_process=16))
tokens = [[token.text for token in doc if not token.is_alpha and not token.like_num and not token.is_punct and not token.is_space] for doc in docs]

# Convert lists of lists into a single list
tokens = list(set(itertools.chain.from_iterable(tokens)))
tokens
# Out:
# ['Waldorf-Astoria',
#  'newly-trained',
#  'N.Y.',
#  "Lincoln's",
#  'ideas—justice',
#  'world"--to',
#  'nation-wide',
#  'pork-barrel',
#  'two-hundredth',
#  '80th',
#  'Asia-first',
#  'D.C',
#  "Administration's",
#  "Grant's",
#  'anti-Chinese',
#  'W.',
#  'and/or',
#  'clean-energy',
#  'D.C.',
#  'cabinet-level',
#  'communism—which',
#  "Committee's",
#  "Revolution's",
#  "MacArthur's",
#  'non-belligerent',
#  'J.P.',
#  "Decatur's",
#  'future—is',
#  'economy—energy',
#  'non-communist',
#  "France's",
#  '20th',
#  "world's",
#  'post-World',
#  'self-made',
#  'it—the',
#  "Laden's",
#  'anti-establishment',
#  "America's",
#  "Clinton's",
#  "Europe's",
#  'Kai-shek',
#  'gender-based',
#  "Institute's",
#  "Hoover's",
#  'post-Cold',
#  'cash-and-carry',
#  "act's",
#  "speech's",
#  'policy—all',
#  '72nd',
#  '11:32',
#  'Webster-Ashburton',
#  'still-young',
#  'Hay-Buneau-Varilla',
#  "Paul's",
#  'AFL-CIO',
#  'Mexican-American',
#  'full-time',
#  'de-emphasizes',
#  "Japan's",
#  "Africa's",
#  '73rd',
#  'U.S.S.',
#  "government's",
#  'war-stricken',
#  '48-hour',
#  "Bush's",
#  '25th',
#  'strategy--',
#  "Nixon's",
#  'mid-term',
#  "Jay's",
#  'issue—peace',
#  'Bergen-Belsen',
#  '11th',
#  'newly-acquired',
#  'drought-stricken',
#  'non-aggression',
#  "family's",
#  'treaty—to',
#  '150th',
#  "People's",
#  "party's",
#  "Kennedy's",
#  "Washington's",
#  "California's",
#  "today's",
#  'self-determination',
#  "Bishop's",
#  'Kansas-Nebraska',
#  'one-year',
#  'military-industrial',
#  "Tyler's",
#  "administration's",
#  'well-funded',
#  'one-third',
#  'I.',
#  "NASA's",
#  'U.S.-British',
#  "state's",
#  'ash-heap',
#  "water's",
#  'B&O',
#  'U.S.',
#  "Ford's",
#  'R-Ohio',
#  'peace-loving',
#  'crime-related',
#  'Anti-trust',
#  'Jr.',
#  'Latin-American',
#  'Maine-Brunswick',
#  'D-Day',
#  'détente',
#  'citizens—“never',
#  'twenty-seven',
#  "year's",
#  '100th',
#  "Six's",
#  '50th',
#  'long-term',
#  "Hayes's",
#  '21st',
#  'hand-in-hand',
#  '100-a-plate',
#  "Ireland's",
#  'twenty-eight',
#  'Interstate-Commerce',
#  "Marietta's",
#  "Hitler's",
#  'J.',
#  'Iran-Contra',
#  "UK's",
#  'Destroyers-for-Bases',
#  'anti-ballistic',
#  'ill-fated',
#  "'s",
#  'bust—often',
#  'H.W.',
#  'H.',
#  "Veteran's",
#  "war's",
#  'HIV/AIDS',
#  "Harding's",
#  'self-reliance',
#  "Jackson's",
#  'Austria-Hungary',
#  'D.',
#  'Mr.',
#  'self-supportive',
#  'war-time',
#  "McKinley's",
#  'cease-fire',
#  'me—and',
#  "Florida's",
#  'anti-war',
#  '26th',
#  'high-level',
#  "Union's",
#  "Britain's",
#  'C.',
#  "nation's",
#  "O'Neill",
#  'Lend-Lease',
#  'silver-purchase',
#  'S.',
#  'long-established',
#  "Noriega's",
#  "Wilson's",
#  'inter-war',
#  'Mrs.',
#  'M.',
#  "Burr's",
#  '15th',
#  '37-day',
#  'responsibility—for',
#  'vs.',
#  "Biddle's",
#  'war—to',
#  'wide-ranging',
#  "Johnson's",
#  'Bland-Allison',
#  'do-nothing',
#  "Stevenson's",
#  "Mussolini's",
#  "Stalin's",
#  'T.',
#  "Madison's",
#  "woman's",
#  'G.I.',
#  'legal-tender',
#  'everyone--',
#  "bill's",
#  "other's",
#  '5th',
#  'ten-mile-wide',
#  'Smoot-Hawley',
#  "Obama's",
#  're-election',
#  'century-long',
#  "Senate's",
#  'compact—which',
#  'two-percent',
#  'self-help',
#  'late-term',
#  'Taft-Hartley',
#  'President-elect',
#  "country's",
#  'laws-',
#  "Party's",
#  "aren't",
#  "Roosevelt's",
#  'St.',
#  'future-Chief',
#  '$',
#  "economy's",
#  "Coolidge's",
#  'Asian-Pacific',
#  'U.S.S.R.',
#  '19th',
#  "Hussein's",
#  "Garfield's",
#  'union—as',
#  '74th',
#  "election's",
#  'Jefferson-Jackson',
#  'L.',
#  'labor/management',
#  'Nations—would',
#  'you—ask',
#  "House's",
#  'Reagan-endorsed',
#  'Then-Senator',
#  "Congress's",
#  "Mu'ammar",
#  'conversation-style',
#  'co-existence',
#  '10-point',
#  'agreed-upon',
#  'government--',
#  'Judeo-Christian',
#  'seventy-third',
#  "senator's",
#  'F.',
#  'U.S.-Soviet',
#  'Anglo-United',
#  'U.S',
#  'well-received',
#  'Texas-Austin',
#  "Government's",
#  'eighteen-year',
#  "President's"]

# %% [markdown]
# > ##### 1. Hyphens <a id='4_4_5_hyphens_id'></a>

# %%
# Examine all tokens with hyphens 
hyphen_tokens = [token for token in tokens if '-' in token]
hyphen_tokens
# Out:
# ['Waldorf-Astoria',
#  'newly-trained',
#  'world"--to',
#  'nation-wide',
#  'pork-barrel',
#  'two-hundredth',
#  'Asia-first',
#  'anti-Chinese',
#  'clean-energy',
#  'cabinet-level',
#  'non-belligerent',
#  'non-communist',
#  'post-World',
#  'self-made',
#  'anti-establishment',
#  'Kai-shek',
#  'gender-based',
#  'post-Cold',
#  'cash-and-carry',
#  'Webster-Ashburton',
#  'still-young',
#  'Hay-Buneau-Varilla',
#  'AFL-CIO',
#  'Mexican-American',
#  'full-time',
#  'de-emphasizes',
#  'war-stricken',
#  '48-hour',
#  'strategy--',
#  'mid-term',
#  'Bergen-Belsen',
#  'newly-acquired',
#  'drought-stricken',
#  'non-aggression',
#  'self-determination',
#  'Kansas-Nebraska',
#  'one-year',
#  'military-industrial',
#  'well-funded',
#  'one-third',
#  'U.S.-British',
#  'ash-heap',
#  'R-Ohio',
#  'peace-loving',
#  'crime-related',
#  'Anti-trust',
#  'Latin-American',
#  'Maine-Brunswick',
#  'D-Day',
#  'twenty-seven',
#  'long-term',
#  'hand-in-hand',
#  '100-a-plate',
#  'twenty-eight',
#  'Interstate-Commerce',
#  'Iran-Contra',
#  'Destroyers-for-Bases',
#  'anti-ballistic',
#  'ill-fated',
#  'self-reliance',
#  'Austria-Hungary',
#  'self-supportive',
#  'war-time',
#  'cease-fire',
#  'anti-war',
#  'high-level',
#  'Lend-Lease',
#  'silver-purchase',
#  'long-established',
#  'inter-war',
#  '37-day',
#  'wide-ranging',
#  'Bland-Allison',
#  'do-nothing',
#  'legal-tender',
#  'everyone--',
#  'ten-mile-wide',
#  'Smoot-Hawley',
#  're-election',
#  'century-long',
#  'two-percent',
#  'self-help',
#  'late-term',
#  'Taft-Hartley',
#  'President-elect',
#  'laws-',
#  'future-Chief',
#  'Asian-Pacific',
#  'Jefferson-Jackson',
#  'Reagan-endorsed',
#  'Then-Senator',
#  'conversation-style',
#  'co-existence',
#  '10-point',
#  'agreed-upon',
#  'government--',
#  'Judeo-Christian',
#  'seventy-third',
#  'U.S.-Soviet',
#  'Anglo-United',
#  'well-received',
#  'Texas-Austin',
#  'eighteen-year']

# %% [markdown]
# >> #### 1.1 Problem: Tokens with two consecutive hyphens <a id='4_4_5_1_1_id'></a>

# %%
pattern = '.*--.*'
hyphens_before = [re.search(pattern, token)[0] for token in hyphen_tokens if re.search(pattern, token)]
hyphens_before
# Out:
# ['world"--to', 'strategy--', 'everyone--', 'government--']

# %% [markdown]
# >> #### 1.2 Solution: Tokens with two consecutive hyphens

# %%
hyphens_after = [token.replace('--', ' ') for token in hyphens_before]
hyphens_after
# Out:
# ['world" to', 'strategy ', 'everyone ', 'government ']

# %% [markdown]
# >> #### 1.3 Prepare token pairs and update dictionary

# %%
# Zip pairs into before and after tuples
hyphens = list(zip(hyphens_before, hyphens_after))

# Update dictionary and hyphen tokens
clean_dict = update_dict(clean_dict, hyphens)
hyphen_tokens = [token for token in hyphen_tokens if token not in clean_dict]

# %% [markdown]
# >> #### 2.1 Problem: Tokens with leading or trailing hyphens <a id='4_4_5_1_2_id'></a>

# %%
pattern = '^-+.*|.*-+$'
hyphens_before = [re.search(pattern, token)[0] for token in hyphen_tokens if re.search(pattern, token)]
hyphens_before
# Out:
# ['laws-']

# %% [markdown]
# >> #### 2.2 Solution: Tokens with two consecutive hyphens

# %%
hyphens_after = [token.replace('-', ' ') for token in hyphens_before]
hyphens_after
# Out:
# ['laws ']

# %% [markdown]
# >> #### 2.3 Prepare token pairs and update dictionary

# %%
# Zip pairs into before and after tuples
hyphens = list(zip(hyphens_before, hyphens_after))

# Update dictionary and hyphen tokens
clean_dict = update_dict(clean_dict, hyphens)
hyphen_tokens = [token for token in hyphen_tokens if token not in clean_dict]

# %% [markdown]
# >> #### 3.1 Problem: Determining which tokens are valid words <a id='4_4_5_1_3_id'></a>

# %%
# Examine tokens
hyphen_tokens
# Out:
# ['Waldorf-Astoria',
#  'newly-trained',
#  'nation-wide',
#  'pork-barrel',
#  'two-hundredth',
#  'Asia-first',
#  'anti-Chinese',
#  'clean-energy',
#  'cabinet-level',
#  'non-belligerent',
#  'non-communist',
#  'post-World',
#  'self-made',
#  'anti-establishment',
#  'Kai-shek',
#  'gender-based',
#  'post-Cold',
#  'cash-and-carry',
#  'Webster-Ashburton',
#  'still-young',
#  'Hay-Buneau-Varilla',
#  'AFL-CIO',
#  'Mexican-American',
#  'full-time',
#  'de-emphasizes',
#  'war-stricken',
#  '48-hour',
#  'mid-term',
#  'Bergen-Belsen',
#  'newly-acquired',
#  'drought-stricken',
#  'non-aggression',
#  'self-determination',
#  'Kansas-Nebraska',
#  'one-year',
#  'military-industrial',
#  'well-funded',
#  'one-third',
#  'U.S.-British',
#  'ash-heap',
#  'R-Ohio',
#  'peace-loving',
#  'crime-related',
#  'Anti-trust',
#  'Latin-American',
#  'Maine-Brunswick',
#  'D-Day',
#  'twenty-seven',
#  'long-term',
#  'hand-in-hand',
#  '100-a-plate',
#  'twenty-eight',
#  'Interstate-Commerce',
#  'Iran-Contra',
#  'Destroyers-for-Bases',
#  'anti-ballistic',
#  'ill-fated',
#  'self-reliance',
#  'Austria-Hungary',
#  'self-supportive',
#  'war-time',
#  'cease-fire',
#  'anti-war',
#  'high-level',
#  'Lend-Lease',
#  'silver-purchase',
#  'long-established',
#  'inter-war',
#  '37-day',
#  'wide-ranging',
#  'Bland-Allison',
#  'do-nothing',
#  'legal-tender',
#  'ten-mile-wide',
#  'Smoot-Hawley',
#  're-election',
#  'century-long',
#  'two-percent',
#  'self-help',
#  'late-term',
#  'Taft-Hartley',
#  'President-elect',
#  'future-Chief',
#  'Asian-Pacific',
#  'Jefferson-Jackson',
#  'Reagan-endorsed',
#  'Then-Senator',
#  'conversation-style',
#  'co-existence',
#  '10-point',
#  'agreed-upon',
#  'Judeo-Christian',
#  'seventy-third',
#  'U.S.-Soviet',
#  'Anglo-United',
#  'well-received',
#  'Texas-Austin',
#  'eighteen-year']

# %% [markdown]
# >> #### 3.2 Solution: Check validity of token using <span style="color:purple">howmanysyllables.com</span>

# %%
# Get all valid words
word_tokens = [token for token in tqdm(hyphen_tokens) if is_word(token)]
word_tokens
# Out:
# 100%|██████████| 98/98 [00:48<00:00,  2.01it/s]
# ['nation-wide',
#  'pork-barrel',
#  'non-belligerent',
#  'non-communist',
#  'self-made',
#  'anti-establishment',
#  'Kai-shek',
#  'cash-and-carry',
#  'AFL-CIO',
#  'full-time',
#  'de-emphasizes',
#  'mid-term',
#  'Bergen-Belsen',
#  'non-aggression',
#  'self-determination',
#  'Kansas-Nebraska',
#  'military-industrial',
#  'ash-heap',
#  'Anti-trust',
#  'Latin-American',
#  'D-Day',
#  'twenty-seven',
#  'long-term',
#  'hand-in-hand',
#  'twenty-eight',
#  'Interstate-Commerce',
#  'anti-ballistic',
#  'ill-fated',
#  'self-reliance',
#  'Austria-Hungary',
#  'war-time',
#  'cease-fire',
#  'anti-war',
#  'high-level',
#  'Lend-Lease',
#  'inter-war',
#  'wide-ranging',
#  'do-nothing',
#  'legal-tender',
#  'Smoot-Hawley',
#  're-election',
#  'self-help',
#  'Taft-Hartley',
#  'President-elect',
#  'co-existence',
#  'Judeo-Christian',
#  'seventy-third']

# %%
# Zip pairs into before and after tuples
hyphens = list(zip(word_tokens, word_tokens))

# Update dictionary and hyphen tokens
clean_dict = update_dict(clean_dict, hyphens)
hyphen_tokens = [token for token in hyphen_tokens if token not in clean_dict]

# %%
# Non-words
hyphen_tokens = sorted(list(set(hyphen_tokens).difference(set(word_tokens))))
hyphen_tokens
# Out:
# ['10-point',
#  '100-a-plate',
#  '37-day',
#  '48-hour',
#  'Anglo-United',
#  'Asia-first',
#  'Asian-Pacific',
#  'Bland-Allison',
#  'Destroyers-for-Bases',
#  'Hay-Buneau-Varilla',
#  'Iran-Contra',
#  'Jefferson-Jackson',
#  'Maine-Brunswick',
#  'Mexican-American',
#  'R-Ohio',
#  'Reagan-endorsed',
#  'Texas-Austin',
#  'Then-Senator',
#  'U.S.-British',
#  'U.S.-Soviet',
#  'Waldorf-Astoria',
#  'Webster-Ashburton',
#  'agreed-upon',
#  'anti-Chinese',
#  'cabinet-level',
#  'century-long',
#  'clean-energy',
#  'conversation-style',
#  'crime-related',
#  'drought-stricken',
#  'eighteen-year',
#  'future-Chief',
#  'gender-based',
#  'late-term',
#  'long-established',
#  'newly-acquired',
#  'newly-trained',
#  'one-third',
#  'one-year',
#  'peace-loving',
#  'post-Cold',
#  'post-World',
#  'self-supportive',
#  'silver-purchase',
#  'still-young',
#  'ten-mile-wide',
#  'two-hundredth',
#  'two-percent',
#  'war-stricken',
#  'well-funded',
#  'well-received']

# %%
# Zip pairs into before and after tuples
hyphens = list(zip(hyphen_tokens, hyphen_tokens))

# Update dictionary and hyphen tokens
clean_dict = update_dict(clean_dict, hyphens)
hyphen_tokens = [token for token in hyphen_tokens if token not in clean_dict]

# %% [markdown]
# > ##### 2. Clean and match remaining tokens <a id='4_4_5_clean_match_id'></a>

# %% [markdown]
# >> #### 1.1 Problem: Some tokens have unnecessary hyphens

# %%
hyphens_before = [token for token in tokens if '—' in token]
hyphens_before
# Out:
# ['ideas—justice',
#  'communism—which',
#  'future—is',
#  'economy—energy',
#  'it—the',
#  'policy—all',
#  'issue—peace',
#  'treaty—to',
#  'citizens—“never',
#  'bust—often',
#  'me—and',
#  'responsibility—for',
#  'war—to',
#  'compact—which',
#  'union—as',
#  'Nations—would',
#  'you—ask']

# %% [markdown]
# >> #### 1.2 Solution: Remove unneessary hyphens from tokens

# %%
hyphens_after = [token.replace('—', ' ') for token in hyphens_before]
hyphens_after
# Out:
# ['ideas justice',
#  'communism which',
#  'future is',
#  'economy energy',
#  'it the',
#  'policy all',
#  'issue peace',
#  'treaty to',
#  'citizens “never',
#  'bust often',
#  'me and',
#  'responsibility for',
#  'war to',
#  'compact which',
#  'union as',
#  'Nations would',
#  'you ask']

# %% [markdown]
# >> #### 1.3 Prepare token pairs and update dictionary

# %%
# Zip pairs
hyphens = list(zip(hyphens_before, hyphens_after))

# Update dictionary and hyphen tokens
clean_dict = update_dict(clean_dict, hyphens)
tokens = [token for token in tokens if not matcher(nlp.make_doc(token)) and token not in clean_dict]

# %% [markdown]
# >> #### 2.1 Problem: Tokens with few pattern similarities <a id='4_4_5_2_2_id'></a>

# %%
tokens
# Out:
# ['N.Y.',
#  '80th',
#  'D.C',
#  'W.',
#  'and/or',
#  'D.C.',
#  'J.P.',
#  '20th',
#  '72nd',
#  '11:32',
#  '73rd',
#  'U.S.S.',
#  '25th',
#  '11th',
#  '150th',
#  'I.',
#  'B&O',
#  'U.S.',
#  'Jr.',
#  'détente',
#  '100th',
#  '50th',
#  '21st',
#  'J.',
#  "'s",
#  'H.W.',
#  'H.',
#  'HIV/AIDS',
#  'D.',
#  'Mr.',
#  '26th',
#  'C.',
#  "O'Neill",
#  'S.',
#  'Mrs.',
#  'M.',
#  '15th',
#  'vs.',
#  'T.',
#  'G.I.',
#  '5th',
#  'St.',
#  '$',
#  'U.S.S.R.',
#  '19th',
#  '74th',
#  'L.',
#  'labor/management',
#  "Mu'ammar",
#  'F.',
#  'U.S']

# %% [markdown]
# >> #### 2.2 Solution: Clean tokens and leave the rest

# %%
# D.C should be D.C.
clean_dict['D.C'] = 'D.C.'
clean_dict['labor/management'] = 'labor or management'
clean_dict['HIV/AIDS'] = 'HIV or AIDS'
clean_dict['and/or'] = 'and or'

# Note, "'s" and "$" will be handled by our pattern matcher so we can ignore them

# %% [markdown]
# ## 4.5. Clean Transcripts <a id='4_5_id'></a>

# %%
with open('speeches_modified/speeches_737.txt') as file:
    speeches.iloc[737].Transcript = file.read()

with open('speeches_modified/speeches_738.txt') as file:
    speeches.iloc[738].Transcript = file.read()
    
with open('speeches_modified/speeches_964.txt') as file:
    speeches.iloc[964].Transcript = file.read()
    
with open('speeches_modified/speeches_575.txt') as file:
    speeches.iloc[575].Transcript = file.read()

with open('speeches_modified/speeches_579.txt') as file:
    speeches.iloc[579].Transcript = file.read()
    
with open('speeches_modified/speeches_675.txt') as file:
    speeches.iloc[675].Transcript = file.read()
    
with open('speeches_modified/speeches_673.txt') as file:
    speeches.iloc[673].Transcript = file.read()
    
with open('speeches_modified/speeches_712.txt') as file:
    speeches.iloc[712].Transcript = file.read()
    
with open('speeches_modified/speeches_572.txt') as file:
    speeches.iloc[572].Transcript = file.read()
    
with open('speeches_modified/speeches_507.txt') as file:
    speeches.iloc[507].Transcript = file.read()
    
with open('speeches_modified/speeches_609.txt') as file:
    speeches.iloc[609].Transcript = file.read()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:5208: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %% [markdown]
# ### 4.5.1 Normalize Unicode <a id='4_5_1_id'></a>

# %%
speeches['Transcript'] = speeches['Transcript'].apply(lambda x: unicodedata.normalize('NFKD', x))

# %% [markdown]
# ### 4.5.2 Initial preprocessing <a id='4_5_2_id'></a>

# %%
# Clean newlines and different apostrophe symbol
speeches['Transcript'] = speeches['Transcript'].apply(lambda x: x.replace('\n', ' '))
speeches['Transcript'] = speeches['Transcript'].apply(lambda x: x.replace('’', '\''))
speeches['Transcript'] = speeches['Transcript'].apply(lambda x: x.replace('\r', ''))
speeches['Transcript'] = speeches['Transcript'].apply(lambda x: x.replace('ooo', '000'))
speeches['Transcript'] = speeches['Transcript'].apply(lambda x: x.replace('(Applause.)', '')) 
speeches['Transcript'] = speeches['Transcript'].apply(lambda x: x.replace('(applause.)', ''))
speeches['Transcript'] = speeches['Transcript'].apply(lambda x: x.replace('(Applause)', '')) 
speeches['Transcript'] = speeches['Transcript'].apply(lambda x: x.replace('(applause)', ''))
speeches['Transcript'] = speeches['Transcript'].apply(lambda x: x.strip())
speeches['Transcript'] = speeches['Transcript'].apply(lambda x: x[10:] if x[:10].lower() == 'transcript' else x)

# %%
speeches.iloc[575].Transcript = re.sub('Final Estimates for 1912 as of November 29 (.*?) COLLECTION.', '', speeches.iloc[575].Transcript)
speeches.iloc[979].Transcript = speeches.iloc[979].Transcript[:-45]
speeches.iloc[679].Transcript = re.match('(.*?)(?=CHESTER A. ARTHUR)', speeches.iloc[679].Transcript)[0]
speeches.iloc[250].Transcript = speeches.iloc[250].Transcript.replace('CCC [Civilian Conservation Corps]-type program', 'CCC-type program, Civilian Conservation Corps,')

text_to_remove = "The rapid increase in the trade between the two countries is shown in the following table:Philippine exports, fiscal years 1908-1910. [Exclusive of gold and silver.]Fiscal Year To: United States To: Other Countries Total 1908$10,323,233$22,493,334$32,816,567190910,215,33120,778,23230,993,563191018,741,77121,122,39839,864,169NOTE.--Latest monthly returns show exports for the year ending August, 1910, to the United States $20,035,902, or 49 per cent of the $41,075,738 total, against 031,275 to the United States, or 34 per cent of the $32,183,871 total for the year ending August, 1909.Philippine imports, fiscal years 1908-1910. [Exclusive of gold and silver and government supplies.]Fiscal Year From: United States From: Other Countries Total 1908$5,079,487$25,838,870$30,918,35719094,691,77023,100,27027,792,397191010,775,30126,292,32937,067,630NOTE.--Latest monthly returns show imports for the year ending August, 1910, from the United States $11,615,982, or 30 per cent of the $39,025,667 total, against $5,193,419 from the United States, or 18 per cent of the $28,948,011 total for the year ending August, 1909."
speeches.iloc[575].Transcript = speeches.iloc[575].Transcript.replace(text_to_remove, '')

# %% [markdown]
# ### 4.5.3 Remove non-presidential text <a id='4_5_3_id'></a>

# %%
# First Pass
pattern = '([A-Z]+\.\s)*([A-Z]+[A-Z\'-]+[A-Z]\s)*[A-Z]+[A-Z\'-]+[A-Z]:'
potential_speakers = list(set(find_pattern(speeches['Transcript'], pattern, 50, -1)))

speaker_dict = {}
for speaker in potential_speakers:
    if speaker not in speaker_dict:
        speaker_dict[speaker] = speaker
    
print('There are {} potential speakers'.format(len(potential_speakers)))
# Out:
# There are 101 potential speakers

# %%
[speaker_dict[speaker] for speaker in sorted(speaker_dict.keys())]
# Out:
# ['AGENT DUNN:',
#  'AIDE:',
#  'AUDIENCE MEMBER:',
#  'AUDIENCE MEMBERS:',
#  'AUDIENCE:',
#  'BROTHER HANDSOME LAKE:',
#  'BUSH:',
#  'C. GENERAL:',
#  'C. LEHRER:',
#  'C. SIR:',
#  'CONGRESS ASSEMBLED:',
#  'CREDENCE. MR. MINISTER:',
#  'CROWD:',
#  'DC. PRESIDENT CLINTON:',
#  'DEAR DOCTOR HERRAN:',
#  'DUKAKIS:',
#  'EDM:',
#  'EITC:',
#  'EXCELLENCY:',
#  'FELLOW CITIZENS:',
#  'FELLOW-CITIZENS:',
#  'GEE:',
#  'GENERAL:',
#  'GENTLEMEN:',
#  'GROER:',
#  'HAWLEY:',
#  'ICE:',
#  'JENNINGS:',
#  'JIM LEHRER:',
#  'JONES:',
#  'KENNEDY:',
#  'LEADER RYAN:',
#  'LEHRER:',
#  'MASHEK:',
#  'MODERATOR:',
#  'MR. CATER:',
#  'MR. CHANCELLOR:',
#  'MR. CRONKITE:',
#  'MR. DRUMMOND:',
#  'MR. EDWARDS:',
#  'MR. FLEMING:',
#  'MR. HOWE:',
#  'MR. KALB:',
#  'MR. KELLY:',
#  'MR. KENNEDY:',
#  'MR. KONDRACKE:',
#  'MR. LEVY:',
#  'MR. MONDALE:',
#  'MR. MORGAN:',
#  'MR. NEWMAN:',
#  'MR. NIVEN:',
#  'MR. NIXON:',
#  'MR. NOVINS:',
#  'MR. SCHWAB:',
#  'MR. SHADEL:',
#  'MR. SINGISER:',
#  'MR. SMITH:',
#  'MR. SPIVAK:',
#  'MR. TREWHITT:',
#  'MR. VANOCUR:',
#  'MR. VON FREMD:',
#  'MR. WARREN:',
#  'MS. GEYER:',
#  'MS. MOZER:',
#  'MS. RIDINGS:',
#  'N. PRESIDENT CLINTON:',
#  'N. SENATOR DOLE:',
#  'NAVY DEPARTMENT:',
#  'NIXON:',
#  'O. THE PRESIDENT:',
#  'PANAMA. MR. PRESIDENT:',
#  'PARTICIPANT:',
#  'PRESIDENT BUSH:',
#  'PRESIDENT CLINTON:',
#  'PRESIDENT PINOCHET:',
#  'PRESIDENT REAGAN:',
#  'PRESIDENT TRUMP:',
#  'PRESIDENT. SIR:',
#  'PRESIDENT:',
#  'REPRESENTATIVES:',
#  'SECRETARY AZAR:',
#  'SECRETARY MNUCHIN:',
#  'SECRETARY PERRY:',
#  'SECRETARY POMPEO:',
#  'SENATOR BOB DOLE:',
#  'SENATOR DOLE:',
#  'SENATOR KENNEDY:',
#  'SIR:',
#  'SMITH:',
#  'SPEAKER RYAN:',
#  'STATE:',
#  'THE CONGRESS:',
#  'THE MANDAN NATION:',
#  'THE PRESIDENT:',
#  'THE UNITED STATES:',
#  'TREASURY DEPARTMENT:',
#  'TRUMP:',
#  'UDIENCE MEMBER:',
#  'VOICE:',
#  'WAR DEPARTMENT:',
#  'WAR. SIR:']

# %%
# Examine 
text_surrounding_speakers([speaker for speaker in sorted(speaker_dict.keys())])
# Out:
# -----------------
# | 0 AGENT DUNN: |
# -----------------
#
# ['ough guys. Come here, Derek.  AGENT DUNN: Just want to say thanks for e']
#
# -----------
# | 1 AIDE: |
# -----------
#
# [' Mr. President — (inaudible). AIDE:  Yes, we do.  There you go. Q']
#
# ----------------------
# | 2 AUDIENCE MEMBER: |
# ----------------------
#
# ['we want to stop it now?       AUDIENCE MEMBER:  Four more years! THE PRESIDE',
#  's?  Go ahead, say that again. AUDIENCE MEMBER:  Vote yes! THE PRESIDENT:  A ',
#  ' in the political process.    AUDIENCE MEMBER:  Because of you!     THE PRES',
#  't give her or him some space. AUDIENCE MEMBER:  Hope you have insurance.  (L',
#  'dam Hussein, we saw a threat. AUDIENCE MEMBER: (Inaudible.) AUDIENCE: U-S-A!']
#
# -----------------------
# | 3 AUDIENCE MEMBERS: |
# -----------------------
#
# [' well --  -- the survivors -- AUDIENCE MEMBERS:  We love you, Obama! THE '
#  'PRES']
#
# ---------------
# | 4 AUDIENCE: |
# ---------------
#
# ['nt of the United States.      AUDIENCE:  Four more years!  Four more ',
#  'ashington for a little while. AUDIENCE:  O-H-I-O. THE PRESIDENT:  Yes',
#  'T:  We need a vote. AUDIENCE:  We want a vote!  We want a v',
#  ' will leave no child behind.  AUDIENCE: Viva Bush! Viva Bush! Viva Bu',
#  'eant. Should we bring him up? AUDIENCE: Yeah!  THE PRESIDENT: Come on']
#
# ----------------------------
# | 5 BROTHER HANDSOME LAKE: |
# ----------------------------
#
# ['TO BROTHER HANDSOME LAKE:           I have received the']
#
# -----------
# | 6 BUSH: |
# -----------
#
# [' address the crowd] PRESIDENT BUSH: It has been my honor to host ',
#  ' three people on your ticket? BUSH: No, I think the debate ought ',
#  '. LEHRER: Mr. Vice President? BUSH: I wrote the anti-terrorist re',
#  "fice in the last eight years? BUSH: You're judged by the whole re",
#  '. LEHRER: Mr. Vice President. BUSH: What troubles me is that when']
#
# -----------------
# | 7 C. GENERAL: |
# -----------------
#
# [' United States, Washington, D.C. GENERAL: The extraordinary character o']
#
# ----------------
# | 8 C. LEHRER: |
# ----------------
#
# [" bureaucracy in Washington, D.C. LEHRER: All right, let's move now to "]
#
# -------------
# | 9 C. SIR: |
# -------------
#
# ['YSSES S. GRANT, Washington, D.C. SIR: The Hon. Edwin M. Stanton hav']
#
# --------------------------
# | 10 CONGRESS ASSEMBLED: |
# --------------------------
#
# ['VES OF THE UNITED STATES   IN CONGRESS ASSEMBLED:           It would have '
#  'given']
#
# ------------------------------
# | 11 CREDENCE. MR. MINISTER: |
# ------------------------------
#
# ['RESENTATION OF HIS LETTERS OF CREDENCE. MR. MINISTER: I am much gratified to '
#  'receiv']
#
# -------------
# | 12 CROWD: |
# -------------
#
# ['Scouts of America. (APPLAUSE) CROWD: USA! USA! USA! TRUMP: You are',
#  ' country you love. (APPLAUSE) CROWD: USA! USA! USA! TRUMP: And nev',
#  "d making America great again. CROWD: USA! USA! USA! TRUMP: And I'l",
#  'really hurting us. (APPLAUSE) CROWD: USA! USA! USA! TRUMP: By the ']
#
# -----------------------------
# | 13 DC. PRESIDENT CLINTON: |
# -----------------------------
#
# ['efused to come—to Washington, DC. PRESIDENT CLINTON: We have a very '
#  'consistent pol']
#
# --------------------------
# | 14 DEAR DOCTOR HERRAN: |
# --------------------------
#
# [' Washington, November 6, 1903 DEAR DOCTOR HERRAN: I inclose Copy of a '
#  'dispatch ']
#
# ---------------
# | 15 DUKAKIS: |
# ---------------
#
# ['e had that. LEHRER: Governor? DUKAKIS: Well, first let me say with r',
#  'support. Thank you very much. DUKAKIS: This has been an extraordinar',
#  'o become a nation of renters? DUKAKIS: Well, I certainly hope not. A',
#  " two minutes is up, Governor. DUKAKIS: If he's serious about what he",
#  ' to be between you and Lloyd. DUKAKIS: I think the American people h']
#
# -----------
# | 16 EDM: |
# -----------
#
# ['. WASHINGTON.By the President:EDM: RANDOLPF']
#
# ------------
# | 17 EITC: |
# ------------
#
# ['nother major expansion of the EITC: to reduce the marriage penalt']
#
# ------------------
# | 18 EXCELLENCY: |
# ------------------
#
# ['gton, D.C., November 6, 1903. EXCELLENCY: I acknowledge the reception o']
#
# -----------------------
# | 19 FELLOW CITIZENS: |
# -----------------------
#
# ['MY FELLOW CITIZENS: As long ago as August, 1906, ']
#
# -----------------------
# | 20 FELLOW-CITIZENS: |
# -----------------------
#
# ['tatives of the United States. FELLOW-CITIZENS: You have been assembled in yo',
#  'e People of the United States FELLOW-CITIZENS: Before my arrival at the seat']
#
# -----------
# | 21 GEE: |
# -----------
#
# ['t stand for our ideals. MR. McGEE: Mr. Levy with a question for ',
#  'nd then try to move on. MR. McGEE: Mr. Vice President. MR. NIXON',
#  't its responsibilities. MR. McGEE: Mr. Vice President. MR. NIXON',
#  'ss in order to do this. MR. McGEE: Senator Kennedy. MR. KENNEDY:',
#  'garian uh - revolution. MR. McGEE: Mr. Morgan, with a question f']
#
# ---------------
# | 22 GENERAL: |
# ---------------
#
# ['ited States, Washington, D.C. GENERAL: The extraordinary character o',
#  'ommanding Army United States. GENERAL: The Secretary of the Treasury']
#
# -----------------
# | 23 GENTLEMEN: |
# -----------------
#
# [' Senate of the United States. GENTLEMEN: The accompanying propositions',
#  'GENTLEMEN: I must be permitted to say th',
#  'the House of Representatives. GENTLEMEN: I have maturely considered th',
#  ' and Others, Committee, etc.: GENTLEMEN: I now avail myself of the fir']
#
# -------------
# | 24 GROER: |
# -------------
#
# ['stion for the Vice President. GROER: Well, Mr. Vice President, you',
#  'ernor. Ann Groer will ask it. GROER: Governor Dukakis, is there a ',
#  "e two minutes to answer, sir. GROER: Mr. Vice President, you've sa",
#  'urs. LEHRER: Follow-up, Anne? GROER: Yes. Since your Massachusetts',
#  ' a question for the Governor. GROER: Yes. Governor Dukakis, speaki']
#
# --------------
# | 25 HAWLEY: |
# --------------
#
# [" Come here, Josh. Come here.  HAWLEY: Well, it's an incredible hono"]
#
# -----------
# | 26 ICE: |
# -----------
#
# ['ns for the aliens arrested by ICE: 11,000 charges or convictions',
#  'll have the summation time. VOICE: This will allow three minutes']
#
# ----------------
# | 27 JENNINGS: |
# ----------------
#
# ['uestion for Governor Dukakis. JENNINGS: Well, Governor, and Vice Pres',
#  'tion for the Governor, Peter. JENNINGS: Governor, the crisis is no le',
#  "stion for the vice president. JENNINGS: Mr. Vice President, I'm struc",
#  'or the Vice President. Peter? JENNINGS: It seems perhaps a good subje',
#  'ngs. It goes to the Governor. JENNINGS: Good evening, Mr. Vice Presid']
#
# ------------------
# | 28 JIM LEHRER: |
# ------------------
#
# ['    JIM LEHRER: Good evening from the Bushnel',
#  ' JIM LEHRER: Good evening. On behalf of th']
#
# -------------
# | 29 JONES: |
# -------------
#
# [" THE PRESIDENT: That's right. JONES:—as a President of the United ",
#  ' Thank you, Allen. Thank you. JONES: God bless you, Mr. President.',
#  'Anytime you want. Anytime. JONES: One last thing, Mr. President',
#  ' Office — THE PRESIDENT: Yes. JONES:—to meet you.  THE PRESIDENT: ',
#  's. May I? THE PRESIDENT: Yes. JONES: Mr. President — (Laughter.) T']
#
# ---------------
# | 30 KENNEDY: |
# ---------------
#
# ['ble for any such decline? MR. KENNEDY: Well I understood that this w',
#  "R. HOWE: Under the agreed MR. KENNEDY: And that's the testimony of u",
#  't courting of the farmer? MR. KENNEDY: Well, because I think that if',
#  'next four to eight years? MR. KENNEDY: One of the areas, and of cour',
#  ' rate would help toward - MR. KENNEDY: No. No. Not reducing the inte']
#
# -------------------
# | 31 LEADER RYAN: |
# -------------------
#
# [' Thank you. They worked very— LEADER RYAN: And Don Young. THE PRESIDENT:']
#
# --------------
# | 32 LEHRER: |
# --------------
#
# ['ion. I do not favor abortion. LEHRER: Question for the Vice Preside',
#  "s. SENATOR DOLE: Are we done? LEHRER: Mr. President, you're first. ",
#  't you could lay that to rest. LEHRER: Mr. President. PRESIDENT CLIN',
#  ' serious mistake in judgment. LEHRER: A question from John Mashek. ',
#  'make it easier for him.  Cuba LEHRER: Well, Mr. President, what is ']
#
# --------------
# | 33 MASHEK: |
# --------------
#
# ['t goes to the Vice President. MASHEK: Mr. Vice President, Democrats',
#  'stion for the Vice President. MASHEK: Mr. Vice President, the Gover',
#  'esident will have a rebuttal. MASHEK: Well, Governor, you did selec',
#  'stion for the vice president. MASHEK: Mr. Vice President, in a deba',
#  's up, too. A follow-up, John. MASHEK: Mr. Vice President, you have ']
#
# -----------------
# | 34 MODERATOR: |
# -----------------
# [' FRANK McGEE, MODERATOR: Good evening. This is Frank M',
#  " BILL SHADEL, MODERATOR: Good evening. I'm Bill Shadel",
#  ' QUINCY HOWE, MODERATOR: I am Quincy Howe of ABC News ',
#  ' HOWARD K. SMITH, MODERATOR: Good evening. The television ']
#
# -----------------
# | 35 MR. CATER: |
# -----------------
#
# [" is for Vice President Nixon. MR. CATER: Mr. Vice President, I'd like ",
#  'question for Senator Kennedy. MR. CATER: Senator Kennedy, last week yo',
#  'r. Cater for Senator Kennedy. MR. CATER: Uh - Mr. Kennedy, uh - Senato']
#
# ----------------------
# | 36 MR. CHANCELLOR: |
# ----------------------
#
# ["ion for Vice President Nixon. MR. CHANCELLOR: Sir, I'd like to ask you an- ",
#  'question for Senator Kennedy. MR. CHANCELLOR: Senator, another question uh ']
#
# --------------------
# | 37 MR. CRONKITE: |
# --------------------
#
# ['question for Senator Kennedy. MR. CRONKITE: Senator, the charge has been ',
#  'ion for Vice President Nixon. MR. CRONKITE: Thank you Quincy. Mr. Vice Pr']
#
# --------------------
# | 38 MR. DRUMMOND: |
# --------------------
#
# ['stion is for Senator Kennedy. MR. DRUMMOND: Uh - Mr. Kennedy, Representat',
#  'tion now for Senator Kennedy. MR. DRUMMOND: Senator Kennedy, a question o',
#  'ond for Vice President Nixon. MR. DRUMMOND: Mr. Nixon, I would like to as',
#  'ion for Vice President Nixon. MR. DRUMMOND: Uh - Mr. Nixon uh - before th']
#
# -------------------
# | 39 MR. EDWARDS: |
# -------------------
#
# ['wards for the Vice President. MR. EDWARDS: Mr. Nixon, carrying forward t',
#  'question for Senator Kennedy. MR. EDWARDS: Senator Kennedy, one test of ']
#
# -------------------
# | 40 MR. FLEMING: |
# -------------------
#
# ['tor Kennedy from Mr. Fleming. MR. FLEMING: Senator, the Vice President i',
#  't Nixon fa- from Mr. Fleming. MR. FLEMING: Mr. Vice President, do I take']
#
# ----------------
# | 41 MR. HOWE: |
# ----------------
#
# ['ospects for our society gain. MR. HOWE: That completes the opening st',
#  'dy has been running her down. MR. HOWE: Comment, Senator Kennedy? MR.',
#  ' whom would be the candidate. MR. HOWE: Mr. Vice President, do you ha',
#  'be discussed in the campaign. MR. HOWE: Senator Kennedy, your comment',
#  'ught to make one last effort. MR. HOWE: Any comment, Mr. Vice Preside']
#
# ----------------
# | 42 MR. KALB: |
# ----------------
#
# ['sident Reagan.   Soviet Union MR. KALB: Mr. President, you have often',
#  'hose things.   Eastern Europe MR. KALB: A related question, Mr. Monda',
#  'gions Vital to U.S. Interests MR. KALB: Mr. President, perhaps the ot',
#  ' Strategic Defense Initiative MR. KALB: Mr. President, when you made ',
#  "resident Reagan.   Armageddon MR. KALB: Mr. President, I'd like to pi"]
#
# -----------------
# | 43 MR. KELLY: |
# -----------------
#
# ['bit about that, Mike. Please. MR. KELLY: So, Adapt is a small company ',
#  'ESIDENT: Thank you very much. MR. KELLY: Thank you. Appreciate it.  TH']
#
# -------------------
# | 44 MR. KENNEDY: |
# -------------------
#
# ['sume its own series of tests? MR. KENNEDY: Yes, I think the next preside',
#  'eduction of the Federal debt. MR. KENNEDY: - reducing the interest rate.',
#  '. MR. McGEE: Senator Kennedy. MR. KENNEDY: Well, let me say I do think t',
#  'HADEL: Senator, your comment. MR. KENNEDY: Well, I always have difficult',
#  'able to get them in January - MR. KENNEDY: Well as you take the bills - ']
#
# ---------------------
# | 45 MR. KONDRACKE: |
# ---------------------
#
# ["we can persevere.   Nicaragua MR. KONDRACKE: You've been quoted as saying ",
#  'as a result.   Nuclear Freeze MR. KONDRACKE: I want to follow up on Mr. Ka',
#  'ilities there in the Pacific. MR. KONDRACKE: And what would you do about i',
#  'our going on a peace mission. MR. KONDRACKE: Mr. President, four years ago',
#  ' Mondale.   Strategic Weapons MR. KONDRACKE: Mr. Mondale, you say that wit']
#
# ----------------
# | 46 MR. LEVY: |
# ----------------
#
# ["y. MR. KENNEDY: That's right. MR. LEVY: Is this what you have in mind",
#  'ion for Vice President Nixon. MR. LEVY: Mr. Vice President, you are u',
#  'question for Senator Kennedy. MR. LEVY: Senator, in your acceptance s',
#  'question for Senator Kennedy. MR. LEVY: Senator, on the same subject,']
#
# -------------------
# | 47 MR. MONDALE: |
# -------------------
#
# [": Mr. Mondale, your rebuttal. MR. MONDALE: Well, that's what a President",
#  '. Mr. Mondale, your rebuttal? MR. MONDALE: Perhaps in no area do we disa',
#  'o first?   Closing Statements MR. MONDALE: I want to thank the League of',
#  ': Mr. Mondale, your rebuttal? MR. MONDALE: There are two distinguished a',
#  'r react to it in those terms? MR. MONDALE: We absolutely must, which is ']
#
# ------------------
# | 48 MR. MORGAN: |
# ------------------
#
# ['question for Senator Kennedy. MR. MORGAN: Senator, last May, in Oregon,',
#  'question for Senator Kennedy. MR. MORGAN: Senator, Saturday on televisi',
#  'ion for Vice President Nixon. MR. MORGAN: Mr. Vice President, in your s']
#
# ------------------
# | 49 MR. NEWMAN: |
# ------------------
#
# ['u appreciate that. [Laughter] MR. NEWMAN: Mr. Kalb, your question to Pr',
#  "here'd been a miscalculation. MR. NEWMAN: I'm sorry, sir— MR. MONDALE: ",
#  ' recognition of that problem. MR. NEWMAN: Mr. Mondale, your rebuttal? M',
#  ' to political assassinations. MR. NEWMAN: Mr. Mondale, your rebuttal. M',
#  'ice Presidential candidates.] MR. NEWMAN: Mr. President, your rebuttal?']
#
# -----------------
# | 50 MR. NIVEN: |
# -----------------
#
# ['ion for Vice President Nixon. MR. NIVEN: Mr. Vice President, you said ',
#  ' is for Vice President Nixon. MR. NIVEN: Mr. Vice President, Senator K',
#  'question for Senator Kennedy. MR. NIVEN: Senator, while the main theme']
#
# -----------------
# | 51 MR. NIXON: |
# -----------------
#
# [' policies uh - to step it up? MR. NIXON: Mr. Drummond, I am never sati',
#  " you could explain that, sir. MR. NIXON: I'm awfully glad you ge- got ",
#  ". SHADEL: Mr. Vice President. MR. NIXON: Senator Kennedy's position an",
#  'R. McGEE: Mr. Vice President. MR. NIXON: I disagree completely with Se',
#  'R. McGEE: Mr. Vice President. MR. NIXON: Well first of all, I think Se']
#
# ------------------
# | 52 MR. NOVINS: |
# ------------------
#
# ['. Not reducing the interest - MR. NOVINS: - a reduction of the Federal ',
#  'ator Kennedy from Mr. Novins. MR. NOVINS: Senator Kennedy, in connectio',
#  'in nineteen sixty-one or two. MR. NOVINS: Senator, I believe in - in on',
#  'he next question: Mr. Novins. MR. NOVINS: Mr. Vice President, your camp',
#  'hes - MR. KENNEDY: No, never. MR. NOVINS: - you suggested that reducing']
#
# ------------------
# | 53 MR. SCHWAB: |
# ------------------
#
# ["to do that. That's very nice. MR. SCHWAB: Yeah. Now— PRESIDENT TRUMP: S",
#  'y much.  Thank you very much. MR. SCHWAB: Thank you, Mr. President, for',
#  ' very much. I appreciate it.  MR. SCHWAB: Thank you. Thank you very muc',
#  'UMP: Sounds very interesting. MR. SCHWAB: —acknowledge that— PRESIDENT ',
#  "I didn't know about this one. MR. SCHWAB: I would like to acknowledge t"]
#
# ------------------
# | 54 MR. SHADEL: |
# ------------------
#
# ['at Mr. Nixon does in any way. MR. SHADEL: Mr. Vice President. MR. NIXON',
#  'we give an image of vitality. MR. SHADEL: Mr. Vice President. MR. NIXON',
#  'ON: Good evening, Mr. Shadel. MR. SHADEL: And now to meet the panel of ',
#  'e coast of the United States. MR. SHADEL: Mr. Von Fremd has a question ',
#  'rage them to more aggression. MR. SHADEL: Senator Kennedy? MR. KENNEDY:']
#
# --------------------
# | 55 MR. SINGISER: |
# --------------------
#
# ["ion for Vice President Nixon. MR. SINGISER: Mr. Vice President, I'd like "]
#
# -----------------
# | 56 MR. SMITH: |
# -----------------
#
# ["party gives them lip service. MR. SMITH: Mr. Warren's question for Sen",
#  'on of the federal government. MR. SMITH: Can I have the summation time',
#  ' our economy is moving ahead. MR. SMITH: The next question to Senator ',
#  'America started moving again. MR. SMITH: And now the opening statement',
#  'ent by the people themselves. MR. SMITH: Senator Kennedy, your conclus']
#
# ------------------
# | 57 MR. SPIVAK: |
# ------------------
#
# ['ion for Vice President Nixon. MR. SPIVAK: Mr. Vice President, according',
#  'question for Senator Kennedy. MR. SPIVAK: Senator, uh - following this ',
#  'ion for Vice President Nixon. MR. SPIVAK: Mr. Vice President, you have ']
#
# --------------------
# | 58 MR. TREWHITT: |
# --------------------
# ["didn't.   The President's Age MR. TREWHITT: Mr. Mondale, I'm going to han",
#  'step forward in human rights. MR. TREWHITT: Mr. Mondale, could I ask you ',
#  "   The President's Leadership MR. TREWHITT: This question of leadership k",
#  "Reagan?   The President's Age MR. TREWHITT: Mr. President, I want to rais",
#  ' candidate.   Nuclear Weapons MR. TREWHITT: Mr. President, could I take y']
#
# -------------------
# | 59 MR. VANOCUR: |
# -------------------
#
# ['ident Nixon from Mr. Vanocur. MR. VANOCUR: Uh - Mr. Vice President, sinc',
#  " Well as you take the bills - MR. VANOCUR: - if you weren't able to get ",
#  "tor Kennedy from Mr. Vanocur. MR. VANOCUR: Senator, you've been promisin",
#  'ion for Vice President Nixon. MR. VANOCUR: Mr. Vice President uh - in on']
#
# ---------------------
# | 60 MR. VON FREMD: |
# ---------------------
#
# ['emd for Vice President Nixon. MR. VON FREMD: Mr. Vice President, a two-par',
#  'emd for Vice President Nixon. MR. VON FREMD: Mr. Vice President, in the pa',
#  "question for Senator Kennedy. MR. VON FREMD: Senator Kennedy, I'd like to "]
#
# ------------------
# | 61 MR. WARREN: |
# ------------------
#
# ['sident Nixon from Mr. Warren. MR. WARREN: Mr. Vice President you mentio',
#  'question for Senator Kennedy. MR. WARREN: Senator Kennedy, on another s',
#  'ator Kennedy from Mr. Warren. MR. WARREN: Uh - Senator Kennedy, during ',
#  " MR. KENNEDY: That's correct. MR. WARREN: I'd like to ask this: It's a "]
#
# -----------------
# | 62 MS. GEYER: |
# -----------------
#
# ['tically in this area as well. MS. GEYER: Sir, people as well-balanced ',
#  'en, and they will be removed. MS. GEYER: Well, Mr. President, you are ',
#  'k with those other countries. MS. GEYER: Mr. President, the experts al',
#  ' the liberties of our people. MS. GEYER: Mr. President, you, too, have',
#  'ondale.   Illegal Immigration MS. GEYER: Mr. Mondale, many analysts ar']
#
# -----------------
# | 63 MS. MOZER: |
# -----------------
#
# ['ere.  Tell us about your boy. MS. MOZER: Adam was our oldest son. He w',
#  ' take care of yourself. Okay? MS. MOZER: Thank you. THE PRESIDENT: Tha']
#
# -------------------
# | 64 MS. RIDINGS: |
# -------------------
#
# [' MS. RIDINGS: Good evening from the Municip']
#
# ----------------------------
# | 65 N. PRESIDENT CLINTON: |
# ----------------------------
#
# ["ENATOR DOLE: That's not the U.N. PRESIDENT CLINTON: Sometimes the United "
#  'States h']
#
# -----------------------
# | 66 N. SENATOR DOLE: |
# -----------------------
#
# ["ed for not working with the U.N. SENATOR DOLE: That's not the U.N. PRESIDENT"]
#
# -----------------------
# | 67 NAVY DEPARTMENT: |
# -----------------------
#
# ['00-21,158,103.50-21,158,076.50NAVY DEPARTMENT:Navy Department proper116,101,']
#
# -------------
# | 68 NIXON: |
# -------------
#
# ["onditions he's laid down? MR. NIXON: No, of course I haven't talke",
#  'vocate and at what point? MR. NIXON: To combat unemployment we fir',
#  'make the first summation? MR. NIXON: Thank you, Mr. Smith. Senator',
#  "ADEL: Mr. Vice President. MR. NIXON: Senator Kennedy's position an",
#  't, do you have a comment? MR. NIXON: Well Mr. Edwards, as you prob']
#
# ------------------------
# | 69 O. THE PRESIDENT: |
# ------------------------
#
# ['ittle while. AUDIENCE:  O-H-I-O. THE PRESIDENT:  Yes, that kid Turner looks '
#  'p']
#
# -----------------------------
# | 70 PANAMA. MR. PRESIDENT: |
# -----------------------------
#
# ['MARKS MADE BY THE MINISTER OF PANAMA. MR. PRESIDENT: In according to the '
#  'minister ']
#
# -------------------
# | 71 PARTICIPANT: |
# -------------------
#
# ['ghters and their sons.  Okay? PARTICIPANT:  This is real. THE PRESIDENT:']
#
# ----------------------
# | 72 PRESIDENT BUSH: |
# ----------------------
#
# ['eral Annan address the crowd] PRESIDENT BUSH: It has been my honor to host ']
#
# -------------------------
# | 73 PRESIDENT CLINTON: |
# -------------------------
#
# ['e have to vote it up or down. PRESIDENT CLINTON: I agree.   Teenage Drug Use '
#  'L',
#  'rence. LEHRER: Mr. President. PRESIDENT CLINTON: The President. Let me say, '
#  'fi',
#  'ld you define the difference? PRESIDENT CLINTON: Well, Jim, I believe that '
#  'the',
#  'be your political philosophy. PRESIDENT CLINTON: I believe that the purpose '
#  'of',
#  ", let's start with education. PRESIDENT CLINTON: First of all, Senator Dole, "
#  'l']
#
# --------------------------
# | 74 PRESIDENT PINOCHET: |
# --------------------------
#
# ['m becoming another Nicaragua? PRESIDENT PINOCHET: Morton, I did criticize '
#  'the P']
#
# ------------------------
# | 75 PRESIDENT REAGAN: |
# ------------------------
#
# ['urvive that kind of calamity? PRESIDENT REAGAN: Mr. Kalb, I think what has '
#  'be',
#  'sident Reagan, your rebuttal. PRESIDENT REAGAN: Well, the invasion of '
#  'Afghani',
#  "there if they were in danger? PRESIDENT REAGAN: Ah, well, now you've added "
#  'a ',
#  'nction in such circumstances? PRESIDENT REAGAN: Not at all, Mr. Trewhitt, '
#  'and',
#  ' AUDIENCE MEMBER: Hear, hear! PRESIDENT REAGAN: Indeed, he was on that side '
#  'v']
#
# -----------------------
# | 76 PRESIDENT TRUMP: |
# -----------------------
#
# ["e doing so, I'd just like to— PRESIDENT TRUMP: Sounds very interesting. MR. ",
#  ' PRESIDENT TRUMP:  Thank you very much.  Thank ',
#  " of releasing the transcript. PRESIDENT TRUMP:  Yeah.  I don't like it. Q   ",
#  'ed for long impeachment saga? PRESIDENT TRUMP:  Well, I thought we won.  I t',
#  ' nice. MR. SCHWAB: Yeah. Now— PRESIDENT TRUMP: Steven, Wilbur, Gary, Robert,']
#
# ----------------------
# | 77 PRESIDENT. SIR: |
# ----------------------
#
# [', D.C., February 6, 1868. The PRESIDENT. SIR: I am in receipt of yours of y',
#  'ington, February 6, 1868. The PRESIDENT. SIR: The meeting to which you refe',
#  'RTMENT, February 6, 1868. The PRESIDENT. SIR: I have received your note of ',
#  ', D.C., February 5, 1868. The PRESIDENT. SIR: Your note of this date was ha',
#  'ARTMENT, August 12, 1867. The PRESIDENT. SIR: Your note of this date has be']
#
# -----------------
# | 78 PRESIDENT: |
# -----------------
#
# ['U.S.A.!  U.S.A.!  U.S.A.! THE PRESIDENT:  Tonight, we pay tribute to t',
#  'Waters — AUDIENCE: B000 — THE PRESIDENT:—and perhaps even worse, Nancy',
#  'Q    Okay. THE PRESIDENT:  And if not, then the next st',
#  "hat he may attempt to do? THE PRESIDENT: You know, Michael, I'm not go",
#  'eeing anything concrete — THE PRESIDENT:  A lot has been accomplished.']
#
# -----------------------
# | 79 REPRESENTATIVES: |
# -----------------------
#
# ['NS OF THE SENATE AND HOUSE OF REPRESENTATIVES:           It is a circumstanc',
#  'TO THE SENATE AND HOUSE OF REPRESENTATIVES:I sincerely regret that I cann']
#
# ----------------------
# | 80 SECRETARY AZAR: |
# ----------------------
#
# ['stoppage? Please. Secretary.  SECRETARY AZAR: Well, thank you, Mr. Presiden',
#  ' your company, right? Or was. SECRETARY AZAR: It was. THE PRESIDENT: Now yo',
#  'ybody.  THE PRESIDENT: Great. SECRETARY AZAR: You also changed the rules so']
#
# -------------------------
# | 81 SECRETARY MNUCHIN: |
# -------------------------
#
# [' PRESIDENT TRUMP:  Thank you. SECRETARY MNUCHIN:  As Secretary Pompeo said '
#  'on ']
#
# -----------------------
# | 82 SECRETARY PERRY: |
# -----------------------
#
# ["ing it right now with energy. SECRETARY PERRY: Ain't bragging if you can do "]
#
# ------------------------
# | 83 SECRETARY POMPEO: |
# ------------------------
#
# ['o a couple of more questions. SECRETARY POMPEO:  Mr. President, I thought '
#  "I'd"]
#
# ------------------------
# | 84 SENATOR BOB DOLE: |
# ------------------------
#
# ['R: Senator Dole, two minutes. SENATOR BOB DOLE: Thank you. Thank you, Mr. '
#  'Pre']
#
# --------------------
# | 85 SENATOR DOLE: |
# --------------------
#
# [' to go. LEHRER: Senator Dole. SENATOR DOLE: The President wants to increa',
#  'week fall into that category? SENATOR DOLE: Well, there were some good pi',
#  "INTON: No comment. [Laughter] SENATOR DOLE: What's the subject matter? [L",
#  "d services to your campaigns? SENATOR DOLE: I think it's very difficult. ",
#  've outlined in this campaign. SENATOR DOLE: I had better correct the Pres']
#
# -----------------------
# | 86 SENATOR KENNEDY: |
# -----------------------
#
# ['t by Senator John F. Kennedy. SENATOR KENNEDY: Mr. Smith, Mr. Nixon. In the ']
#
# -----------
# | 87 SIR: |
# -----------
#
# ['ashington, November 29, 1881. SIR:* The attitude of the United S',
#  'SIR: I desire to call your attenti',
#  'ruary 5, 1868. The PRESIDENT. SIR: Your note of this date was ha',
#  'ruary 6, 1868. The PRESIDENT. SIR: The meeting to which you refe',
#  'ruary 6, 1868. The PRESIDENT. SIR: I am in receipt of yours of y']
#
# -------------
# | 88 SMITH: |
# -------------
# ['by the people themselves. MR. SMITH: Senator Kennedy, your conclus',
#  "er a government can have. MR. SMITH: Senator Kennedy's comment? MR",
#  'f success for the future. MR. SMITH: Mr. Nixon, comment? MR. NIXON',
#  'cts which are in surplus. Mr. SMITH: The next question to Vice Pre',
#  'g to face in the sixties? MR. SMITH: The next question to Senator ']
#
# --------------------
# | 89 SPEAKER RYAN: |
# --------------------
#
# ["r many, many years. So—right? SPEAKER RYAN: Yep. THE PRESIDENT: That's go"]
#
# -------------
# | 90 STATE: |
# -------------
#
# ['er 11, 1903. MR. SECRETARY OF STATE: I have the very great honor t']
#
# --------------------
# | 91 THE CONGRESS: |
# --------------------
#
# ['GENTLEMEN OF THE CONGRESS: The year that has elapsed sin',
#  'GENTLEMEN OF THE CONGRESS:When I addressed myself to per',
#  'MEMBERS OF THE CONGRESS:So many problems are calling f',
#  'GENTLEMEN OF THE CONGRESS: In fulfilling at this time th',
#  'GENTLEMEN OF THE CONGRESS: Since I last had the privileg']
#
# -------------------------
# | 92 THE MANDAN NATION: |
# -------------------------
#
# ['LDREN, THE WOLF AND PEOPLE OF THE MANDAN NATION:  I take you by the hand of '
#  'fr']
#
# ---------------------
# | 93 THE PRESIDENT: |
# ---------------------
#
# ['ry much. Q    Mr. President — THE PRESIDENT:  Yes, go ahead.  Go ahead. Q ',
#  '  I love you, Mr. President.  THE PRESIDENT:  I appreciate that.  (Laughte',
#  "bama!  Obama!  Obama!  Obama! THE PRESIDENT:  I'm here because of my own m",
#  's on this national emergency? THE PRESIDENT:  I would talk about it.  Look',
#  'up! Lock her up! Lock her up! THE PRESIDENT: I will say this, folks: Every']
#
# -------------------------
# | 94 THE UNITED STATES: |
# -------------------------
#
# ['D HOUSE OF REPRESENTATIVES OF THE UNITED STATES:           It would have '
#  'been ',
#  'as follows:  The PRESIDENT OF THE UNITED STATES:  The Senate of the United '
#  'Sta',
#  'D HOUSE OF REPRESENTATIVES OF THE UNITED STATES:             In calling you '
#  'to',
#  'D HOUSE OF REPRESENTATIVES OF THE UNITED STATES:Agreeably to the request of '
#  'th']
#
# ---------------------------
# | 95 TREASURY DEPARTMENT: |
# ---------------------------
#
# ['775.00- 171,125.00- 296,900.00TREASURY DEPARTMENT:Treasury Department '
#  'proper68,7']
#
# -------------
# | 96 TRUMP: |
# -------------
#
# [' PRESIDENT TRUMP:  Thank you very much.  Thank ',
#  'w days.  Thank you. PRESIDENT TRUMP:  Thank you. SECRETARY MNUCHIN',
#  "ussia (inaudible) — PRESIDENT TRUMP:  We're — we're watching it ve",
#  ' for being with us. PRESIDENT TRUMP: Thank you. Thank you very muc',
#  'u worried about it? PRESIDENT TRUMP:  Well, I just say that social']
#
# ----------------------
# | 97 UDIENCE MEMBER: |
# ----------------------
#
# ['Young, also. Don, thank you. AUDIENCE MEMBER: (Inaudible) all along. THE PR',
#  'g people, Dennis Kucinich.   AUDIENCE MEMBER:  Vote yes! THE PRESIDENT:  Di',
#  't is wonderful to be here -- AUDIENCE MEMBER:  I love you! THE PRESIDENT:  ',
#  " here's what we have to do.  AUDIENCE MEMBER:  I love you, Mr. President.  ",
#  ' UDIENCE MEMBER:  We love you, President Obama']
#
# -------------
# | 98 VOICE: |
# -------------
#
# ["e'll have the summation time. VOICE: This will allow three minutes"]
#
# ----------------------
# | 99 WAR DEPARTMENT: |
# ----------------------
#
# ['7.41+ 2,162,439.91+ 668,532.50WAR DEPARTMENT:War Department proper120,104,2']
#
# ----------------
# | 100 WAR. SIR: |
# ----------------
#
# ['8. The Honorable SECRETARY OF WAR. SIR: It is represented to this Dep',
#  'he Honorable the SECRETARY OF WAR. SIR: It has been represented to th']

# %%
speaker_dict['BROTHER HANDSOME LAKE:'] = 'TO BROTHER HANDSOME LAKE:'
speaker_dict['C. LEHRER:'] = 'LEHRER:'
speaker_dict['CONGRESS ASSEMBLED:'] = 'TO THE SENATE AND HOUSE OF REPRESENTATIVES OF THE UNITED STATES   IN CONGRESS ASSEMBLED:'
speaker_dict['CREDENCE. MR. MINISTER:'] = 'THE PRESIDENT\'S REPLY TO THE REMARKS MADE BY SENOR BUNAU VARILLA ON THE OCCASION OF THE PRESENTATION OF HIS LETTERS OF CREDENCE. MR. MINISTER:'
speaker_dict['DC. PRESIDENT CLINTON:'] = 'PRESIDENT CLINTON:'
speaker_dict['FELLOW CITIZENS:'] = 'MY FELLOW CITIZENS:'
speaker_dict['GEE:'] = 'MR. McGEE:'
speaker_dict['KENNEDY:'] = 'MR. KENNEDY:'
speaker_dict['N. PRESIDENT CLINTON:'] = 'PRESIDENT CLINTON:'
speaker_dict['N. SENATOR DOLE:'] = 'SENATOR DOLE:'
speaker_dict['NIXON:'] = 'MR. NIXON:'
speaker_dict['O. THE PRESIDENT:'] = 'THE PRESIDENT:'
speaker_dict['PANAMA. MR. PRESIDENT:'] = 'MR. PRESIDENT:'
speaker_dict['PRESIDENT:'] = 'THE PRESIDENT:'
speaker_dict['SM1TH:'] = 'MR. SMITH:'
speaker_dict['STATE:'] = 'MR. SECRETARY OF STATE:'
speaker_dict['THE MANDAN NATION:'] = 'MY CHILDREN, THE WOLF AND PEOPLE OF THE MANDAN NATION:'
speaker_dict['TRUMP:'] = 'PRESIDENT TRUMP:'
speaker_dict['UDIENCE MEMBER:'] = 'AUDIENCE MEMBER:'

# Add SM1TH
speaker_dict['MR. SM1TH:'] = 'MR. SM1TH:'

# 'MODERATORS:'
del speaker_dict['MODERATOR:']
speaker_dict['QUINCY HOWE, MODERATOR:'] = 'QUINCY HOWE, MODERATOR:'
speaker_dict['HOWARD K. SMITH, MODERATOR:'] = 'HOWARD K. SMITH, MODERATOR:'
speaker_dict['FRANK McGEE, MODERATOR:'] = 'FRANK McGEE, MODERATOR:'
speaker_dict['BILL SHADEL, MODERATOR:'] = 'BILL SHADEL, MODERATOR:'

# 'REPRESENTATIVES:''
del speaker_dict['REPRESENTATIVES:']
speaker_dict['TO THE SENATE AND HOUSE OF REPRESENTATIVES:'] = 'TO THE SENATE AND HOUSE OF REPRESENTATIVES:'
speaker_dict['FELLOW CITIZENS OF THE SENATE AND HOUSE OF REPRESENTATIVES:'] = 'FELLOW CITIZENS OF THE SENATE AND HOUSE OF REPRESENTATIVES:'
speaker_dict['TO THE SENATE AND HOUSE OF REPRESENTATIVES OF THE UNITED STATES:'] = 'TO THE SENATE AND HOUSE OF REPRESENTATIVES OF THE UNITED STATES:'

speaker_dict['THE UNITED STATES:'] = 'The PRESIDENT OF THE UNITED STATES:'

speaker_dict['THE CONGRESS:'] = 'GENTLEMEN OF THE CONGRESS:'
speaker_dict['MEMBERS OF THE CONGRESS:'] = 'MEMBERS OF THE CONGRESS:'

# %%
all_speakers = list(set([speaker_dict[keys] for keys in speaker_dict.keys()]))

# %%
president_speakers = [
    'GRANT:',
    'TO THE SENATE AND HOUSE OF REPRESENTATIVES:',
    'TO BROTHER HANDSOME LAKE:',
    'FELLOW-CITIZENS:',
    'GENTLEMEN:',
    'PRESIDENT CLINTON:'
    'PRESIDENT BUSH:',
    'PRESIDENT REAGAN:',
    'PRESIDENT TRUMP:',
    "THE PRESIDENT'S REPLY TO THE REMARKS MADE BY SENOR BUNAU VARILLA ON THE OCCASION OF THE PRESENTATION OF HIS LETTERS OF CREDENCE. MR. MINISTER:",
    'MR. PRESIDENT:',
    'SIR:',
    'BUSH:',
    'MY CHILDREN, THE WOLF AND PEOPLE OF THE MANDAN NATION:',
    'MY FELLOW CITIZENS:',
    'TO THE SENATE AND HOUSE OF REPRESENTATIVES OF THE UNITED STATES   IN CONGRESS ASSEMBLED:',
    'MEMBERS OF THE CONGRESS:',
    'GENTLEMEN OF THE CONGRESS:',
    'THE PRESIDENT:',
    'The PRESIDENT OF THE UNITED STATES:',
    'FELLOW CITIZENS OF THE SENATE AND HOUSE OF REPRESENTATIVES:'    
]

# Get all non-presidential speakers
non_president_speakers = list(set(all_speakers).difference(set(president_speakers)))
non_president_speakers += ['Audience:']

# Get all sayings for each non-president
non_president_speaker_sayings_dict = {}
for speaker in tqdm(non_president_speakers):
    non_president_speaker_sayings_dict[speaker] = clean_removable_speaker_text(speaker, all_speakers)
# Out:
# 100%|██████████| 81/81 [00:25<00:00,  3.18it/s]

# %%
# List of non-president sayings
non_president_speaker_sayings = [sayings for sayings in non_president_speaker_sayings_dict.values()]
non_president_speaker_sayings = list(itertools.chain.from_iterable(non_president_speaker_sayings))
non_president_speaker_sayings
# Out:
# ["SENATOR KENNEDY: Mr. Smith, Mr. Nixon. In the election of 1860, Abraham Lincoln said the question was whether this nation could exist half-slave or half-free. In the election of 1960, and with the world around us, the question is whether the world will exist half-slave or half-free, whether it will move in the direction of freedom, in the direction of the road that we are taking, or whether it will move in the direction of slavery. I think it will depend in great measure upon what we do here in the United States, on the kind of society that we build, on the kind of strength that we maintain. We discuss tonight domestic issues, but I would not want that to be any implication to be given that this does not involve directly our struggle with Mr. Khrushchev for survival. Mr. Khrushchev is in New York, and he maintains the Communist offensive throughout the world because of the productive power of the Soviet Union itself. The Chinese Communists have always had a large population. But they are important and dangerous now because they are mounting a major effort within their own country. The kind of country we have here, the kind of society we have, the kind of strength we build in the United States will be the defense of freedom. If we do well here, if we meet our obligations, if we're moving ahead, then I think freedom will be secure around the world. If we fail, then freedom fails. Therefore, I think the question before the American people is",
#  "MR. SMITH: Thank you very much, gentlemen. This hour has gone by all too quickly. Thank you very much for permitting us to present the next president of the United States on this unique program. I've been asked by the candidates to thank the American networks and the affiliated stations for providing time and facilities for this joint appearance. Other debates in this series will be announced later and will be on different subjects. This is Howard K. Smith. Good night from Chicago.",
#  'MR. SMITH: Mr. Nixon, would you like to comment on that statement? Mr. NIXON',
#  "MR. SMITH: Mr. Nixon, comment? MR. NIXON; I of course disagree with Senator Kennedy insofar as his suggestions as to what should be done uh - with re- on the farm program. He has made the suggestion that what we need is to move in the direction of more government controls, a suggestion that would also mean raising prices uh - that the consumers pay for products and im- and imposing upon the farmers uh - controls on acreage even far more than they have today. I think this is the wrong direction. I don't think this has worked in the past; I do not think it will work in the future. The program that I have advocated is one which departs from the present program that we have in this respect. It recognizes that the government has a responsibility to get the farmer out of the trouble he presently is in because the government got him into it. And that's the fundamental reason why we can't let the farmer go by himself at the present time. The farmer produced these surpluses because the government asked him to through legislation during the war. Now that we have these surpluses, it's our responsibility to indemnify the farmer during that period that we get rid of the farmer uh - the surpluses. Until we get the surpluses off the farmer's back, however, we should have a program such as I announced, which will see that farm income holds up. But I would propose holding that income up not through a type of program that Senator Kennedy has suggested that would raise prices, but one that would indemnify the farmer, pay the farmer in kind uh - from the products which are in surplus. Mr. ",
#  'MR. SMITH: The next question to Senator Kennedy from Mr. Warren. ',
#  'MR. SMITH: Senator Kennedy. ',
#  "MR. SMITH: Thank you, Mr. Nixon. That completes the opening statements, and now the candidates will answer questions or comment upon one another's answers to questions, put by correspondents of the networks. The correspondents",
#  'MR. SMITH: The next question to Vice President Nixon fa- from Mr. Fleming. ',
#  'MR. SMITH: The next question to Vice President Nixon from Mr. Warren. ',
#  'MR. SMITH: Mr. Nixon, comment? ',
#  'MR. SMITH: Senator Kennedy, your conclusion. ',
#  'MR. SMITH: The next question to Senator Kennedy from Mr. Novins. ',
#  'MR. SMITH: Senator Kennedy. Mr. KENNEDY',
#  "MR. SMITH: Mr. Warren's question for Senator Kennedy. ",
#  'MR. SMITH: And now the opening statement by Vice President Richard M. Nixon. ',
#  "MR. SMITH: Can I have the summation time please? We've completed our questions and our comments, and in just a moment, we'll have the summation time. ",
#  "MR. SMITH: Can I have the summation time please? We've completed our questions and our comments, and in just a moment, we'll have the summation time. VO",
#  "MR. SMITH: Senator Kennedy's comment? ",
#  'MR. SMITH: The next question to Senator Kennedy from Mr. Vanocur. ',
#  "MR. SMITH: Mr. Vanocur's question for Vice President Nixon. ",
#  'MR. SMITH: Mr. Nixon, your comment? ',
#  'MR. McGEE: Senator Kennedy. ',
#  'MR. McGEE: Mr. Levy with a question for Senator Kennedy. ',
#  'MR. McGEE: Mr. Morgan with a question for Vice President Nixon. ',
#  'MR. McGEE: Mr. Niven with a question for Vice President Nixon. ',
#  'MR. McGEE: Uh - Senator Kennedy, a moment ago you mentioned tax loopholes. Now your running mate, Senator Lyndon Johnson, is from Texas, an oil-producing state and one that many political leaders feel is in doubt in this election year. And reports from there say that oil men in Texas are seeking assurance from Senator Johnson that the oil depletion allowance will not be cut. The Democratic platform pledges to plug holes in the tax laws and refers to inequitable depletion allowance as being conspicuous loopholes. My question is, do you consider the twenty-seven and a half per cent depletion allowance inequitable, and would you ask that it be cut? ',
#  'MR. McGEE: Senator Kennedy, yesterday you used the words "trigger-happy" in referring to Vice President Richard Nixon\'s stand on defending the islands of Quemoy and Matsu. Last week on a program like this one, you said the next president would come face to face with a serious crisis in Berlin. So the question is',
#  'MR. McGEE: Mr. Morgan, with a question for Senator Kennedy. ',
#  'MR. McGEE: Thank you gentlemen. Neither the questions from the reporters nor the answers you heard from Senator John Kennedy or Vice President Richard Nixon were rehearsed. By agreement neither candidate made an opening statement or a closing summation. They further agreed that the clock alone would decide who would speak last and each has asked me to express his thanks to the networks and their affiliated stations. Another program similar to this one will be presented Thursday, October thirteenth, and the final program will be presented Friday, October twenty-first. We hope this series of radio and television programs will help you toward a fuller understanding of the issues facing our country today and that on election day, November eighth, you will vote for the candidate of your choice. This is Frank McGee. Good night from Washington.',
#  'MR. McGEE: Gentlemen, we have approximately four minutes remaining. May I ask you to make your questions and answers as brief as possible consistent with clarity. And Mr. Levy has a question for Vice President Nixon. ',
#  'MR. McGEE: Senator Kennedy, would you care to comment? ',
#  'MR. McGEE: Mr. Levy with a question for Vice President Nixon. MR. LEVY; Mr. Vice President, the Labor Department today added five more major industrial centers to the list of areas with substantial unemployment. You said in New York this week that as president you would use the full powers of the government, if necessary, to combat unemployment. Specifically what measures would you advocate and at what point? ',
#  'MR. McGEE: Mr. Vice President. ',
#  'MR. McGEE: Mr. Spivak with a question for Vice President Nixon. ',
#  'MR. McGEE: Mr. Spivak with a question for Senator Kennedy. ',
#  'MR. McGEE: Mr. Niven with a question for Senator Kennedy. ',
#  'MR. McGEE: Mr. Morgan with a question for Senator Kennedy. ',
#  'MR. McGEE: Mr. Vice President, some of your early campaign literature said you were making a study to see if new laws were needed to protect the public against excessive use of power by labor unions. Have you decided whether such new laws are needed, and, if so, what would they do? ',
#  'C. SIR: The Hon. Edwin M. Stanton having been this day suspended as Secretary of War, you are hereby authorized and empowered to act as Secretary of War ad interim, and will at once enter upon the discharge of the duties of the office. The Secretary of War has been instructed to transfer to you all the records, books, papers, and other public property now in his custody and charge. The following communication was received from Mr. Stanton',
#  "JIM LEHRER: Good evening. On behalf of the Commission on Presidential Debates I am pleased to welcome you to this first presidential debate of the 1988 campaign. I'm Jim Lehrer of the MacNeil/Lehrer News Hour. My colleagues on the panel are John Mashek of the Atlanta Journal-Constitution; Ann Groer of the Orlando Sentinel; and Peter Jennings of ABC News. For the next 90 minutes we will be questioning the candidates for President of the United States following a format designed and agreed to by representatives of the two candidates. The candidates are Vice President George Bush, the Republican nominee; Governor Michael Dukakis, the Democratic nominee. ",
#  "JIM LEHRER: Good evening from the Bushnell Theater in Hartford, Connecticut. I'm Jim Lehrer, of The NewsHour on PBS. Welcome to the first of the 1996 Presidential debates between President Bill Clinton, the Democratic nominee, and Senator Bob Dole, the Republican nominee. This event is sponsored by the Commission on Presidential Debates. It will last 90 minutes, following a format and rules worked out by the two campaigns. There will be two-minute opening and closing statements; in between, a series of questions, each having three parts",
#  'GROER: Governor Dukakis, as many U.S. farmers face or undergo foreclosure, the United States is considering the possibility of forgiving a certain percentage of debt owed by Latin American and Third World countries, do you favor giving these countries a break in their loans and, if so, how do you explain that to the American farmers who are losing their land and livelihood? ',
#  'GROER: Yes. Governor Dukakis, speaking of seeming changes of position, you have gone from calling the Strategic Defense Initiative, or Star Wars, a fantasy and a fraud, to saying recently that you would continue SDI research and might even deploy the system if Congress supported such a move. Why the change of heart? ',
#  "GROER: Yes. Mr. Vice President, I'd like to stay with abortion for just a moment if I might. Over the years you have expressed several positions, while opposing nearly all forms of government payment for it. You now say that you support abortion only in cases of rape, incest, or threat to a mother's life, and you also support a constitutional amendment that if ratified would outlaw most abortions. But if abortions were to become illegal again, do you think that the women who defy the law and have them anyway, as they did before it was okayed by the Supreme Court, and the doctors who perform them should go to jail? ",
#  "GROER: Yes. Since your Massachusetts health plan has been attacked by the Vice President and you have defended it in this way, I would like to move on to perhaps one of the most costly medical catastrophes facing Americans today and that is AIDS. In – at the end of September, the thousands of AIDS patients will lose their access to AZT, which is the only Federally approved drug for treatment of the disease. Now, I'd like to now, sir, if – what your position is on extending that and what it is you think the government ought to be doing about making AZT and other drugs available to people who are suffering from this disease. ",
#  "GROER: Governor Dukakis, is there a conflict between your opposition to the death penalty and your support for abortion on demand, even though in the minds of many people, that's also killing? ",
#  "GROER: Mr. Vice President, you've said you want a kinder, gentler presidency, one that helps the less fortunate. Today, 37 million Americans including many working families with aging parents and young children cannot afford any health insurance, but earn too much to qualify for Medicaid. What will you do to provide protection for them and how will you pay for it? ",
#  "GROER: Well, Mr. Vice President, you said you've met with Secretary General Gorbachev, you've met with Mr. Shevardnadze, but for the last 40 years Americans have been taught to regard the Soviet Union as the enemy. Yet, President Reagan has signed two arms control treaties and he's promised to share Star Wars technology with the very country he once called the evil empire. So, perhaps you can tell us this evening, should we be doing a lot to help the economics and the social development of a country that we have so long regarded as an adversary? ",
#  'PRESIDENT. SIR: Your note of this date was handed to me this evening. My recollection of the conversation at the Cabinet meeting on Tuesday, the 14th of January, corresponds with your statement of it in the letter of the 31st ultimo in the published correspondence. The three points specified in that letter, giving your recollection of the conversation, are correctly stated. Very respectfully, GIDEON WELLES. TREASURY DEPARTMENT, February 6, 1868. The ',
#  'PRESIDENT. SIR: Your note of this date was handed to me this evening. My recollection of the conversation at the Cabinet meeting on Tuesday, the 14th of January, corresponds with your statement of it in the letter of the 31st ultimo in the published correspondence. The three points specified in that letter, giving your recollection of the conversation, are correctly stated. Very respectfully, GIDEON WELLES. TREASURY DEPARTMENT, February 6, 1868. The PRESIDENT. ',
#  'PRESIDENT. SIR: Your note of this date has been received, informing me that by virtue of the powers and authority vested in you as President by the Constitution and laws of the United States I am suspended from office as Secretary of War, and will cease to exercise any and all functions pertaining to the same, and also directing me at once to transfer to General Ulysses S. Grant, who has this day been authorized and empowered to act as Secretary of War ad interim , all records, books, papers, and other public property now in my custody and charge. Under a sense of public duty I am compelled to deny your right under the Constitution and laws of the United States, without the advice and consent of the Senate and without any legal cause, to suspend me from office as Secretary of War or the exercise of any or all functions pertaining to the same, or without such advice and consent to compel me to transfer to any person the records, books, papers, and public property in my custody as Secretary. But inasmuch as the General Commanding the armies of the United States has been appointed ad interim , and has notified me that he has accepted the appointment, I have no alternative but to submit, under protest, to superior force. To the PRESIDENT. The suspension has not been revoked, and the business of the War Department is conducted by the Secretary ad interim. Prior to the date of this suspension I had come to the conclusion that the time had arrived when it was proper Mr. Stanton should retire from my Cabinet. The mutual confidence and general accord which should exist in such a relation had ceased. I supposed that Mr. Stanton was well advised that his continuance in the Cabinet was contrary to my wishes, for I had repeatedly given him so to understand by every mode short of an express request that he should resign. Having waited full time for the voluntary action of Mr. Stanton, and seeing no manifestation on his part of an intention to resign, I addressed him the following note on the 5th of August',
#  "PRESIDENT. SIR: The meeting to which you refer in your letter was a regular Cabinet meeting. While the members were assembling, and before the President had entered the council chamber, General Grant on coming in said to me that he was in attendance there, not as a member of the Cabinet, but upon invitation, and I replied by the inquiry whether there was a change in the War Department. After the President had taken his seat, business went on in the usual way of hearing matters submitted by the several Secretaries. When the time came for the Secretary of War, General Grant said that he was now there, not as Secretary of War, but upon the President's invitation; that he had retired from the War Department. A slight difference then appeared about the supposed invitation, General Grant saying that the officer who had borne his letter to the President that morning announcing his retirement from the War Department had told him that the President desired to see him at the Cabinet, to which the President answered that when General Grant's communication was delivered to him the President simply replied that he supposed General Grant would be very soon at the Cabinet meeting. I regarded the conversation thus begun as an incidental one. It went on quite informally, and consisted of a statement on your part of your views in regard to the understanding of the tenure upon which General Grant had assented to hold the War Department ad interim and of his replies by way of answer and explanation. It was respectful and courteous on both sides. Being in this conversational form, its details could only have been preserved by verbatim report. So far as I know, no such report was made at the time. I can give only the general effect of the conversation. Certainly you stated that, although you had reported the reasons for Mr. Stanton's suspension to the Senate, you nevertheless held that he would not be entitled to resume the office of Secretary of War even if the Senate should disapprove of his suspension, and that you had proposed to have the question tested by judicial process, to be applied to the person who should be the incumbent of the Department under your designation of Secretary of War ad interim in the place of Mr. Stanton. You contended that this was well understood between yourself and General Grant; that when he entered the War Department as Secretary ad interim he expressed his concurrence in a belief that the question of Mr. Stanton's restoration would be a question for the courts; that in a subsequent conversation with General Grant you had adverted to the understanding thus had, and that General Grant expressed his concurrence in it; that at some conversation which had been previously held General Grant said he still adhered to the same construction of the law, but said if he should change his opinion he would give you seasonable notice of it, so that you should in any case be placed in the same position in regard to the War Department that you were while General Grant held it ad interim . I did not understand General Grant as denying nor as explicitly admitting these statements in the form and full extent to which you made them. His admission of them was rather indirect and circumstantial, though I did not understand it to be an evasive one. He said that, reasoning from what occurred in the case of the police in Maryland, which he regarded as a parallel one, he was of opinion, and so assured you, that it would be his right and duty under your instructions to hold the War Office after the Senate should disapprove of Mr. Stanton's suspension until the question should be decided upon by the courts; that he remained until very recently of that opinion, and that on the Saturday before the Cabinet meeting a conversation was held between yourself and him in which the subject was generally discussed. General Grant's statement was that in that conversation he had stated to you the legal difficulties which might arise, involving fine and i ...
#  'PRESIDENT. SIR: I am in receipt of your letter of the 5th of February, calling my attention to the correspondence published in the Chronicle between the President and General Grant, and especially to that part of it which refers to the conversation between the President and General Grant at the Cabinet meeting on Tuesday, the 14th of January, with a request that state what was said in that conversation. In reply I have the honor to state that I have read carefully the correspondence in question, and particularly the letter of the President to General Grant dated January 31, 1868. The following extract from your letter of the 31st January to General Grant is, according to my recollection, a correct statement of the conversation that took place between the President and General Grant at the Cabinet meeting on the 14th of January last. In the presence of the Cabinet the President asked General Grant whether, "in conversation which took place after his appointment as Secretary of War ad interim, he did not agree either to remain at the head of the War Department and abide any judicial proceedings that might follow the nonconcurrence by the Senate in Mr. Stanton\'s suspension, or, should he wish not to become involved in such a controversy, to put the President in the same position with respect to the office as be occupied previous to General Grant\'s appointment, by returning it to the President in time to anticipate such action by the Senate." This General Grant admitted. The President then asked General Grant if at the conference on the preceding Saturday he had not, to avoid misunderstanding, requested General Grant to state what he intended to do, and, further, if in reply to that inquiry he (General Grant) had not referred to their former conversations, saying that from them the President understood his position, and that his (General Grant\'s) action would be consistent with the understanding which had been reached. To these questions General Grant replied in the affirmative. The President asked General Grant if at the conclusion of their interview on Saturday it was not understood that they were to have another conference on Monday before final action by the Senate in the case of Mr. Stanton. General Grant replied that such was the understanding, but that he did not suppose the Senate would act so soon; that on Monday he had been engaged in a conference with General Sherman, and was occupied with "many little matters," and asked if General Sherman had not called on that day. I take this mode of complying with the request contained in the President\'s letter to me, because my attention had been called to the subject before, when the conversation between the President and General Grant was under consideration. Very respectfully, your obedient servant, ALEX. W. RANDALL, Postmaster-General. DEPARTMENT OF THE INTERIOR, Washington, D.C., February 6, 1868. The ',
#  'PRESIDENT. SIR: I am in receipt of your letter of the 5th of February, calling my attention to the correspondence published in the Chronicle between the President and General Grant, and especially to that part of it which refers to the conversation between the President and General Grant at the Cabinet meeting on Tuesday, the 14th of January, with a request that state what was said in that conversation. In reply I have the honor to state that I have read carefully the correspondence in question, and particularly the letter of the President to General Grant dated January 31, 1868. The following extract from your letter of the 31st January to General Grant is, according to my recollection, a correct statement of the conversation that took place between the President and General Grant at the Cabinet meeting on the 14th of January last. In the presence of the Cabinet the President asked General Grant whether, "in conversation which took place after his appointment as Secretary of War ad interim, he did not agree either to remain at the head of the War Department and abide any judicial proceedings that might follow the nonconcurrence by the Senate in Mr. Stanton\'s suspension, or, should he wish not to become involved in such a controversy, to put the President in the same position with respect to the office as be occupied previous to General Grant\'s appointment, by returning it to the President in time to anticipate such action by the Senate." This General Grant admitted. The President then asked General Grant if at the conference on the preceding Saturday he had not, to avoid misunderstanding, requested General Grant to state what he intended to do, and, further, if in reply to that inquiry he (General Grant) had not referred to their former conversations, saying that from them the President understood his position, and that his (General Grant\'s) action would be consistent with the understanding which had been reached. To these questions General Grant replied in the affirmative. The President asked General Grant if at the conclusion of their interview on Saturday it was not understood that they were to have another conference on Monday before final action by the Senate in the case of Mr. Stanton. General Grant replied that such was the understanding, but that he did not suppose the Senate would act so soon; that on Monday he had been engaged in a conference with General Sherman, and was occupied with "many little matters," and asked if General Sherman had not called on that day. I take this mode of complying with the request contained in the President\'s letter to me, because my attention had been called to the subject before, when the conversation between the President and General Grant was under consideration. Very respectfully, your obedient servant, ALEX. W. RANDALL, Postmaster-General. DEPARTMENT OF THE INTERIOR, Washington, D.C., February 6, 1868. The PRESIDENT. ',
#  'MR. WARREN: Uh - Senator Kennedy, during your brief speech a few minutes ago you mentioned farm surpluses. ',
#  "MR. WARREN: I'd like to ask this",
#  'MR. WARREN: Senator Kennedy, on another subject, Communism is so often described as an ideology or a belief that exists somewhere other than in the United States. Let me ask you, sir',
#  "MR. WARREN: Mr. Vice President you mentioned schools and it was just yesterday I think you asked for a crash program to raise education standards, and this evening you talked about advances in education. Mr. Vice President, you said - it was back in 1957 - that salaries paid to school teachers were nothing short of a national disgrace. Higher salaries for teachers, you added, were important and if the situation wasn't corrected it could lead to a national disaster. And yet, you refused to vote in the Senate in order to break a tie vote when that single vote, if it had been yes, would have granted salary increases to teachers. I wonder if you could explain that, sir. ",
#  "BILL SHADEL, MODERATOR: Good evening. I'm Bill Shadel of ABC News. It's my privilege this evening to preside at this the third in the series of meetings on radio and television of the two major presidential candidates. Now like the last meeting the subjects to be discussed will be suggested by questions from a panel of correspondents. Unlike the first two programs, however, the two candidates will not be sharing the same platform. In New York the Democratic presidential nominee, Senator John F. Kennedy; separated by three thousand miles in a Los Angeles studio, the Republican presidential nominee, Vice President Richard M. Nixon; now joined for tonight's discussion by a network of electronic facilities which permits each candidate to see and hear the other. Good evening, Senator Kennedy. ",
#  'SENATOR DOLE: Food. [Laughter]   Iraq ',
#  'SENATOR DOLE: Well, that\'s the point I made—we have to be firm and strong. And I hope that will happen. It will happen starting next January and maybe can happen the balance of this year. We have not been firm and strong. If you look at the poor people who still live in Cuba, it\'s a haven for drug smugglers, and we don\'t have a firm policy when it comes to Fidel Castro. In my view, the policy has failed. So Congress passes a law, the President signs it like he does a lot of things, but he—like welfare reform, "Well, I\'m going to sign it, but I\'m going to try to change it next year." I mean, a lot of these election-year conversions the President is talking about—all the drug money and all the other things, all this antismoking campaign—all happened in 1996. And I think the people viewing out there ought to go back and take a look at the record. When he fought a balanced budget amendment, when he gave you that biggest tax increase in history, when he tried to take over your health care system, when he fought regulatory reform that costs the average family $6,000 to $7,000 a year—this is serious business. It\'s about your family. It\'s about your business. And in this case, it\'s about a firmer policy with Cuba. ',
#  "SENATOR DOLE: Oh, yes, and you'll be eligible. [Laughter] ",
#  "SENATOR DOLE: Again, you're very selective, Mr. President. You don't want to politicize drugs, but it's all right to politicize Medicare and go out and scare senior citizens and other vulnerable groups, veterans and people who get Pell grants and things like this. I mean, you say we have done all these bad things, which isn't the case. But it seems to me the record is clear. The record was pretty clear in Arkansas when you were Governor",
#  "SENATOR DOLE: Well, after World War I we had a policy of disengagement. Then from World War I to World War II we had sort of a compulsory engagement policy. Now, I think we have to have a selective engagement policy. We have to determine when our interests are involved, not the United Nations' interests. And many of the things the President talked about he turned over to the United Nations; they decided. He's deployed more troops than any President in history around the world. It's cost us billions and billions of dollars for peacekeeping operations. These are facts. And it seems to me that when you make a decision, the decision is made by the President of the United States, by the Commander in Chief. He makes that decision when he commits young men or young women who are going to go around and defend our liberty and our freedom. That would be my position. Then I'm going to have a top-down review at the Pentagon, not a bottom-up review where you all fight over how much money is there. I want a top-down review to determine what our priorities are and what we should do in defense and then follow that policy, instead of this bottom-up review with all of the services fighting for the money. The President said he was going to cut defense $60 billion; he cut defense $112 billion, devastated States like California and others. And I think now we've got a problem. We've got to go back and look. It's just like you said in Texas one day, you know, you raised taxes too much—and you did—and you cut defense too much, Mr. President—and you did, and you may have said that, too. But the bottom line is, we are the strongest nation in the world, we provide the leadership, and we're going to have to continue to provide the leadership. But let's do it on our terms when our interests are involved and not when somebody blows a whistle at the United Nations. ",
#  "SENATOR DOLE: I think it's very difficult. Let's be honest about it. That's why we need campaign finance reform. That's why I reach out to the Perot voters, and we've done about all that--we are the reform party, the Republican Party, and the Perot voters who are looking for a home ought to take a look at the Republican record. Whatever it is, whatever the checklist was in '92, it's all done but campaign finance reform. I worked with Senator Mitchell, who played me, I guess, in the debate warmup. We tried six or eight years ago to—he appointed three people, I appointed three people—to get campaign finance reform. We couldn't get it done because it wasn't enforceable. You suggested a commission; Newt Gingrich did. I've suggested that, at least four or five years ago, we have a commission on campaign finance reform, they send it to Congress, and we have to vote it up or down. That's how it works. We're never going to fix it by the parties, because Democrats want a better advantage for themselves, we want a better advantage as Republicans, and that's not how it's going to work. But I want to touch on this tobacco thing. I know the President's been puffing a lot on that. But I want to go back to 1965. That was my first vote against tobacco companies when I said we ought to label cigarettes, and I've had a consistent record ever since 1965. We passed a bill in 1992 to encourage the States to adopt programs to stop kids from smoking. All 50 states did it. It took three years. It wasn't until election year, Mr. President, that you ever thought about stopping smoking. What about drugs that have increased—doubled in the last 44 months? Cocaine is up 141 percent—or marijuana; cocaine up 166 percent. And it seems to me that you have a selective memory. Mine doesn't work that way, so I just want to try to correct it as we go along. ",
#  "SENATOR DOLE: Well, I'm really encouraged to know of your renewed friendship with Al D'Amato, and I know he appreciates it. [Laughter] You didn't even have tax cuts in your budget, Mr. President, the first two years you were President. It wasn't until we had a Republican Congress that you even thought about—you talked about tax cuts. And getting back to personal differences, I think, Jim, if you're a little more specific, but I think the President could clarify one thing tonight, and that's the question of pardons. I know you talked about it with Jim Lehrer on the PBS show. And I've never discussed Whitewater, as I've told you personally; I'm not discussing Whitewater now. But I am discussing a power the President has to grant pardons, and hopefully in the next segment you could lay that to rest. ",
#  'SENATOR DOLE: Yes. I didn\'t favor it when it was started. I voted against it. It was a tribute after President Carter\'s election to the National Education Association, who sent a lot of delegates to the Democratic Convention, who give 99.5 percent of their money to Democrats and the President. And a lot of the teachers send their kids to private schools or better public schools. So what we want to do is called opportunity scholarships. Now, some say, "Oh, you\'re Republican; you can\'t be reaching out to these people." I\'ve reached out to people all my life. I\'ve worked on the food stamp program proudly and the WIC program and the school lunch program with Senators like George McGovern, Hubert Humphrey, and others, to name a few of my Democratic friends. I\'m not some extremist out here. I care about people. I have my own little foundation that\'s raised about $10 million for the disabled. I don\'t advertise it—just did, haven\'t before. I try to do a lot of things that I think might be helpful to people. So it seems to me that we ought to take that money we can save from the Department of Education, put it into opportunity scholarships, and tell little Landel Shakespeare out in Cleveland, Ohio, and tell your mother and father you\'re going to get to go to school because we\'re going to match what the State puts up, and you\'re going to get to go to the school of your choice. I don\'t fault the President or the Vice President for sending their children to private schools or better schools; I applaud them for it. I don\'t criticize them. But why shouldn\'t everybody have that choice? Why shouldn\'t low-income Americans and low-middle-income Americans? I\'m excited about it. It\'s going to be a big, big opportunity for a lot of people. ',
#  "SENATOR DOLE: Well, the President can define himself in any way he wants, but I think we have to look at the record. Go back to the time he was, what, Texas director for George McGovern. George McGovern is a friend of mine, so I don't mean—but he was a liberal, proud liberal. I've just finished reading a book. I think it's called, what is it, The Demise of the Democratic Party by Ronald Radosh or something, talking about all the liberal influences in the administration, whether it's organized labor or whether it's the Hollywood elite or whether it's some of the media elite or whether it's the labor unions or whatever. And so I think—you take a look at it, but the bottom line is this",
#  "SENATOR DOLE: Well, my blood pressure is lower and my weight, my cholesterol. But I will not make health an issue in this campaign. [Laughter] I think he's a bit taller than I am. But I think there are personal differences. I mean, I don't like to get into personal matters. As far as I'm concerned, this is a campaign about issues. It's about my vision for America and about his liberal vision for America, and not about personal things. And I think his liberal vision is a thing of the past. I know he wants to disown it. I wouldn't want to be a liberal either, Mr. President, but you're stuck with it because that's your record. It's your record in Arkansas, the biggest tax increase in history, the biggest crime increase in history, biggest drug increase in history in Arkansas. ",
#  "SENATOR DOLE: The President wants to increase spending 20 percent over the next six years. I want to increase spending 14 percent. That's how simple it is. I want the government to pinch pennies for a change, instead of the American families. We're talking about six percentage points over six years. And with that money, you give it back to the working people. You also provide opportunity scholarships so low-income parents will have the same choice that others have in sending their children to better schools. And it will work. And when it does work, Mr. President, I know you will congratulate me.  Campaign Financing ",
#  "SENATOR DOLE: Well, I was disappointed the President did not call for an unconditional end to the violence. I mean, it seemed to me the violence would stop when these leaders came to America. The killing and the tragedies had taken place, and it's unfortunate. And it is a difficult area; no doubt about it. It shouldn't be politicized in any way, by the President or by his opponent, and I don't intend to politicize it. I hope that they have talked, and I hope they've reached some result and that the killing will end.   Vision for the Future ",
#  'SENATOR DOLE: Let me say first on the President\'s promise for another tax cut—I mean, I\'ve told people as I travel around, "All of you who got the tax cut he promised last time, vote for him in \'96," and not many hands go up. So the question is, would you buy a used election promise from my opponent? The people want economic reform. They\'re having a hard time making ends meet. You got one parent working for the government, the other parent working for the family. And this is important business. This is about getting the economy moving again. This is about American jobs and opportunities. It\'s about the government, as I said before, pinching its pennies for a change instead of the poor taxpayer. When they raise your taxes, nobody runs around asking people, "Where are you going to get the extra money?" I think the government can do better. ',
#  "SENATOR DOLE: I think the basic difference is—and I have had some experience in this—I think the basic difference—I trust the people; the President trusts the government. If you go back and look at the health care plan that he wanted to impose on the American people—one-seventh the total economy, 17 new taxes, price controls, 35 to 50 new bureaucracies, a cost of $1.5 trillion. Don't forget that; that happened in 1993. A tax increase that taxed everybody in America, not just the rich. If you made $25,000—that's the original proposal—you got your Social Security taxes increased. We had a BTU tax that turned into a $35 billion gas tax, a $265 billion tax increase. I guess I rely more on the individual. I carry a little card around in my pocket called the 10th Amendment. Where possible, I want to give power back to the States and back to the people. That's my difference for the present, and we'll have specific differences later. He noted a few, but there are others. ",
#  "SENATOR DOLE: Well, the President's own CIA Director says that Saddam is stronger now than he was. And I don't understand extending the no-fly zone in the south when the trouble was in the north. And what we've done—during the Bush administration the Kurds were at the State Department negotiating, trying to work their differences out. Now we've got all—thousands and thousands of refugees. We're even shipping, I guess, 3,000 Kurds to Guam. It involves Turkey. It's a real problem, and Saddam is probably stronger than he ever was. We shot, what, 44 cruise missiles—they're worth about $1.2 million apiece—and hit some radar that—repaired in a couple, three days. Did we inflict any damage? No. Did we have any of our allies helping? Well, we have Great Britain. They're always very loyal to us, and I appreciate that. And of course Kuwait, even though they had to find out they had 5,000 troops coming. They didn't even understand that. We had to get their permission. The bottom line is, we went in there alone. We're supposed to be operating under a U.N. resolution. We did it without any of our allies that helped us in the Gulf. ",
#  "SENATOR DOLE: And I may be better off four years from now. But—[laughter] I don't know, I look at the slowest growth in a century. He inherited a growth of 4.7, 4.8 percent; now it's down to about 2.4 percent. We're going to pass a million bankruptcies this year for the first time in history. We've got stagnant wages; in fact, women's wages have dropped 2.2 percent. Men's wages haven't gone up, gone down. So we have stagnation. We have the highest foreign debt in history. And it seems to me that if you take a look—are you better off? Well, I guess some may be better off. Saddam Hussein is probably better off than he was four years ago. Rene Preval is probably better off than he was four years ago. But are the American people? They're working harder and harder and paying more taxes. For the first time in history, you pay about 40 percent of what you earn, more than you spend for food, clothing, and shelter combined, for taxes under this administration. So some may be better off. They talk about family income being up. That's not true in Connecticut; family income is down. And it's up in some cases because both parents are working; one works for the family, and one works to pay taxes for the Government. We're going to give them a tax cut so they can spend more time with their children, maybe even take a vacation. That's what America is all about. ",
#  'SENATOR DOLE: But it seems to me the President shouldn\'t have any comment at all, particularly where it\'s someone where you\'ve had business dealings. I mean, you may be sending a signal; I don\'t know. I\'m not questioning anybody. But as the President of the United States, when somebody asks you about pardons, you say "no comment," period. And I think he made a mistake, and I think when you make a mistake, you say, "I made a mistake." But apparently his position hasn\'t changed. If there are other specific areas—but beyond that, I haven\'t gotten into any of these things, as the President knows. We\'ve had that discussion. And again, I know Senator D\'Amato I think may have had a hearing or two on Whitewater; I can\'t remember. [Laughter] But he\'s not my general chairman, he\'s a friend of mine. And so is Senator Kennedy a friend of yours... ',
#  "SENATOR DOLE: Well, many of the provisions in the Kassebaum bill were provisions—my provisions, like deductions for long-term care, making certain that self-employed people who are watching tonight can deduct not 30 percent but 80 percent of what you pay for premiums; you can also deduct long-term care now. So it's a good start. I think—we're even looking at our tax cut proposal, our economic package. There may be a way there to reach out to the uninsured, because there are a lot of uninsured people in this country, particularly children, that should be covered. Another way you can do it is to expand Medicaid. In America, no one will go without health care, no one will go without food... ",
#  "SENATOR DOLE: That's not true. ",
#  "SENATOR DOLE: Let me first answer that question about the 1982 tax cut. You know, we were closing loopholes; we were going after big corporations. I know you probably would oppose it, Mr. President, but I think we should have a fairer system and a flatter system. And we will have a fairer, flatter system, and we're going to make the economic package work. Health care",
#  'SENATOR DOLE: And so will the former President, yes. [Laughter] ',
#  "SENATOR DOLE: I had better correct the President. I don't know what time it is, but it's probably getting late. But I want to correct—all of these things I voted against, they were probably part of some big package that had a lot of pork in it, or a lot of things that we shouldn't have had, and we probably voted no. I've supported all of the education programs; I've supported Head Start. I think we ought to look at it. So I don't want anybody out there to think that we've just been voting no, no, no. Let's give low-income parents the same right that people of power and prestige have in America and let them go to better schools. Let's turn the schools back to the teachers and back to the parents and take it away from the National Education Association. ",
#  "SENATOR DOLE: I doubt that I acknowledged that this year, but in any event, I think we just look at the facts. We ask the people that are viewing tonight, “Are you better off than you were four years ago?” It's not whether we're better off; it's whether they're better off. Are you working harder to put food on the table, to feed your children? Are your children getting a better education? Drug use has doubled the past 44 months all across America. Crime has gone down, but it's because of mayors like Rudy Giuliani, where one-third of the drop happened in one city, New York City. So, yes, some may be better off. But of the people listening tonight, the working families who will benefit from our economic package, they'll be better off when Bob Dole is President and Jack Kemp is Vice President.  Medicare Reform ",
#  "SENATOR DOLE: What's the subject matter? [Laughter] ",
#  "SENATOR DOLE: Well, I have a different view again. I've supported the President on Bosnia. And I think we were told the troops would be out in a year. Now I understand it's been extended 'til sometime next year. But let's start with Somalia, where they dragged Americans through the streets and where 18 Americans were killed one day because they didn't have—they were pinned down for eight hours, the Rangers; they didn't have the weapons; they didn't have the tanks. They asked for the tanks. They didn't get the tanks from this administration, because we were nation building. It's called mission creep. We turn it over to the United Nations. The President didn't have much to do about it. Look at Haiti where we've spent about $3 billion, and we got an alarm call there about two weeks ago",
# ...
#  'WAR. SIR: It has been represented to this Department that in October last a military commission was appointed to settle upon some general plan of defense for the Texas frontiers, and that the said commission has made a report recommending a line of posts from the Rio Grande to the Red River. An application is now pending in this Department for a change in the course of the San Antonio and El Paso mail, so as to send it by way of Forts Mason, Griffin, and Stockton instead of Camps Hudson and Lancaster. This application requires immediate decision, but before final action can be had thereon it is desired to have some official information as to the report of the commission above referred to. Accordingly, I have the honor to request that you will cause this Department to be furnished as early as possible with the information desired in the premises, and also with a copy of the report, if any has been made by the commission. Very respectfully, etc., GEORGE. W. McLELLAN, Second Assistant Postmaster-General. FEBRUARY 3, 1868. Referred to the General of the Army for report. EDWIN M. STANTON, Secretary of War. TREASURY DEPARTMENT, January, 29 1868. The Honorable SECRETARY OF ',
#  'MR. SHADEL: Senator Kennedy? ',
#  'MR. SHADEL: The next question is by Mr. Cater for Senator Kennedy. ',
#  "MR. SHADEL: And now to meet the panel of correspondents. Frank McGee, NBC News; Charles Van Fremd, CBS News; Douglass Cater, Reporter magazine; Roscoe Drummond, New York Herald Tribune. Now, as you've probably noted, the four reporters include a newspaper man and a magazine reporter; these two selected by lot by the press secretaries of the candidates from among the reporters traveling with the candidates. The broadcasting representatives were chosen by their companies. The rules for this evening have been agreed upon by the representatives of both candidates and the radio and television networks and I should like to read them. There will be no opening statements by the candidates nor any closing summation. The entire hour will be devoted to answering questions from the reporters. Each candidate to be questioned in turn with opportunity for comment by the other. Each answer will be limited to two and one-half minutes, each comment to one and a half minutes. The reporters are free to ask any question they choose on any subject. Neither candidate knows what questions will be asked. Time alone will dete- determine who will be asked the final question. Now the first question is from Mr. McGee and is for Senator Kennedy. ",
#  'MR. SHADEL: Senator, your comment. ',
#  'MR. SHADEL: Mr. McGee has the next question for Senator Kennedy. ',
#  'MR. SHADEL: Mr. Von Fremd has a question for Senator Kennedy. ',
#  "MR. SHADEL: Mr. Drummond's question is for Senator Kennedy. ",
#  'MR. SHADEL: Mr. Vice President? ',
#  'MR. SHADEL: Mr. Vice President, do you wish to comment? ',
#  "MR. SHADEL: Mr. Cater's question is for Vice President Nixon. ",
#  'MR. SHADEL: Thank you gentlemen. As we mentioned at the opening of this program, the candidates agreed that the clock alone would determine who had the last word. The two candidates wish to thank the networks for the opportunity to appear for this discussion. I would repeat the ground rules likewise agreed upon by representatives of the two candidates and the radio and television networks. The entire hour was devoted to answering questions from the reporters. Each candidate was questioned in turn and each had the opportunity to comment on the answer of his opponent. The reporters were free to ask any question on any subject. Neither candidate was given any advance information on any question that would be asked. Those were the conditions agreed upon for this third meeting of the candidates tonight. Now I might add that also agreed upon was the fact that when the hour got down to the last few minutes, if there was not sufficient time left for another question and suitable time for answers and comment, the questioning would end at that point. That is the situation at this moment. And after reviewing the rules for this evening I might use the remaining moments of the hour to tell you something about the other arrangements for this debate with the participants a continent apart. I would emphasize first that each candidate was in a studio alone except for three photographers and three reporters of the press and the television technicians. Those studios identical in every detail of lighting, background, physical equipment, even to the paint used in decorating. We newsmen in a third studio have also experienced a somewhat similar isolation. Now, I would remind you the fourth in the series of these historic joint appearances, scheduled for Friday, October twenty-first. At that time the candidates will again share the same platform to discuss foreign policy. This is Bill Shadel. Goodnight.',
#  'MR. SHADEL: Senator Kennedy, do you wish to comment? ',
#  'MR. SHADEL: Mr. Vice President, your comment? ',
#  'MR. SHADEL: The next question is by Mr. Drummond for Vice President Nixon. ',
#  'MR. SHADEL: Mr. Cater has the next question for Senator Kennedy. ',
#  'MR. SHADEL: Gentlemen, if I may remind you, time is growing short, so please keep your questions and answers as brief as possible consistent with clarity. Mr. Von Fremd for Vice President Nixon. ',
#  'MR. SHADEL: The next question is by Mr. Von Fremd for Vice President Nixon. ',
#  'MR. SHADEL: And good evening to you, Vice President Nixon. ',
#  'MR. SHADEL: Mr. Vice President. ',
#  "MR. SHADEL: Mr. Drummond's question now for Senator Kennedy. ",
#  "MR. SHADEL: Next, Mr. Drummond's question for Vice President Nixon. ",
#  'MR. SHADEL: Senator Kennedy. ',
#  'MR. SHADEL: Any comment, Mr. Vice President? ',
#  'MR. SHADEL: Mr. McGee has a question for Vice President Nixon. ',
#  'CROWD: USA! USA! USA! TRUMP',
#  'LEADER RYAN: And Don Young. ',
#  "MR. KONDRACKE: I want to follow up on Mr. Kalb's question. It seems to me on the question of verifiability, that you do have some problems with the extent of the freeze. It seems to me, for example, that testing would be very difficult to verify because the Soviets encode their telemetry. Research would be impossible to verify. Numbers of warheads would be impossible to verify by satellite, except for with on-site inspection, and production of any weapon would be impossible to verify. Now, in view of that, what is going to be frozen? ",
#  'MR. KONDRACKE: Mr. President, I want to ask you a question about negotiating with friends. You severely criticized President Carter for helping to undermine two friendly dictators who got into trouble with their own people—the Shah of Iran and President Somoza of Nicaragua. Now there are other such leaders heading for trouble, including President Pinochet of Chile and President Marcos of the Philippines. What should you do, and what can you do to prevent the Philippines from becoming another Nicaragua? ',
#  "MR. KONDRACKE: You've been quoted as saying that you might quarantine Nicaragua. I'd like to know what that means. Would you stop Soviet ships, as President Kennedy did in 1962? And wouldn't that be more dangerous than President Reagan's covert war? ",
#  'MR. KONDRACKE: And what would you do about it? ',
#  "MR. KONDRACKE: Mr. President, four years ago you criticized President Carter for ignoring ample warnings that our diplomats in Iran might be taken hostage. Haven't you done exactly the same thing in Lebanon, not once, but three times, with 300 Americans, not hostages, but dead? And you vowed swift retaliation against terrorists, but doesn't our lack of response suggest that you're just bluffing? ",
#  'MR. KONDRACKE: Mr. President, since the United States has two strategically important bases in the Philippines, would the overthrow of President Marcos constitute a threat to vital American interests and, if so, what would you do about it? ',
#  "MR. KONDRACKE: Mr. Mondale, you say that with respect to the Soviet Union you want to negotiate a mutual nuclear freeze, yet you would unilaterally give up the MX missile and the B-1 bomber before the talks have even begun. And you have announced, in advance, that reaching an agreement with the Soviets is the most important thing in the world to you. Now, aren't you giving away half the store before you even sit down to talk? ",
#  'MR. KONDRACKE: Mr. Mondale, in an address earlier this year you said that before this country resorts to military force, and I\'m quoting, "American interests should be sharply defined, publicly supported, congressionally sanctioned, militarily feasible, internationally defensible, open to independent scrutiny, and alert to regional history." Now, aren\'t you setting up such a gauntlet of tests here that adversaries could easily suspect that as President you would never use force to protect American interests? ',
#  "MR. KONDRACKE: President Reagan, you introduced U.S. forces into Lebanon as neutral peacekeepers, but then you made them combatants on the side of the Lebanese government. Eventually you were forced to withdraw them under fire, and now Syria, a Soviet ally, is dominant in the country. Doesn't Lebanon represent a major failure on the part of your administration and raise serious questions about your capacity as a foreign policy strategist and as Commander in Chief?. ",
#  'MR. SCHWAB: Thank you. Thank you very much, Mr. President, for being with us. The World Economic Forum community, who is assembled here, will be certainly—and I quote you from the last piece of your remarks—will be certainly among “the hardworking men and women who do their duty each and every day making this world a better place for everyone.” Thank you very much for being with us. ',
#  'MR. SCHWAB: Thank you, Mr. President, for this inspiring speech. As it is tradition at the forum, I will ask you one or two questions. And my first question is, why is the tax reform —why has it been of such a high priority for your administration? ',
#  "MR. SCHWAB: Mr. President, I will ask you, maybe, a personal question. But before doing so, I'd just like to— ",
#  'MR. SCHWAB: —who tremendously contributed to the discussions the last (inaudible). ',
#  'MR. SCHWAB: I would like to acknowledge the strong presence of your Cabinet members ',
#  'MR. SCHWAB: Now my, maybe personal, question would be',
#  'MR. SCHWAB: —acknowledge that— ',
#  'MR. SCHWAB: Yeah. Now— ',
#  'AIDE:  Yes, we do.  There you go. Q    You were prepared.  Mr. President, a lot of the money — ',
#  'QUINCY HOWE, MODERATOR: I am Quincy Howe of ABC News saying good evening from New York where the two major candidates for president of the United States are about to engage in their fourth radio-television discussion of the present campaign. Tonight these men will confine that discussion to foreign policy. Good evening, Vice President Nixon. ',
#  "MS. RIDINGS: Good evening from the Municipal Auditorium in Kansas City. I am Dorothy Ridings, the president of the League of Women Voters, the sponsor of this final Presidential debate of the 1984 campaign between Republican Ronald Reagan and Democrat Walter Mondale. Our panelists for tonight's debate on defense and foreign policy issues are Georgie Anne Geyer, syndicated columnist for Universal Press Syndicate; Marvin Kalb, chief diplomatic correspondent for NBC News; Morton Kondracke, executive editor of The New Republic magazine; and Henry Trewhitt, diplomatic correspondent for the Baltimore Sun. Edwin Newman, formerly of NBC News and now a syndicated columnist for King Features, is our moderator. Ed. ",
#  'VOICE: This will allow three minutes and twenty seconds for the summation by each candidate. ',
#  'MR. CRONKITE: Senator, the charge has been made frequently that the United States for many years has been on the defensive around the world, that our policy has been uh - one of reaction to the Soviet Union rather than positive action on our own. What areas do you see where the United States might take the offensive in a challenge to Communism over the next four to eight years? ',
#  'MR. CRONKITE: Thank you Quincy. Mr. Vice President, Senator Fulbright and now tonight, Senator Kennedy, maintain that the Administration is suppressing a report by the United States Information Agency that shows a decline in United States prestige overseas. Are you aware of such a report, and if you are aware of the existence of such a report, should not that report, because of the great importance this issue has been given in this campaign, be released to the public? ',
#  'EDM: RANDOLPF',
#  'MR. NEWMAN: President Reagan, your rebuttal? ',
#  'MR. NEWMAN: Mr. Kalb, your question to President Reagan.   Soviet Union ',
#  "MR. NEWMAN: I'm sorry, sir— ",
#  'MR. NEWMAN: No applause, please. Mr. Kalb, your question to President Reagan.   Armageddon ',
#  "MR. NEWMAN: I'm sorry, Mr. President. Sir, your time was up. ",
#  "MR. NEWMAN: Mr. President, I'm obliged to cut you off there under the rules of the debate. I'm sorry. ",
#  'MR. NEWMAN: One question to each candidate.   Nuclear Weapons ',
#  "MR. NEWMAN: Mr. Trewhitt, your question to President Reagan?   The President's Age ",
#  "MR. NEWMAN: Thank you, Mr. President. Thank you, Mr. Mondale. Our thanks also to the panel, finally, to our audience. We thank you, and the League of Women Voters asks me to say to you, don't forget to vote on November 6.",
#  'MR. NEWMAN: I would ask the audience not to applaud. All it does is take up time that we would like to devote to the debate. Mr. Kondracke, your question to Mr. Mondale.   Use of Military Force ',
#  'MR. NEWMAN: Ms. Geyer, your question to Mr. Mondale.   Illegal Immigration ',
#  'MR. NEWMAN: — with the League, as you know, sir. ',
#  'MR. NEWMAN: Your time is up, Mr. Mondale. ',
#  'MR. NEWMAN: Perhaps I should point out that the rules under which I did that were agreed upon by the two campaigns— ',
#  'MR. NEWMAN: President Reagan, your summation, please. ',
#  'MR. NEWMAN: Mr. Mondale, your rebuttal. ',
#  'MR. NEWMAN: President Reagan, your rebuttal. ',
#  'MR. NEWMAN: Mr. Mondale, your rebuttal? ',
#  'MR. NEWMAN: Mr. President, your rebuttal. ',
#  "MR. NEWMAN: Sorry. I'm sorry, you've asked the followup question. Mr. Mondale, your rebuttal? ",
#  'MR. NEWMAN: In this segment, because of the pressure of time, there will be no rebuttals, and there will be no followup questions. Mr. Trewhitt, your question to President Reagan. ',
#  "MR. NEWMAN: Dorothy Ridings, thank you. A brief word about our procedure tonight. The first question will go to Mr. Mondale. He'll have two and a half minutes to reply. Then the panel member who put the question will ask a followup. The answer to that will be limited to one minute. After that, the same question will be put to President Reagan. Again, there will be a followup. And then each man will have one minute for rebuttal. The second question will go to President Reagan first. After that, the alternating will continue. At the end there will be four-minute summations, with President Reagan going last. We have asked the questioners to be brief. Let's begin. Ms. Geyer, your question to Mr. Mondale.   Central America ",
#  'MR. NEWMAN: Mr. President, your rebuttal? ',
#  'MR. NEWMAN: Mr. Kondracke, your question to Mr. Mondale.   Strategic Weapons ',
#  "MR. NEWMAN: Please, I must again ask the audience not to applaud, not to cheer, not to demonstrate its feelings in any way. We've arrived at the point in the debate now where we call for closing statements. You have the full four minutes, each of you. Mr. Mondale, will you go first?   Closing Statements ",
#  'Audience: No-o-o!  President Clinton',
#  'Audience: Four more years! Four more years! Four more years!  President Clinton']

# %%
# For each transcript, iterate through sayings and remove and if they are present
for row in tqdm(speeches.itertuples()):
    index = row[0]
    transcript = row[5]
    
    for saying in non_president_speaker_sayings:
        if saying in transcript:
            speeches.Transcript[index] = speeches.Transcript[index].replace(saying, ' ')
# Out:
# 0it [00:00, ?it/s]/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 992it [00:08, 112.38it/s]

# %%
# Examine remaining speakers not cleaned up
remaining_speakers = []
for row in tqdm(speeches.itertuples()):
    transcript = row[5]
    for non_president in non_president_speakers:
        if non_president in transcript and non_president not in remaining_speakers:
            remaining_speakers += [non_president]
remaining_speakers
# Out:
# 992it [00:00, 1543.43it/s]
# ['AUDIENCE MEMBER:', 'LEHRER:', 'DUKAKIS:', 'PRESIDENT. SIR:', 'WAR. SIR:']

# %%
# Get remaining non-presidential speakers
remaining_non_president_speakers = []
for speaker in remaining_speakers:
    remaining_non_president_speakers += clean_removable_speaker_text(speaker, all_speakers)

# %%
# Removing remaining sayings
for row in tqdm(speeches.itertuples()):
    index = row[0]
    transcript = row[5]
    
    for saying in remaining_non_president_speakers:
        if saying in transcript:
            speeches.Transcript[index] = speeches.Transcript[index].replace(saying, ' ')
# Out:
# 0it [00:00, ?it/s]/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 992it [00:00, 8109.82it/s]

# %%
# Examine remaining speakers not cleaned up again
remaining_speakers = []
for row in tqdm(speeches.itertuples()):
    transcript = row[5]
    for non_president in non_president_speakers:
        if non_president in transcript and non_president not in remaining_speakers:
            remaining_speakers += [non_president]
            
remaining_speakers
# Out:
# 992it [00:00, 1599.67it/s]
# ['PRESIDENT. SIR:']

# %%
# Removing presidents
for row in tqdm(speeches.itertuples()):
    index = row[0]
    transcript = row[5]
    
    for president in president_speakers:
        if president in transcript:
            speeches.Transcript[index] = speeches.Transcript[index].replace(president, ' ')
# Out:
# 0it [00:00, ?it/s]/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 992it [00:00, 8055.54it/s]

# %%
speeches
# Out:
#           Date          President  \
# 0   2019-09-25       Donald Trump
# 1   2019-09-24       Donald Trump
# 2   2019-02-15       Donald Trump
# 3   2019-02-05       Donald Trump
# 4   2019-01-19       Donald Trump
# ..         ...                ...
# 987 1790-12-29  George Washington
# 988 1790-12-08  George Washington
# 989 1790-01-08  George Washington
# 990 1789-10-03  George Washington
# 991 1789-04-30  George Washington
#
#                                           Speech Title  \
# 0                                     Press Conference
# 1       Remarks at the United Nations General Assembly
# 2                Speech Declaring a National Emergency
# 3                           State of the Union Address
# 4                 Remarks about the US Southern Border
# ..                                                 ...
# 987  Talk to the Chiefs and Counselors of the Senec...
# 988                  Second Annual Message to Congress
# 989                   First Annual Message to Congress
# 990                          Thanksgiving Proclamation
# 991                            First Inaugural Address
#
#                                                Summary  \
# 0    President Donald Trump holds a press conferenc...
# 1    President Donald Trump speaks to the 74th sess...
# 2    President Donald Trump declares a national eme...
# 3    In his second State of the Union Address, Pres...
# 4    President Donald Trump speaks about what he se...
# ..                                                 ...
# 987  The President reassures the Seneca Nation that...
# 988  Washington focuses on commerce in his second a...
# 989  In a wide-ranging speech, President Washington...
# 990  At the request of Congress, Washington establi...
# 991  Washington calls on Congress to avoid local an...
#
#                                             Transcript  \
# 0        Thank you very much.  Thank you. Well, tha...
# 1        Thank you very much.  Mr. President, Mr. S...
# 2        Thank you very much, everybody.  Before we...
# 3      Madam Speaker, Mr. Vice President, Members o...
# 4       Just a short time ago, I had the honor of p...
# ..                                                 ...
# 987   I the President of the United States, by my o...
# 988   Fellow citizens of the Senate and House of Re...
# 989  Fellow Citizens of the Senate and House of Rep...
# 990  Whereas it is the duty of all Nations to ackno...
# 991  Fellow Citizens of the Senate and the House of...
#
#                                                    URL
# 0    https://millercenter.org/the-presidency/presid...
# 1    https://millercenter.org/the-presidency/presid...
# 2    https://millercenter.org/the-presidency/presid...
# 3    https://millercenter.org/the-presidency/presid...
# 4    https://millercenter.org/the-presidency/presid...
# ..                                                 ...
# 987  https://millercenter.org/the-presidency/presid...
# 988  https://millercenter.org/the-presidency/presid...
# 989  https://millercenter.org/the-presidency/presid...
# 990  https://millercenter.org/the-presidency/presid...
# 991  https://millercenter.org/the-presidency/presid...
#
# [992 rows x 6 columns]

# %%
transcript_tokens = list(set(get_transcript_tokens(speeches.Transcript, 50, -1, True)))
print(len(transcript_tokens))
# Out:
# Processing batch 1/20
# Processing batch 2/20
# Processing batch 3/20
# Processing batch 4/20
# Processing batch 5/20
# Processing batch 6/20
# Processing batch 7/20
# Processing batch 8/20
# Processing batch 9/20
# Processing batch 10/20
# Processing batch 11/20
# Processing batch 12/20
# Processing batch 13/20
# Processing batch 14/20
# Processing batch 15/20
# Processing batch 16/20
# Processing batch 17/20
# Processing batch 18/20
# Processing batch 19/20
# Processing batch 20/20
# 11533

# %% [markdown]
# #### Clean transcript tokens by replacing all  EM dashes, '—', with a comma followed by a space

# %%
tokens_before = [token for token in transcript_tokens if '—' in token]
tokens_after = [token.replace('—', ', ') for token in tokens_before]

# Zip pairs into before and after tuples
em_dash_tokens = list(zip(tokens_before, tokens_after))

# Update dictionary and transcript tokens
clean_dict = update_dict(clean_dict, em_dash_tokens)
transcript_tokens = list(set(transcript_tokens).difference(set([a for (a,b) in set(em_dash_tokens)])))

# %% [markdown]
# > ##### 1. Hyphens <a id='4_4_5_hyphens_id'></a>

# %%
# Examine all tokens with hyphens 
hyphen_tokens_list = [token for token in transcript_tokens if '-' in token]
hyphen_tokens = hyphen_tokens_list.copy()
print(len(hyphen_tokens))
hyphen_tokens
# Out:
# 4747
# ['Vice-Presidency',
#  'self-protection',
#  'pass-throughs',
#  'employer-provided',
#  'lower-paid',
#  'control-moves',
#  '1920--and',
#  'non-Marxist',
#  '1865.--Revolution',
#  'time-lag',
#  'States-a',
#  'double-digit',
#  'self-confidence',
#  'Presidents-President',
#  'follow-the-leader',
#  'all-black',
#  '-Japan',
#  'Tsung-li',
#  'record-keeping',
#  'islands-----------------------------------------------',
#  'argument---some',
#  'across-the-board',
#  'upside-down',
#  'all-absorbing',
#  '5-ambulatory',
#  'half-a',
#  'Island----------------------------------------------------------',
#  'last-named',
#  'that--',
#  'otherwise-or',
#  'that-nothing',
#  'legend-such',
#  'dominate-which',
#  'common-law',
#  'SS-5',
#  'vice-admiral',
#  'everything-including',
#  '1--The',
#  'Canada----------',
#  'fugitive-slave',
#  'shop-worn',
#  'Communist-dominated',
#  'Total--------------------------',
#  'one-twelfth',
#  'two-tenths',
#  '--Moreover',
#  'four-square',
#  'eighty-two',
#  'medium-sized',
#  'save-later',
#  'vice-consul',
#  'Ten-forties',
#  'over-crowding',
#  'barbed-wire',
#  'follow-everyone',
#  'problems-will',
#  'well-doing',
#  'surveyors-general',
#  'Once-bitter',
#  'trick-or-treat',
#  'long-held',
#  'people-are',
#  '1902.--Revolution',
#  'free-spending',
#  'nation-wide',
#  'down-to-earth',
#  'paper-thin',
#  'pre-eminent',
#  'freedom-the',
#  'sugar-cane',
#  'behind-the-scenes',
#  'President-that',
#  'home-maker',
#  'twenty-first',
#  '31,280,372-----------------------E',
#  'highest-ranking',
#  'of-----------------------------------------------',
#  'provost-marshals',
#  'church-supported',
#  '--Our',
#  'organization-the',
#  'self-constitution',
#  '1,221,956,620-----------------',
#  'were--',
#  'One-fourth',
#  '1878.--Revolt',
#  'state-of-the-art',
#  'war-seeking',
#  'work-plan',
#  'cyber-threats',
#  'unanimity-and',
#  'moisture-laden',
#  '1851.--Outbreak',
#  'reasons-their',
#  'slaves---being',
#  'tie-ups',
#  'Egyptian-Israeli',
#  'question-and',
#  'non-British',
#  'nuclear-armed',
#  'ever-widening',
#  'court-martial',
#  'back-alley',
#  'God-awful',
#  'Total---------------------------',
#  'flint-lock',
#  'present-year',
#  'Island------------------------------------------------------------------',
#  'fake-news',
#  'horse-trading',
#  '1903--9:15',
#  'better-equipped',
#  'Fifty-seventh',
#  "reorganization-I'd",
#  'war-ravaged',
#  'service-pension',
#  'all-embracing',
#  'passion---a',
#  'summer-the',
#  '20-point',
#  'action-to',
#  'half-clad',
#  'mustering-out',
#  'Humphrey-Hawkins',
#  'LATIN-AMERICAN',
#  'near-by',
#  '1,719,428,069----------',
#  'twenty-second',
#  'hard-hit',
#  'Attorney-General',
#  'self-centered',
#  'foreigners-as',
#  'top-level',
#  'Thirty-six',
#  'sensation-mongers',
#  'law-enforcement',
#  'ground-to-air',
#  'U.S.-Soviet',
#  'Rear-Admiral',
#  'post---the',
#  'forty-second',
#  'peace-keeping',
#  '1851.--Revolution',
#  'installations-and',
#  'Thirty-five',
#  'tax-exempt',
#  'interest--------------------------------------',
#  'open-door',
#  'sweated-labor',
#  'al-Suhail',
#  'STABT-Strategic',
#  'involved-I',
#  'mail-order',
#  'hydrogen-powered',
#  'feet-of',
#  'Thirty-eighth',
#  'much-debated',
#  'self-containment',
#  '125,775.00-',
#  're-enforced',
#  'andlaw-abiding',
#  'Free-market',
#  'full-fledged',
#  '--not',
#  'built-in',
#  'bank-note',
#  'undreamed-of',
#  'ground-launch',
#  'same-sex',
#  'habit-forming',
#  '3-minute',
#  'Low-tax',
#  'lake-bed',
#  '1-yard',
#  'dry-dock',
#  'country-could',
#  'front-page',
#  'white-man',
#  'English-speaking',
#  'post-racial',
#  'self-protecting',
#  'III-C',
#  '1885.--Revolutionary',
#  'ground-work',
#  'uh-oh',
#  'Congo-Kinshasa',
#  'co-operations',
#  'Tsai-tao',
#  'fund-raising',
#  '16-inch-type',
#  'ill-concerted',
#  'take-it-or-leave-it',
#  'direction-not',
#  'Yang-Tse',
#  'Marxist-Leninists',
#  '1882--',
#  '1859.--Riots',
#  'NAVY-YARDS',
#  'war-worn',
#  '1835--a',
#  'house-to-house',
#  'ill-fitting',
#  'sorghum-sugar',
#  'co-chairs',
#  'nationally-aided',
#  'up-to-date',
#  'examinations.--For',
#  '50-cent-a-gallon',
#  'thirty-four',
#  's-',
#  'non-partisan',
#  'deep-graven',
#  'war-strained',
#  'arm-in-arm',
#  'Mansfield-Scott',
#  'high-powered',
#  'high-value',
#  'background-not',
#  'Quissibis----------------------------------------------------------------------',
#  'catch-and',
#  'Faith-based',
#  'wide-sweeping',
#  '581,813---while',
#  'family-wage',
#  'Nazi-ism',
#  'resources-militarily',
#  '--to',
#  'two-part',
#  'on-14(b',
#  'high-strength',
#  '15-year-olds',
#  'condition--',
#  'Illinois---that',
#  'Berlin-and',
#  'beverages-------------------------------------------------',
#  'over-exposure',
#  'higgledy-piggledy',
#  'food-producing',
#  'water-power',
#  'be-the',
#  'Reagan-Kemp-Roth',
#  're-tool',
#  'here---that',
#  '--I',
#  'Oil-producing',
#  'right-to-work',
#  'permit---prohibiting',
#  'check-dams',
#  'workers-whose',
#  'home-makers',
#  'term-within',
#  'of-he',
#  'law-makers',
#  'quarter-million',
#  'air-raid',
#  'slave-trade---that',
#  'over-looked',
#  'Sino-Soviet',
#  'rubber-check',
#  'North-South',
#  '--during',
#  'ninety-fourth',
#  'Short-term',
#  'Clayton-Bulwer',
#  'shorter-range',
#  'host-nation',
#  'administration-and',
#  'fair-share',
#  'service---the',
#  'equal-handed',
#  'South-Carolina',
#  'ahead--',
#  'unemployment-which',
#  'SS-20',
#  'multiple-warhead',
#  'market-oriented',
#  'much-loved',
#  'second-tier',
#  'them-in',
#  'Forty-ninth',
#  'courts-martial',
#  'experimental-station',
#  'so-called',
#  'Qaeda-Iraq',
#  'anti-trust',
#  'Manila-Hongkong',
#  'All-time',
#  'Bunau-Varilla',
#  'Middleton-Doctor',
#  'battle-front',
#  'lemon-box',
#  'tree-cutting',
#  'flat-out',
#  'three-way',
#  'pre-emptions',
#  'three-tenths',
#  'people-housewives',
#  'F-14',
#  'capital-intensive',
#  'third-year',
#  'non-nuclear',
#  '40,000-odd',
#  'seventy-eight',
#  'Government-owned',
#  'Union-men',
#  'on-site',
#  'sub-agencies',
#  'well-educated',
#  'Silks-----------------------------------------------------------------------',
#  'President-to-be',
#  're-ignite',
#  'thirty-six',
#  '1791.--Copy',
#  'tax-free',
#  'us-and',
#  'by-word',
#  'left-wing',
#  'office-seeker',
#  'cold-blooded',
#  'commitments-the',
#  'newly-agreed',
#  'pooh-poohed',
#  'all-weather',
#  'old-timers',
#  'Nine-eleven',
#  'freedom-loving',
#  'open-handed',
#  'following-named',
#  '45-year',
#  'U.S.-Panamanian',
#  'secondly--',
#  'ninety-three',
#  'over-producing',
#  'tenure-of-office',
#  'Hawaiian-Japanese',
#  'father-land',
#  'provide--',
#  'not---cannot',
#  'oil-for-food',
#  'throw-weight',
#  'prospective---north',
#  'short-range',
#  'cost-plus-fixed',
#  'judgment--',
#  'Seventy-six',
#  'forty-three',
#  'forty-third',
#  'Alsace-Lorraine',
#  '90-day',
#  'U.S.-Mexico-Canada',
#  'State-administered',
#  'labor-must',
#  '--As',
#  'big-power',
#  'risk-adverse',
#  'Sundries---------------------------------------------------',
#  'fruit-growing',
#  'repudiated---discarded',
#  'whole-hearted',
#  'go---is',
#  'Inter-American',
#  '16-inch',
#  'heart-warming',
#  'of--',
#  'D-day',
#  'over-zealous',
#  'battle-lines',
#  'growth-if',
#  'over-clouded',
#  'carefully-drafted',
#  'risk-taking',
#  'television-if',
#  'self-evident',
#  'friend---brother',
#  'by-the',
#  'possibility-he',
#  'decades-long',
#  'boundary-survey',
#  'fur-seal',
#  'PostMaster-General',
#  'man-made',
#  'Missouri---and',
#  'of-----------------------',
#  'budget-cutting',
#  'three-quarter',
#  'Law-clerk',
#  'did-not',
#  'islands-------------------------',
#  'excess-profits',
#  'coal-fired',
#  'ever-glorious',
#  'Congress--"more',
#  'pre-embryo',
#  'American-owned',
#  'corn-hog',
#  '200-year-old',
#  'long-sought',
#  'ever-shifting',
#  'know-how',
#  'thirty-two',
#  'fine-tuned',
#  'long-established',
#  'take-the-hindermost',
#  'tide-water',
#  'wage-workers',
#  'sixty-eight',
#  'would-be',
#  'administration-helped',
#  'States-besides',
#  'do-nothing',
#  'good-hearted',
#  'forty-eighth',
#  'statesmen-authors',
#  'fee-simple',
#  'sugar-producing',
#  'well-stocked',
#  'much-discussed',
#  'Federally-funded',
#  'Gramm-Rudman-Hollings',
#  'Panama-Pacific',
#  '--Not',
#  'awe-inspiring',
#  'offense--',
#  'navy-yards',
#  'money,-expenditures',
#  'fresh-water',
#  'holier-than-thou',
#  'timber-culture',
#  'non-member',
#  '3-point',
#  'burnt-out',
#  'wide-spread',
#  'self-serving',
#  'statement-has',
#  'war-weary',
#  'under-rate',
#  'Solicitor-General',
#  'ready-to-work',
#  'co-operationwith',
#  'seventy-three',
#  'representatives---being',
#  'principle---do',
#  'klieg-lights',
#  'out-build',
#  'anever-increasing',
#  'well-attested',
#  'first-time',
#  'non-service-connected',
#  'emergencies-nor',
#  'it---to',
#  'well-guarded',
#  'constitution---during',
#  'two-thirds',
#  'under-',
#  'Allies-in',
#  'bounty-land',
#  're-entering',
#  'servants--',
#  'self-improvement',
#  'resource"--of',
#  'America--------------------------',
#  'well-organized',
#  'snow-covered',
#  'high-license',
#  'self-definition',
#  'this-',
#  'ninety-first',
#  'Lieutenant-Commander',
#  'stand-up',
#  'master-race',
#  'drivers-to',
#  '1866.--Unsuccessful',
#  'tr-',
#  'elbow-to-elbow',
#  'objects-that',
#  'islands-------------------------------------------------------------',
#  'fire-arm',
#  'money-order',
#  'toll-free',
#  'Austria-Hungary',
#  'building-up',
#  '--our',
#  'low-rental',
#  '35-percent',
#  'drug-resistant',
#  'future,---',
#  'Suz-ahn',
#  'shell-fish',
#  '50-hour',
#  'anti-poverty',
#  'non-American',
#  'navy-yards15,283,437.17For',
#  'text-books',
#  'co-inciding',
#  'self-comprehension',
#  'over-issues',
#  'change-where',
#  '1808---the',
#  'over-anxious',
#  'one-interest',
#  'State-an',
#  'boll-weevil',
#  'defied-pledges',
#  'hard-working',
#  'tin-plate',
#  'Arab-Israeli',
#  '--when',
#  'above-mentioned',
#  'Post-offices',
#  'long-suffering',
#  'well-merited',
#  'nine-tenths',
#  'B-l',
#  'eight-year-old',
#  'Re-employment',
#  'zoot-suiters',
#  'back-to-school',
#  'Re-enlistment',
#  'sub-districts',
#  'rusted-out',
#  'Mazar-e-Sharif',
#  'self-disciplined',
#  'middle-class',
#  'lieutenant-commanders',
#  'three-star',
#  'of-------------------',
#  'government-approved',
#  'clear-eyed',
#  'plenipotentiaries--',
#  '60,000,000--a',
#  'light-hearted',
#  'high-school',
#  'broad-based',
#  'Civil-Service',
#  'entered--30',
#  'settlers-on',
#  'God-imposed',
#  '1-year-old',
#  'longest-serving',
#  'ill-clad',
#  'soul-stifling',
#  '-because',
#  'Pan-Americanism',
#  'years-we',
#  'double-talk',
#  'one-fourth',
#  '5?-percent',
#  'semi-arid',
#  'Federal-highway',
#  'amount-',
#  'post-graduate',
#  'price-',
#  'far-off',
#  '--90',
#  '-ire',
#  'north-eastern',
#  'north-west',
#  'inter-American',
#  'multi-party',
#  'ceased---that',
#  'servant-Jim',
#  'President-as',
#  'air-lift',
#  'aspirations-have',
#  'East-mark',
#  'conscience-impelled',
#  'hard-core',
#  'right-minded',
#  'justice-justice',
#  'people-consistent',
#  'non-essential',
#  'above-named',
#  'one-term',
#  'penetration-then',
#  'life-changing',
#  'self-described',
#  'extreme---against',
#  'fire-proof',
#  '4-or',
#  'Egypt-Saudi',
#  'over-all',
#  '265,093--a',
#  'Dar-Es-Salaam',
#  'life-extending',
#  'steam-shovel',
#  'Government-regulated',
#  'politico-geographical',
#  'convictions-can',
#  'and-towns',
#  'gur-reat',
#  'work-study',
#  'ever-advancing',
#  'Communists-',
#  'commissioner-general',
#  'hesitate-all',
#  'justice--',
#  'man-one',
#  'well-known',
#  'tax-deferred',
#  'adoption---that',
#  'thirty-fourth',
#  'sea-boards',
#  'Hope-renewed',
#  '60-second',
#  'per-child',
#  'Fellow-citizens',
#  'income-producing',
#  'humanity-the',
#  'storms-joint',
#  'half-million',
#  'half-a-billion',
#  'fast-spreading',
#  'dead-end',
#  'Kansas-Nebraska',
#  'well-maintained',
#  'labor-saving',
#  'State-supported',
#  'D-Day',
#  'short-run',
#  'weapons-of-mass-destruction-related',
#  '10,000-foot',
#  'multi-billion',
#  'starry-eyed',
#  'five-year',
#  'defense-',
#  '2-in-3',
#  'round-the-clock',
#  'POSTAL-SAVINGS',
#  '800-HELPNOW',
#  'bombed-out',
#  'longer-term',
#  'slow-burning',
#  'Kellogg-Briand',
#  '90-minute',
#  'located-a',
#  'surveyor-general',
#  'lands-some',
#  'Chi-li',
#  'Surgeon-General',
#  'American-Soviet',
#  'carrier-delivery',
#  'out-of-date',
#  'ADJUTANT-GENERAL',
#  'out-of-control',
#  'semi-judicial',
#  'U.S.-Korea',
#  'employ-',
#  'wrong-doing',
#  'can-then',
#  '--applying',
#  'high-profile',
#  '-sovereignty',
#  'whistle-stop',
#  'State-directed',
#  'jumping-off',
#  'cross-examination',
#  'gang-violence',
#  'Com-',
#  '-fact',
#  'well-constituted',
#  'nationalism-and',
#  'improving-our',
#  'law-respecting',
#  'President-with',
#  'Mid-Atlantic',
#  'scientifically-based',
#  'five-star',
#  'fast-growing',
#  '300,965,953-----------------------F',
#  'Navy-Yard',
#  'one-hundredth',
#  'not-emphasizing',
#  'fourteen-thousand-mile',
#  'free-men',
#  '10,000-page',
#  '70-percent',
#  'Governor-General',
#  'well-rounded',
#  'surface-to-surface',
#  'epoch-making',
#  'Island----------------------------------------------------------------',
#  'well-established',
#  'international-affairs',
#  'foreign-born',
#  'under-nourishment',
#  'by-products',
#  '24-knot',
#  'African-owned',
#  're-settling',
#  'OB-GYN',
#  'forty-two',
#  '14-to-1',
#  'SS-4',
#  'special-improvement',
#  '--that',
#  '-that',
#  'commander-in-chief',
#  'proposed-simple',
#  'low-tariff',
#  '22-percent',
#  '48-story',
#  'break-water',
#  '1811--is',
#  'Lieutenant-Colonel',
#  'worldly--',
#  'seven-point',
#  'cent.--of',
#  'farnorth-west',
#  'high-grade',
#  'co-operatives',
#  'crime-mapping',
#  'Hay-Pauncefote',
#  'first-step',
#  'peace-pursuing',
#  'high-skilled',
#  '20-percent',
#  'Assembly-have',
#  'The-world',
#  '18-hour',
#  'world-and',
#  'future-our',
#  'anti-Fascist',
#  '37-day',
#  'cross-examining',
#  'non-Communist',
#  'high-ranking',
#  'poll-takers',
#  'fourth-class',
#  'semi-independent',
#  'trade---that',
#  'legal-tender',
#  'ill-founded',
#  'post-Khomeini',
#  'yesterday-indicates',
#  'well-informed',
#  'then-as',
#  'postal-savings',
#  'U.S.-Japan',
#  'anti-retroviral',
#  'pleas-are',
#  'twenty-six',
#  "unrestrained-isn't",
#  'North-Western',
#  'long-maintained',
#  'eleventh-hour',
#  'co-tenants',
#  'Texas--"I',
#  'Inter-Departmental',
#  'Sheppard-Towner',
#  '--For',
#  '1842--',
#  'anti-bullying',
#  'Soviet-supported',
#  'flood-control',
#  'F1a.-there',
#  'gut-wrenching',
#  'rapid-fire',
#  'week-he',
#  'self-reform',
#  'anti-government',
#  '18-percent',
#  'mine-to',
#  'RS-70',
#  'bond-paying',
#  'calamity-howlers',
#  'red-blooded',
#  'service-connected',
#  'of-Western',
#  'MI-8',
#  'ill-timed',
#  'Lion---and',
#  'objection-and',
#  'Irish-American',
#  'six-in',
#  'confusion,-by',
#  'duty-of',
#  '--Next',
#  'work-in-progress',
#  'air-based',
#  '1846--',
#  'tax-gatherer',
#  'due-first',
#  'roof-top',
#  'Island-------------------------------------------------------------------',
#  'Major-General',
#  'sub-Cabinet',
#  'laid-off',
#  'Labor-Management',
#  '40-some',
#  're-written',
#  'aid-to-democracies',
#  '17-year-low',
#  'Sze-chuen',
#  'semi-necessity',
#  'disgrace-the',
#  'half-hour',
#  'II--0.13',
#  '6-inch',
#  'ninety-six',
#  'anti-Somoza',
#  'people-to-people',
#  'congress---that',
#  'Forty-fourth',
#  'bomb-detection',
#  'once-distant',
#  '14-year',
#  'forces-to',
#  'work-experience',
#  'difference-and',
#  'Fifty-fifth',
#  'counter-attacks',
#  '47-year-old',
#  'well-handled',
#  'thrice-armed',
#  'non-commissioned',
#  'Corps]-type',
#  'Medicare-rarely',
#  'three-fourths',
#  'young-man',
#  'minority-owned',
#  'internal-improvement',
#  'latter-mentioned',
#  'Twenty-first',
#  '19-year-old',
#  'lead-time',
#  'Self-government',
#  'all-powerful',
#  'public-spiritedness',
#  'self-inspection',
#  'super-added',
#  '100-cent',
#  'War-would',
#  'self-delusion',
#  'independence---repeal',
#  'single-most',
#  'cast-iron',
#  'dangers--',
#  'Sixty-seven',
#  'noninterest-bearing',
#  'independence-loving',
#  'Tacna-Arica',
#  'non-essentials',
#  'Twenty-one',
#  'one-seventh',
#  'emissions-free',
#  'self-determination',
#  'hereafter--',
#  'small-pox',
#  'stronger-and',
#  'beings-might',
#  're-embarked',
#  'thousand-fold',
#  'Asian-American',
#  'China-U.S.',
#  'job-ready',
#  'trans-Isthmian',
#  'POST-OFFICE',
#  'low-interest',
#  'Sino-American',
#  'Baltic-Americans',
#  'bed-fellows',
#  'nations-are',
#  'discriminations--',
#  'fellow-beings',
#  'tin-foil',
#  'past-time',
#  'century-old',
#  'cheap-postage',
#  'highly-skilled',
#  'land-indeed',
#  'Ninety-three',
#  'break-in',
#  'Hill-Burton',
#  'well-paying',
#  'worker-training',
#  'self-seekers',
#  're-open',
#  'oil-rich',
#  'Soviet-U.S.',
#  'well-coordinated',
#  'agricultural-college',
#  'real-life',
#  'cost-free',
#  'sixty-two',
#  '--more',
#  'sea-borne',
#  'less-',
#  'federally-funded',
#  'Payne-Aldrich',
#  'Medicare-approved',
#  'Well-considered',
#  'Greek-Turkish',
#  'Twenty-six',
#  '--Turmoil',
#  '10-year',
#  'job-producing',
#  'in-between',
#  'eh-',
#  'CAPITAL-GAINS',
#  'otherwise-because',
#  'F-1',
#  'native-born',
#  'country-man',
#  'sustained-until',
#  're-elected',
#  'short-sighted',
#  'lowest-paid',
#  'Self-preservation',
#  'federal-local',
#  'cross-section',
#  'ware------------------',
#  'high-priced',
#  'far-left',
#  '3-mile',
#  'gladness--',
#  'umbilical-cord-blood',
#  'stepping-stones',
#  'under-involvement',
#  'reports-accelerations',
#  'seventy-two',
#  '--raise',
#  'sugar-beet',
#  'eighty-seventh',
#  'live-',
#  'anti-semitic',
#  'under-gone',
#  'out-compete',
#  'be-we',
#  'slave-masters',
#  'ninety-seven',
#  '--Second',
#  'three-decker',
#  'self-organized',
#  'time-worn',
#  'ocean-steamship',
#  '--the',
#  'Germany-the',
#  'B-1',
#  'number---does',
#  'trans-Asian',
#  'agreements-agreements',
#  'twenty-fourth',
#  'mankind-and',
#  '1867.--Attempt',
#  'production-and',
#  'well-served',
#  'Armenian-Americans',
#  'fact-finding',
#  '--The',
#  'nothing-less',
#  'been-',
#  'for-also',
#  'does--[laughter]--and',
#  'thelaw-abiding',
#  'one-hoss',
#  'it-',
#  'taxpayer-that',
#  'combat-equipped',
#  'leaders-is',
#  'inter-oceanic',
#  'ill-rounded',
#  'second-guess',
#  'long-fourteen',
#  '4-star',
#  'wealth-producing',
#  'counter-weapons',
#  '40-nation',
#  'never-to-be-neglected',
#  'rear-admiral',
#  're-create',
#  'sixty-five',
#  'not-take',
#  'been---any',
#  '--or',
#  'safe-keeping',
#  'Sixty-third',
#  '800-some',
#  'Seong-ho',
#  'most-favored-nations',
#  'Federal-State',
#  'Kemp-Roth',
#  'Trenton-Princeton',
#  'subjects-matter',
#  '1826--the',
#  'beach-head',
#  'long-running',
#  '1860.--Outbreak',
#  'pseudo-philanthropy',
#  'trip-hammer',
#  'near-term',
#  'war-revenue',
#  'side-by-side',
#  'SS-18',
#  'important-much',
#  'mind-boggling',
#  '18-year-old',
#  'Peru-Bolivian',
#  'straight-backed',
#  'air-to-air',
#  'Eighty-five',
#  ...]

# %% [markdown]
# >> #### 1.1 Problem: Tokens with leading or trailing hyphens <a id='4_4_5_1_1_id'></a>

# %%
pattern = '^-+.*|.*-+$'
hyphens_before = [re.search(pattern, token)[0] for token in hyphen_tokens if re.search(pattern, token)]
hyphens_before
# Out:
# ['-Japan',
#  'islands-----------------------------------------------',
#  'Island----------------------------------------------------------',
#  'that--',
#  'Canada----------',
#  'Total--------------------------',
#  '--Moreover',
#  'of-----------------------------------------------',
#  '--Our',
#  '1,221,956,620-----------------',
#  'were--',
#  'Total---------------------------',
#  'Island------------------------------------------------------------------',
#  '1,719,428,069----------',
#  'interest--------------------------------------',
#  '125,775.00-',
#  '--not',
#  '1882--',
#  's-',
#  'Quissibis----------------------------------------------------------------------',
#  '--to',
#  'condition--',
#  'beverages-------------------------------------------------',
#  '--I',
#  '--during',
#  'ahead--',
#  'Silks-----------------------------------------------------------------------',
#  'secondly--',
#  'provide--',
#  'judgment--',
#  '--As',
#  'Sundries---------------------------------------------------',
#  'of--',
#  'of-----------------------',
#  'islands-------------------------',
#  '--Not',
#  'offense--',
#  'under-',
#  'servants--',
#  'America--------------------------',
#  'this-',
#  'tr-',
#  'islands-------------------------------------------------------------',
#  '--our',
#  'future,---',
#  '--when',
#  'of-------------------',
#  'plenipotentiaries--',
#  '-because',
#  'amount-',
#  'price-',
#  '--90',
#  '-ire',
#  'Communists-',
#  'justice--',
#  'defense-',
#  'employ-',
#  '--applying',
#  '-sovereignty',
#  'Com-',
#  '-fact',
#  'Island----------------------------------------------------------------',
#  '--that',
#  '-that',
#  'worldly--',
#  '--For',
#  '1842--',
#  '--Next',
#  '1846--',
#  'Island-------------------------------------------------------------------',
#  'dangers--',
#  'hereafter--',
#  'discriminations--',
#  '--more',
#  'less-',
#  '--Turmoil',
#  'eh-',
#  'ware------------------',
#  'gladness--',
#  '--raise',
#  'live-',
#  '--Second',
#  '--the',
#  '--The',
#  'been-',
#  'it-',
#  '--or',
#  'emphaticwords--',
#  'America-----------',
#  'over-',
#  'Brazil-------------------------------------',
#  'provisions-----------------------',
#  'to--',
#  '--Total',
#  '-Our',
#  'be.-',
#  'Republic-----------------------',
#  'Isle-----------------------------------------------------------------',
#  'or--',
#  'Peru---------------------------------------',
#  'South--',
#  'Total---------------------------------------------------------',
#  'of---------------',
#  'etc--------------------------------',
#  '30--',
#  'Island---------------------------------------------------------------',
#  'spe-',
#  '--Germany',
#  'come-',
#  'Pro-',
#  '--betrayers',
#  '--Income',
#  'Uruguay-----------------------',
#  '--A',
#  'October-----------------------------------------------',
#  'States---------------',
#  '--Measures',
#  'direct--',
#  '483,430,637-------------',
#  'paints--------------------------------',
#  '-a',
#  'Uruguay----------------------------------',
#  'Total---------------------------------------------------------------------------',
#  '--Corporate',
#  '--This',
#  'Island-------------------------------------------------------------',
#  'them--',
#  'Nations-',
#  'Isle--------------------------------------------------------------',
#  'provisions-----------',
#  'Venezuela----------------------',
#  'States---------',
#  'of------------------------',
#  '--United',
#  '1-',
#  'Jefferson--',
#  'Treasury-',
#  'of----------------------',
#  '--again',
#  'Rico---------------------',
#  'Venezuela--------------------------------',
#  '-The',
#  'States-----------------',
#  'Thi-',
#  'first-',
#  'ordains--',
#  'considered--',
#  'boards.-',
#  'Island------------------------------------------------',
#  '-These',
#  'was--',
#  '--After',
#  'of---------------------',
#  'Indies--------------',
#  '--Three',
#  '--messages',
#  'thirty-',
#  'resolved--',
#  'advan-',
#  '--By',
#  '433,099,846----------',
#  '-operates',
#  '--We',
#  'Sundries----------------------------------------',
#  '--deliberate',
#  '--reform',
#  'and--',
#  'Sea-',
#  'etc-----------------------------',
#  'Islands--------------',
#  'Cuba--------------------------',
#  'tribes--',
#  '--Regional',
#  '--with',
#  'freedom-',
#  '--During',
#  '--First',
#  '--50',
#  'Western--',
#  '22,127,145---------------',
#  'Mexico-------------------------',
#  '--and',
#  '--To',
#  '--Mr',
#  'glassware-------------------------',
#  'China-',
#  'medium-',
#  'attention--',
#  '67,628,055-----------',
#  'resolution--',
#  '--Finally',
#  '--These',
#  '171,125.00-',
#  'b-',
#  '-have',
#  '--Imports',
#  '1851-',
#  'Congress-',
#  'Indies-----------',
#  '20-',
#  'Colombia----------------------',
#  'danger--',
#  '--whence',
#  'fellow-',
#  'workers.-',
#  'Island--------------------------------------------------------------',
#  'produc-',
#  'numbers------------------------------------------------------',
#  '-at',
#  '-from',
#  'time-',
#  'prosperity-',
#  'of-----------',
#  'm-',
#  '--set',
#  'goods-------------------------------------------',
#  'manufactures----------------------------',
#  'books-------------------------',
#  'declared--',
#  '-Mexicans',
#  '--many',
#  'world-',
#  'Domingo---------',
#  '--That',
#  'articles-------------',
#  'land-',
#  '700-',
#  'South---',
#  'which--',
#  '--In',
#  'Republic------------',
#  'lslands-----------------------------------------------------------',
#  'recommended-',
#  '566,870,950--------------------',
#  '--Freedom',
#  '--And',
#  'sir--',
#  'conveyed--',
#  'pursuits--',
#  '45-',
#  '--60',
#  'oath--',
#  '-we',
#  'com-',
#  'provides--',
#  'd-',
#  'non-',
#  'manufactures------------------------------------------------------------------',
#  '7,947,568----------',
#  'middle-',
#  '--He',
#  'imme-',
#  '--Fully',
#  '--Many',
#  'Chile---------------------------',
#  '--increase',
#  '1858-',
#  'ho-',
#  'Guiana---------------------------',
#  'America--------------',
#  'Islands------------------------------------------------------------',
#  'moderate-',
#  '1825-',
#  'system-',
#  'ra-',
#  '-centered',
#  '-and',
#  'liquors-----------------------------------------------------------------------------',
#  'mother-to-',
#  '18--',
#  '--their',
#  '--Protection',
#  '-body',
#  '--especially',
#  'slavery-',
#  'Depart-',
#  'Brazil-------------------------',
#  '--Crime',
#  'ascertain--',
#  '--return',
#  '--Wages',
#  '--because',
#  'books--------------------------------------',
#  '--Christopher',
#  '-Indonesia',
#  'lower-',
#  '--greater',
#  'Commissary-',
#  'Freight-',
#  'de-',
#  'examiners--',
#  'comprise--',
#  'three-',
#  'Total------------------------------',
#  'shall--',
#  'Guiana----------',
#  'people--',
#  'ac-',
#  'Island------------------------------------------------------------',
#  're-',
#  'Indies----------------------',
#  '--i',
#  'Chile--------------------------------------',
#  'states-',
#  'Commission--',
#  'well-',
#  '--Hospital',
#  '-Communist',
#  '-New',
#  'Charter-',
#  'social-',
#  'thing-',
#  'ends-',
#  '127,420.00-',
#  '--six',
#  'declares--',
#  'President--',
#  'mid-',
#  'safe-',
#  'prudence--',
#  '--Allied',
#  'after-',
#  '--all',
#  '--Fourth',
#  '--statistics',
#  'Isles-----------------------------------------------------------------',
#  'long-',
#  '--Last',
#  'young--',
#  '--Third',
#  'second-',
#  '--new',
#  'ma-',
#  '-to',
#  'wou-',
#  '--we',
#  'Total-----------------',
#  '--beyond',
#  'bodies--',
#  'devotion--',
#  'moment--',
#  '--"unconditional',
#  '--Violence',
#  'Ill-',
#  '--Legislation',
#  'Mexico-----------------------------------',
#  'Colombia---------------------------------',
#  'low-',
#  'wh-',
#  'that-',
#  '--Fifth',
#  'courts-',
#  'provided--',
#  'the--',
#  '--No',
#  'goods-------------------------------',
#  '--every',
#  '1841---------------------',
#  'large-',
#  'certify--',
#  'Island-----------------------------------------------------------',
#  'patriotism--',
#  'possession--',
#  '-the',
#  'sea-',
#  'run--',
#  '-comprehension',
#  'with-',
#  'pre-',
#  'race--',
#  'self-',
#  'treaty-',
#  '--belligerent',
#  '-And',
#  'Union--',
#  'islands-----------------------------------------------------------',
#  'pass-',
#  'nations--',
#  '--New']

# %% [markdown]
# >> #### 1.2 Solution: Replace hyphens with spaces

# %%
hyphens_after = [token.replace('-', ' ') for token in hyphens_before]
hyphens_after
# Out:
# [' Japan',
#  'islands                                               ',
#  'Island                                                          ',
#  'that  ',
#  'Canada          ',
#  'Total                          ',
#  '  Moreover',
#  'of                                               ',
#  '  Our',
#  '1,221,956,620                 ',
#  'were  ',
#  'Total                           ',
#  'Island                                                                  ',
#  '1,719,428,069          ',
#  'interest                                      ',
#  '125,775.00 ',
#  '  not',
#  '1882  ',
#  's ',
#  'Quissibis                                                                      ',
#  '  to',
#  'condition  ',
#  'beverages                                                 ',
#  '  I',
#  '  during',
#  'ahead  ',
#  'Silks                                                                       ',
#  'secondly  ',
#  'provide  ',
#  'judgment  ',
#  '  As',
#  'Sundries                                                   ',
#  'of  ',
#  'of                       ',
#  'islands                         ',
#  '  Not',
#  'offense  ',
#  'under ',
#  'servants  ',
#  'America                          ',
#  'this ',
#  'tr ',
#  'islands                                                             ',
#  '  our',
#  'future,   ',
#  '  when',
#  'of                   ',
#  'plenipotentiaries  ',
#  ' because',
#  'amount ',
#  'price ',
#  '  90',
#  ' ire',
#  'Communists ',
#  'justice  ',
#  'defense ',
#  'employ ',
#  '  applying',
#  ' sovereignty',
#  'Com ',
#  ' fact',
#  'Island                                                                ',
#  '  that',
#  ' that',
#  'worldly  ',
#  '  For',
#  '1842  ',
#  '  Next',
#  '1846  ',
#  'Island                                                                   ',
#  'dangers  ',
#  'hereafter  ',
#  'discriminations  ',
#  '  more',
#  'less ',
#  '  Turmoil',
#  'eh ',
#  'ware                  ',
#  'gladness  ',
#  '  raise',
#  'live ',
#  '  Second',
#  '  the',
#  '  The',
#  'been ',
#  'it ',
#  '  or',
#  'emphaticwords  ',
#  'America           ',
#  'over ',
#  'Brazil                                     ',
#  'provisions                       ',
#  'to  ',
#  '  Total',
#  ' Our',
#  'be. ',
#  'Republic                       ',
#  'Isle                                                                 ',
#  'or  ',
#  'Peru                                       ',
#  'South  ',
#  'Total                                                         ',
#  'of               ',
#  'etc                                ',
#  '30  ',
#  'Island                                                               ',
#  'spe ',
#  '  Germany',
#  'come ',
#  'Pro ',
#  '  betrayers',
#  '  Income',
#  'Uruguay                       ',
#  '  A',
#  'October                                               ',
#  'States               ',
#  '  Measures',
#  'direct  ',
#  '483,430,637             ',
#  'paints                                ',
#  ' a',
#  'Uruguay                                  ',
#  'Total                                                                           ',
#  '  Corporate',
#  '  This',
#  'Island                                                             ',
#  'them  ',
#  'Nations ',
#  'Isle                                                              ',
#  'provisions           ',
#  'Venezuela                      ',
#  'States         ',
#  'of                        ',
#  '  United',
#  '1 ',
#  'Jefferson  ',
#  'Treasury ',
#  'of                      ',
#  '  again',
#  'Rico                     ',
#  'Venezuela                                ',
#  ' The',
#  'States                 ',
#  'Thi ',
#  'first ',
#  'ordains  ',
#  'considered  ',
#  'boards. ',
#  'Island                                                ',
#  ' These',
#  'was  ',
#  '  After',
#  'of                     ',
#  'Indies              ',
#  '  Three',
#  '  messages',
#  'thirty ',
#  'resolved  ',
#  'advan ',
#  '  By',
#  '433,099,846          ',
#  ' operates',
#  '  We',
#  'Sundries                                        ',
#  '  deliberate',
#  '  reform',
#  'and  ',
#  'Sea ',
#  'etc                             ',
#  'Islands              ',
#  'Cuba                          ',
#  'tribes  ',
#  '  Regional',
#  '  with',
#  'freedom ',
#  '  During',
#  '  First',
#  '  50',
#  'Western  ',
#  '22,127,145               ',
#  'Mexico                         ',
#  '  and',
#  '  To',
#  '  Mr',
#  'glassware                         ',
#  'China ',
#  'medium ',
#  'attention  ',
#  '67,628,055           ',
#  'resolution  ',
#  '  Finally',
#  '  These',
#  '171,125.00 ',
#  'b ',
#  ' have',
#  '  Imports',
#  '1851 ',
#  'Congress ',
#  'Indies           ',
#  '20 ',
#  'Colombia                      ',
#  'danger  ',
#  '  whence',
#  'fellow ',
#  'workers. ',
#  'Island                                                              ',
#  'produc ',
#  'numbers                                                      ',
#  ' at',
#  ' from',
#  'time ',
#  'prosperity ',
#  'of           ',
#  'm ',
#  '  set',
#  'goods                                           ',
#  'manufactures                            ',
#  'books                         ',
#  'declared  ',
#  ' Mexicans',
#  '  many',
#  'world ',
#  'Domingo         ',
#  '  That',
#  'articles             ',
#  'land ',
#  '700 ',
#  'South   ',
#  'which  ',
#  '  In',
#  'Republic            ',
#  'lslands                                                           ',
#  'recommended ',
#  '566,870,950                    ',
#  '  Freedom',
#  '  And',
#  'sir  ',
#  'conveyed  ',
#  'pursuits  ',
#  '45 ',
#  '  60',
#  'oath  ',
#  ' we',
#  'com ',
#  'provides  ',
#  'd ',
#  'non ',
#  'manufactures                                                                  ',
#  '7,947,568          ',
#  'middle ',
#  '  He',
#  'imme ',
#  '  Fully',
#  '  Many',
#  'Chile                           ',
#  '  increase',
#  '1858 ',
#  'ho ',
#  'Guiana                           ',
#  'America              ',
#  'Islands                                                            ',
#  'moderate ',
#  '1825 ',
#  'system ',
#  'ra ',
#  ' centered',
#  ' and',
#  'liquors                                                                             ',
#  'mother to ',
#  '18  ',
#  '  their',
#  '  Protection',
#  ' body',
#  '  especially',
#  'slavery ',
#  'Depart ',
#  'Brazil                         ',
#  '  Crime',
#  'ascertain  ',
#  '  return',
#  '  Wages',
#  '  because',
#  'books                                      ',
#  '  Christopher',
#  ' Indonesia',
#  'lower ',
#  '  greater',
#  'Commissary ',
#  'Freight ',
#  'de ',
#  'examiners  ',
#  'comprise  ',
#  'three ',
#  'Total                              ',
#  'shall  ',
#  'Guiana          ',
#  'people  ',
#  'ac ',
#  'Island                                                            ',
#  're ',
#  'Indies                      ',
#  '  i',
#  'Chile                                      ',
#  'states ',
#  'Commission  ',
#  'well ',
#  '  Hospital',
#  ' Communist',
#  ' New',
#  'Charter ',
#  'social ',
#  'thing ',
#  'ends ',
#  '127,420.00 ',
#  '  six',
#  'declares  ',
#  'President  ',
#  'mid ',
#  'safe ',
#  'prudence  ',
#  '  Allied',
#  'after ',
#  '  all',
#  '  Fourth',
#  '  statistics',
#  'Isles                                                                 ',
#  'long ',
#  '  Last',
#  'young  ',
#  '  Third',
#  'second ',
#  '  new',
#  'ma ',
#  ' to',
#  'wou ',
#  '  we',
#  'Total                 ',
#  '  beyond',
#  'bodies  ',
#  'devotion  ',
#  'moment  ',
#  '  "unconditional',
#  '  Violence',
#  'Ill ',
#  '  Legislation',
#  'Mexico                                   ',
#  'Colombia                                 ',
#  'low ',
#  'wh ',
#  'that ',
#  '  Fifth',
#  'courts ',
#  'provided  ',
#  'the  ',
#  '  No',
#  'goods                               ',
#  '  every',
#  '1841                     ',
#  'large ',
#  'certify  ',
#  'Island                                                           ',
#  'patriotism  ',
#  'possession  ',
#  ' the',
#  'sea ',
#  'run  ',
#  ' comprehension',
#  'with ',
#  'pre ',
#  'race  ',
#  'self ',
#  'treaty ',
#  '  belligerent',
#  ' And',
#  'Union  ',
#  'islands                                                           ',
#  'pass ',
#  'nations  ',
#  '  New']

# %% [markdown]
# >> #### 1.3 Prepare token pairs and update dictionary

# %%
# Zip pairs into before and after tuples
hyphens = list(zip(hyphens_before, hyphens_after))

# Update dictionary and hyphen tokens
clean_dict = update_dict(clean_dict, hyphens)
hyphen_tokens = [token for token in hyphen_tokens if token not in clean_dict]

# %% [markdown]
# >> #### 2.1 Problem: Tokens with 2 or more consecutive inner hyphens

# %%
pattern = '[^-]+(-{2,}[^-]+)+'
hyphens_before = [re.search(pattern, token)[0] for token in hyphen_tokens if re.search(pattern, token)]
hyphens_before
# Out:
# ['1920--and',
#  '1865.--Revolution',
#  'argument---some',
#  '1--The',
#  '1902.--Revolution',
#  '31,280,372-----------------------E',
#  '1878.--Revolt',
#  '1851.--Outbreak',
#  'slaves---being',
#  '1903--9:15',
#  'passion---a',
#  'post---the',
#  '1851.--Revolution',
#  '1885.--Revolutionary',
#  '1859.--Riots',
#  '1835--a',
#  'examinations.--For',
#  '581,813---while',
#  'Illinois---that',
#  'here---that',
#  'permit---prohibiting',
#  'trade---that',
#  'service---the',
#  '1791.--Copy',
#  'not---cannot',
#  'prospective---north',
#  'repudiated---discarded',
#  'go---is',
#  'friend---brother',
#  'Missouri---and',
#  'Congress--"more',
#  'representatives---being',
#  'principle---do',
#  'it---to',
#  'constitution---during',
#  'resource"--of',
#  '1866.--Unsuccessful',
#  '1808---the',
#  '60,000,000--a',
#  'entered--30',
#  'ceased---that',
#  'extreme---against',
#  '265,093--a',
#  'adoption---that',
#  '300,965,953-----------------------F',
#  '1811--is',
#  'cent.--of',
#  'trade---that',
#  'Texas--"I',
#  'Lion---and',
#  'II--0.13',
#  'congress---that',
#  'independence---repeal',
#  'number---does',
#  '1867.--Attempt',
#  'does--[laughter]--and',
#  'been---any',
#  '1826--the',
#  '1860.--Outbreak',
#  '10--got',
#  'compromises---repeal',
#  'debate--"without',
#  '1849--the',
#  'problematical---while',
#  '1903--9:45',
#  'that--"The',
#  '55,094---about',
#  'Union---an',
#  'January)--and',
#  'pitchfork---a',
#  '1875--the',
#  '1961--from',
#  '4,000--but',
#  'matter---to',
#  'disarmament"--a',
#  'me---and',
#  '1861.--Intervention',
#  '1899.--Revolution',
#  'expressed---showing',
#  'friends---that',
#  '.--These',
#  'States---Delaware',
#  'permission---we',
#  'stilled---that',
#  'qualified--16',
#  'states---demand',
#  'them---a',
#  'world---enables',
#  'employment,--those',
#  '1856.--Conflict',
#  'consent---and',
#  'south---let',
#  'dead---but',
#  'then---could',
#  'tomb---his',
#  '2--The',
#  'quoting--"hopeless',
#  'abundance?--but',
#  '1837--it',
#  'period--$11,800',
#  'compensated---paid',
#  'surprise---astounded',
#  '1879.--Revolution',
#  'figures---of',
#  'was---what',
#  'right---absolutely',
#  'right---but',
#  'right---that',
#  'slavery---those',
#  '1972--which',
#  '1862.--Mosquera',
#  'center---in',
#  'recommends--1',
#  'former---because',
#  'debated---experience',
#  'intended---the',
#  'examination.--This',
#  'Compromise---ever',
#  '1853.--Insurrection',
#  'hushed---hushed',
#  'question---or',
#  '.--This',
#  'national---his',
#  'authority---are',
#  'NOTE.--The',
#  'rebellion"--a',
#  'ours---those',
#  'quote--"swollen',
#  'liberty---criticising',
#  'independence---who',
#  'friends---No',
#  '1887.--Disturbance',
#  'freedom---the',
#  'republic---for',
#  '1834--a',
#  '87,500--an',
#  'law---showing',
#  'examinations.--These',
#  'foes---that',
#  'principle---who',
#  'contract"--often',
#  'there---has',
#  'sailor---that',
#  '1850.--Revolutionary',
#  '310,000,000--making',
#  'hypocrites---causes',
#  'mind---and',
#  'law?---go',
#  'scythe---a',
#  'people---a',
#  '1883.--Riot',
#  '35,000,000--at',
#  'spell---with',
#  '1901.--City',
#  '1895.--Revolution',
#  'argument---I',
#  'government---that',
#  'examinations.--Such',
#  'unconstitutional---I',
#  'government?---while',
#  'restriction---they',
#  '1854--Political',
#  '33,069,356.28--an',
#  'will---nothing',
#  'consensus"--more',
#  '1865.--Riots',
#  'times--10',
#  'it---first',
#  'free"--unless',
#  'fact---naked',
#  '1908$10,323,233$22,493,334$32,816,567190910,215,33120,778,23230,993,563191018,741,77121,122,39839,864,169NOTE.--Latest',
#  '1895.--Incendiary',
#  'reach---a',
#  '1873.--Revolution',
#  'State---that',
#  '457,500,000--making',
#  '1868.--Revolution',
#  'motive---even',
#  '1860.--Landing',
#  'Territory---the',
#  'endorsement---if',
#  'harm---it',
#  'is---`One',
#  'particular---in',
#  '1861.--Insurrection',
#  'earth---his',
#  'Union---we',
#  'compromise---repeal',
#  'alliances"--as',
#  'countries---as',
#  '1789--not',
#  'terms---it',
#  'offer--$1.25',
#  'Nation---the',
#  'own,--not',
#  '1908$5,079,487$25,838,870$30,918,35719094,691,77023,100,27027,792,397191010,775,30126,292,32937,067,630NOTE.--Latest',
#  '1871.--Revolution',
#  'spell---the',
#  'us---by',
#  '1903--7:40',
#  'people---Jefferson',
#  'thoughts---"Alas',
#  '1854.--Attempted',
#  '1884.--Revolutionary',
#  'Territory---this',
#  'discord---negro',
#  'liberty---a',
#  'world---pointing',
#  'Washington---that',
#  '1856.--Riot',
#  'authorized--$1',
#  '87---that',
#  '1854.--Independence',
#  'again---to',
#  '1--which',
#  'question---the',
#  '1961--and',
#  '1885.--Revolution',
#  'subject---in',
#  'Liberia,---to',
#  'man---less',
#  '96,660--a',
#  '1889.--Riot',
#  'everywhere---join',
#  '1867--a',
#  '2--February',
#  '87---was',
#  'ceremony---instinctively',
#  'quote--"I',
#  'quiet---when',
#  '128,423,732-----------------------C',
#  'Nebraska---and',
#  'military---its',
#  'rates)----------------------------------------------------------------L',
#  'for---the',
#  'concession---that',
#  '1902.--Revolutionary',
#  'language---"I',
#  'Ohio---being',
#  '117---while',
#  '322,000,000--making',
#  'nation---the',
#  'dead!---He',
#  'adherents---we',
#  'champion---the',
#  '1878.--Rebellion',
#  'nation---that',
#  'now?--now',
#  'know---we',
#  'revolution---that',
#  'act---great',
#  'subject---that',
#  '1901.--Revolutionary',
#  'Revolution--"We',
#  'endorsement---let',
#  '1903--7:05',
#  'compromise---that',
#  'whig---less',
#  'States---“If',
#  'this---if',
#  'all?--but',
#  'opinions---their',
#  '1858.--Attempted',
#  'City--"the',
#  '1855--which',
#  'territories---not',
#  'fall---one',
#  'one---one',
#  'country---to',
#  'Y.--are',
#  'people---and',
#  'alive---for',
#  'Americans---let',
#  '37,675,804-----------------------D',
#  'territory---the',
#  'palliation---a',
#  'principle---the',
#  'countrymen---Americans',
#  'necessary"--to',
#  'government---the',
#  '1850.--Outbreak',
#  'nature---opposition',
#  'boards.--One',
#  'falsehood"--gentlemen',
#  '1903--9:41',
#  '1876.--Civil',
#  '1945--during',
#  'danger---naturally',
#  '1900.--Revolution',
#  '1901--Revolution',
#  'of--"The',
#  'compromise---an',
#  'state---we',
#  'service--10',
#  'Senators---each',
#  'example---their',
#  'live---these',
#  'question---arose',
#  'years---as',
#  'men"--the',
#  'himself---that',
#  'country--$65',
#  'States--"that',
#  'history--50',
#  'been---arguing',
#  'occasionally---now',
#  'they---establish',
#  'ocean---and',
#  'liberation"--for',
#  'through---who',
#  'where---that',
#  'of--1',
#  'illustrate---Suppose',
#  'thing---ever',
#  '1837--exceeding',
#  'congress---by',
#  'principle---intend',
#  '42--a',
#  'affairs---they',
#  '1--show',
#  '1862.--Measures',
#  'Nowadays--75']

# %% [markdown]
# >> #### 2.2 Solution: Replace hyphens with spaces

# %%
hyphens_after = [token.replace('-', ' ') for token in hyphens_before]
hyphens_after
# Out:
# ['1920  and',
#  '1865.  Revolution',
#  'argument   some',
#  '1  The',
#  '1902.  Revolution',
#  '31,280,372                       E',
#  '1878.  Revolt',
#  '1851.  Outbreak',
#  'slaves   being',
#  '1903  9:15',
#  'passion   a',
#  'post   the',
#  '1851.  Revolution',
#  '1885.  Revolutionary',
#  '1859.  Riots',
#  '1835  a',
#  'examinations.  For',
#  '581,813   while',
#  'Illinois   that',
#  'here   that',
#  'permit   prohibiting',
#  'trade   that',
#  'service   the',
#  '1791.  Copy',
#  'not   cannot',
#  'prospective   north',
#  'repudiated   discarded',
#  'go   is',
#  'friend   brother',
#  'Missouri   and',
#  'Congress  "more',
#  'representatives   being',
#  'principle   do',
#  'it   to',
#  'constitution   during',
#  'resource"  of',
#  '1866.  Unsuccessful',
#  '1808   the',
#  '60,000,000  a',
#  'entered  30',
#  'ceased   that',
#  'extreme   against',
#  '265,093  a',
#  'adoption   that',
#  '300,965,953                       F',
#  '1811  is',
#  'cent.  of',
#  'trade   that',
#  'Texas  "I',
#  'Lion   and',
#  'II  0.13',
#  'congress   that',
#  'independence   repeal',
#  'number   does',
#  '1867.  Attempt',
#  'does  [laughter]  and',
#  'been   any',
#  '1826  the',
#  '1860.  Outbreak',
#  '10  got',
#  'compromises   repeal',
#  'debate  "without',
#  '1849  the',
#  'problematical   while',
#  '1903  9:45',
#  'that  "The',
#  '55,094   about',
#  'Union   an',
#  'January)  and',
#  'pitchfork   a',
#  '1875  the',
#  '1961  from',
#  '4,000  but',
#  'matter   to',
#  'disarmament"  a',
#  'me   and',
#  '1861.  Intervention',
#  '1899.  Revolution',
#  'expressed   showing',
#  'friends   that',
#  '.  These',
#  'States   Delaware',
#  'permission   we',
#  'stilled   that',
#  'qualified  16',
#  'states   demand',
#  'them   a',
#  'world   enables',
#  'employment,  those',
#  '1856.  Conflict',
#  'consent   and',
#  'south   let',
#  'dead   but',
#  'then   could',
#  'tomb   his',
#  '2  The',
#  'quoting  "hopeless',
#  'abundance?  but',
#  '1837  it',
#  'period  $11,800',
#  'compensated   paid',
#  'surprise   astounded',
#  '1879.  Revolution',
#  'figures   of',
#  'was   what',
#  'right   absolutely',
#  'right   but',
#  'right   that',
#  'slavery   those',
#  '1972  which',
#  '1862.  Mosquera',
#  'center   in',
#  'recommends  1',
#  'former   because',
#  'debated   experience',
#  'intended   the',
#  'examination.  This',
#  'Compromise   ever',
#  '1853.  Insurrection',
#  'hushed   hushed',
#  'question   or',
#  '.  This',
#  'national   his',
#  'authority   are',
#  'NOTE.  The',
#  'rebellion"  a',
#  'ours   those',
#  'quote  "swollen',
#  'liberty   criticising',
#  'independence   who',
#  'friends   No',
#  '1887.  Disturbance',
#  'freedom   the',
#  'republic   for',
#  '1834  a',
#  '87,500  an',
#  'law   showing',
#  'examinations.  These',
#  'foes   that',
#  'principle   who',
#  'contract"  often',
#  'there   has',
#  'sailor   that',
#  '1850.  Revolutionary',
#  '310,000,000  making',
#  'hypocrites   causes',
#  'mind   and',
#  'law?   go',
#  'scythe   a',
#  'people   a',
#  '1883.  Riot',
#  '35,000,000  at',
#  'spell   with',
#  '1901.  City',
#  '1895.  Revolution',
#  'argument   I',
#  'government   that',
#  'examinations.  Such',
#  'unconstitutional   I',
#  'government?   while',
#  'restriction   they',
#  '1854  Political',
#  '33,069,356.28  an',
#  'will   nothing',
#  'consensus"  more',
#  '1865.  Riots',
#  'times  10',
#  'it   first',
#  'free"  unless',
#  'fact   naked',
#  '1908$10,323,233$22,493,334$32,816,567190910,215,33120,778,23230,993,563191018,741,77121,122,39839,864,169NOTE.  Latest',
#  '1895.  Incendiary',
#  'reach   a',
#  '1873.  Revolution',
#  'State   that',
#  '457,500,000  making',
#  '1868.  Revolution',
#  'motive   even',
#  '1860.  Landing',
#  'Territory   the',
#  'endorsement   if',
#  'harm   it',
#  'is   `One',
#  'particular   in',
#  '1861.  Insurrection',
#  'earth   his',
#  'Union   we',
#  'compromise   repeal',
#  'alliances"  as',
#  'countries   as',
#  '1789  not',
#  'terms   it',
#  'offer  $1.25',
#  'Nation   the',
#  'own,  not',
#  '1908$5,079,487$25,838,870$30,918,35719094,691,77023,100,27027,792,397191010,775,30126,292,32937,067,630NOTE.  Latest',
#  '1871.  Revolution',
#  'spell   the',
#  'us   by',
#  '1903  7:40',
#  'people   Jefferson',
#  'thoughts   "Alas',
#  '1854.  Attempted',
#  '1884.  Revolutionary',
#  'Territory   this',
#  'discord   negro',
#  'liberty   a',
#  'world   pointing',
#  'Washington   that',
#  '1856.  Riot',
#  'authorized  $1',
#  '87   that',
#  '1854.  Independence',
#  'again   to',
#  '1  which',
#  'question   the',
#  '1961  and',
#  '1885.  Revolution',
#  'subject   in',
#  'Liberia,   to',
#  'man   less',
#  '96,660  a',
#  '1889.  Riot',
#  'everywhere   join',
#  '1867  a',
#  '2  February',
#  '87   was',
#  'ceremony   instinctively',
#  'quote  "I',
#  'quiet   when',
#  '128,423,732                       C',
#  'Nebraska   and',
#  'military   its',
#  'rates)                                                                L',
#  'for   the',
#  'concession   that',
#  '1902.  Revolutionary',
#  'language   "I',
#  'Ohio   being',
#  '117   while',
#  '322,000,000  making',
#  'nation   the',
#  'dead!   He',
#  'adherents   we',
#  'champion   the',
#  '1878.  Rebellion',
#  'nation   that',
#  'now?  now',
#  'know   we',
#  'revolution   that',
#  'act   great',
#  'subject   that',
#  '1901.  Revolutionary',
#  'Revolution  "We',
#  'endorsement   let',
#  '1903  7:05',
#  'compromise   that',
#  'whig   less',
#  'States   “If',
#  'this   if',
#  'all?  but',
#  'opinions   their',
#  '1858.  Attempted',
#  'City  "the',
#  '1855  which',
#  'territories   not',
#  'fall   one',
#  'one   one',
#  'country   to',
#  'Y.  are',
#  'people   and',
#  'alive   for',
#  'Americans   let',
#  '37,675,804                       D',
#  'territory   the',
#  'palliation   a',
#  'principle   the',
#  'countrymen   Americans',
#  'necessary"  to',
#  'government   the',
#  '1850.  Outbreak',
#  'nature   opposition',
#  'boards.  One',
#  'falsehood"  gentlemen',
#  '1903  9:41',
#  '1876.  Civil',
#  '1945  during',
#  'danger   naturally',
#  '1900.  Revolution',
#  '1901  Revolution',
#  'of  "The',
#  'compromise   an',
#  'state   we',
#  'service  10',
#  'Senators   each',
#  'example   their',
#  'live   these',
#  'question   arose',
#  'years   as',
#  'men"  the',
#  'himself   that',
#  'country  $65',
#  'States  "that',
#  'history  50',
#  'been   arguing',
#  'occasionally   now',
#  'they   establish',
#  'ocean   and',
#  'liberation"  for',
#  'through   who',
#  'where   that',
#  'of  1',
#  'illustrate   Suppose',
#  'thing   ever',
#  '1837  exceeding',
#  'congress   by',
#  'principle   intend',
#  '42  a',
#  'affairs   they',
#  '1  show',
#  '1862.  Measures',
#  'Nowadays  75']

# %% [markdown]
# >> #### 2.3 Prepare token pairs and update dictionary

# %%
# Zip pairs into before and after tuples
hyphens = list(zip(hyphens_before, hyphens_after))

# Update dictionary and hyphen tokens
clean_dict = update_dict(clean_dict, hyphens)
hyphen_tokens = [token for token in hyphen_tokens if token not in clean_dict]

# %% [markdown]
# >> #### 3.1 Problem: Some tokens are valid words while others are not

# %%
word_tokens_transcript = [(token, is_word(token)) for token in tqdm(hyphen_tokens) if is_word(token)]
word_tokens_transcript
# Out:
# 100%|██████████| 3991/3991 [39:37<00:00,  1.68it/s]
# [('Vice-Presidency', 'vice presidency'),
#  ('self-protection', 'self-protection'),
#  ('pass-throughs', 'pass-through'),
#  ('non-Marxist', 'non-Marxist'),
#  ('time-lag', 'time lag'),
#  ('double-digit', 'double-digit'),
#  ('self-confidence', 'self-confidence'),
#  ('follow-the-leader', 'follow-the-leader'),
#  ('across-the-board', 'across-the-board'),
#  ('upside-down', 'upside down'),
#  ('half-a', 'halfa'),
#  ('common-law', 'common-law'),
#  ('vice-admiral', 'vice admiral'),
#  ('fugitive-slave', 'Fugitive Slave Acts'),
#  ('shop-worn', 'shopworn'),
#  ('four-square', 'foursquare'),
#  ('eighty-two', 'eighty-two'),
#  ('medium-sized', 'medium-sized'),
#  ('vice-consul', 'vice-consul'),
#  ('over-crowding', 'overcrowd'),
#  ('barbed-wire', 'barbed wire'),
#  ('surveyors-general', 'surveyor general'),
#  ('trick-or-treat', 'trick or treat'),
#  ('down-to-earth', 'down-to-earth'),
#  ('paper-thin', 'paper-thin'),
#  ('pre-eminent', 'preeminent'),
#  ('freedom-the', 'freedom of the seas'),
#  ('sugar-cane', 'sugarcane'),
#  ('behind-the-scenes', 'behind-the-scenes'),
#  ('home-maker', 'homemaker'),
#  ('twenty-first', 'twenty-first'),
#  ('provost-marshals', 'provost marshal'),
#  ('state-of-the-art', 'state of the art'),
#  ('tie-ups', 'tie-up'),
#  ('question-and', 'question and answer session'),
#  ('court-martial', 'court-martial'),
#  ('back-alley', 'back-alley'),
#  ('God-awful', 'god-awful'),
#  ('flint-lock', 'flintlock'),
#  ('horse-trading', 'horse trade'),
#  ('Fifty-seventh', 'fifty-seventh'),
#  ('all-embracing', 'all-embracing'),
#  ('mustering-out', 'muster out'),
#  ('LATIN-AMERICAN', 'Latin-American'),
#  ('near-by', 'nearby'),
#  ('twenty-second', 'twenty-second'),
#  ('hard-hit', 'hard-hit'),
#  ('Attorney-General', 'attorney general'),
#  ('self-centered', 'self-centered'),
#  ('top-level', 'top-level'),
#  ('Thirty-six', 'thirty-six'),
#  ('sensation-mongers', 'sensation-monger'),
#  ('law-enforcement', 'law enforcement'),
#  ('Rear-Admiral', 'rear admiral'),
#  ('forty-second', 'forty-second'),
#  ('peace-keeping', 'peacekeeping'),
#  ('Thirty-five', 'thirty-five'),
#  ('tax-exempt', 'tax-exempt'),
#  ('open-door', 'open door'),
#  ('mail-order', 'mail order'),
#  ('feet-of', 'feet of clay'),
#  ('Thirty-eighth', 'thirty-eighth'),
#  ('self-containment', 'self-contained'),
#  ('re-enforced', 'reinforce'),
#  ('Free-market', 'free market'),
#  ('full-fledged', 'full-fledged'),
#  ('built-in', 'built-in'),
#  ('bank-note', 'banknote'),
#  ('undreamed-of', 'undreamed of'),
#  ('same-sex', 'same-sex'),
#  ('habit-forming', 'habit-forming'),
#  ('lake-bed', 'lake bed'),
#  ('dry-dock', 'dry-dock'),
#  ('front-page', 'front-page'),
#  ('post-racial', 'post-racial'),
#  ('ground-work', 'groundwork'),
#  ('uh-oh', 'uh-oh'),
#  ('co-operations', 'cooperation'),
#  ('fund-raising', 'fundraise'),
#  ('take-it-or-leave-it', 'take it or leave it'),
#  ('Marxist-Leninists', 'Marxism-Leninism'),
#  ('NAVY-YARDS', 'navy yard'),
#  ('war-worn', 'warworn'),
#  ('house-to-house', 'house-to-house'),
#  ('co-chairs', 'cochair'),
#  ('up-to-date', 'up-to-date'),
#  ('thirty-four', 'thirty-four'),
#  ('non-partisan', 'nonpartisan'),
#  ('arm-in-arm', 'arm'),
#  ('high-powered', 'high-powered'),
#  ('high-value', 'place a high value on'),
#  ('family-wage', 'family wage'),
#  ('Nazi-ism', 'Nazism'),
#  ('two-part', 'two-part'),
#  ('over-exposure', 'overexpose'),
#  ('higgledy-piggledy', 'higgledy-piggledy'),
#  ('water-power', 'waterpower'),
#  ('be-the', 'Bethe'),
#  ('re-tool', 'retool'),
#  ('right-to-work', 'right-to-work'),
#  ('check-dams', 'check dam'),
#  ('home-makers', 'homemaker'),
#  ('law-makers', 'lawmaker'),
#  ('air-raid', 'air raid'),
#  ('over-looked', 'overlook'),
#  ('rubber-check', 'rubber check'),
#  ('ninety-fourth', 'ninety-fourth'),
#  ('Short-term', 'short-term'),
#  ('fair-share', 'fair share'),
#  ('South-Carolina', 'South Carolina'),
#  ('Forty-ninth', 'forty-ninth'),
#  ('courts-martial', 'court-martial'),
#  ('so-called', 'so-called'),
#  ('anti-trust', 'antitrust'),
#  ('All-time', 'all-time'),
#  ('battle-front', 'battlefront'),
#  ('flat-out', 'flat-out'),
#  ('three-way', 'three-way'),
#  ('pre-emptions', 'preemption'),
#  ('capital-intensive', 'capital-intensive'),
#  ('non-nuclear', 'nonnuclear'),
#  ('seventy-eight', 'seventy-eight'),
#  ('on-site', 'on-site'),
#  ('sub-agencies', 'subagency'),
#  ('re-ignite', 'reignite'),
#  ('thirty-six', 'thirty-six'),
#  ('tax-free', 'tax-free'),
#  ('us-and', 'U.S. Citizenship and Immigration Services(USCIS)'),
#  ('by-word', 'byword'),
#  ('left-wing', 'left wing'),
#  ('office-seeker', 'office seeker'),
#  ('cold-blooded', 'cold-blooded'),
#  ('pooh-poohed', 'pooh-pooh'),
#  ('all-weather', 'all-weather'),
#  ('old-timers', 'old-timer'),
#  ('open-handed', 'openhanded'),
#  ('ninety-three', 'ninety-three'),
#  ('over-producing', 'overproduce'),
#  ('father-land', 'fatherland'),
#  ('throw-weight', 'throw weight'),
#  ('short-range', 'short-range'),
#  ('Seventy-six', 'seventy-six'),
#  ('forty-three', 'forty-three'),
#  ('forty-third', 'forty-third'),
#  ('Alsace-Lorraine', 'Alsace-Lorraine'),
#  ('90-day', 'letter'),
#  ('whole-hearted', 'wholehearted'),
#  ('Inter-American', 'inter-American'),
#  ('heart-warming', 'heartwarming'),
#  ('D-day', 'D-Day'),
#  ('over-zealous', 'overzealous'),
#  ('battle-lines', 'battle line'),
#  ('over-clouded', 'overcloud'),
#  ('risk-taking', 'risk-taking'),
#  ('self-evident', 'self-evident'),
#  ('by-the', 'gill-go-by-the-ground'),
#  ('decades-long', 'decades-long'),
#  ('fur-seal', 'fur seal'),
#  ('PostMaster-General', 'postmaster general'),
#  ('man-made', 'man-made'),
#  ('three-quarter', 'three-quarter'),
#  ('Law-clerk', 'law clerk'),
#  ('excess-profits', 'excess-profits tax'),
#  ('corn-hog', 'corn-hog ratio'),
#  ('know-how', 'know-how'),
#  ('thirty-two', 'thirty-two'),
#  ('fine-tuned', 'fine-tuned'),
#  ('tide-water', 'tidewater'),
#  ('wage-workers', 'wageworker'),
#  ('sixty-eight', 'sixty-eight'),
#  ('would-be', 'would-be'),
#  ('good-hearted', 'good-hearted'),
#  ('forty-eighth', 'forty-eighth'),
#  ('fee-simple', 'fee simple'),
#  ('awe-inspiring', 'awe-inspiring'),
#  ('navy-yards', 'navy yard'),
#  ('fresh-water', 'freshwater'),
#  ('holier-than-thou', 'holier-than-thou'),
#  ('non-member', 'nonmember'),
#  ('burnt-out', 'burned-out'),
#  ('wide-spread', 'widespread'),
#  ('self-serving', 'self-serving'),
#  ('war-weary', 'war-weary'),
#  ('under-rate', 'underrate'),
#  ('Solicitor-General', 'solicitor general'),
#  ('seventy-three', 'seventy-three'),
#  ('klieg-lights', 'klieg light'),
#  ('out-build', 'outbuild'),
#  ('first-time', 'first-time'),
#  ('two-thirds', 'two-thirds rule'),
#  ('re-entering', 'reenter'),
#  ('self-improvement', 'self-improvement'),
#  ('self-definition', 'self-definition'),
#  ('ninety-first', 'ninety-first'),
#  ('Lieutenant-Commander', 'lieutenant commander'),
#  ('stand-up', 'stand-up'),
#  ('master-race', 'master race'),
#  ('fire-arm', 'firearm'),
#  ('money-order', 'money order'),
#  ('toll-free', 'toll-free'),
#  ('building-up', 'buildup'),
#  ('shell-fish', 'shellfish'),
#  ('anti-poverty', 'anti-poverty'),
#  ('non-American', 'non-American'),
#  ('text-books', 'textbook'),
#  ('co-inciding', 'coincide'),
#  ('over-issues', 'overissue'),
#  ('over-anxious', 'overanxious'),
#  ('boll-weevil', 'boll weevil'),
#  ('hard-working', 'hardworking'),
#  ('tin-plate', 'tinplate'),
#  ('above-mentioned', 'abovementioned'),
#  ('Post-offices', 'post office'),
#  ('long-suffering', 'long-suffering'),
#  ('B-l', 'bl'),
#  ('Re-employment', 'reemploy'),
#  ('zoot-suiters', 'zoot suit'),
#  ('Re-enlistment', 'reenlistment'),
#  ('sub-districts', 'subdistrict'),
#  ('Mazar-e-Sharif', 'Mazar-e-Sharif'),
#  ('self-disciplined', 'self-disciplined'),
#  ('middle-class', 'middle-class'),
#  ('lieutenant-commanders', 'lieutenant commander'),
#  ('clear-eyed', 'clear-eyed'),
#  ('light-hearted', 'lighthearted'),
#  ('high-school', 'high school'),
#  ('broad-based', 'broad-based'),
#  ('Civil-Service', 'civil service'),
#  ('Pan-Americanism', 'Pan-Americanism'),
#  ('double-talk', 'double-talk'),
#  ('5?-percent', '5-HT'),
#  ('semi-arid', 'semiarid'),
#  ('post-graduate', 'postgraduate'),
#  ('far-off', 'far-off'),
#  ('north-eastern', 'northeastern'),
#  ('north-west', 'northwest'),
#  ('inter-American', 'inter-American'),
#  ('multi-party', 'multiparty'),
#  ('air-lift', 'airlift'),
#  ('hard-core', 'hard-core'),
#  ('right-minded', 'right-minded'),
#  ('non-essential', 'nonessential'),
#  ('above-named', 'abovenamed'),
#  ('self-described', 'self-described'),
#  ('fire-proof', 'fireproof'),
#  ('over-all', 'overall'),
#  ('Dar-Es-Salaam', 'Dar es Salaam'),
#  ('steam-shovel', 'steam shovel'),
#  ('work-study', 'work-study program'),
#  ('commissioner-general', 'commissioner-general'),
#  ('man-one', 'the odd man/one out'),
#  ('well-known', 'well-known'),
#  ('tax-deferred', 'tax-deferred'),
#  ('thirty-fourth', 'thirty-fourth'),
#  ('sea-boards', 'seaboard'),
#  ('dead-end', 'dead-end'),
#  ('labor-saving', 'laborsaving'),
#  ('short-run', 'short run'),
#  ('multi-billion', 'multibillion'),
#  ('starry-eyed', 'starry-eyed'),
#  ('five-year', 'five-year cure'),
#  ('round-the-clock', 'round-the-clock'),
#  ('POSTAL-SAVINGS', 'postal savings bank'),
#  ('bombed-out', 'bombed-out'),
#  ('slow-burning', 'slow-burning'),
#  ('surveyor-general', 'surveyor general'),
#  ('Chi-li', 'chili'),
#  ('Surgeon-General', 'surgeon general'),
#  ('out-of-date', 'out-of-date'),
#  ('ADJUTANT-GENERAL', 'adjutant general'),
#  ('out-of-control', 'spin out of control'),
#  ('wrong-doing', 'wrongdoing'),
#  ('high-profile', 'high-profile'),
#  ('whistle-stop', 'whistle-stop'),
#  ('jumping-off', 'jumping-off place'),
#  ('cross-examination', 'cross-examination'),
#  ('Mid-Atlantic', 'mid-Atlantic'),
#  ('five-star', 'five-star'),
#  ('Navy-Yard', 'navy yard'),
#  ('free-men', 'freeman'),
#  ('Governor-General', 'governor-general'),
#  ('well-rounded', 'well-rounded'),
#  ('surface-to-surface', 'surface-to-surface missile'),
#  ('epoch-making', 'epoch-making'),
#  ('foreign-born', 'foreign-born'),
#  ('under-nourishment', 'undernourished'),
#  ('by-products', 'by-product'),
#  ('re-settling', 'resettle'),
#  ('OB-GYN', 'ob-gyn'),
#  ('forty-two', 'forty-two'),
#  ('commander-in-chief', 'commander in chief'),
#  ('break-water', 'breakwater'),
#  ('Lieutenant-Colonel', 'lieutenant colonel'),
#  ('high-grade', 'high-grade'),
#  ('co-operatives', 'cooperative'),
#  ('The-world', 'the world'),
#  ('anti-Fascist', 'anti-fascist'),
#  ('cross-examining', 'cross-examination'),
#  ('non-Communist', 'noncommunist'),
#  ('high-ranking', 'high-ranking'),
#  ('poll-takers', 'polltaker'),
#  ('fourth-class', 'fourth class'),
#  ('semi-independent', 'semi-independent'),
#  ('well-informed', 'well-informed'),
#  ('postal-savings', 'postal savings bank'),
#  ('anti-retroviral', 'antiretroviral'),
#  ('twenty-six', 'twenty-six'),
#  ('North-Western', 'northwestern'),
#  ('eleventh-hour', 'eleventh hour'),
#  ('co-tenants', 'cotenant'),
#  ('Inter-Departmental', 'interdepartmental'),
#  ('gut-wrenching', 'gut-wrenching'),
#  ('rapid-fire', 'rapid-fire'),
#  ('self-reform', 'self-reform'),
#  ('anti-government', 'anti-government'),
#  ('calamity-howlers', 'calamity howler'),
#  ('red-blooded', 'red-blooded'),
#  ('ill-timed', 'ill-timed'),
#  ('duty-of', 'duty'),
#  ('work-in-progress', 'work in progress'),
#  ('roof-top', 'rooftop'),
#  ('Major-General', 'major general'),
#  ('sub-Cabinet', 'subcabinet'),
#  ('laid-off', 'layoff'),
#  ('Labor-Management', 'Labor Management Relations Act'),
#  ('re-written', 'rewrite'),
#  ('half-hour', 'half hour'),
#  ('ninety-six', 'ninety-six'),
#  ('Forty-fourth', 'forty-fourth'),
#  ('work-experience', 'work experience'),
#  ('Fifty-fifth', 'fifty-fifth'),
#  ('counter-attacks', 'counterattack'),
#  ('well-handled', 'well-handled'),
#  ('non-commissioned', 'noncommissioned'),
#  ('three-fourths', 'three-fourths value clause'),
#  ('young-man', 'young man'),
#  ('Twenty-first', 'twenty-first'),
#  ('lead-time', 'lead time'),
#  ('Self-government', 'self-government'),
#  ('all-powerful', 'all-powerful'),
#  ('public-spiritedness', 'public-spirited'),
#  ('super-added', 'superadd'),
#  ('self-delusion', 'self-delusion'),
#  ('cast-iron', 'cast-iron'),
#  ('Sixty-seven', 'sixty-seven'),
#  ('Tacna-Arica', 'Tacna'),
#  ('non-essentials', 'nonessential'),
#  ('Twenty-one', 'twenty-one'),
#  ('small-pox', 'smallpox'),
#  ('thousand-fold', 'thousand'),
#  ('Asian-American', 'Asian American'),
#  ('trans-Isthmian', 'transisthmian'),
#  ('POST-OFFICE', 'post office'),
#  ('bed-fellows', 'bedfellow'),
#  ('tin-foil', 'tinfoil'),
#  ('Ninety-three', 'ninety-three'),
#  ('break-in', 'break-in'),
#  ('self-seekers', 'self-seeker'),
#  ('re-open', 'reopen'),
#  ('real-life', 'real-life'),
#  ('sixty-two', 'sixty-two'),
#  ('sea-borne', 'seaborne'),
#  ('Twenty-six', 'twenty-six'),
#  ('in-between', 'in-between'),
#  ('CAPITAL-GAINS', 'capital gain'),
#  ('F-1', 'F1 layer'),
#  ('native-born', 'native-born'),
#  ('country-man', 'countryman'),
#  ('re-elected', 'reelect'),
#  ('short-sighted', 'shortsighted'),
#  ('Self-preservation', 'self-preservation'),
#  ('cross-section', 'cross section'),
#  ('far-left', 'the far left'),
#  ('stepping-stones', 'stepping-stone'),
#  ('seventy-two', 'seventy-two'),
#  ('sugar-beet', 'sugar beet'),
#  ('eighty-seventh', 'eighty-seventh'),
#  ('anti-semitic', 'anti-Semitic'),
#  ('under-gone', 'undergo'),
#  ('out-compete', 'outcompete'),
#  ('ninety-seven', 'ninety-seven'),
#  ('three-decker', 'three-decker'),
#  ('time-worn', 'timeworn'),
#  ('B-1', 'vitamin B1'),
#  ('twenty-fourth', 'twenty-fourth'),
#  ('fact-finding', 'fact finder'),
#  ('nothing-less', 'nothing less than'),
#  ('inter-oceanic', 'interoceanic'),
#  ('second-guess', 'second-guess'),
#  ('rear-admiral', 'rear admiral'),
#  ('re-create', 'recreate'),
#  ('sixty-five', 'sixty-five'),
#  ('not-take', 'not take no for an answer'),
#  ('safe-keeping', 'safekeeping'),
#  ('Sixty-third', 'sixty-third'),
#  ('beach-head', 'beachhead'),
#  ('trip-hammer', 'trip-hammer'),
#  ('side-by-side', 'side by side'),
#  ('mind-boggling', 'mind-boggling'),
#  ('straight-backed', 'straight-backed'),
#  ('air-to-air', 'air-to-air'),
#  ('Eighty-five', 'eighty-five'),
#  ('live-stock', 'livestock'),
#  ('parcel-post', 'parcel post'),
#  ('mortgage-backed', 'security'),
#  ('soft-headed', 'softheaded'),
#  ('re-deposit', 'redeposit'),
#  ('foundation-stone', 'foundation stone'),
#  ('close-knit', 'close-knit'),
#  ('Tse-tung', 'Mao Tse-tung'),
#  ('long-staple', 'long-staple'),
#  ('first-aid', 'first aid'),
#  ('Non-Discrimination', 'nondiscrimination'),
#  ('lay-off', 'layoff'),
#  ('well-to-do', 'well-to-do'),
#  ('sub-Saharan', 'sub-Saharan'),
#  ('number-one', 'number one'),
#  ('Free-State', 'Free State'),
#  ('African-American', 'African American'),
#  ('Twenty-four', 'twenty-four'),
#  ('postmaster-ships', 'postmaster'),
#  ('multi-millionaires', 'multimillionaire'),
#  ('sixty-second', 'sixty-second'),
#  ('two-party', 'two-party'),
#  ('leave-taking', 'leave-taking'),
#  ('low-rent', 'low-rent'),
#  ('log-rolling', 'logrolling'),
#  ('self-assured', 'self-assured'),
#  ('national-bank', 'national bank'),
#  ('foreign-service', 'foreign service'),
#  ('flex-time', 'flextime'),
#  ('Quartermaster-General', 'quartermaster general'),
#  ('run-down', 'rundown'),
#  ('old-style', 'old style'),
#  ('anti-terrorist', 'anti-terrorist'),
#  ('twenty-third', 'twenty-third'),
#  ('re-think', 'rethink'),
#  ('self-denying', 'self-denying'),
#  ('non-interference', 'noninterference'),
#  ('Director-General', 'director general'),
#  ('Aix-la-Chapelle', 'Aachen'),
#  ('anti-tank', 'anti-tank'),
#  ('rose-colored', 'rose-colored'),
#  ('strip-mining', 'strip mine'),
#  ('wrong-headed', 'wrongheaded'),
#  ('half-hearted', 'half-hearted'),
#  ('dust-up', 'dustup'),
#  ('sixty-three', 'sixty-three'),
#  ('must-have', 'must-have'),
#  ('re-corded', 'record'),
#  ('mail-messenger', 'mail messenger'),
#  ('Internal-revenue', 'internal revenue tax'),
#  ('faint-hearted', 'fainthearted'),
#  ('secret-service', 'secret service'),
#  ('over-capitalization', 'overcapitalize'),
#  ('free-trade', 'free trade'),
#  ('up-turn', 'upturn'),
#  ('worth-while', 'worthwhile'),
#  ('prisoner-of-war', 'prisoner of war'),
#  ('co-pays', 'co-pay'),
#  ('cure-all', 'cure-all'),
#  ('light-draft', 'light-draft'),
#  ('lip-service', 'lip service'),
#  ('pre-war', 'prewar'),
#  ('re-enlist', 'reenlist'),
#  ('in-fighting', 'infighting'),
#  ('modern-day', 'modern-day'),
#  ('better-off', 'better-off'),
#  ('Hard-headedness', 'hardheaded'),
#  ('judge-advocates', 'judge advocate'),
#  ('well-developed', 'well-developed'),
#  ('self-deceit', 'self-deceit'),
#  ('bona-fide', 'bona fide'),
#  ('trade-marks', 'trademark'),
#  ('full-scale', 'full-scale'),
#  ('hands-off', 'hands-off'),
#  ('log-line', 'log line'),
#  ('anti-Communist', 'anti-communist'),
#  ('sixty-third', 'sixty-third'),
#  ('post-route', 'post route'),
#  ('Brigadier-General', 'brigadier general'),
#  ('self-restraint', 'self-restraint'),
#  ('minimum-wage', 'minimum wage'),
#  ('right-to-know', 'right-to-know'),
#  ('over-looking', 'overlook'),
#  ('money-changers', 'money changer'),
#  ('ill-defined', 'ill-defined'),
#  ('Fifty-two', 'fifty-two'),
#  ('over-sanguine', 'oversanguine'),
#  ('scandal-mongers', 'scandalmonger'),
#  ('bomb-proof', 'bombproof'),
#  ('special-interest', 'special interest'),
#  ('anti-inflationary', 'anti-inflation'),
#  ('ante-revolutionary', 'anterevolutionary'),
#  ('internal-tax', 'internal revenue tax'),
#  ('Kiao-chow', 'Jiaozhou'),
#  ('first-name', 'first name'),
#  ('pay-envelope', 'pay envelope'),
#  ('over-bearing', 'overbearing'),
#  ('wage-earners', 'wage earner'),
#  ('cyber-attacks', 'cyberattack'),
#  ('every-day', 'everyday'),
#  ("employer's-liability", "employer's liability insurance"),
#  ('Non-intervention', 'nonintervention'),
#  ('common-school', 'common school'),
#  ('Post-office', 'post office'),
#  ('fault-finding', 'faultfinding'),
#  ('rah-rah', 'rah-rah'),
#  ('self-styled', 'self-styled'),
#  ('start-ups', 'start-up'),
#  ('dilly-dallying', 'dillydally'),
#  ('drug-free', 'drug-free zone'),
#  ('fifty-second', 'fifty-second'),
#  ('field-work', 'fieldwork'),
#  ('tamper-proof', 'tamper'),
#  ('long-view', 'long view'),
#  ('U-boats', 'U-boat'),
#  ('wide-spreading', 'wide-spreading'),
#  ('good-will', 'goodwill'),
#  ('thirty-year', 'thirty-year man'),
#  ('life-blood', 'lifeblood'),
#  ('An-tung', 'Dandong'),
#  ('super-government', 'supergovernment'),
#  ('fifty-six', 'fifty-six'),
#  ('point-scoring', 'total-point scoring'),
#  ('self-maintenance', 'self-maintenance'),
#  ('long-time', 'longtime'),
#  ('fair-minded', 'fair-minded'),
#  ('criminal-law', 'criminal law'),
#  ('Fish-Culture', 'fish culture'),
#  ('man-days', 'man-day'),
#  ('fifty-three', 'fifty-three'),
#  ('by-laws', 'bylaw'),
#  ('sixty-one', 'sixty-one'),
#  ('short-lived', 'short-lived'),
#  ('consulate-general', 'consulate general'),
#  ('sea-going', 'seagoing'),
#  ('home-loan', 'home loan'),
#  ('draw-backs', 'drawback'),
#  ('ninety-five', 'ninety-five'),
#  ('high-water', 'high-water'),
#  ('breech-loading', 'breechloader'),
#  ('self-propelled', 'self-propelled'),
#  ('eighty-seven', 'eighty-seven'),
#  ('de-emphasize', 'de-emphasize'),
#  ('performance-enhancing', 'performance-enhancing drug'),
#  ('short-term', 'short-term'),
#  ('not-too-distant', 'in the not too distant future'),
#  ('real-world', 'real-world'),
#  ('all-and', 'be-all and end-all'),
#  ('sky-rocketing', 'skyrocket'),
#  ('fifty-four', 'fifty-four'),
#  ('first-mortgage', 'first mortgage'),
#  ('New-Orleans', 'New Orleans'),
#  ('semi-monthly', 'semimonthly'),
#  ('non-addictive', 'nonaddictive'),
#  ('A-plus', 'A-plus'),
#  ('seventy-five', 'seventy-five'),
#  ('broad-minded', 'broad-minded'),
#  ('water-rents', 'water rate'),
#  ('to-morrow', 'tomorrow'),
#  ('Fifty-nine', 'fifty-nine'),
#  ('team-work', 'teamwork'),
#  ('heart-rending', 'heartrending'),
#  ('clear-cut', 'clear-cut'),
#  ('Co-operation', 'cooperation'),
#  ('build-up', 'buildup'),
#  ('merchant-men', 'merchantman'),
#  ('low-cost', 'low-cost'),
#  ('men-of-war', 'man-of-war'),
#  ('loud-mouthed', 'loudmouthed'),
#  ('get-rich-quick', 'get rich quick'),
#  ('good-natured', 'good-natured'),
#  ('well-off', 'well-off'),
#  ('do-or-die', 'do-or-die'),
#  ('wage-earner', 'wage earner'),
#  ('self-indulgent', 'self-indulgence'),
#  ('Christ-like', 'Christ'),
#  ('Long-term', 'long-term'),
#  ('hot-headed', 'hotheaded'),
#  ('South-west', 'southwest'),
#  ('parent-teacher', 'parent-teacher association'),
#  ('Follow-up', 'follow-up'),
#  ('revenue-cutter', 'revenue cutter'),
#  ('Light-houses', 'lighthouse'),
#  ('Far-reaching', 'far-reaching'),
#  ('Postmaster-General', 'postmaster general'),
#  ('mean-spirited', 'mean-spirited'),
#  ('self-examination', 'self-examination'),
#  ('extra-territorial', 'extraterritorial'),
#  ('bore-down', 'bear down'),
#  ('Viet-Nam', 'Vietnam'),
#  ('Consul-General', 'consul general'),
#  ('truth-the', 'the truth of the matter'),
#  ('set-backs', 'setback'),
#  ('over-planted', 'overplant'),
#  ('under-developed', 'underdeveloped'),
#  ('self-governed', 'self-governed'),
#  ('non-negotiable', 'nonnegotiable'),
#  ('beet-sugar', 'beet sugar'),
#  ('Two-thirds', 'two-thirds rule'),
#  ('lieutenant-commander', 'lieutenant commander'),
#  ('it-the', 'get it in the neck'),
#  ('to-night', 'tonight'),
#  ('single-parent', 'single parent'),
#  ('Law-abiding', 'law-abiding'),
#  ('strait-jacket', 'straitjacket'),
#  ('paid-up', 'pay up'),
#  ('leaf-eating', 'leaf-eating ladybird'),
#  ('call-in', 'call-in'),
#  ('high-minded', 'high-minded'),
#  ('side-track', 'sidetrack'),
#  ('Mason-Dixon', 'Mason-Dixon Line'),
#  ('non-combatants', 'noncombatant'),
#  ('all-out', 'all-out'),
#  ('battle-ship', 'battleship'),
#  ('high-sounding', 'high-sounding'),
#  ('life-insurance', 'life insurance'),
#  ('fifty-third', 'fifty-third'),
#  ('re-hearings', 'rehearing'),
#  ('body-politic', 'body politic'),
#  ('Ninety-five', 'ninety-five'),
#  ('worn-out', 'worn-out'),
#  ('zero-based', 'zero-based'),
#  ('safe-guarded', 'safeguard'),
#  ('out-of-wedlock', 'wedlock'),
#  ('re-transfer', 'retransfer'),
#  ('business-like', 'businesslike'),
#  ('self-elected', 'self-elected'),
#  ('one-sided', 'one-sided'),
#  ('thirty-nine', 'thirty-nine'),
#  ('day-to-day', 'day-to-day'),
#  ('junior-grade', 'lieutenant junior grade'),
#  ('out-going', 'outgoing'),
#  ('well-being', 'well-being'),
#  ('working-class', 'working-class'),
#  ('pre-K', 'pre-K'),
#  ('hands-on', 'hands-on'),
#  ('Money-Order', 'money order'),
#  ('quasi-judicial', 'quasi-judicial'),
#  ('forty-seven', 'forty-seven'),
#  ('steel-mill', 'steel mill'),
#  ('re-imposing', 'reimpose'),
#  ('Lieutenant-General', 'lieutenant general'),
#  ('self-destruction', 'self-destruction'),
#  ('bracket-creep', 'bracket creep'),
#  ('Free-Soilers', 'free-soil'),
#  ('stand-by', 'standby'),
#  ('faint-heartedly', 'fainthearted'),
#  ('hangers-on', 'hanger-on'),
#  ('country-men', 'countryman'),
#  ('grown-up', 'grown-up'),
#  ('Secretary-General', 'secretary-general'),
#  ('seventy-first', 'seventy-first'),
#  ('over-speculation', 'overspeculate'),
#  ('over-work', 'overwork'),
#  ('Ninety-four', 'ninety-four'),
#  ('half-an-eye', 'half an eye'),
#  ('Vice-Presidential', 'vice president'),
#  ('dive-bomber', 'dive-bomb'),
#  ('stay-at-home', 'stay-at-home'),
#  ('two-way', 'two-way'),
#  ('out-standing', 'outstanding'),
#  ('self-government', 'self-government'),
#  ('tax-paying', 'taxpaying'),
#  ('rock-solid', 'rock-solid'),
#  ('write-off', 'write-off'),
#  ('inheritance-tax', 'inheritance tax'),
#  ('first-responders', 'first responder'),
#  ('ready-made', 'ready-made'),
#  ('slave-holding', 'slaveholder'),
#  ('thirty-three', 'thirty-three'),
#  ('first-generation', 'first-generation'),
#  ('cash-strapped', 'cash-strapped'),
#  ('open-minded', 'open-minded'),
#  ('non-alcoholic', 'nonalcoholic'),
#  ('bi-partisan', 'bipartisan'),
#  ('Sixty-eighth', 'sixty-eighth'),
#  ('pure-food', 'pure-food law'),
#  ('non-resident', 'nonresident'),
#  ('money-making', 'moneymaker'),
#  ('eighty-ninth', 'eighty-ninth'),
#  ('self-interested', 'self-interest'),
#  ('Boutros-Ghali', 'Boutros-Ghali'),
#  ('V-chip', 'V-chip'),
#  ('world-class', 'world-class'),
#  ('Half-hearted', 'half-hearted'),
#  ('Pent-up', 'pent-up'),
#  ('age-old', 'age-old'),
#  ('Forty-three', 'forty-three'),
#  ('sixty-four', 'sixty-four'),
#  ('Twenty-five', 'twenty-five'),
#  ('special-agency', 'agency'),
#  ('re-equip', 'reequip'),
#  ('wage-worker', 'wageworker'),
#  ('pass-book', 'passbook'),
#  ('re-creation', 'recreate'),
#  ('motor-car', 'motorcar'),
#  ('cut-over', 'cutover'),
#  ('Forty-four', 'forty-four'),
#  ('rip-off', 'rip-off'),
#  ('value-added', 'value-added'),
#  ('six-shooters', 'six-shooter'),
#  ('live-oak', 'live oak'),
#  ('post-roads', 'post road'),
#  ('bread-winning', 'breadwinner'),
#  ('non-governmental', 'nongovernmental'),
#  ('top-to-bottom', 'from top to bottom'),
#  ('well-grounded', 'well-grounded'),
#  ('custom-house', 'customhouse'),
#  ('shoot-to-kill', 'shoot to kill'),
#  ('under-consumption', 'underconsumption'),
#  ('Postmaster-Generals', 'postmaster general'),
#  ('two-step', 'two-step'),
#  ('well-balanced', 'well-balanced'),
#  ('anti-pollution', 'antipollution'),
#  ('democratic-republican', 'Democratic-Republican'),
#  ('non-tidal', 'nontidal'),
#  ('dry-land', 'dryland'),
#  ('SECOND-CLASS', 'second-class'),
#  ('one-for-one', 'one-for-one'),
#  ('contract-labor', 'contract labor'),
#  ('out-of-pocket', 'out of pocket'),
#  ('Five-Year', 'five-year cure'),
#  ('grants-in-aid', 'grant-in-aid'),
#  ('to-as', 'toas'),
#  ('twentieth-century', 'twentieth-century cut'),
#  ('East-West', 'east-west'),
#  ('muscle-bound', 'muscle-bound'),
#  ('inter-service', 'interservice'),
#  ('ocean-going', 'oceangoing'),
#  ('Wage-workers', 'wageworker'),
#  ('non-slave-holding', 'nonslaveholding'),
#  ('over-optimism', 'overoptimism'),
#  ('hot-bed', 'hotbed'),
#  ('face-to-face', 'face-to-face'),
#  ('Light-House', 'lighthouse'),
#  ('V-J', 'VJ'),
#  ('world-wide', 'worldwide'),
#  ('year-long', 'yearlong'),
#  ('make-believe', 'make-believe'),
#  ('consist,-of', 'consist of'),
#  ('country-and', 'country and western'),
#  ('open-ended', 'open-ended'),
#  ('off-ramp', 'off-ramp'),
#  ('non-payment', 'nonpayment'),
#  ('stand-in', 'stand-in'),
#  ('land-and', 'land of milk and honey'),
#  ('trigger-happy', 'trigger-happy'),
#  ('year-to-year', 'tenancy from year to year'),
#  ('Re-Election', 'reelect'),
#  ('Tien-Tsin', 'Tianjin'),
#  ('over-emphasizing', 'overemphasize'),
#  ('forty-ninth', 'forty-ninth'),
#  ("it's-the", "if it's the last thing someone does"),
#  ('self-denial', 'self-denial'),
#  ('re-argument', 'reargument'),
#  ('Thirty-ninth', 'thirty-ninth'),
#  ('there-it', 'there you have it'),
#  ('believe-that', "if you believe that, you'll believe anything"),
#  ('middle-management', 'middle management'),
#  ('Forty-seventh', 'forty-seventh'),
#  ('re-enter', 'reenter'),
#  ('mother-in-law', 'mother-in-law'),
#  ('wife-beater', 'wifebeater'),
#  ('life-saving', 'lifesaving'),
#  ('snow-capped', 'snowcap'),
#  ('court-houses', 'courthouse'),
#  ('self-possessed', 'self-possessed'),
#  ('Indo-Chinese', 'Indo-Chinese'),
#  ('Sixty-sixth', 'sixty-sixth'),
#  ('after-school', 'after-school'),
#  ('merry-go-round', 'merry-go-round'),
#  ('deal-making', 'dealmaking'),
#  ('V-2', 'V-2'),
#  ('between-decks', 'between decks'),
#  ('cut-throat', 'cutthroat'),
#  ('path-breaking', 'pathbreaking'),
#  ('TACNA-ARICA', 'Tacna'),
#  ('well-wishing', 'well-wisher'),
#  ('re-echoed', 'reecho'),
#  ('after-effect', 'aftereffect'),
#  ('stepping-stone', 'stepping-stone'),
#  ('Three-quarters', 'three-quarters'),
#  ('twenty-five', 'twenty-five'),
#  ('Post-Roads', 'post road'),
#  ('heart-felt', 'heartfelt'),
#  ('all-time', 'all-time'),
#  ('Tsing-tao', 'Qingdao'),
#  ('non-action', 'nonaction'),
#  ('fellow-servants', 'fellow servant'),
#  ('three-mile', 'three-mile limit'),
#  ('flare-up', 'flare-up'),
#  ('evil-doers', 'evildoer'),
#  ('out-traded', 'outtrade'),
#  ('30-day', 'letter'),
#  ('18-wheelers', '18-wheeler'),
#  ('big-money', 'big money'),
#  ('forty-one', 'forty-one'),
#  ('One-half', 'two-and-one-half striper'),
#  ('brand-new', 'brand-new'),
#  ('non-combat', 'noncombat'),
#  ('President-Elect', 'president-elect'),
#  ('well-spent', 'well spent'),
#  ('FUR-SEAL', 'fur seal'),
#  ('Dead-Letter', 'dead letter'),
#  ('custom-houses', 'customhouse'),
#  ('front-line', 'frontline'),
#  ('seventy-fifth', 'seventy-fifth'),
#  ('LONG-STANDING', 'long-standing'),
#  ('pass-key', 'passkey'),
#  ('inter-fere', 'interfere'),
#  ('al-Assad', 'Assad, al-'),
#  ('percentage-wise', 'percentagewise'),
#  ('big-shots', 'big shot'),
#  ('non-intervention', 'nonintervention'),
#  ('under-taking', 'undertaking'),
#  ('twenty-one', 'twenty-one'),
#  ('self-devotion', 'self-devotion'),
#  ('safe-guarding', 'safeguard'),
#  ('low-lying', 'low-lying'),
#  ('seventy-four', 'seventy-four'),
#  ('insurance-and',
#   'Health Insurance Portability and Accountability Act of 1996(HIPAA)'),
#  ('pre-dawn', 'predawn'),
#  ('V-1', 'V-1'),
#  ('booby-trapped', 'booby trap'),
#  ('re-establishment', 'reestablish'),
#  ('most-favored-nation', 'most-favored-nation'),
#  ('thirty-first', 'thirty-first'),
#  ('be-from', 'nothing could be farther from the truth'),
#  ('fellow-man', 'fellow man'),
#  ('inter-island', 'interisland'),
#  ('co-ordination', 'coordination'),
#  ('well-nigh', 'well-nigh'),
#  ('appropriate-and',
#   'Uniting and Strengthening America by Providing Appropriate Tools Required to Intercept and Obstruct Terrorism Act of 2001'),
#  ('self-liquidating', 'self-liquidating'),
#  ('North-West', 'northwest'),
#  ('three-part', 'three-part form'),
#  ('take-home', 'take-home'),
#  ('self-expression', 'self-expression'),
#  ('ground-breaking', 'groundbreaking'),
#  ('self-interest', 'self-interest'),
#  ('Self-interest', 'self-interest'),
#  ('tie-up', 'tie-up'),
#  ('short-notice', 'at short notice'),
#  ('B-2', 'vitamin B2'),
#  ('happy-go-lucky', 'happy-go-lucky'),
#  ('co-operates', 'cooperate'),
#  ('after-dinner', 'afterdinner'),
#  ('wool-growers', 'woolgrower'),
#  ('no-more', 'no more'),
#  ('price-fixing', 'price-fixing'),
#  ('Self-determination', 'self-determination'),
#  ('Post-roads', 'post road'),
#  ('re-issue', 'reissue'),
#  ('large-scale', 'large-scale'),
#  ('middle-aged', 'middle age'),
#  ('over-reaching', 'overreach'),
#  ('Fifty-six', 'fifty-six'),
#  ('hand-maiden', 'handmaiden'),
#  ('paymaster-General', 'paymaster general'),
#  ('straight-line', 'straight-line'),
#  ('law-maker', 'lawmaker'),
#  ('forty-six', 'forty-six'),
#  ('super-rich', 'superrich'),
#  ('thought-out', 'thought-out'),
#  ('stop-press', 'stop press'),
#  ('teach-in', 'teach-in'),
#  ('seventy-seventh', 'seventy-seventh'),
#  ('ibn-Khaldun', 'Ibn-Khaldūn'),
#  ('good-looking', 'good-looking'),
#  ('sixty-seven', 'sixty-seven'),
#  ('Seventy-two', 'seventy-two'),
#  ('pleuro-pneumonia', 'pleuropneumonia'),
#  ('HOME-LOAN', 'home loan'),
#  ('Forty-sixth', 'forty-sixth'),
#  ('full-blown', 'full-blown'),
#  ('court-appointed', 'court-appointed attorney'),
#  ('second-guessing', 'second-guess'),
#  ('small-busi-ness', 'small business'),
#  ('turning-point', 'turning point'),
#  ('self-respecting', 'self-respecting'),
#  ('nation-state', 'nation-state'),
#  ('health-care', 'health care'),
#  ('go-ahead', 'go-ahead'),
#  ('one-liners', 'one-liner'),
#  ('non-profit', 'nonprofit'),
#  ('over-mastering', 'overmastering'),
#  ('Latter-day', 'latter-day'),
#  ('no-nonsense', 'no-nonsense'),
#  ('special-delivery', 'special delivery'),
#  ('walk-in', 'walk-in'),
#  ('armor-piercing', 'armor-piercing'),
#  ('black-and-white', 'black-and-white'),
#  ('counter-offensive', 'counteroffensive'),
#  ('cost-cutting', 'cost cutting'),
#  ('well-ordered', 'well-ordered'),
#  ('over-the-top', 'over-the-top'),
#  ('pre-eminently', 'preeminent'),
#  ('two-to-one', 'two-to-one'),
#  ('over-night', 'overnight'),
#  ('here-after', 'hereafter'),
#  ('single-payer', 'single-payer'),
#  ('multi-lateral', 'multilateral'),
#  ('one-man', 'one-man'),
#  ('fellow-men', 'fellow man'),
#  ('Seventy-four', 'seventy-four'),
#  ('self-selection', 'self-select'),
#  ('pro-abortion', 'proabortion'),
#  ('Judge-Advocate-General', 'judge advocate general'),
#  ('stock-holders', 'stockholder'),
#  ('bumper-sticker', 'bumper sticker'),
#  ('ninety-two', 'ninety-two'),
#  ('part-way', 'partway'),
#  ('thirty-eighth', 'thirty-eighth'),
#  ('write-in', 'write-in'),
#  ('freedom-fighters', 'freedom fighter'),
#  ('fair-dealing', 'fair dealing'),
#  ('all-American', 'all-American'),
#  ('non-believers', 'nonbeliever'),
#  ('brothers-in-arms', 'brother-in-arms'),
#  ('thirty-one', 'thirty-one'),
#  ('Prize-winning', 'prizewinning'),
#  ('Twenty-eight', 'twenty-eight'),
#  ('post-card', 'postcard'),
#  ('ninety-fifth', 'ninety-fifth'),
#  ('at-risk', 'risk'),
#  ('half-breeds', 'half-breed'),
#  ('well-tried', 'well-tried'),
#  ('never-ending', 'never-ending'),
#  ('world-shaking', 'world-shaking'),
#  ('H-bomb', 'H-bomb'),
#  ('day-by-day', 'day by day'),
#  ('Fifty-first', 'fifty-first'),
#  ('Ninety-seven', 'ninety-seven'),
#  ('single-mindedness', 'single-minded'),
#  ('years-long', 'yearslong'),
#  ('re-employment', 'reemploy'),
#  ('twenty-sixth', 'twenty-sixth'),
#  ('double-edged', 'double-edged'),
#  ('battle-cry', 'battle cry'),
#  ('do-it-yourself', 'do-it-yourself'),
#  ('co-States', 'New York Times Co. v. United States'),
#  ('rock-and-roll', 'rock and roll'),
#  ('first-rate', 'first-rate'),
#  ('anti-Catholic', 'anti-Catholic'),
#  ('rank-and-file', 'rank and file'),
#  ('water-closets', 'water closet'),
#  ('EIGHT-HOUR', 'eight-hour law'),
#  ('torpedo-boat', 'torpedo boat'),
#  ('weeding-out', 'weed out'),
#  ('hair-splitting', 'hairsplitter'),
#  ('comp-time', 'compensatory time'),
#  ('coin-operated', 'coin-operated'),
#  ('good-bye', 'goodbye'),
#  ('trunk-line', 'trunk line'),
#  ('decision-making', 'decision-making'),
#  ('New-York', 'New York'),
#  ('under-represented', 'underrepresented'),
#  ('New-England', 'New England'),
#  ('fiber-optic', 'fiber-optic'),
#  ('card-carrying', 'card-carrying'),
#  ('like-minded', 'like-minded'),
#  ('quick-lime', 'quicklime'),
#  ('value-free', 'value-free'),
#  ('forty-fifth', 'forty-fifth'),
#  ('subject-matter', 'subject matter'),
#  ('turn-around', 'turnaround'),
#  ('slave-holder', 'slaveholder'),
#  ('unheard-of', 'unheard-of'),
#  ('Revenue-Cutter', 'revenue cutter'),
#  ('over-subscribed', 'oversubscribe'),
#  ('meat-packing', 'meatpacking'),
#  ('Star-Spangled', 'star-spangled'),
#  ('mass-meeting', 'mass meeting'),
#  ('cutting-edge', 'cutting edge'),
#  ('e-mails', 'e-mail'),
#  ('Blue-collar', 'blue-collar'),
#  ('self-deception', 'self-deception'),
#  ('self-imposed', 'self-imposed'),
#  ('ex-post', 'ex post'),
#  ('labor-management', 'Labor Management Relations Act'),
#  ('out-produce', 'outproduce'),
#  ('ninety-eight', 'ninety-eight'),
#  ('Fifty-one', 'fifty-one'),
#  ('twenty-four', 'twenty-four'),
#  ('free-delivery', 'rural free delivery'),
#  ('re-impose', 'reimpose'),
#  ('co-payments', 'co-payment'),
#  ('sinking-fund', 'sinking fund'),
#  ('silver-dollar', 'silver dollar'),
#  ('tenement-house', 'tenement house'),
#  ('eighty-eight', 'eighty-eight'),
#  ('fifty-one', 'fifty-one'),
#  ('under-estimate', 'underestimate'),
#  ('counter-revolution', 'counterrevolution'),
#  ('all-important', 'all-important'),
#  ('Spanish-American', 'Spanish American'),
#  ('well-meaning', 'well-meaning'),
#  ('new-found', 'newfound'),
#  ...]

# %% [markdown]
# >> #### 3.2 Solution: Remove valid words from tokens to be cleaned

# %%
# Remove valid words
hyphen_tokens = sorted(list(set(hyphen_tokens).difference(set(word_tokens_transcript))))
print(len(hyphen_tokens))
hyphen_tokens
# Out:
# 3991
# ['1,500-a-year',
#  '1-day',
#  '1-in-20',
#  '1-yard',
#  '1-year',
#  '1-year-old',
#  '1/2-inch',
#  '1/2-percent',
#  '10,000-foot',
#  '10,000-page',
#  '10,000-ton',
#  '10-day',
#  '10-inch',
#  '10-man',
#  '10-minute',
#  '10-percent',
#  '10-round',
#  '10-to-1',
#  '10-year',
#  '10-year-old',
#  '100-cent',
#  '11-year-old',
#  '12-hour',
#  '12-inch',
#  '12-month',
#  '12-year-old',
#  '122-foot',
#  '122-percent',
#  '13-year-old',
#  '13Ѕ-inch',
#  '14-percent',
#  '14-point',
#  '14-to-1',
#  '14-year',
#  '14-year-old',
#  '15-percent',
#  '15-year-olds',
#  '152-millimeter',
#  '16-inch',
#  '16-inch-type',
#  '16-year-old',
#  '167-page',
#  '17-year',
#  '17-year-low',
#  '17-year-old',
#  '18-hour',
#  '18-nation',
#  '18-percent',
#  '18-wheelers',
#  '18-year-old',
#  '18-year-olds',
#  '180-odd',
#  '19-foot',
#  '19-year-old',
#  '19-year-olds',
#  '190-year',
#  '1970s-era',
#  '19th-century',
#  '2,000-foot',
#  '2,000-mile',
#  '2-in-3',
#  '2-is',
#  '2-minute',
#  '2-percent',
#  '2-year',
#  '2-year-old',
#  '2-year-olds',
#  '20-knot',
#  '20-percent',
#  '20-point',
#  '20-year',
#  '20-year-old',
#  '200-mile',
#  '200-year',
#  '200-year-old',
#  '21st-century',
#  '22,000-word',
#  '22-month',
#  '22-percent',
#  '23-knot',
#  '24-hour',
#  '24-knot',
#  '24-year',
#  '25-percent',
#  '25-year',
#  '250-bed',
#  '26-year-old',
#  '28-minute',
#  '28-percent',
#  '28-square-mile',
#  '3-day',
#  '3-inch',
#  '3-mile',
#  '3-minute',
#  '3-point',
#  '3-to-1',
#  '3-year',
#  '3/4-year',
#  '30-cent',
#  '30-day',
#  '30-minute',
#  '30-odd',
#  '30-percent',
#  '30-second',
#  '30-year',
#  '35-day',
#  '35-hour',
#  '35-percent',
#  '36-percent',
#  '37-point',
#  '3D-print',
#  '3rd-grade',
#  '4-or',
#  '4-percent',
#  '4-point',
#  '4-something',
#  '4-star',
#  '4-year',
#  '4-year-old',
#  '4.8-percent',
#  '40,000-odd',
#  '40-nation',
#  '40-percent',
#  '40-some',
#  '40-yard',
#  '40-year',
#  '45-second',
#  '45-year',
#  '47-year-old',
#  '48-story',
#  '49-year-old',
#  '5-ambulatory',
#  '5-day',
#  '5-letter',
#  '5-percent',
#  '5-power',
#  '5-year',
#  '5-year-old',
#  '50,000-a-year',
#  '50-cent',
#  '50-cent-a-gallon',
#  '50-hour',
#  '50-percent',
#  '50-year',
#  '500-billion',
#  '500-million',
#  '500-per-child',
#  '500-year',
#  '55-mile',
#  '5?-percent',
#  '6-day',
#  '6-inch',
#  '6-month',
#  '6-months',
#  '6-percent',
#  '6-point',
#  '6-pounder',
#  '6-year',
#  '60,000-plus',
#  '60-day',
#  '60-second',
#  '600,000-man',
#  '600-page',
#  '600-percent',
#  '600-ship',
#  '62-year-olders',
#  '65-year',
#  '650-billion-a-year',
#  '7-day',
#  '7-percent',
#  '7-year',
#  '7-year-long',
#  '70-million',
#  '70-percent',
#  '73-percent',
#  '75-bed',
#  '75-page',
#  '75-year-old',
#  '77-percent',
#  '8-inch',
#  '8-year',
#  '8-year-old',
#  '8-year-olds',
#  '800-HELPNOW',
#  '800-some',
#  '81-which',
#  '85-foot',
#  '88-year-old',
#  '9,000-men',
#  '9-foot',
#  '9-hour',
#  '9-millimeter',
#  '9-year-olds',
#  '9.2-percent',
#  '90-day',
#  '90-minute',
#  '90-second',
#  '900,000-$900,000',
#  '91-to-1',
#  '960-acre',
#  'A-11',
#  'A-6F',
#  'A-grade',
#  'A-plus',
#  'ACT-UP',
#  'ADJUTANT-GENERAL',
#  'AIDS-free',
#  'AK-47s',
#  'AMERICA-HONDURAS',
#  'ANTI-TRUST',
#  'ARBITRATIONS-PANAMA',
#  'Adjutant-General',
#  'Administration-Mr',
#  'African-American',
#  'African-Americans',
#  'African-owned',
#  'Ah-h-h',
#  'Aigner-Clark',
#  'Aix-la-Chapelle',
#  'Al-Azhar',
#  'Alaskan-Yukon-Pacific',
#  'All-merciful',
#  'All-powerful',
#  'All-time',
#  'Allies-in',
#  'Alsace-Lorraine',
#  'Amazon-Washington',
#  'Ambassador-Mr',
#  'America-in',
#  'America-the',
#  'American-British',
#  'American-Hellenic',
#  'American-Soviet',
#  'American-born',
#  'American-built',
#  'American-made',
#  'American-mediated',
#  'American-owned',
#  'Americans-to',
#  'Americas-the',
#  'An-tung',
#  'Anglo-Saxon',
#  'Anglo-Venezuelan',
#  'Anti-Trust',
#  'Antung-Mukden',
#  'Apollo-Gemini',
#  'Arab-Israeli',
#  'Armenian-Americans',
#  'As-salaamu',
#  'Asia-Pacific',
#  'Asia-and',
#  'Asia-which',
#  'Asian-American',
#  'Asian-Americans',
#  'Assembly-have',
#  'Atlantic-Mississippi',
#  'Attorney-General',
#  'Attorneys-General',
#  'Austro-Hungarian',
#  'B-1',
#  'B-1B',
#  'B-2',
#  'B-22',
#  'B-29',
#  'B-47',
#  'B-52',
#  'B-l',
#  'BUNAU-VARILLA',
#  'Baltic-Americans',
#  'Band-Aid',
#  'Band-aid',
#  'Berlin-and',
#  'Big-Brother-is-watching-you',
#  'Big-hearted',
#  'Black-owned',
#  'Blue-collar',
#  'Boo-o-o',
#  'Bosnia-wide',
#  'Boutros-Ghali',
#  'Brest-Litovsk',
#  'Briand-Kellogg',
#  'Brigadier-General',
#  'British-American',
#  'Bunau-Varilla',
#  'Bush-McCain',
#  'C-1',
#  'C-SPAN',
#  'C-minus',
#  'CAPITAL-GAINS',
#  'CIVIL-SERVICE',
#  'CONFERENCE-UNFORTUNATE',
#  'CONSULATE-GENERAL',
#  'Cabinet-level',
#  'Cambodian-Vietnam',
#  'Capper-Ketcham',
#  'Capper-Volstead',
#  'Captain-General',
#  'Captain-Generalto',
#  'Carter-Mondale',
#  'Catch-and-release',
#  'Census-we',
#  'Cha-Cha-Cha',
#  'Chamber-the',
#  'Chi-li',
#  'China-U.S.',
#  'Chinchow-Aigun',
#  'Chinese-American',
#  'Chinese-Japanese',
#  'Chinese-made',
#  'Christ-like',
#  'Civil-Service',
#  'Civil-service',
#  'Clayton-Bulwer',
#  'Clear-eyed',
#  'Co-operation',
#  'Coal-land',
#  'Coleman-Singleton',
#  'Columbia-it',
#  'Commander-in-Chief',
#  'Commissary-General',
#  'Commissioner-General',
#  'Communist-controlled',
#  'Communist-directed',
#  'Communist-dominated',
#  'Communist-inspired',
#  'Communist-supplied',
#  'Communist-supported',
#  'Conable-Hanee',
#  'Congo-Adoula',
#  'Congo-Kinshasa',
#  'Congress-and',
#  'Congress-by',
#  'Congress-through',
#  'Consul-General',
#  'Convention-my',
#  'Corps]-type',
#  'Cuban-Soviet',
#  'D-day',
#  'DECISION-MERELY',
#  'Dar-Es-Salaam',
#  'Day-inspector',
#  'Dead-Letter',
#  'Democratic-controlled',
#  'Director-General',
#  'Disarmament-Canada',
#  'Double-digit',
#  'Douglas-Home',
#  'Drug-Free',
#  'E-rate',
#  'EIGHT-HOUR',
#  'ELECTRICAL-POWER',
#  'Earth-based',
#  'East-West',
#  'East-mark',
#  'East-there',
#  'Egypt-Saudi',
#  'Egyptian-Israeli',
#  'Eighty-five',
#  'Eighty-one',
#  'Eisenhower-and',
#  'Eisenhower-they',
#  'Elizabeth-City',
#  'Empress-Queen',
#  'English-speaking',
#  'Entente-Allies',
#  'Establishment-this',
#  'Europe-the',
#  'Ex-Corporal',
#  'Export-Import',
#  'Eyre-Cragin',
#  'F-1',
#  'F-14',
#  'F-14s',
#  'F-15',
#  'F-35',
#  'F1a.-there',
#  'FBI-in',
#  'FELLOW-CITIZENS',
#  'FIFTY-TWO',
#  'FUR-SEAL',
#  'Fair-minded',
#  'Faith-Based',
#  'Faith-based',
#  'Far-reaching',
#  'Farmer-Labor',
#  'Federal-State',
#  'Federal-assisted',
#  'Federal-highway',
#  'Federally-funded',
#  'Fellow-Citizens',
#  'Fellow-Countrymen',
#  'Fellow-citizens',
#  'Fiat-Chrysler',
#  'Fifty-eighth',
#  'Fifty-fifth',
#  'Fifty-first',
#  'Fifty-five',
#  'Fifty-four-forty',
#  'Fifty-nine',
#  'Fifty-one',
#  'Fifty-seventh',
#  'Fifty-six',
#  'Fifty-sixth',
#  'Fifty-third',
#  'Fifty-two',
#  'Fish-Culture',
#  'Five-Year',
#  'Five-twenties',
#  'Fix-It-First',
#  'Flat-head',
#  'Follow-up',
#  'Foo-Choo-Foo',
#  'Food-for-Peace',
#  'Fordney-McCumber',
#  'Forty-eight',
#  'Forty-fifth',
#  'Forty-first',
#  'Forty-five',
#  'Forty-four',
#  'Forty-fourth',
#  'Forty-ninth',
#  'Forty-seventh',
#  'Forty-six',
#  'Forty-sixth',
#  'Forty-three',
#  'Forty-two',
#  'Four-Power',
#  'Four-fifths',
#  'Franco-American',
#  'Frankfort-on-the-Main',
#  'Franklin-leaning',
#  'Free-Soilers',
#  'Free-State',
#  'Free-delivery',
#  'Free-market',
#  'G-20',
#  'G-8',
#  'GS-12',
#  'GS-18',
#  'Gall-lard',
#  'Garner-Rainey',
#  'Germany-the',
#  'Germany-voting',
#  'God-awful',
#  'God-blessed',
#  'God-fearing',
#  'God-given',
#  'God-imposed',
#  'Government-improved',
#  'Government-its',
#  'Government-led',
#  'Government-owned',
#  'Government-regulated',
#  'Government-the',
#  'Government-under',
#  'Government-wide',
#  'Governments-Germany',
#  'Governor-General',
#  'Governor-to',
#  'Gramm-Rudman',
#  'Gramm-Rudman-Hollings',
#  'Grant-in-aid',
#  'Greek-Turkish',
#  'H-43',
#  'H-bomb',
#  'HIV-positive',
#  'HOME-LOAN',
#  'Haitian-Americans',
#  'Haitian-Dominican',
#  'Half-hearted',
#  'Hard-headedness',
#  'Harley-Davidson',
#  'Harvard-trained',
#  'Hawaiian-Japanese',
#  'Hawley-Smoot',
#  'Hay-Herran',
#  'Hay-Pauncefote',
#  'Heaven-favored',
#  'Heavy-armed',
#  'Hesse-Darmstadt',
#  'High-ranking',
#  'High-wage',
#  'Hill-Burton',
#  'Hispanic-Americans',
#  'Hiss-Chambers',
#  'Hitler-dominated',
#  'Ho-si-woo',
#  'Hope-renewed',
#  'House-business',
#  'Hsiao-ping',
#  'Hudson-Fulton',
#  'Humphrey-Hawkins',
#  'IA-ECOSOC',
#  'II-has',
#  'III-C',
#  'INTER-AMERICAN',
#  'INTERSTATE-COMMERCE',
#  'Indian-school',
#  'Indo-China',
#  'Indo-Chinese',
#  'Indonesian-Malaysian',
#  'Inspector-General',
#  'Inter-American',
#  'Inter-Departmental',
#  'Intermediate-Range',
#  'Internal-Revenue',
#  'Internal-revenue',
#  'Iran-Iraq',
#  'Iraqi-led',
#  'Irish-American',
#  'Irish-Catholic',
#  'Irish-Protestant',
#  'Israeli-Jordanian',
#  'Israeli-Palestinian',
#  'Italian-Americans',
#  'J-58',
#  'Jackson-Vanik',
#  'Jaish-e-Mohammed',
#  'Japanese-American',
#  'Jefferson-like',
#  'Jewish-Americans',
#  'Job-killing',
#  'Johnson-Humphrey',
#  'Judas-like',
#  'Judge-Advocate-General',
#  'Judge-Advocates',
#  'Kassebaum-Kennedy',
#  'Kellogg-Briand',
#  'Kemp-Roth',
#  'Kennedy-Johnson',
#  'Kennedy-Kassebaum',
#  'Kennedy-McCarthy',
#  'Key-Stone',
#  'Kiao-chow',
#  'Klan-minded',
#  'LATIN-AMERICAN',
#  'LAW-THE',
#  'LIGHT-HOUSE',
#  'LIGHT-HOUSES',
#  'LONG-STANDING',
#  'Labor-Management',
#  'Lakes-St',
#  'Lao-tzu',
#  'Laos-regained',
#  'Large-scale',
#  'Latter-day',
#  'Law-abiding',
#  'Law-clerk',
#  'Lieutenant-Colonel',
#  'Lieutenant-Commander',
#  'Lieutenant-General',
#  'Life-Saving',
#  'Light-House',
#  'Light-houses',
#  'Lincoln\'s-"Let',
#  'Long-term',
#  'Low-income',
#  'Low-tax',
#  'M-1',
#  'MI-8',
#  'MS-13',
#  'Major-General',
#  'Man-of-war',
#  'Manila-Hongkong',
#  'Mansfield-Scott',
#  'Marine-Hospital',
#  'Marquez-Greene',
#  'Marxism-Leninism',
#  'Marxist-Leninism',
#  'Marxist-Leninist',
#  'Marxist-Leninists',
#  'Mason-Dixon',
#  'Mazar-e-Sharif',
#  'McCain-Feingold',
#  'Mecklenburg-Schwerin',
#  'Medicare-approved',
#  'Medicare-rarely',
#  'Meuse-Argonne',
#  'Mid-Atlantic',
#  'Middle-class',
#  'Middleton-Doctor',
#  'Mig-23',
#  'Mm-hmm',
#  'Modern-day',
#  'Money-Order',
#  'Moore-Brown',
#  'Muslim-majority',
#  'Mustering-out',
#  'NAVY-YARDS',
#  'Nation-wide',
#  'Nations-and',
#  'Nations-led',
#  'Navy-Yard',
#  'Nazi-dominated',
#  'Nazi-ism',
#  'Nebraska-Kansas',
#  'New-England',
#  'New-Jersey',
#  'New-Orleans',
#  'New-York',
#  'Night-inspector',
#  'Nine-eleven',
#  'Ninety-five',
#  'Ninety-four',
#  'Ninety-seven',
#  'Ninety-six',
#  'Ninety-three',
#  'Nixon-16',
#  'Nixon-Ford',
#  'Non-Discrimination',
#  'Non-Proliferation',
#  'Non-intervention',
#  'North-Carolina',
#  'North-South',
#  'North-West',
#  'North-Western',
#  'Nuclear-Test-Ban',
#  'OB-GYN',
#  'Oil-producing',
#  'Old-fashioned',
#  'On-site',
#  'Once-bitter',
#  'One-eighth',
#  'One-fourth',
#  'One-half',
#  'One-third',
#  'Ottoman-born',
#  'P-Tech',
#  'PANAMA-PACIFIC',
#  'POST-OFFICE',
#  'POSTAL-SAVINGS',
#  'PURE-FOOD',
#  'Pacific-cable',
#  'Pago-Pago',
#  'Pakistan-600',
#  'Pan-Amencan',
#  'Pan-American',
#  'Pan-Americanism',
#  'Panama-Pacific',
#  'Paper-covered',
#  'Paymaster-General',
#  'Paymaster-General.3',
#  'Payne-Aldrich',
#  'Pei-Ho',
#  'Peit-sang',
#  'Pent-up',
#  'Peru-Bolivian',
#  'Port-au-Prince',
#  'Post-9/11',
#  'Post-Dispatch',
#  'Post-Office',
#  'Post-OfficeDepartment',
#  'Post-Roads',
#  'Post-office',
#  'Post-offices',
#  'Post-roads',
#  'PostMaster-General',
#  'Postmaster-General',
#  'Postmaster-Generalagainst',
#  'Postmaster-Generals',
#  'Pre-K',
#  'President-Elect',
#  'President-and',
#  'President-as',
#  'President-some',
#  'President-that',
#  'President-to-be',
#  'President-tried',
#  'President-with',
#  'Presidents-President',
#  'Prize-winning',
#  'Provost-Marshal-General',
#  'Qaeda-Iraq',
#  'Quartermaster-General',
#  'R-U',
#  'R-e-g-a-n',
#  'RC-135',
#  'RICA-COLOMBIA',
#  'RS-70',
#  'Ranger-type',
#  'Re-Election',
#  'Re-employment',
#  'Re-enlistment',
#  'Reagan-Bush',
#  'Reagan-Kemp-Roth',
#  'Rear-Admiral',
#  'Revenue-Cutter',
#  'Richmond-based',
#  'Rip-Rap',
#  'Rush-Bagot',
#  'Russo-American',
#  'Russo-Japanese',
#  'SECOND-CLASS',
#  'SELF-DEFENSE',
#  'SEMI-CENTENNIAL',
#  'SLAVE-DEALER',
#  'SR-71',
#  'SR-7I',
#  'SS-18',
#  'SS-20',
#  'SS-20s',
#  'SS-21',
#  'SS-4',
#  'SS-4s',
#  'SS-5',
#  'STABT-Strategic',
#  'Sabbath-Sunday',
#  'Sai-shek',
#  'Sam-whoever',
#  'Saxe-Coburg',
#  'Schleswig-Holstein',
#  'Scotch-Irish',
#  'Scripps-Howard',
#  'Scud-type',
#  'Secret-Service',
#  'Secretary-General',
#  'Secretary-then-Regan',
#  'Self-defense',
#  'Self-determination',
#  'Self-governed',
#  'Self-government',
#  'Self-interest',
#  'Self-preservation',
#  'Self-reliance',
#  'Self-restraint',
#  'Seong-ho',
#  'September-immediately',
#  'Seventy-Fifth',
#  'Seventy-first',
#  'Seventy-four',
#  'Seventy-seven',
#  'Seventy-six',
#  'Seventy-third',
#  'Seventy-two',
#  'Shan-tung',
#  'Sheppard-Towner',
#  'Short-term',
#  'Signal-Service',
#  'Simpson-Bowles',
#  'Simpson-Mazzoli',
#  'Sino-American',
#  'Sino-Soviet',
#  'Sixty-eighth',
#  'Sixty-first',
#  'Sixty-five',
#  'Sixty-fourth',
#  'Sixty-seven',
#  'Sixty-sixth',
#  'Sixty-third',
#  'Slave-Code',
#  'Small-business',
#  'Smoot-Haw',
#  'Solicitor-General',
#  'South-Carolina',
#  'South-west',
#  'Soviet-American',
#  'Soviet-Chinese',
#  'Soviet-Cuban',
#  'Soviet-U.S.',
#  'Soviet-built',
#  'Soviet-made',
#  'Soviet-occupied',
#  'Soviet-sponsored',
#  'Soviet-supported',
#  'Spanish-American',
#  'Spanish-speaking',
#  'Speaker-elect',
#  'Star-Spangled',
#  'Star-Warring',
#  'State-administered',
#  'State-an',
#  'State-bank',
#  'State-controlled',
#  'State-directed',
#  'State-owned',
#  'State-sponsored',
#  'State-supported',
#  'States-Mexican',
#  'States-a',
#  'States-besides',
#  'Steamboat-Inspection',
#  'Sung-pu',
#  'Surgeon-General',
#  'Suz-ahn',
#  'Syrian-backed',
#  'Sze-chuen',
#  'TACNA-ARICA',
#  'Ta-lien-wan',
#  'Tacna-Arica',
#  'Taft-Ellender-Wagner',
#  'Tax-exempt',
#  'Ten-forties',
#  'The-world',
#  'Thirty-eighth',
#  'Thirty-fifth',
#  'Thirty-five',
#  'Thirty-four',
#  'Thirty-ninth',
#  'Thirty-one',
#  'Thirty-seven',
#  'Thirty-six',
#  'Thomas-Anita',
#  'Three-fourths',
#  'Three-quarters',
#  'Tien-Tsin',
#  'Tien-tsin',
#  'Ting-fang',
#  'To-day',
#  'To-morrow',
#  'Trans-Missouri',
#  'Trans-Pacific',
#  'Trenton-Princeton',
#  'Truman-Acheson',
#  'Trump-Pence',
#  'Tsai-Hsun',
#  'Tsai-tao',
#  'Tse-tung',
#  'Tsing-tao',
#  'Tsung-li',
#  'Twenty-eight',
#  'Twenty-fifth',
#  'Twenty-first',
#  'Twenty-five',
#  'Twenty-four',
#  'Twenty-nine',
#  'Twenty-one',
#  'Twenty-seven',
#  'Twenty-six',
#  'Twenty-three',
#  'Twenty-two',
#  'Two-thirds',
#  'U-2',
#  'U-Boats',
#  'U-boats',
#  'U.S.-Canadian',
#  'U.S.-Japan',
#  'U.S.-Korea',
#  'U.S.-Mexico',
#  'U.S.-Mexico-Canada',
#  'U.S.-Panamanian',
#  'Ukrainian-Americans',
#  'Union-for',
#  'Union-loving',
#  'Union-men',
#  'Union-saving',
#  'Union-supporting',
#  'V-1',
#  'V-2',
#  'V-J',
#  'V-chip',
#  'Vice-Presidency',
#  'Vice-President',
#  'Vice-Presidential',
#  'Viet-Nam',
#  'Vietnam-and',
#  'Vietnam-apply',
#  'Vietnam-backed',
#  'W-GDP',
#  'Wage-workers',
#  'Wagner-Ellender-Taft',
#  'War-would',
#  'Washington-based',
#  'Web-feet',
#  'Wei-hai-wei',
#  'Well-considered',
#  'Well-founded',
#  'Well-trained',
#  'Western-proposed',
#  'Western-type',
#  'Wilkes-Barre',
#  'X-rated',
#  'Yang-Tse',
#  'Yen-hoon',
#  'Zero-Option',
#  'Zimbabwe-Rhodesia',
#  'able-bodied',
#  'above-cited',
#  'above-estimated',
#  'above-mentioned',
#  'above-named',
#  'above-recited',
#  'abroad-the',
#  'abroad-to',
#  'academy-type',
#  'accept-and',
#  'across-the-board',
#  'act-$350,000,000',
#  'action-to',
#  'add-ons',
#  'adjusted-service',
#  'administration-and',
#  'administration-as',
#  'administration-helped',
#  'administration-laws',
#  'administration-tried',
#  'administrations-to',
#  'advance-and',
#  'advanced-placement',
#  'advantage-and',
#  'advantages-in',
#  "afflicted-they've",
#  'afford-along',
#  'after-dinner',
#  'after-effect',
#  'after-effects',
#  'after-school',
#  'after-tax',
#  'again,-a',
#  'age-long',
#  'age-old',
#  'agencies-as',
#  'agencies-is',
#  'aggression-and',
#  'aggression-that',
#  'aggression-to',
#  'ago-and',
#  'ago-ideas',
#  'ago-many',
#  'ago-passed',
#  'ago-was',
#  'agreements-agreements',
#  'agricultural-college',
#  'ahead-immediately',
#  'aid-to-democracies',
#  'air-based',
#  'air-landing',
#  'air-lane',
#  'air-lift',
#  'air-mail',
#  'air-raid',
#  'air-to-air',
#  'al-Assad',
#  'al-Baghdadi',
#  "al-Qa'ida",
#  'al-Qaeda',
#  'al-Sabah',
#  'al-Suhail',
#  'all-American',
#  'all-Asian',
#  'all-German',
#  'all-Indochina',
#  'all-absorbing',
#  'all-and',
#  'all-black',
#  'all-embracing',
#  'all-engrossing',
#  'all-important',
#  'all-in',
#  'all-inclusive',
#  'all-male',
#  'all-merciful',
#  'all-military',
#  'all-of-the-above',
#  'all-or-nothing',
#  'all-out',
#  'all-pervading',
#  'all-powerful',
#  'all-round',
#  'all-solar',
#  'all-time',
#  'all-volunteer',
#  'all-weather',
#  'all-wind',
#  'all-wise',
#  'alliance-building',
#  'allies-just',
#  'alone-and',
#  'amendments-it',
#  'and-towns',
#  'andlaw-abiding',
#  'anever-increasing',
#  'animal-killers',
#  'anniversary-let',
#  'antagonisms-that',
#  'ante-revolutionary',
#  'anti-American',
#  'anti-Catholic',
#  'anti-Communism',
#  'anti-Communist',
#  'anti-Fascist',
#  'anti-Nazi',
#  'anti-Semitic',
#  'anti-Semitism',
#  'anti-Somoza',
#  'anti-Soviet',
#  'anti-U.S.',
#  'anti-Vietnam',
#  'anti-Washington',
#  'anti-aircraft',
#  'anti-bullying',
#  'anti-business',
#  'anti-climb',
#  'anti-communism',
#  'anti-corruption',
#  'anti-craft',
#  'anti-crime',
#  'anti-drug-trafficking',
#  'anti-energy',
#  'anti-fraud',
#  'anti-government',
#  ...]

# %% [markdown]
# >> #### 4.1 Problem: Cardinal numbers do not need to be cleaned

# %%
token_numbers = [token for token in hyphen_tokens if is_number(token)]
token_numbers
# Out:
# ['Eighty-five',
#  'Eighty-one',
#  'FIFTY-TWO',
#  'Fifty-five',
#  'Fifty-nine',
#  'Fifty-one',
#  'Fifty-six',
#  'Fifty-two',
#  'Forty-eight',
#  'Forty-five',
#  'Forty-four',
#  'Forty-six',
#  'Forty-three',
#  'Forty-two',
#  'Ninety-five',
#  'Ninety-four',
#  'Ninety-seven',
#  'Ninety-six',
#  'Ninety-three',
#  'Seventy-four',
#  'Seventy-seven',
#  'Seventy-six',
#  'Seventy-two',
#  'Sixty-five',
#  'Sixty-seven',
#  'Thirty-five',
#  'Thirty-four',
#  'Thirty-one',
#  'Thirty-seven',
#  'Thirty-six',
#  'Twenty-eight',
#  'Twenty-five',
#  'Twenty-four',
#  'Twenty-nine',
#  'Twenty-one',
#  'Twenty-seven',
#  'Twenty-six',
#  'Twenty-three',
#  'Twenty-two',
#  'eighty-eight',
#  'eighty-five',
#  'eighty-one',
#  'eighty-seven',
#  'eighty-two',
#  'fifty-eight',
#  'fifty-five',
#  'fifty-four',
#  'fifty-nine',
#  'fifty-one',
#  'fifty-seven',
#  'fifty-six',
#  'fifty-three',
#  'fifty-two',
#  'forty-eight',
#  'forty-five',
#  'forty-four',
#  'forty-one',
#  'forty-seven',
#  'forty-six',
#  'forty-three',
#  'forty-two',
#  'ninety-eight',
#  'ninety-five',
#  'ninety-nine',
#  'ninety-seven',
#  'ninety-six',
#  'ninety-three',
#  'ninety-two',
#  'seventy-eight',
#  'seventy-five',
#  'seventy-four',
#  'seventy-nine',
#  'seventy-one',
#  'seventy-seven',
#  'seventy-six',
#  'seventy-three',
#  'seventy-two',
#  'sixty-eight',
#  'sixty-five',
#  'sixty-four',
#  'sixty-nine',
#  'sixty-one',
#  'sixty-seven',
#  'sixty-six',
#  'sixty-three',
#  'sixty-two',
#  'thirty-eight',
#  'thirty-five',
#  'thirty-four',
#  'thirty-nine',
#  'thirty-one',
#  'thirty-seven',
#  'thirty-six',
#  'thirty-three',
#  'thirty-two',
#  'twenty-five',
#  'twenty-four',
#  'twenty-nine',
#  'twenty-one',
#  'twenty-six',
#  'twenty-three',
#  'twenty-two']

# %% [markdown]
# >> #### 4.2 Solution: Remove cardinal numbers from tokens to be cleaned

# %%
hyphen_tokens = sorted(list(set(hyphen_tokens).difference(set(token_numbers))))
print(len(hyphen_tokens))
hyphen_tokens
# Out:
# 3889
# ['1,500-a-year',
#  '1-day',
#  '1-in-20',
#  '1-yard',
#  '1-year',
#  '1-year-old',
#  '1/2-inch',
#  '1/2-percent',
#  '10,000-foot',
#  '10,000-page',
#  '10,000-ton',
#  '10-day',
#  '10-inch',
#  '10-man',
#  '10-minute',
#  '10-percent',
#  '10-round',
#  '10-to-1',
#  '10-year',
#  '10-year-old',
#  '100-cent',
#  '11-year-old',
#  '12-hour',
#  '12-inch',
#  '12-month',
#  '12-year-old',
#  '122-foot',
#  '122-percent',
#  '13-year-old',
#  '13Ѕ-inch',
#  '14-percent',
#  '14-point',
#  '14-to-1',
#  '14-year',
#  '14-year-old',
#  '15-percent',
#  '15-year-olds',
#  '152-millimeter',
#  '16-inch',
#  '16-inch-type',
#  '16-year-old',
#  '167-page',
#  '17-year',
#  '17-year-low',
#  '17-year-old',
#  '18-hour',
#  '18-nation',
#  '18-percent',
#  '18-wheelers',
#  '18-year-old',
#  '18-year-olds',
#  '180-odd',
#  '19-foot',
#  '19-year-old',
#  '19-year-olds',
#  '190-year',
#  '1970s-era',
#  '19th-century',
#  '2,000-foot',
#  '2,000-mile',
#  '2-in-3',
#  '2-is',
#  '2-minute',
#  '2-percent',
#  '2-year',
#  '2-year-old',
#  '2-year-olds',
#  '20-knot',
#  '20-percent',
#  '20-point',
#  '20-year',
#  '20-year-old',
#  '200-mile',
#  '200-year',
#  '200-year-old',
#  '21st-century',
#  '22,000-word',
#  '22-month',
#  '22-percent',
#  '23-knot',
#  '24-hour',
#  '24-knot',
#  '24-year',
#  '25-percent',
#  '25-year',
#  '250-bed',
#  '26-year-old',
#  '28-minute',
#  '28-percent',
#  '28-square-mile',
#  '3-day',
#  '3-inch',
#  '3-mile',
#  '3-minute',
#  '3-point',
#  '3-to-1',
#  '3-year',
#  '3/4-year',
#  '30-cent',
#  '30-day',
#  '30-minute',
#  '30-odd',
#  '30-percent',
#  '30-second',
#  '30-year',
#  '35-day',
#  '35-hour',
#  '35-percent',
#  '36-percent',
#  '37-point',
#  '3D-print',
#  '3rd-grade',
#  '4-or',
#  '4-percent',
#  '4-point',
#  '4-something',
#  '4-star',
#  '4-year',
#  '4-year-old',
#  '4.8-percent',
#  '40,000-odd',
#  '40-nation',
#  '40-percent',
#  '40-some',
#  '40-yard',
#  '40-year',
#  '45-second',
#  '45-year',
#  '47-year-old',
#  '48-story',
#  '49-year-old',
#  '5-ambulatory',
#  '5-day',
#  '5-letter',
#  '5-percent',
#  '5-power',
#  '5-year',
#  '5-year-old',
#  '50,000-a-year',
#  '50-cent',
#  '50-cent-a-gallon',
#  '50-hour',
#  '50-percent',
#  '50-year',
#  '500-billion',
#  '500-million',
#  '500-per-child',
#  '500-year',
#  '55-mile',
#  '5?-percent',
#  '6-day',
#  '6-inch',
#  '6-month',
#  '6-months',
#  '6-percent',
#  '6-point',
#  '6-pounder',
#  '6-year',
#  '60,000-plus',
#  '60-day',
#  '60-second',
#  '600,000-man',
#  '600-page',
#  '600-percent',
#  '600-ship',
#  '62-year-olders',
#  '65-year',
#  '650-billion-a-year',
#  '7-day',
#  '7-percent',
#  '7-year',
#  '7-year-long',
#  '70-million',
#  '70-percent',
#  '73-percent',
#  '75-bed',
#  '75-page',
#  '75-year-old',
#  '77-percent',
#  '8-inch',
#  '8-year',
#  '8-year-old',
#  '8-year-olds',
#  '800-HELPNOW',
#  '800-some',
#  '81-which',
#  '85-foot',
#  '88-year-old',
#  '9,000-men',
#  '9-foot',
#  '9-hour',
#  '9-millimeter',
#  '9-year-olds',
#  '9.2-percent',
#  '90-day',
#  '90-minute',
#  '90-second',
#  '900,000-$900,000',
#  '91-to-1',
#  '960-acre',
#  'A-11',
#  'A-6F',
#  'A-grade',
#  'A-plus',
#  'ACT-UP',
#  'ADJUTANT-GENERAL',
#  'AIDS-free',
#  'AK-47s',
#  'AMERICA-HONDURAS',
#  'ANTI-TRUST',
#  'ARBITRATIONS-PANAMA',
#  'Adjutant-General',
#  'Administration-Mr',
#  'African-American',
#  'African-Americans',
#  'African-owned',
#  'Ah-h-h',
#  'Aigner-Clark',
#  'Aix-la-Chapelle',
#  'Al-Azhar',
#  'Alaskan-Yukon-Pacific',
#  'All-merciful',
#  'All-powerful',
#  'All-time',
#  'Allies-in',
#  'Alsace-Lorraine',
#  'Amazon-Washington',
#  'Ambassador-Mr',
#  'America-in',
#  'America-the',
#  'American-British',
#  'American-Hellenic',
#  'American-Soviet',
#  'American-born',
#  'American-built',
#  'American-made',
#  'American-mediated',
#  'American-owned',
#  'Americans-to',
#  'Americas-the',
#  'An-tung',
#  'Anglo-Saxon',
#  'Anglo-Venezuelan',
#  'Anti-Trust',
#  'Antung-Mukden',
#  'Apollo-Gemini',
#  'Arab-Israeli',
#  'Armenian-Americans',
#  'As-salaamu',
#  'Asia-Pacific',
#  'Asia-and',
#  'Asia-which',
#  'Asian-American',
#  'Asian-Americans',
#  'Assembly-have',
#  'Atlantic-Mississippi',
#  'Attorney-General',
#  'Attorneys-General',
#  'Austro-Hungarian',
#  'B-1',
#  'B-1B',
#  'B-2',
#  'B-22',
#  'B-29',
#  'B-47',
#  'B-52',
#  'B-l',
#  'BUNAU-VARILLA',
#  'Baltic-Americans',
#  'Band-Aid',
#  'Band-aid',
#  'Berlin-and',
#  'Big-Brother-is-watching-you',
#  'Big-hearted',
#  'Black-owned',
#  'Blue-collar',
#  'Boo-o-o',
#  'Bosnia-wide',
#  'Boutros-Ghali',
#  'Brest-Litovsk',
#  'Briand-Kellogg',
#  'Brigadier-General',
#  'British-American',
#  'Bunau-Varilla',
#  'Bush-McCain',
#  'C-1',
#  'C-SPAN',
#  'C-minus',
#  'CAPITAL-GAINS',
#  'CIVIL-SERVICE',
#  'CONFERENCE-UNFORTUNATE',
#  'CONSULATE-GENERAL',
#  'Cabinet-level',
#  'Cambodian-Vietnam',
#  'Capper-Ketcham',
#  'Capper-Volstead',
#  'Captain-General',
#  'Captain-Generalto',
#  'Carter-Mondale',
#  'Catch-and-release',
#  'Census-we',
#  'Cha-Cha-Cha',
#  'Chamber-the',
#  'Chi-li',
#  'China-U.S.',
#  'Chinchow-Aigun',
#  'Chinese-American',
#  'Chinese-Japanese',
#  'Chinese-made',
#  'Christ-like',
#  'Civil-Service',
#  'Civil-service',
#  'Clayton-Bulwer',
#  'Clear-eyed',
#  'Co-operation',
#  'Coal-land',
#  'Coleman-Singleton',
#  'Columbia-it',
#  'Commander-in-Chief',
#  'Commissary-General',
#  'Commissioner-General',
#  'Communist-controlled',
#  'Communist-directed',
#  'Communist-dominated',
#  'Communist-inspired',
#  'Communist-supplied',
#  'Communist-supported',
#  'Conable-Hanee',
#  'Congo-Adoula',
#  'Congo-Kinshasa',
#  'Congress-and',
#  'Congress-by',
#  'Congress-through',
#  'Consul-General',
#  'Convention-my',
#  'Corps]-type',
#  'Cuban-Soviet',
#  'D-day',
#  'DECISION-MERELY',
#  'Dar-Es-Salaam',
#  'Day-inspector',
#  'Dead-Letter',
#  'Democratic-controlled',
#  'Director-General',
#  'Disarmament-Canada',
#  'Double-digit',
#  'Douglas-Home',
#  'Drug-Free',
#  'E-rate',
#  'EIGHT-HOUR',
#  'ELECTRICAL-POWER',
#  'Earth-based',
#  'East-West',
#  'East-mark',
#  'East-there',
#  'Egypt-Saudi',
#  'Egyptian-Israeli',
#  'Eisenhower-and',
#  'Eisenhower-they',
#  'Elizabeth-City',
#  'Empress-Queen',
#  'English-speaking',
#  'Entente-Allies',
#  'Establishment-this',
#  'Europe-the',
#  'Ex-Corporal',
#  'Export-Import',
#  'Eyre-Cragin',
#  'F-1',
#  'F-14',
#  'F-14s',
#  'F-15',
#  'F-35',
#  'F1a.-there',
#  'FBI-in',
#  'FELLOW-CITIZENS',
#  'FUR-SEAL',
#  'Fair-minded',
#  'Faith-Based',
#  'Faith-based',
#  'Far-reaching',
#  'Farmer-Labor',
#  'Federal-State',
#  'Federal-assisted',
#  'Federal-highway',
#  'Federally-funded',
#  'Fellow-Citizens',
#  'Fellow-Countrymen',
#  'Fellow-citizens',
#  'Fiat-Chrysler',
#  'Fifty-eighth',
#  'Fifty-fifth',
#  'Fifty-first',
#  'Fifty-four-forty',
#  'Fifty-seventh',
#  'Fifty-sixth',
#  'Fifty-third',
#  'Fish-Culture',
#  'Five-Year',
#  'Five-twenties',
#  'Fix-It-First',
#  'Flat-head',
#  'Follow-up',
#  'Foo-Choo-Foo',
#  'Food-for-Peace',
#  'Fordney-McCumber',
#  'Forty-fifth',
#  'Forty-first',
#  'Forty-fourth',
#  'Forty-ninth',
#  'Forty-seventh',
#  'Forty-sixth',
#  'Four-Power',
#  'Four-fifths',
#  'Franco-American',
#  'Frankfort-on-the-Main',
#  'Franklin-leaning',
#  'Free-Soilers',
#  'Free-State',
#  'Free-delivery',
#  'Free-market',
#  'G-20',
#  'G-8',
#  'GS-12',
#  'GS-18',
#  'Gall-lard',
#  'Garner-Rainey',
#  'Germany-the',
#  'Germany-voting',
#  'God-awful',
#  'God-blessed',
#  'God-fearing',
#  'God-given',
#  'God-imposed',
#  'Government-improved',
#  'Government-its',
#  'Government-led',
#  'Government-owned',
#  'Government-regulated',
#  'Government-the',
#  'Government-under',
#  'Government-wide',
#  'Governments-Germany',
#  'Governor-General',
#  'Governor-to',
#  'Gramm-Rudman',
#  'Gramm-Rudman-Hollings',
#  'Grant-in-aid',
#  'Greek-Turkish',
#  'H-43',
#  'H-bomb',
#  'HIV-positive',
#  'HOME-LOAN',
#  'Haitian-Americans',
#  'Haitian-Dominican',
#  'Half-hearted',
#  'Hard-headedness',
#  'Harley-Davidson',
#  'Harvard-trained',
#  'Hawaiian-Japanese',
#  'Hawley-Smoot',
#  'Hay-Herran',
#  'Hay-Pauncefote',
#  'Heaven-favored',
#  'Heavy-armed',
#  'Hesse-Darmstadt',
#  'High-ranking',
#  'High-wage',
#  'Hill-Burton',
#  'Hispanic-Americans',
#  'Hiss-Chambers',
#  'Hitler-dominated',
#  'Ho-si-woo',
#  'Hope-renewed',
#  'House-business',
#  'Hsiao-ping',
#  'Hudson-Fulton',
#  'Humphrey-Hawkins',
#  'IA-ECOSOC',
#  'II-has',
#  'III-C',
#  'INTER-AMERICAN',
#  'INTERSTATE-COMMERCE',
#  'Indian-school',
#  'Indo-China',
#  'Indo-Chinese',
#  'Indonesian-Malaysian',
#  'Inspector-General',
#  'Inter-American',
#  'Inter-Departmental',
#  'Intermediate-Range',
#  'Internal-Revenue',
#  'Internal-revenue',
#  'Iran-Iraq',
#  'Iraqi-led',
#  'Irish-American',
#  'Irish-Catholic',
#  'Irish-Protestant',
#  'Israeli-Jordanian',
#  'Israeli-Palestinian',
#  'Italian-Americans',
#  'J-58',
#  'Jackson-Vanik',
#  'Jaish-e-Mohammed',
#  'Japanese-American',
#  'Jefferson-like',
#  'Jewish-Americans',
#  'Job-killing',
#  'Johnson-Humphrey',
#  'Judas-like',
#  'Judge-Advocate-General',
#  'Judge-Advocates',
#  'Kassebaum-Kennedy',
#  'Kellogg-Briand',
#  'Kemp-Roth',
#  'Kennedy-Johnson',
#  'Kennedy-Kassebaum',
#  'Kennedy-McCarthy',
#  'Key-Stone',
#  'Kiao-chow',
#  'Klan-minded',
#  'LATIN-AMERICAN',
#  'LAW-THE',
#  'LIGHT-HOUSE',
#  'LIGHT-HOUSES',
#  'LONG-STANDING',
#  'Labor-Management',
#  'Lakes-St',
#  'Lao-tzu',
#  'Laos-regained',
#  'Large-scale',
#  'Latter-day',
#  'Law-abiding',
#  'Law-clerk',
#  'Lieutenant-Colonel',
#  'Lieutenant-Commander',
#  'Lieutenant-General',
#  'Life-Saving',
#  'Light-House',
#  'Light-houses',
#  'Lincoln\'s-"Let',
#  'Long-term',
#  'Low-income',
#  'Low-tax',
#  'M-1',
#  'MI-8',
#  'MS-13',
#  'Major-General',
#  'Man-of-war',
#  'Manila-Hongkong',
#  'Mansfield-Scott',
#  'Marine-Hospital',
#  'Marquez-Greene',
#  'Marxism-Leninism',
#  'Marxist-Leninism',
#  'Marxist-Leninist',
#  'Marxist-Leninists',
#  'Mason-Dixon',
#  'Mazar-e-Sharif',
#  'McCain-Feingold',
#  'Mecklenburg-Schwerin',
#  'Medicare-approved',
#  'Medicare-rarely',
#  'Meuse-Argonne',
#  'Mid-Atlantic',
#  'Middle-class',
#  'Middleton-Doctor',
#  'Mig-23',
#  'Mm-hmm',
#  'Modern-day',
#  'Money-Order',
#  'Moore-Brown',
#  'Muslim-majority',
#  'Mustering-out',
#  'NAVY-YARDS',
#  'Nation-wide',
#  'Nations-and',
#  'Nations-led',
#  'Navy-Yard',
#  'Nazi-dominated',
#  'Nazi-ism',
#  'Nebraska-Kansas',
#  'New-England',
#  'New-Jersey',
#  'New-Orleans',
#  'New-York',
#  'Night-inspector',
#  'Nine-eleven',
#  'Nixon-16',
#  'Nixon-Ford',
#  'Non-Discrimination',
#  'Non-Proliferation',
#  'Non-intervention',
#  'North-Carolina',
#  'North-South',
#  'North-West',
#  'North-Western',
#  'Nuclear-Test-Ban',
#  'OB-GYN',
#  'Oil-producing',
#  'Old-fashioned',
#  'On-site',
#  'Once-bitter',
#  'One-eighth',
#  'One-fourth',
#  'One-half',
#  'One-third',
#  'Ottoman-born',
#  'P-Tech',
#  'PANAMA-PACIFIC',
#  'POST-OFFICE',
#  'POSTAL-SAVINGS',
#  'PURE-FOOD',
#  'Pacific-cable',
#  'Pago-Pago',
#  'Pakistan-600',
#  'Pan-Amencan',
#  'Pan-American',
#  'Pan-Americanism',
#  'Panama-Pacific',
#  'Paper-covered',
#  'Paymaster-General',
#  'Paymaster-General.3',
#  'Payne-Aldrich',
#  'Pei-Ho',
#  'Peit-sang',
#  'Pent-up',
#  'Peru-Bolivian',
#  'Port-au-Prince',
#  'Post-9/11',
#  'Post-Dispatch',
#  'Post-Office',
#  'Post-OfficeDepartment',
#  'Post-Roads',
#  'Post-office',
#  'Post-offices',
#  'Post-roads',
#  'PostMaster-General',
#  'Postmaster-General',
#  'Postmaster-Generalagainst',
#  'Postmaster-Generals',
#  'Pre-K',
#  'President-Elect',
#  'President-and',
#  'President-as',
#  'President-some',
#  'President-that',
#  'President-to-be',
#  'President-tried',
#  'President-with',
#  'Presidents-President',
#  'Prize-winning',
#  'Provost-Marshal-General',
#  'Qaeda-Iraq',
#  'Quartermaster-General',
#  'R-U',
#  'R-e-g-a-n',
#  'RC-135',
#  'RICA-COLOMBIA',
#  'RS-70',
#  'Ranger-type',
#  'Re-Election',
#  'Re-employment',
#  'Re-enlistment',
#  'Reagan-Bush',
#  'Reagan-Kemp-Roth',
#  'Rear-Admiral',
#  'Revenue-Cutter',
#  'Richmond-based',
#  'Rip-Rap',
#  'Rush-Bagot',
#  'Russo-American',
#  'Russo-Japanese',
#  'SECOND-CLASS',
#  'SELF-DEFENSE',
#  'SEMI-CENTENNIAL',
#  'SLAVE-DEALER',
#  'SR-71',
#  'SR-7I',
#  'SS-18',
#  'SS-20',
#  'SS-20s',
#  'SS-21',
#  'SS-4',
#  'SS-4s',
#  'SS-5',
#  'STABT-Strategic',
#  'Sabbath-Sunday',
#  'Sai-shek',
#  'Sam-whoever',
#  'Saxe-Coburg',
#  'Schleswig-Holstein',
#  'Scotch-Irish',
#  'Scripps-Howard',
#  'Scud-type',
#  'Secret-Service',
#  'Secretary-General',
#  'Secretary-then-Regan',
#  'Self-defense',
#  'Self-determination',
#  'Self-governed',
#  'Self-government',
#  'Self-interest',
#  'Self-preservation',
#  'Self-reliance',
#  'Self-restraint',
#  'Seong-ho',
#  'September-immediately',
#  'Seventy-Fifth',
#  'Seventy-first',
#  'Seventy-third',
#  'Shan-tung',
#  'Sheppard-Towner',
#  'Short-term',
#  'Signal-Service',
#  'Simpson-Bowles',
#  'Simpson-Mazzoli',
#  'Sino-American',
#  'Sino-Soviet',
#  'Sixty-eighth',
#  'Sixty-first',
#  'Sixty-fourth',
#  'Sixty-sixth',
#  'Sixty-third',
#  'Slave-Code',
#  'Small-business',
#  'Smoot-Haw',
#  'Solicitor-General',
#  'South-Carolina',
#  'South-west',
#  'Soviet-American',
#  'Soviet-Chinese',
#  'Soviet-Cuban',
#  'Soviet-U.S.',
#  'Soviet-built',
#  'Soviet-made',
#  'Soviet-occupied',
#  'Soviet-sponsored',
#  'Soviet-supported',
#  'Spanish-American',
#  'Spanish-speaking',
#  'Speaker-elect',
#  'Star-Spangled',
#  'Star-Warring',
#  'State-administered',
#  'State-an',
#  'State-bank',
#  'State-controlled',
#  'State-directed',
#  'State-owned',
#  'State-sponsored',
#  'State-supported',
#  'States-Mexican',
#  'States-a',
#  'States-besides',
#  'Steamboat-Inspection',
#  'Sung-pu',
#  'Surgeon-General',
#  'Suz-ahn',
#  'Syrian-backed',
#  'Sze-chuen',
#  'TACNA-ARICA',
#  'Ta-lien-wan',
#  'Tacna-Arica',
#  'Taft-Ellender-Wagner',
#  'Tax-exempt',
#  'Ten-forties',
#  'The-world',
#  'Thirty-eighth',
#  'Thirty-fifth',
#  'Thirty-ninth',
#  'Thomas-Anita',
#  'Three-fourths',
#  'Three-quarters',
#  'Tien-Tsin',
#  'Tien-tsin',
#  'Ting-fang',
#  'To-day',
#  'To-morrow',
#  'Trans-Missouri',
#  'Trans-Pacific',
#  'Trenton-Princeton',
#  'Truman-Acheson',
#  'Trump-Pence',
#  'Tsai-Hsun',
#  'Tsai-tao',
#  'Tse-tung',
#  'Tsing-tao',
#  'Tsung-li',
#  'Twenty-fifth',
#  'Twenty-first',
#  'Two-thirds',
#  'U-2',
#  'U-Boats',
#  'U-boats',
#  'U.S.-Canadian',
#  'U.S.-Japan',
#  'U.S.-Korea',
#  'U.S.-Mexico',
#  'U.S.-Mexico-Canada',
#  'U.S.-Panamanian',
#  'Ukrainian-Americans',
#  'Union-for',
#  'Union-loving',
#  'Union-men',
#  'Union-saving',
#  'Union-supporting',
#  'V-1',
#  'V-2',
#  'V-J',
#  'V-chip',
#  'Vice-Presidency',
#  'Vice-President',
#  'Vice-Presidential',
#  'Viet-Nam',
#  'Vietnam-and',
#  'Vietnam-apply',
#  'Vietnam-backed',
#  'W-GDP',
#  'Wage-workers',
#  'Wagner-Ellender-Taft',
#  'War-would',
#  'Washington-based',
#  'Web-feet',
#  'Wei-hai-wei',
#  'Well-considered',
#  'Well-founded',
#  'Well-trained',
#  'Western-proposed',
#  'Western-type',
#  'Wilkes-Barre',
#  'X-rated',
#  'Yang-Tse',
#  'Yen-hoon',
#  'Zero-Option',
#  'Zimbabwe-Rhodesia',
#  'able-bodied',
#  'above-cited',
#  'above-estimated',
#  'above-mentioned',
#  'above-named',
#  'above-recited',
#  'abroad-the',
#  'abroad-to',
#  'academy-type',
#  'accept-and',
#  'across-the-board',
#  'act-$350,000,000',
#  'action-to',
#  'add-ons',
#  'adjusted-service',
#  'administration-and',
#  'administration-as',
#  'administration-helped',
#  'administration-laws',
#  'administration-tried',
#  'administrations-to',
#  'advance-and',
#  'advanced-placement',
#  'advantage-and',
#  'advantages-in',
#  "afflicted-they've",
#  'afford-along',
#  'after-dinner',
#  'after-effect',
#  'after-effects',
#  'after-school',
#  'after-tax',
#  'again,-a',
#  'age-long',
#  'age-old',
#  'agencies-as',
#  'agencies-is',
#  'aggression-and',
#  'aggression-that',
#  'aggression-to',
#  'ago-and',
#  'ago-ideas',
#  'ago-many',
#  'ago-passed',
#  'ago-was',
#  'agreements-agreements',
#  'agricultural-college',
#  'ahead-immediately',
#  'aid-to-democracies',
#  'air-based',
#  'air-landing',
#  'air-lane',
#  'air-lift',
#  'air-mail',
#  'air-raid',
#  'air-to-air',
#  'al-Assad',
#  'al-Baghdadi',
#  "al-Qa'ida",
#  'al-Qaeda',
#  'al-Sabah',
#  'al-Suhail',
#  'all-American',
#  'all-Asian',
#  'all-German',
#  'all-Indochina',
#  'all-absorbing',
#  'all-and',
#  'all-black',
#  'all-embracing',
#  'all-engrossing',
#  'all-important',
#  'all-in',
#  'all-inclusive',
#  'all-male',
#  'all-merciful',
#  'all-military',
#  'all-of-the-above',
#  'all-or-nothing',
#  'all-out',
#  'all-pervading',
#  'all-powerful',
#  'all-round',
#  'all-solar',
#  'all-time',
#  'all-volunteer',
#  'all-weather',
#  'all-wind',
#  'all-wise',
#  'alliance-building',
#  'allies-just',
#  'alone-and',
#  'amendments-it',
#  'and-towns',
#  'andlaw-abiding',
#  'anever-increasing',
#  'animal-killers',
#  'anniversary-let',
#  'antagonisms-that',
#  'ante-revolutionary',
#  'anti-American',
#  'anti-Catholic',
#  'anti-Communism',
#  'anti-Communist',
#  'anti-Fascist',
#  'anti-Nazi',
#  'anti-Semitic',
#  'anti-Semitism',
#  'anti-Somoza',
#  'anti-Soviet',
#  'anti-U.S.',
#  'anti-Vietnam',
#  'anti-Washington',
#  'anti-aircraft',
#  'anti-bullying',
#  'anti-business',
#  'anti-climb',
#  'anti-communism',
#  'anti-corruption',
#  'anti-craft',
#  'anti-crime',
#  'anti-drug-trafficking',
#  'anti-energy',
#  'anti-fraud',
#  'anti-government',
#  'anti-guerrilla',
#  'anti-inflation',
#  'anti-inflationary',
#  'anti-intellectualism',
#  'anti-military',
#  'anti-narcotic',
#  'anti-philosophers',
#  'anti-pollution',
#  'anti-poverty',
#  'anti-recession',
#  'anti-retroviral',
#  'anti-semitic',
#  'anti-slavery',
#  'anti-submarine',
#  'anti-tank',
#  'anti-terrorism',
#  'anti-terrorist',
#  'anti-trust',
#  'anti-worker',
#  'antici-pations',
#  'apple-selling',
#  'appropriate-and',
#  'are-five',
#  'areas-new',
#  'arena-an',
#  'arm-in-arm',
#  'armor-piercing',
#  'armor-plate',
#  'arms-Mother',
#  'army-not',
#  'aspirations-have',
#  'asylum-seekers',
#  'at-risk',
#  'atomic-missile',
#  'attack,-dangers',
#  'attorney-client',
#  'attorney-general',
#  'audience-it',
#  'available-and',
#  ...]

# %% [markdown]
# >> #### 5.1 Problem: Ordinal numbers do not need to be cleaned

# %%
valid_token_word_nums = [token for token in hyphen_tokens if is_ordinal(token.lower())]
valid_token_word_nums
# Out:
# ['Fifty-first',
#  'Fifty-seventh',
#  'Fifty-sixth',
#  'Fifty-third',
#  'Forty-first',
#  'Forty-fourth',
#  'Forty-seventh',
#  'Forty-sixth',
#  'Seventy-first',
#  'Seventy-third',
#  'Sixty-first',
#  'Sixty-fourth',
#  'Sixty-sixth',
#  'Sixty-third',
#  'Twenty-first',
#  'eighty-second',
#  'eighty-seventh',
#  'fifty-fourth',
#  'fifty-second',
#  'fifty-seventh',
#  'fifty-sixth',
#  'fifty-third',
#  'forty-first',
#  'forty-second',
#  'forty-third',
#  'ninety-first',
#  'ninety-fourth',
#  'ninety-second',
#  'ninety-sixth',
#  'ninety-third',
#  'seventy-first',
#  'seventy-seventh',
#  'sixty-second',
#  'sixty-third',
#  'thirty-first',
#  'thirty-fourth',
#  'thirty-second',
#  'thirty-sixth',
#  'twenty-first',
#  'twenty-fourth',
#  'twenty-second',
#  'twenty-seventh',
#  'twenty-sixth',
#  'twenty-third']

# %% [markdown]
# >> #### 5.2 Solution: Remove ordinal tokens from tokens to be cleaned

# %%
hyphen_tokens = sorted(list(set(hyphen_tokens).difference(set(valid_token_word_nums))))
hyphen_tokens
# Out:
# ['1,500-a-year',
#  '1-day',
#  '1-in-20',
#  '1-yard',
#  '1-year',
#  '1-year-old',
#  '1/2-inch',
#  '1/2-percent',
#  '10,000-foot',
#  '10,000-page',
#  '10,000-ton',
#  '10-day',
#  '10-inch',
#  '10-man',
#  '10-minute',
#  '10-percent',
#  '10-round',
#  '10-to-1',
#  '10-year',
#  '10-year-old',
#  '100-cent',
#  '11-year-old',
#  '12-hour',
#  '12-inch',
#  '12-month',
#  '12-year-old',
#  '122-foot',
#  '122-percent',
#  '13-year-old',
#  '13Ѕ-inch',
#  '14-percent',
#  '14-point',
#  '14-to-1',
#  '14-year',
#  '14-year-old',
#  '15-percent',
#  '15-year-olds',
#  '152-millimeter',
#  '16-inch',
#  '16-inch-type',
#  '16-year-old',
#  '167-page',
#  '17-year',
#  '17-year-low',
#  '17-year-old',
#  '18-hour',
#  '18-nation',
#  '18-percent',
#  '18-wheelers',
#  '18-year-old',
#  '18-year-olds',
#  '180-odd',
#  '19-foot',
#  '19-year-old',
#  '19-year-olds',
#  '190-year',
#  '1970s-era',
#  '19th-century',
#  '2,000-foot',
#  '2,000-mile',
#  '2-in-3',
#  '2-is',
#  '2-minute',
#  '2-percent',
#  '2-year',
#  '2-year-old',
#  '2-year-olds',
#  '20-knot',
#  '20-percent',
#  '20-point',
#  '20-year',
#  '20-year-old',
#  '200-mile',
#  '200-year',
#  '200-year-old',
#  '21st-century',
#  '22,000-word',
#  '22-month',
#  '22-percent',
#  '23-knot',
#  '24-hour',
#  '24-knot',
#  '24-year',
#  '25-percent',
#  '25-year',
#  '250-bed',
#  '26-year-old',
#  '28-minute',
#  '28-percent',
#  '28-square-mile',
#  '3-day',
#  '3-inch',
#  '3-mile',
#  '3-minute',
#  '3-point',
#  '3-to-1',
#  '3-year',
#  '3/4-year',
#  '30-cent',
#  '30-day',
#  '30-minute',
#  '30-odd',
#  '30-percent',
#  '30-second',
#  '30-year',
#  '35-day',
#  '35-hour',
#  '35-percent',
#  '36-percent',
#  '37-point',
#  '3D-print',
#  '3rd-grade',
#  '4-or',
#  '4-percent',
#  '4-point',
#  '4-something',
#  '4-star',
#  '4-year',
#  '4-year-old',
#  '4.8-percent',
#  '40,000-odd',
#  '40-nation',
#  '40-percent',
#  '40-some',
#  '40-yard',
#  '40-year',
#  '45-second',
#  '45-year',
#  '47-year-old',
#  '48-story',
#  '49-year-old',
#  '5-ambulatory',
#  '5-day',
#  '5-letter',
#  '5-percent',
#  '5-power',
#  '5-year',
#  '5-year-old',
#  '50,000-a-year',
#  '50-cent',
#  '50-cent-a-gallon',
#  '50-hour',
#  '50-percent',
#  '50-year',
#  '500-billion',
#  '500-million',
#  '500-per-child',
#  '500-year',
#  '55-mile',
#  '5?-percent',
#  '6-day',
#  '6-inch',
#  '6-month',
#  '6-months',
#  '6-percent',
#  '6-point',
#  '6-pounder',
#  '6-year',
#  '60,000-plus',
#  '60-day',
#  '60-second',
#  '600,000-man',
#  '600-page',
#  '600-percent',
#  '600-ship',
#  '62-year-olders',
#  '65-year',
#  '650-billion-a-year',
#  '7-day',
#  '7-percent',
#  '7-year',
#  '7-year-long',
#  '70-million',
#  '70-percent',
#  '73-percent',
#  '75-bed',
#  '75-page',
#  '75-year-old',
#  '77-percent',
#  '8-inch',
#  '8-year',
#  '8-year-old',
#  '8-year-olds',
#  '800-HELPNOW',
#  '800-some',
#  '81-which',
#  '85-foot',
#  '88-year-old',
#  '9,000-men',
#  '9-foot',
#  '9-hour',
#  '9-millimeter',
#  '9-year-olds',
#  '9.2-percent',
#  '90-day',
#  '90-minute',
#  '90-second',
#  '900,000-$900,000',
#  '91-to-1',
#  '960-acre',
#  'A-11',
#  'A-6F',
#  'A-grade',
#  'A-plus',
#  'ACT-UP',
#  'ADJUTANT-GENERAL',
#  'AIDS-free',
#  'AK-47s',
#  'AMERICA-HONDURAS',
#  'ANTI-TRUST',
#  'ARBITRATIONS-PANAMA',
#  'Adjutant-General',
#  'Administration-Mr',
#  'African-American',
#  'African-Americans',
#  'African-owned',
#  'Ah-h-h',
#  'Aigner-Clark',
#  'Aix-la-Chapelle',
#  'Al-Azhar',
#  'Alaskan-Yukon-Pacific',
#  'All-merciful',
#  'All-powerful',
#  'All-time',
#  'Allies-in',
#  'Alsace-Lorraine',
#  'Amazon-Washington',
#  'Ambassador-Mr',
#  'America-in',
#  'America-the',
#  'American-British',
#  'American-Hellenic',
#  'American-Soviet',
#  'American-born',
#  'American-built',
#  'American-made',
#  'American-mediated',
#  'American-owned',
#  'Americans-to',
#  'Americas-the',
#  'An-tung',
#  'Anglo-Saxon',
#  'Anglo-Venezuelan',
#  'Anti-Trust',
#  'Antung-Mukden',
#  'Apollo-Gemini',
#  'Arab-Israeli',
#  'Armenian-Americans',
#  'As-salaamu',
#  'Asia-Pacific',
#  'Asia-and',
#  'Asia-which',
#  'Asian-American',
#  'Asian-Americans',
#  'Assembly-have',
#  'Atlantic-Mississippi',
#  'Attorney-General',
#  'Attorneys-General',
#  'Austro-Hungarian',
#  'B-1',
#  'B-1B',
#  'B-2',
#  'B-22',
#  'B-29',
#  'B-47',
#  'B-52',
#  'B-l',
#  'BUNAU-VARILLA',
#  'Baltic-Americans',
#  'Band-Aid',
#  'Band-aid',
#  'Berlin-and',
#  'Big-Brother-is-watching-you',
#  'Big-hearted',
#  'Black-owned',
#  'Blue-collar',
#  'Boo-o-o',
#  'Bosnia-wide',
#  'Boutros-Ghali',
#  'Brest-Litovsk',
#  'Briand-Kellogg',
#  'Brigadier-General',
#  'British-American',
#  'Bunau-Varilla',
#  'Bush-McCain',
#  'C-1',
#  'C-SPAN',
#  'C-minus',
#  'CAPITAL-GAINS',
#  'CIVIL-SERVICE',
#  'CONFERENCE-UNFORTUNATE',
#  'CONSULATE-GENERAL',
#  'Cabinet-level',
#  'Cambodian-Vietnam',
#  'Capper-Ketcham',
#  'Capper-Volstead',
#  'Captain-General',
#  'Captain-Generalto',
#  'Carter-Mondale',
#  'Catch-and-release',
#  'Census-we',
#  'Cha-Cha-Cha',
#  'Chamber-the',
#  'Chi-li',
#  'China-U.S.',
#  'Chinchow-Aigun',
#  'Chinese-American',
#  'Chinese-Japanese',
#  'Chinese-made',
#  'Christ-like',
#  'Civil-Service',
#  'Civil-service',
#  'Clayton-Bulwer',
#  'Clear-eyed',
#  'Co-operation',
#  'Coal-land',
#  'Coleman-Singleton',
#  'Columbia-it',
#  'Commander-in-Chief',
#  'Commissary-General',
#  'Commissioner-General',
#  'Communist-controlled',
#  'Communist-directed',
#  'Communist-dominated',
#  'Communist-inspired',
#  'Communist-supplied',
#  'Communist-supported',
#  'Conable-Hanee',
#  'Congo-Adoula',
#  'Congo-Kinshasa',
#  'Congress-and',
#  'Congress-by',
#  'Congress-through',
#  'Consul-General',
#  'Convention-my',
#  'Corps]-type',
#  'Cuban-Soviet',
#  'D-day',
#  'DECISION-MERELY',
#  'Dar-Es-Salaam',
#  'Day-inspector',
#  'Dead-Letter',
#  'Democratic-controlled',
#  'Director-General',
#  'Disarmament-Canada',
#  'Double-digit',
#  'Douglas-Home',
#  'Drug-Free',
#  'E-rate',
#  'EIGHT-HOUR',
#  'ELECTRICAL-POWER',
#  'Earth-based',
#  'East-West',
#  'East-mark',
#  'East-there',
#  'Egypt-Saudi',
#  'Egyptian-Israeli',
#  'Eisenhower-and',
#  'Eisenhower-they',
#  'Elizabeth-City',
#  'Empress-Queen',
#  'English-speaking',
#  'Entente-Allies',
#  'Establishment-this',
#  'Europe-the',
#  'Ex-Corporal',
#  'Export-Import',
#  'Eyre-Cragin',
#  'F-1',
#  'F-14',
#  'F-14s',
#  'F-15',
#  'F-35',
#  'F1a.-there',
#  'FBI-in',
#  'FELLOW-CITIZENS',
#  'FUR-SEAL',
#  'Fair-minded',
#  'Faith-Based',
#  'Faith-based',
#  'Far-reaching',
#  'Farmer-Labor',
#  'Federal-State',
#  'Federal-assisted',
#  'Federal-highway',
#  'Federally-funded',
#  'Fellow-Citizens',
#  'Fellow-Countrymen',
#  'Fellow-citizens',
#  'Fiat-Chrysler',
#  'Fifty-eighth',
#  'Fifty-fifth',
#  'Fifty-four-forty',
#  'Fish-Culture',
#  'Five-Year',
#  'Five-twenties',
#  'Fix-It-First',
#  'Flat-head',
#  'Follow-up',
#  'Foo-Choo-Foo',
#  'Food-for-Peace',
#  'Fordney-McCumber',
#  'Forty-fifth',
#  'Forty-ninth',
#  'Four-Power',
#  'Four-fifths',
#  'Franco-American',
#  'Frankfort-on-the-Main',
#  'Franklin-leaning',
#  'Free-Soilers',
#  'Free-State',
#  'Free-delivery',
#  'Free-market',
#  'G-20',
#  'G-8',
#  'GS-12',
#  'GS-18',
#  'Gall-lard',
#  'Garner-Rainey',
#  'Germany-the',
#  'Germany-voting',
#  'God-awful',
#  'God-blessed',
#  'God-fearing',
#  'God-given',
#  'God-imposed',
#  'Government-improved',
#  'Government-its',
#  'Government-led',
#  'Government-owned',
#  'Government-regulated',
#  'Government-the',
#  'Government-under',
#  'Government-wide',
#  'Governments-Germany',
#  'Governor-General',
#  'Governor-to',
#  'Gramm-Rudman',
#  'Gramm-Rudman-Hollings',
#  'Grant-in-aid',
#  'Greek-Turkish',
#  'H-43',
#  'H-bomb',
#  'HIV-positive',
#  'HOME-LOAN',
#  'Haitian-Americans',
#  'Haitian-Dominican',
#  'Half-hearted',
#  'Hard-headedness',
#  'Harley-Davidson',
#  'Harvard-trained',
#  'Hawaiian-Japanese',
#  'Hawley-Smoot',
#  'Hay-Herran',
#  'Hay-Pauncefote',
#  'Heaven-favored',
#  'Heavy-armed',
#  'Hesse-Darmstadt',
#  'High-ranking',
#  'High-wage',
#  'Hill-Burton',
#  'Hispanic-Americans',
#  'Hiss-Chambers',
#  'Hitler-dominated',
#  'Ho-si-woo',
#  'Hope-renewed',
#  'House-business',
#  'Hsiao-ping',
#  'Hudson-Fulton',
#  'Humphrey-Hawkins',
#  'IA-ECOSOC',
#  'II-has',
#  'III-C',
#  'INTER-AMERICAN',
#  'INTERSTATE-COMMERCE',
#  'Indian-school',
#  'Indo-China',
#  'Indo-Chinese',
#  'Indonesian-Malaysian',
#  'Inspector-General',
#  'Inter-American',
#  'Inter-Departmental',
#  'Intermediate-Range',
#  'Internal-Revenue',
#  'Internal-revenue',
#  'Iran-Iraq',
#  'Iraqi-led',
#  'Irish-American',
#  'Irish-Catholic',
#  'Irish-Protestant',
#  'Israeli-Jordanian',
#  'Israeli-Palestinian',
#  'Italian-Americans',
#  'J-58',
#  'Jackson-Vanik',
#  'Jaish-e-Mohammed',
#  'Japanese-American',
#  'Jefferson-like',
#  'Jewish-Americans',
#  'Job-killing',
#  'Johnson-Humphrey',
#  'Judas-like',
#  'Judge-Advocate-General',
#  'Judge-Advocates',
#  'Kassebaum-Kennedy',
#  'Kellogg-Briand',
#  'Kemp-Roth',
#  'Kennedy-Johnson',
#  'Kennedy-Kassebaum',
#  'Kennedy-McCarthy',
#  'Key-Stone',
#  'Kiao-chow',
#  'Klan-minded',
#  'LATIN-AMERICAN',
#  'LAW-THE',
#  'LIGHT-HOUSE',
#  'LIGHT-HOUSES',
#  'LONG-STANDING',
#  'Labor-Management',
#  'Lakes-St',
#  'Lao-tzu',
#  'Laos-regained',
#  'Large-scale',
#  'Latter-day',
#  'Law-abiding',
#  'Law-clerk',
#  'Lieutenant-Colonel',
#  'Lieutenant-Commander',
#  'Lieutenant-General',
#  'Life-Saving',
#  'Light-House',
#  'Light-houses',
#  'Lincoln\'s-"Let',
#  'Long-term',
#  'Low-income',
#  'Low-tax',
#  'M-1',
#  'MI-8',
#  'MS-13',
#  'Major-General',
#  'Man-of-war',
#  'Manila-Hongkong',
#  'Mansfield-Scott',
#  'Marine-Hospital',
#  'Marquez-Greene',
#  'Marxism-Leninism',
#  'Marxist-Leninism',
#  'Marxist-Leninist',
#  'Marxist-Leninists',
#  'Mason-Dixon',
#  'Mazar-e-Sharif',
#  'McCain-Feingold',
#  'Mecklenburg-Schwerin',
#  'Medicare-approved',
#  'Medicare-rarely',
#  'Meuse-Argonne',
#  'Mid-Atlantic',
#  'Middle-class',
#  'Middleton-Doctor',
#  'Mig-23',
#  'Mm-hmm',
#  'Modern-day',
#  'Money-Order',
#  'Moore-Brown',
#  'Muslim-majority',
#  'Mustering-out',
#  'NAVY-YARDS',
#  'Nation-wide',
#  'Nations-and',
#  'Nations-led',
#  'Navy-Yard',
#  'Nazi-dominated',
#  'Nazi-ism',
#  'Nebraska-Kansas',
#  'New-England',
#  'New-Jersey',
#  'New-Orleans',
#  'New-York',
#  'Night-inspector',
#  'Nine-eleven',
#  'Nixon-16',
#  'Nixon-Ford',
#  'Non-Discrimination',
#  'Non-Proliferation',
#  'Non-intervention',
#  'North-Carolina',
#  'North-South',
#  'North-West',
#  'North-Western',
#  'Nuclear-Test-Ban',
#  'OB-GYN',
#  'Oil-producing',
#  'Old-fashioned',
#  'On-site',
#  'Once-bitter',
#  'One-eighth',
#  'One-fourth',
#  'One-half',
#  'One-third',
#  'Ottoman-born',
#  'P-Tech',
#  'PANAMA-PACIFIC',
#  'POST-OFFICE',
#  'POSTAL-SAVINGS',
#  'PURE-FOOD',
#  'Pacific-cable',
#  'Pago-Pago',
#  'Pakistan-600',
#  'Pan-Amencan',
#  'Pan-American',
#  'Pan-Americanism',
#  'Panama-Pacific',
#  'Paper-covered',
#  'Paymaster-General',
#  'Paymaster-General.3',
#  'Payne-Aldrich',
#  'Pei-Ho',
#  'Peit-sang',
#  'Pent-up',
#  'Peru-Bolivian',
#  'Port-au-Prince',
#  'Post-9/11',
#  'Post-Dispatch',
#  'Post-Office',
#  'Post-OfficeDepartment',
#  'Post-Roads',
#  'Post-office',
#  'Post-offices',
#  'Post-roads',
#  'PostMaster-General',
#  'Postmaster-General',
#  'Postmaster-Generalagainst',
#  'Postmaster-Generals',
#  'Pre-K',
#  'President-Elect',
#  'President-and',
#  'President-as',
#  'President-some',
#  'President-that',
#  'President-to-be',
#  'President-tried',
#  'President-with',
#  'Presidents-President',
#  'Prize-winning',
#  'Provost-Marshal-General',
#  'Qaeda-Iraq',
#  'Quartermaster-General',
#  'R-U',
#  'R-e-g-a-n',
#  'RC-135',
#  'RICA-COLOMBIA',
#  'RS-70',
#  'Ranger-type',
#  'Re-Election',
#  'Re-employment',
#  'Re-enlistment',
#  'Reagan-Bush',
#  'Reagan-Kemp-Roth',
#  'Rear-Admiral',
#  'Revenue-Cutter',
#  'Richmond-based',
#  'Rip-Rap',
#  'Rush-Bagot',
#  'Russo-American',
#  'Russo-Japanese',
#  'SECOND-CLASS',
#  'SELF-DEFENSE',
#  'SEMI-CENTENNIAL',
#  'SLAVE-DEALER',
#  'SR-71',
#  'SR-7I',
#  'SS-18',
#  'SS-20',
#  'SS-20s',
#  'SS-21',
#  'SS-4',
#  'SS-4s',
#  'SS-5',
#  'STABT-Strategic',
#  'Sabbath-Sunday',
#  'Sai-shek',
#  'Sam-whoever',
#  'Saxe-Coburg',
#  'Schleswig-Holstein',
#  'Scotch-Irish',
#  'Scripps-Howard',
#  'Scud-type',
#  'Secret-Service',
#  'Secretary-General',
#  'Secretary-then-Regan',
#  'Self-defense',
#  'Self-determination',
#  'Self-governed',
#  'Self-government',
#  'Self-interest',
#  'Self-preservation',
#  'Self-reliance',
#  'Self-restraint',
#  'Seong-ho',
#  'September-immediately',
#  'Seventy-Fifth',
#  'Shan-tung',
#  'Sheppard-Towner',
#  'Short-term',
#  'Signal-Service',
#  'Simpson-Bowles',
#  'Simpson-Mazzoli',
#  'Sino-American',
#  'Sino-Soviet',
#  'Sixty-eighth',
#  'Slave-Code',
#  'Small-business',
#  'Smoot-Haw',
#  'Solicitor-General',
#  'South-Carolina',
#  'South-west',
#  'Soviet-American',
#  'Soviet-Chinese',
#  'Soviet-Cuban',
#  'Soviet-U.S.',
#  'Soviet-built',
#  'Soviet-made',
#  'Soviet-occupied',
#  'Soviet-sponsored',
#  'Soviet-supported',
#  'Spanish-American',
#  'Spanish-speaking',
#  'Speaker-elect',
#  'Star-Spangled',
#  'Star-Warring',
#  'State-administered',
#  'State-an',
#  'State-bank',
#  'State-controlled',
#  'State-directed',
#  'State-owned',
#  'State-sponsored',
#  'State-supported',
#  'States-Mexican',
#  'States-a',
#  'States-besides',
#  'Steamboat-Inspection',
#  'Sung-pu',
#  'Surgeon-General',
#  'Suz-ahn',
#  'Syrian-backed',
#  'Sze-chuen',
#  'TACNA-ARICA',
#  'Ta-lien-wan',
#  'Tacna-Arica',
#  'Taft-Ellender-Wagner',
#  'Tax-exempt',
#  'Ten-forties',
#  'The-world',
#  'Thirty-eighth',
#  'Thirty-fifth',
#  'Thirty-ninth',
#  'Thomas-Anita',
#  'Three-fourths',
#  'Three-quarters',
#  'Tien-Tsin',
#  'Tien-tsin',
#  'Ting-fang',
#  'To-day',
#  'To-morrow',
#  'Trans-Missouri',
#  'Trans-Pacific',
#  'Trenton-Princeton',
#  'Truman-Acheson',
#  'Trump-Pence',
#  'Tsai-Hsun',
#  'Tsai-tao',
#  'Tse-tung',
#  'Tsing-tao',
#  'Tsung-li',
#  'Twenty-fifth',
#  'Two-thirds',
#  'U-2',
#  'U-Boats',
#  'U-boats',
#  'U.S.-Canadian',
#  'U.S.-Japan',
#  'U.S.-Korea',
#  'U.S.-Mexico',
#  'U.S.-Mexico-Canada',
#  'U.S.-Panamanian',
#  'Ukrainian-Americans',
#  'Union-for',
#  'Union-loving',
#  'Union-men',
#  'Union-saving',
#  'Union-supporting',
#  'V-1',
#  'V-2',
#  'V-J',
#  'V-chip',
#  'Vice-Presidency',
#  'Vice-President',
#  'Vice-Presidential',
#  'Viet-Nam',
#  'Vietnam-and',
#  'Vietnam-apply',
#  'Vietnam-backed',
#  'W-GDP',
#  'Wage-workers',
#  'Wagner-Ellender-Taft',
#  'War-would',
#  'Washington-based',
#  'Web-feet',
#  'Wei-hai-wei',
#  'Well-considered',
#  'Well-founded',
#  'Well-trained',
#  'Western-proposed',
#  'Western-type',
#  'Wilkes-Barre',
#  'X-rated',
#  'Yang-Tse',
#  'Yen-hoon',
#  'Zero-Option',
#  'Zimbabwe-Rhodesia',
#  'able-bodied',
#  'above-cited',
#  'above-estimated',
#  'above-mentioned',
#  'above-named',
#  'above-recited',
#  'abroad-the',
#  'abroad-to',
#  'academy-type',
#  'accept-and',
#  'across-the-board',
#  'act-$350,000,000',
#  'action-to',
#  'add-ons',
#  'adjusted-service',
#  'administration-and',
#  'administration-as',
#  'administration-helped',
#  'administration-laws',
#  'administration-tried',
#  'administrations-to',
#  'advance-and',
#  'advanced-placement',
#  'advantage-and',
#  'advantages-in',
#  "afflicted-they've",
#  'afford-along',
#  'after-dinner',
#  'after-effect',
#  'after-effects',
#  'after-school',
#  'after-tax',
#  'again,-a',
#  'age-long',
#  'age-old',
#  'agencies-as',
#  'agencies-is',
#  'aggression-and',
#  'aggression-that',
#  'aggression-to',
#  'ago-and',
#  'ago-ideas',
#  'ago-many',
#  'ago-passed',
#  'ago-was',
#  'agreements-agreements',
#  'agricultural-college',
#  'ahead-immediately',
#  'aid-to-democracies',
#  'air-based',
#  'air-landing',
#  'air-lane',
#  'air-lift',
#  'air-mail',
#  'air-raid',
#  'air-to-air',
#  'al-Assad',
#  'al-Baghdadi',
#  "al-Qa'ida",
#  'al-Qaeda',
#  'al-Sabah',
#  'al-Suhail',
#  'all-American',
#  'all-Asian',
#  'all-German',
#  'all-Indochina',
#  'all-absorbing',
#  'all-and',
#  'all-black',
#  'all-embracing',
#  'all-engrossing',
#  'all-important',
#  'all-in',
#  'all-inclusive',
#  'all-male',
#  'all-merciful',
#  'all-military',
#  'all-of-the-above',
#  'all-or-nothing',
#  'all-out',
#  'all-pervading',
#  'all-powerful',
#  'all-round',
#  'all-solar',
#  'all-time',
#  'all-volunteer',
#  'all-weather',
#  'all-wind',
#  'all-wise',
#  'alliance-building',
#  'allies-just',
#  'alone-and',
#  'amendments-it',
#  'and-towns',
#  'andlaw-abiding',
#  'anever-increasing',
#  'animal-killers',
#  'anniversary-let',
#  'antagonisms-that',
#  'ante-revolutionary',
#  'anti-American',
#  'anti-Catholic',
#  'anti-Communism',
#  'anti-Communist',
#  'anti-Fascist',
#  'anti-Nazi',
#  'anti-Semitic',
#  'anti-Semitism',
#  'anti-Somoza',
#  'anti-Soviet',
#  'anti-U.S.',
#  'anti-Vietnam',
#  'anti-Washington',
#  'anti-aircraft',
#  'anti-bullying',
#  'anti-business',
#  'anti-climb',
#  'anti-communism',
#  'anti-corruption',
#  'anti-craft',
#  'anti-crime',
#  'anti-drug-trafficking',
#  'anti-energy',
#  'anti-fraud',
#  'anti-government',
#  'anti-guerrilla',
#  'anti-inflation',
#  'anti-inflationary',
#  'anti-intellectualism',
#  'anti-military',
#  'anti-narcotic',
#  'anti-philosophers',
#  'anti-pollution',
#  'anti-poverty',
#  'anti-recession',
#  'anti-retroviral',
#  'anti-semitic',
#  'anti-slavery',
#  'anti-submarine',
#  'anti-tank',
#  'anti-terrorism',
#  'anti-terrorist',
#  'anti-trust',
#  'anti-worker',
#  'antici-pations',
#  'apple-selling',
#  'appropriate-and',
#  'are-five',
#  'areas-new',
#  'arena-an',
#  'arm-in-arm',
#  'armor-piercing',
#  'armor-plate',
#  'arms-Mother',
#  'army-not',
#  'aspirations-have',
#  'asylum-seekers',
#  'at-risk',
#  'atomic-missile',
#  'attack,-dangers',
#  'attorney-client',
#  'attorney-general',
#  'audience-it',
#  'available-and',
#  'awe-inspiring',
#  'back-alley',
#  'back-and-forth',
#  'back-to-back',
#  'back-to-school',
#  'background-not',
#  'balance-of-payments',
#  'ballot-box',
#  'bally-ho',
#  'bank-note',
#  'barbed-wire',
#  'base-and',
#  'base-loaded',
#  'battle-cry',
#  'battle-field',
#  ...]

# %% [markdown]
# >> #### 6.1 Problem: Some tokens are two words separated by a hyphen with the second word being a stopword

# %%
STOP_WORDS = spacy.lang.en.stop_words.STOP_WORDS

# Pattern that matches all lowercase tokens
pattern = '^[^-0-9A-Z]+-[^-A-Z]+$'
hyphen_pattern_matches = [re.search(pattern, token)[0] for token in hyphen_tokens if re.search(pattern, token)]

# Pattern that matches the last token
pattern = '([^-]*?)$'
hyphen_pattern_matches_last_token = [re.search(pattern, token)[0] for token in hyphen_pattern_matches if re.search(pattern, token)]

# Pair hyphens
hyphen_pairs = list(zip(hyphen_pattern_matches, hyphen_pattern_matches_last_token))

# Get all hyphen tokens where last token is a stopword
hyphens_before = [a for (a,b) in hyphen_pairs if b in STOP_WORDS]
hyphens_before
# Out:
# ['abroad-the',
#  'abroad-to',
#  'accept-and',
#  'action-to',
#  'administration-and',
#  'administration-as',
#  'administrations-to',
#  'advance-and',
#  'advantage-and',
#  'advantages-in',
#  'afford-along',
#  'again,-a',
#  'agencies-as',
#  'agencies-is',
#  'aggression-and',
#  'aggression-that',
#  'aggression-to',
#  'ago-and',
#  'ago-many',
#  'ago-was',
#  'all-and',
#  'all-in',
#  'all-out',
#  'allies-just',
#  'alone-and',
#  'amendments-it',
#  'antagonisms-that',
#  'appropriate-and',
#  'are-five',
#  'arena-an',
#  'army-not',
#  'aspirations-have',
#  'audience-it',
#  'available-and',
#  'background-not',
#  'base-and',
#  'battle-front',
#  'be-from',
#  'be-the',
#  'be-then',
#  'be-we',
#  'beefed-up',
#  'beings-might',
#  'believe-that',
#  'belt-will',
#  'better-off',
#  'bombed-out',
#  'borders-how',
#  'bore-down',
#  'born-again',
#  'breadth-from',
#  'break-in',
#  'break-through',
#  'budget-for',
#  'build-up',
#  'builders-if',
#  'building-up',
#  'built-in',
#  'burnt-out',
#  'by-the',
#  'call-in',
#  'campaign-and',
#  "can't–-in",
#  'can-and',
#  'can-then',
#  'capacity-in',
#  'capital-all',
#  'catch-and',
#  'categories-and',
#  'change-where',
#  'child-for',
#  'child-not',
#  'children-who',
#  'choose-as',
#  'cities-all',
#  'close-up',
#  'colleges-with',
#  'commissions-some',
#  'commitments-the',
#  'committee-that',
#  'communism-is',
#  'community-to',
#  'complain-to',
#  'concerns-not',
#  'conflict-our',
#  'conflicts-to',
#  'confusion,-by',
#  'consist,-of',
#  'construct-and',
#  'construction-all',
#  'continent-the',
#  'controllers-how',
#  'convictions-can',
#  'countries-we',
#  'country-all',
#  'country-and',
#  'country-could',
#  'country-other',
#  'country-the',
#  'covenant-to',
#  'creation-then',
#  'crisis-to',
#  'crisis-what',
#  'cure-all',
#  'cut-off',
#  'cut-over',
#  'daring-by',
#  'democracy"-that',
#  'demonstrate-against',
#  'departments-the',
#  'depression-and',
#  'depression-that',
#  'deserves-and',
#  'design"-it',
#  'destroyed-the',
#  'developing-or',
#  'development-are',
#  'did-not',
#  'difference-and',
#  'dignity-the',
#  'direction-not',
#  'direction-the',
#  'disagree-and',
#  'disgrace-the',
#  'dissent-who',
#  'do-and',
#  'dominate-which',
#  'done-and',
#  'done-as',
#  'done-we',
#  'double-down',
#  'dramatically-more',
#  'drawn-out',
#  'drive-through',
#  'drivers-to',
#  'due-first',
#  'dust-up',
#  'duty-for',
#  'duty-of',
#  'earlier-the',
#  'earnest-and',
#  'elected-and',
#  'element-of',
#  'emergencies-nor',
#  'emotion-in',
#  'employees-whether',
#  'enterprise-to',
#  'environment-the',
#  'equipment-one',
#  'eras-the',
#  'everyone-some',
#  'exception-we',
#  'exercises-a',
#  'exigency-that',
#  'expansion-all',
#  'expenditures-a',
#  'expenditures-but',
#  'fact-the',
#  'fall-out',
#  'far-off',
#  'favor-that',
#  'feet-of',
#  'fellow-being',
#  'financed-which',
#  'firm-because',
#  'first-ever',
#  'first-name',
#  'flare-up',
#  'flat-out',
#  'follow-everyone',
#  'follow-up',
#  'for-also',
#  'for-that',
#  'forces-to',
#  'foreign-made',
#  'foreigners-as',
#  'forget-that',
#  'forty-something',
#  'foundation-for',
#  'four-part',
#  'freedom-the',
#  'friends-they',
#  'fully-as',
#  'functioning-and',
#  'future-our',
#  'gate-less',
#  'generally-with',
#  'generation-of',
#  'geography-because',
#  'gift-after',
#  'globe-those',
#  'goals-then',
#  'good-will',
#  'government-must',
#  'government-the',
#  'grown-up',
#  'growth-but',
#  'growth-if',
#  'growth-in',
#  'half-a',
#  'hand-full',
#  'hands-off',
#  'hands-on',
#  'hangers-on',
#  'happened-the',
#  'happiness-in',
#  'have-after',
#  'head-on',
#  'health-if',
#  'hear-nothing',
#  'hearts-for',
#  'here-after',
#  'here-not',
#  'here-the',
#  'heroes-and',
#  'hesitate-all',
#  'high-and',
#  'high-sometimes',
#  'him-that',
#  'history-an',
#  'history-and',
#  'hoped-for',
#  'hour-and',
#  'humanity-the',
#  'hundred-fifty',
#  'ill-will',
#  'impatient-but',
#  'important-much',
#  'imports-will',
#  'improving-our',
#  'in-between',
#  'independence–-not',
#  'inflation-over',
#  'installations-and',
#  'insurance-and',
#  'is-that',
#  'issues-also',
#  "it's-the",
#  'it-the',
#  'itself-a',
#  'itself-that',
#  'juiced-up',
#  'jumping-off',
#  'knock-out',
#  'know-how',
#  'know-that',
#  'labor-must',
#  'laid-off',
#  'land-and',
#  'land-indeed',
#  'lands-some',
#  'lands-to',
#  'language-that',
#  'lay-off',
#  'leaders-is',
#  'left-over',
#  'legend-such',
#  'legislative-to',
#  'let-up',
#  'lists-for',
#  'living-a',
#  'located-a',
#  'love-to',
#  'lunch-the',
#  'make-up',
#  'man-made',
#  'man-one',
#  'mankind-and',
#  'marines-the',
#  'markets-the',
#  'matter-would',
#  'measure-almost',
#  'measures-not',
#  'measures-this',
#  'meetings-will',
#  'million-and',
#  'million-more',
#  'million-which',
#  'mine-to',
#  'missiles-the',
#  'momentum-if',
#  'mopping-up',
#  'more-all',
#  'mothers-this',
#  'movement-indeed',
#  'municipal-all',
#  'must-have',
#  'mustering-out',
#  'nation-and',
#  'nation-must',
#  'nationalism-and',
#  'nations-are',
#  'near-by',
#  'necessity-be',
#  'needed-that',
#  'neighborhood-the',
#  'news-where',
#  'no-more',
#  'nomination-and',
#  'not-but',
#  'not-take',
#  'nothing-less',
#  'now-except',
#  'number-one',
#  'objection-and',
#  'objects-that',
#  'occurred-and',
#  'of-he',
#  'off-again',
#  'old-and',
#  'on-again',
#  'only,-must',
#  'open-to',
#  'opinion-a',
#  'opinion-for',
#  'organization-the',
#  'other-and',
#  'others-whatever',
#  'otherwise-because',
#  'otherwise-or',
#  'ours-yours',
#  'out-go',
#  'out-third',
#  'outlawed-they',
#  'outlined-a',
#  'over-all',
#  'overridden-he',
#  'own-from',
#  'paid-up',
#  'pass-through',
#  'passers-by',
#  'pat-down',
#  'penetration-then',
#  'pent-up',
#  'people-a',
#  'people-are',
#  'people-have',
#  'people-those',
#  'people-to',
#  'percent-that',
#  'personnel-those',
#  'pick-up',
#  'pleas-are',
#  'plug-in',
#  'possibility-he',
#  'power-must',
#  'prayers-have',
#  'president-that',
#  'problems-will',
#  'production-and',
#  'profits-to',
#  'progress-the',
#  'promise-now',
#  'property-much',
#  'protect-and',
#  'provision-that',
#  'purpose-the',
#  'question-and',
#  'rapidly-nothing',
#  'rates-which',
#  'rather-well',
#  'reach-in',
#  'reached-and',
#  'ready-made',
#  'reasons-their',
#  'record-the',
#  'recovery-the',
#  'recreation-we',
#  'relief-the',
#  'remarked-this',
#  'remembers-the',
#  'renewed-it',
#  'republic-is',
#  'required-and',
#  'resources-has',
#  'respect-now',
#  'rights-or',
#  'rights-the',
#  'rights-we',
#  'rip-off',
#  'roof-top',
#  'rulerstwenty-five',
#  'run-down',
#  'run-off',
#  'rusted-out',
#  'said-you',
#  'sailors-and',
#  'say-so',
#  'says-and',
#  'scores-and',
#  'secure,-and',
#  'security-but',
#  'see-nothing',
#  'see-through',
#  'service-have',
#  'settlers-on',
#  'shadow-and',
#  'shelters-they',
#  'side-in',
#  'single-most',
#  'sit-down',
#  'six-in',
#  'six-part',
#  'slowed-down',
#  'something-a',
#  'something-however',
#  'sometime-perhaps',
#  'space-all',
#  'space-in',
#  'speed-full',
#  'speed-up',
#  'spending-and',
#  'spirit-the',
#  'stand-by',
#  'stand-in',
#  'stand-up',
#  'started-as',
#  'statement-has',
#  'step-up',
#  'stepped-up',
#  'stepping-up',
#  'strong-have',
#  'stronger-and',
#  'struggle-no',
#  'study-and',
#  'subject-to',
#  'success-to',
#  'suggestions-the',
#  'summer-the',
#  'sustained-until',
#  'swearing-in',
#  'system-namely',
#  'system-the',
#  'taxpayer-that',
#  'teach-in',
#  'television-and',
#  'television-if',
#  'term-within',
#  'textiles-you',
#  'that-a',
#  'that-nothing',
#  'them,-such',
#  'them-could',
#  'them-in',
#  'them-to',
#  'then-as',
#  'there-is',
#  'there-it',
#  'therefore-and',
#  'these-and',
#  'think-was',
#  'this-many',
#  'thought,-the',
#  'thought-out',
#  'three-part',
#  'tie-up',
#  'time-an',
#  'tip-top',
#  'to-as',
#  'to-you',
#  'together-well',
#  'ton-each',
#  'tonight-to',
#  'toold"-and',
#  'top-down',
#  'toughest-ever',
#  'tranquillity-a',
#  'transition-a',
#  'transportation-using',
#  'trickle-down',
#  'trip-and',
#  'triumph-for',
#  'truth-the',
#  'turn-around',
#  'two-front',
#  'two-hundred',
#  'two-it',
#  'two-part',
#  'unanimity-and',
#  'understanding-not',
#  'undreamed-of',
#  'unemployment-which',
#  'unheard-of',
#  'unlooked-for',
#  'unprecedented-the',
#  'up-from',
#  'upside-down',
#  'us-and',
#  'us-however',
#  'us-to',
#  'venture-to',
#  'veto-the',
#  'walk-in',
#  'war-or',
#  'war-which',
#  'warfare-the',
#  'wars-in',
#  'weeding-out',
#  'week-he',
#  'well-being',
#  'well-doing',
#  'well-off',
#  'with-out',
#  'women,-of',
#  'women-not',
#  'wool-this',
#  'workers-and',
#  'workers-whose',
#  'works-a',
#  'world-and',
#  'world-we',
#  'worn-out',
#  'worth-while',
#  'would-be',
#  'write-in',
#  'write-off',
#  'written-not',
#  'wrong-doing',
#  'year-a',
#  'year-in',
#  'year-is',
#  'year-others',
#  'year-out',
#  'year-we',
#  'years-and',
#  'years-by',
#  'years-since',
#  'years-we',
#  'yet-but']

# %% [markdown]
# >> #### 6.2 Solution: Replace hyphens with spaces

# %%
hyphens_after = [token.replace('-', ' ') for token in hyphens_before]
hyphens_after
# Out:
# ['abroad the',
#  'abroad to',
#  'accept and',
#  'action to',
#  'administration and',
#  'administration as',
#  'administrations to',
#  'advance and',
#  'advantage and',
#  'advantages in',
#  'afford along',
#  'again, a',
#  'agencies as',
#  'agencies is',
#  'aggression and',
#  'aggression that',
#  'aggression to',
#  'ago and',
#  'ago many',
#  'ago was',
#  'all and',
#  'all in',
#  'all out',
#  'allies just',
#  'alone and',
#  'amendments it',
#  'antagonisms that',
#  'appropriate and',
#  'are five',
#  'arena an',
#  'army not',
#  'aspirations have',
#  'audience it',
#  'available and',
#  'background not',
#  'base and',
#  'battle front',
#  'be from',
#  'be the',
#  'be then',
#  'be we',
#  'beefed up',
#  'beings might',
#  'believe that',
#  'belt will',
#  'better off',
#  'bombed out',
#  'borders how',
#  'bore down',
#  'born again',
#  'breadth from',
#  'break in',
#  'break through',
#  'budget for',
#  'build up',
#  'builders if',
#  'building up',
#  'built in',
#  'burnt out',
#  'by the',
#  'call in',
#  'campaign and',
#  "can't– in",
#  'can and',
#  'can then',
#  'capacity in',
#  'capital all',
#  'catch and',
#  'categories and',
#  'change where',
#  'child for',
#  'child not',
#  'children who',
#  'choose as',
#  'cities all',
#  'close up',
#  'colleges with',
#  'commissions some',
#  'commitments the',
#  'committee that',
#  'communism is',
#  'community to',
#  'complain to',
#  'concerns not',
#  'conflict our',
#  'conflicts to',
#  'confusion, by',
#  'consist, of',
#  'construct and',
#  'construction all',
#  'continent the',
#  'controllers how',
#  'convictions can',
#  'countries we',
#  'country all',
#  'country and',
#  'country could',
#  'country other',
#  'country the',
#  'covenant to',
#  'creation then',
#  'crisis to',
#  'crisis what',
#  'cure all',
#  'cut off',
#  'cut over',
#  'daring by',
#  'democracy" that',
#  'demonstrate against',
#  'departments the',
#  'depression and',
#  'depression that',
#  'deserves and',
#  'design" it',
#  'destroyed the',
#  'developing or',
#  'development are',
#  'did not',
#  'difference and',
#  'dignity the',
#  'direction not',
#  'direction the',
#  'disagree and',
#  'disgrace the',
#  'dissent who',
#  'do and',
#  'dominate which',
#  'done and',
#  'done as',
#  'done we',
#  'double down',
#  'dramatically more',
#  'drawn out',
#  'drive through',
#  'drivers to',
#  'due first',
#  'dust up',
#  'duty for',
#  'duty of',
#  'earlier the',
#  'earnest and',
#  'elected and',
#  'element of',
#  'emergencies nor',
#  'emotion in',
#  'employees whether',
#  'enterprise to',
#  'environment the',
#  'equipment one',
#  'eras the',
#  'everyone some',
#  'exception we',
#  'exercises a',
#  'exigency that',
#  'expansion all',
#  'expenditures a',
#  'expenditures but',
#  'fact the',
#  'fall out',
#  'far off',
#  'favor that',
#  'feet of',
#  'fellow being',
#  'financed which',
#  'firm because',
#  'first ever',
#  'first name',
#  'flare up',
#  'flat out',
#  'follow everyone',
#  'follow up',
#  'for also',
#  'for that',
#  'forces to',
#  'foreign made',
#  'foreigners as',
#  'forget that',
#  'forty something',
#  'foundation for',
#  'four part',
#  'freedom the',
#  'friends they',
#  'fully as',
#  'functioning and',
#  'future our',
#  'gate less',
#  'generally with',
#  'generation of',
#  'geography because',
#  'gift after',
#  'globe those',
#  'goals then',
#  'good will',
#  'government must',
#  'government the',
#  'grown up',
#  'growth but',
#  'growth if',
#  'growth in',
#  'half a',
#  'hand full',
#  'hands off',
#  'hands on',
#  'hangers on',
#  'happened the',
#  'happiness in',
#  'have after',
#  'head on',
#  'health if',
#  'hear nothing',
#  'hearts for',
#  'here after',
#  'here not',
#  'here the',
#  'heroes and',
#  'hesitate all',
#  'high and',
#  'high sometimes',
#  'him that',
#  'history an',
#  'history and',
#  'hoped for',
#  'hour and',
#  'humanity the',
#  'hundred fifty',
#  'ill will',
#  'impatient but',
#  'important much',
#  'imports will',
#  'improving our',
#  'in between',
#  'independence– not',
#  'inflation over',
#  'installations and',
#  'insurance and',
#  'is that',
#  'issues also',
#  "it's the",
#  'it the',
#  'itself a',
#  'itself that',
#  'juiced up',
#  'jumping off',
#  'knock out',
#  'know how',
#  'know that',
#  'labor must',
#  'laid off',
#  'land and',
#  'land indeed',
#  'lands some',
#  'lands to',
#  'language that',
#  'lay off',
#  'leaders is',
#  'left over',
#  'legend such',
#  'legislative to',
#  'let up',
#  'lists for',
#  'living a',
#  'located a',
#  'love to',
#  'lunch the',
#  'make up',
#  'man made',
#  'man one',
#  'mankind and',
#  'marines the',
#  'markets the',
#  'matter would',
#  'measure almost',
#  'measures not',
#  'measures this',
#  'meetings will',
#  'million and',
#  'million more',
#  'million which',
#  'mine to',
#  'missiles the',
#  'momentum if',
#  'mopping up',
#  'more all',
#  'mothers this',
#  'movement indeed',
#  'municipal all',
#  'must have',
#  'mustering out',
#  'nation and',
#  'nation must',
#  'nationalism and',
#  'nations are',
#  'near by',
#  'necessity be',
#  'needed that',
#  'neighborhood the',
#  'news where',
#  'no more',
#  'nomination and',
#  'not but',
#  'not take',
#  'nothing less',
#  'now except',
#  'number one',
#  'objection and',
#  'objects that',
#  'occurred and',
#  'of he',
#  'off again',
#  'old and',
#  'on again',
#  'only, must',
#  'open to',
#  'opinion a',
#  'opinion for',
#  'organization the',
#  'other and',
#  'others whatever',
#  'otherwise because',
#  'otherwise or',
#  'ours yours',
#  'out go',
#  'out third',
#  'outlawed they',
#  'outlined a',
#  'over all',
#  'overridden he',
#  'own from',
#  'paid up',
#  'pass through',
#  'passers by',
#  'pat down',
#  'penetration then',
#  'pent up',
#  'people a',
#  'people are',
#  'people have',
#  'people those',
#  'people to',
#  'percent that',
#  'personnel those',
#  'pick up',
#  'pleas are',
#  'plug in',
#  'possibility he',
#  'power must',
#  'prayers have',
#  'president that',
#  'problems will',
#  'production and',
#  'profits to',
#  'progress the',
#  'promise now',
#  'property much',
#  'protect and',
#  'provision that',
#  'purpose the',
#  'question and',
#  'rapidly nothing',
#  'rates which',
#  'rather well',
#  'reach in',
#  'reached and',
#  'ready made',
#  'reasons their',
#  'record the',
#  'recovery the',
#  'recreation we',
#  'relief the',
#  'remarked this',
#  'remembers the',
#  'renewed it',
#  'republic is',
#  'required and',
#  'resources has',
#  'respect now',
#  'rights or',
#  'rights the',
#  'rights we',
#  'rip off',
#  'roof top',
#  'rulerstwenty five',
#  'run down',
#  'run off',
#  'rusted out',
#  'said you',
#  'sailors and',
#  'say so',
#  'says and',
#  'scores and',
#  'secure, and',
#  'security but',
#  'see nothing',
#  'see through',
#  'service have',
#  'settlers on',
#  'shadow and',
#  'shelters they',
#  'side in',
#  'single most',
#  'sit down',
#  'six in',
#  'six part',
#  'slowed down',
#  'something a',
#  'something however',
#  'sometime perhaps',
#  'space all',
#  'space in',
#  'speed full',
#  'speed up',
#  'spending and',
#  'spirit the',
#  'stand by',
#  'stand in',
#  'stand up',
#  'started as',
#  'statement has',
#  'step up',
#  'stepped up',
#  'stepping up',
#  'strong have',
#  'stronger and',
#  'struggle no',
#  'study and',
#  'subject to',
#  'success to',
#  'suggestions the',
#  'summer the',
#  'sustained until',
#  'swearing in',
#  'system namely',
#  'system the',
#  'taxpayer that',
#  'teach in',
#  'television and',
#  'television if',
#  'term within',
#  'textiles you',
#  'that a',
#  'that nothing',
#  'them, such',
#  'them could',
#  'them in',
#  'them to',
#  'then as',
#  'there is',
#  'there it',
#  'therefore and',
#  'these and',
#  'think was',
#  'this many',
#  'thought, the',
#  'thought out',
#  'three part',
#  'tie up',
#  'time an',
#  'tip top',
#  'to as',
#  'to you',
#  'together well',
#  'ton each',
#  'tonight to',
#  'toold" and',
#  'top down',
#  'toughest ever',
#  'tranquillity a',
#  'transition a',
#  'transportation using',
#  'trickle down',
#  'trip and',
#  'triumph for',
#  'truth the',
#  'turn around',
#  'two front',
#  'two hundred',
#  'two it',
#  'two part',
#  'unanimity and',
#  'understanding not',
#  'undreamed of',
#  'unemployment which',
#  'unheard of',
#  'unlooked for',
#  'unprecedented the',
#  'up from',
#  'upside down',
#  'us and',
#  'us however',
#  'us to',
#  'venture to',
#  'veto the',
#  'walk in',
#  'war or',
#  'war which',
#  'warfare the',
#  'wars in',
#  'weeding out',
#  'week he',
#  'well being',
#  'well doing',
#  'well off',
#  'with out',
#  'women, of',
#  'women not',
#  'wool this',
#  'workers and',
#  'workers whose',
#  'works a',
#  'world and',
#  'world we',
#  'worn out',
#  'worth while',
#  'would be',
#  'write in',
#  'write off',
#  'written not',
#  'wrong doing',
#  'year a',
#  'year in',
#  'year is',
#  'year others',
#  'year out',
#  'year we',
#  'years and',
#  'years by',
#  'years since',
#  'years we',
#  'yet but']

# %% [markdown]
# >> #### 6.3 Prepare token pairs and update dictionary

# %%
# Zip pairs into before and after tuples
hyphens = list(zip(hyphens_before, hyphens_after))

# Update dictionary and hyphen tokens
clean_dict = update_dict(clean_dict, hyphens)
hyphen_tokens = [token for token in hyphen_tokens if token not in clean_dict]

# %%
print(len(hyphen_tokens))
hyphen_tokens
# Out:
# 3316
# ['1,500-a-year',
#  '1-day',
#  '1-in-20',
#  '1-yard',
#  '1-year',
#  '1-year-old',
#  '1/2-inch',
#  '1/2-percent',
#  '10,000-foot',
#  '10,000-page',
#  '10,000-ton',
#  '10-day',
#  '10-inch',
#  '10-man',
#  '10-minute',
#  '10-percent',
#  '10-round',
#  '10-to-1',
#  '10-year',
#  '10-year-old',
#  '100-cent',
#  '11-year-old',
#  '12-hour',
#  '12-inch',
#  '12-month',
#  '12-year-old',
#  '122-foot',
#  '122-percent',
#  '13-year-old',
#  '13Ѕ-inch',
#  '14-percent',
#  '14-point',
#  '14-to-1',
#  '14-year',
#  '14-year-old',
#  '15-percent',
#  '15-year-olds',
#  '152-millimeter',
#  '16-inch',
#  '16-inch-type',
#  '16-year-old',
#  '167-page',
#  '17-year',
#  '17-year-low',
#  '17-year-old',
#  '18-hour',
#  '18-nation',
#  '18-percent',
#  '18-wheelers',
#  '18-year-old',
#  '18-year-olds',
#  '180-odd',
#  '19-foot',
#  '19-year-old',
#  '19-year-olds',
#  '190-year',
#  '1970s-era',
#  '19th-century',
#  '2,000-foot',
#  '2,000-mile',
#  '2-in-3',
#  '2-is',
#  '2-minute',
#  '2-percent',
#  '2-year',
#  '2-year-old',
#  '2-year-olds',
#  '20-knot',
#  '20-percent',
#  '20-point',
#  '20-year',
#  '20-year-old',
#  '200-mile',
#  '200-year',
#  '200-year-old',
#  '21st-century',
#  '22,000-word',
#  '22-month',
#  '22-percent',
#  '23-knot',
#  '24-hour',
#  '24-knot',
#  '24-year',
#  '25-percent',
#  '25-year',
#  '250-bed',
#  '26-year-old',
#  '28-minute',
#  '28-percent',
#  '28-square-mile',
#  '3-day',
#  '3-inch',
#  '3-mile',
#  '3-minute',
#  '3-point',
#  '3-to-1',
#  '3-year',
#  '3/4-year',
#  '30-cent',
#  '30-day',
#  '30-minute',
#  '30-odd',
#  '30-percent',
#  '30-second',
#  '30-year',
#  '35-day',
#  '35-hour',
#  '35-percent',
#  '36-percent',
#  '37-point',
#  '3D-print',
#  '3rd-grade',
#  '4-or',
#  '4-percent',
#  '4-point',
#  '4-something',
#  '4-star',
#  '4-year',
#  '4-year-old',
#  '4.8-percent',
#  '40,000-odd',
#  '40-nation',
#  '40-percent',
#  '40-some',
#  '40-yard',
#  '40-year',
#  '45-second',
#  '45-year',
#  '47-year-old',
#  '48-story',
#  '49-year-old',
#  '5-ambulatory',
#  '5-day',
#  '5-letter',
#  '5-percent',
#  '5-power',
#  '5-year',
#  '5-year-old',
#  '50,000-a-year',
#  '50-cent',
#  '50-cent-a-gallon',
#  '50-hour',
#  '50-percent',
#  '50-year',
#  '500-billion',
#  '500-million',
#  '500-per-child',
#  '500-year',
#  '55-mile',
#  '5?-percent',
#  '6-day',
#  '6-inch',
#  '6-month',
#  '6-months',
#  '6-percent',
#  '6-point',
#  '6-pounder',
#  '6-year',
#  '60,000-plus',
#  '60-day',
#  '60-second',
#  '600,000-man',
#  '600-page',
#  '600-percent',
#  '600-ship',
#  '62-year-olders',
#  '65-year',
#  '650-billion-a-year',
#  '7-day',
#  '7-percent',
#  '7-year',
#  '7-year-long',
#  '70-million',
#  '70-percent',
#  '73-percent',
#  '75-bed',
#  '75-page',
#  '75-year-old',
#  '77-percent',
#  '8-inch',
#  '8-year',
#  '8-year-old',
#  '8-year-olds',
#  '800-HELPNOW',
#  '800-some',
#  '81-which',
#  '85-foot',
#  '88-year-old',
#  '9,000-men',
#  '9-foot',
#  '9-hour',
#  '9-millimeter',
#  '9-year-olds',
#  '9.2-percent',
#  '90-day',
#  '90-minute',
#  '90-second',
#  '900,000-$900,000',
#  '91-to-1',
#  '960-acre',
#  'A-11',
#  'A-6F',
#  'A-grade',
#  'A-plus',
#  'ACT-UP',
#  'ADJUTANT-GENERAL',
#  'AIDS-free',
#  'AK-47s',
#  'AMERICA-HONDURAS',
#  'ANTI-TRUST',
#  'ARBITRATIONS-PANAMA',
#  'Adjutant-General',
#  'Administration-Mr',
#  'African-American',
#  'African-Americans',
#  'African-owned',
#  'Ah-h-h',
#  'Aigner-Clark',
#  'Aix-la-Chapelle',
#  'Al-Azhar',
#  'Alaskan-Yukon-Pacific',
#  'All-merciful',
#  'All-powerful',
#  'All-time',
#  'Allies-in',
#  'Alsace-Lorraine',
#  'Amazon-Washington',
#  'Ambassador-Mr',
#  'America-in',
#  'America-the',
#  'American-British',
#  'American-Hellenic',
#  'American-Soviet',
#  'American-born',
#  'American-built',
#  'American-made',
#  'American-mediated',
#  'American-owned',
#  'Americans-to',
#  'Americas-the',
#  'An-tung',
#  'Anglo-Saxon',
#  'Anglo-Venezuelan',
#  'Anti-Trust',
#  'Antung-Mukden',
#  'Apollo-Gemini',
#  'Arab-Israeli',
#  'Armenian-Americans',
#  'As-salaamu',
#  'Asia-Pacific',
#  'Asia-and',
#  'Asia-which',
#  'Asian-American',
#  'Asian-Americans',
#  'Assembly-have',
#  'Atlantic-Mississippi',
#  'Attorney-General',
#  'Attorneys-General',
#  'Austro-Hungarian',
#  'B-1',
#  'B-1B',
#  'B-2',
#  'B-22',
#  'B-29',
#  'B-47',
#  'B-52',
#  'B-l',
#  'BUNAU-VARILLA',
#  'Baltic-Americans',
#  'Band-Aid',
#  'Band-aid',
#  'Berlin-and',
#  'Big-Brother-is-watching-you',
#  'Big-hearted',
#  'Black-owned',
#  'Blue-collar',
#  'Boo-o-o',
#  'Bosnia-wide',
#  'Boutros-Ghali',
#  'Brest-Litovsk',
#  'Briand-Kellogg',
#  'Brigadier-General',
#  'British-American',
#  'Bunau-Varilla',
#  'Bush-McCain',
#  'C-1',
#  'C-SPAN',
#  'C-minus',
#  'CAPITAL-GAINS',
#  'CIVIL-SERVICE',
#  'CONFERENCE-UNFORTUNATE',
#  'CONSULATE-GENERAL',
#  'Cabinet-level',
#  'Cambodian-Vietnam',
#  'Capper-Ketcham',
#  'Capper-Volstead',
#  'Captain-General',
#  'Captain-Generalto',
#  'Carter-Mondale',
#  'Catch-and-release',
#  'Census-we',
#  'Cha-Cha-Cha',
#  'Chamber-the',
#  'Chi-li',
#  'China-U.S.',
#  'Chinchow-Aigun',
#  'Chinese-American',
#  'Chinese-Japanese',
#  'Chinese-made',
#  'Christ-like',
#  'Civil-Service',
#  'Civil-service',
#  'Clayton-Bulwer',
#  'Clear-eyed',
#  'Co-operation',
#  'Coal-land',
#  'Coleman-Singleton',
#  'Columbia-it',
#  'Commander-in-Chief',
#  'Commissary-General',
#  'Commissioner-General',
#  'Communist-controlled',
#  'Communist-directed',
#  'Communist-dominated',
#  'Communist-inspired',
#  'Communist-supplied',
#  'Communist-supported',
#  'Conable-Hanee',
#  'Congo-Adoula',
#  'Congo-Kinshasa',
#  'Congress-and',
#  'Congress-by',
#  'Congress-through',
#  'Consul-General',
#  'Convention-my',
#  'Corps]-type',
#  'Cuban-Soviet',
#  'D-day',
#  'DECISION-MERELY',
#  'Dar-Es-Salaam',
#  'Day-inspector',
#  'Dead-Letter',
#  'Democratic-controlled',
#  'Director-General',
#  'Disarmament-Canada',
#  'Double-digit',
#  'Douglas-Home',
#  'Drug-Free',
#  'E-rate',
#  'EIGHT-HOUR',
#  'ELECTRICAL-POWER',
#  'Earth-based',
#  'East-West',
#  'East-mark',
#  'East-there',
#  'Egypt-Saudi',
#  'Egyptian-Israeli',
#  'Eisenhower-and',
#  'Eisenhower-they',
#  'Elizabeth-City',
#  'Empress-Queen',
#  'English-speaking',
#  'Entente-Allies',
#  'Establishment-this',
#  'Europe-the',
#  'Ex-Corporal',
#  'Export-Import',
#  'Eyre-Cragin',
#  'F-1',
#  'F-14',
#  'F-14s',
#  'F-15',
#  'F-35',
#  'F1a.-there',
#  'FBI-in',
#  'FELLOW-CITIZENS',
#  'FUR-SEAL',
#  'Fair-minded',
#  'Faith-Based',
#  'Faith-based',
#  'Far-reaching',
#  'Farmer-Labor',
#  'Federal-State',
#  'Federal-assisted',
#  'Federal-highway',
#  'Federally-funded',
#  'Fellow-Citizens',
#  'Fellow-Countrymen',
#  'Fellow-citizens',
#  'Fiat-Chrysler',
#  'Fifty-eighth',
#  'Fifty-fifth',
#  'Fifty-four-forty',
#  'Fish-Culture',
#  'Five-Year',
#  'Five-twenties',
#  'Fix-It-First',
#  'Flat-head',
#  'Follow-up',
#  'Foo-Choo-Foo',
#  'Food-for-Peace',
#  'Fordney-McCumber',
#  'Forty-fifth',
#  'Forty-ninth',
#  'Four-Power',
#  'Four-fifths',
#  'Franco-American',
#  'Frankfort-on-the-Main',
#  'Franklin-leaning',
#  'Free-Soilers',
#  'Free-State',
#  'Free-delivery',
#  'Free-market',
#  'G-20',
#  'G-8',
#  'GS-12',
#  'GS-18',
#  'Gall-lard',
#  'Garner-Rainey',
#  'Germany-the',
#  'Germany-voting',
#  'God-awful',
#  'God-blessed',
#  'God-fearing',
#  'God-given',
#  'God-imposed',
#  'Government-improved',
#  'Government-its',
#  'Government-led',
#  'Government-owned',
#  'Government-regulated',
#  'Government-the',
#  'Government-under',
#  'Government-wide',
#  'Governments-Germany',
#  'Governor-General',
#  'Governor-to',
#  'Gramm-Rudman',
#  'Gramm-Rudman-Hollings',
#  'Grant-in-aid',
#  'Greek-Turkish',
#  'H-43',
#  'H-bomb',
#  'HIV-positive',
#  'HOME-LOAN',
#  'Haitian-Americans',
#  'Haitian-Dominican',
#  'Half-hearted',
#  'Hard-headedness',
#  'Harley-Davidson',
#  'Harvard-trained',
#  'Hawaiian-Japanese',
#  'Hawley-Smoot',
#  'Hay-Herran',
#  'Hay-Pauncefote',
#  'Heaven-favored',
#  'Heavy-armed',
#  'Hesse-Darmstadt',
#  'High-ranking',
#  'High-wage',
#  'Hill-Burton',
#  'Hispanic-Americans',
#  'Hiss-Chambers',
#  'Hitler-dominated',
#  'Ho-si-woo',
#  'Hope-renewed',
#  'House-business',
#  'Hsiao-ping',
#  'Hudson-Fulton',
#  'Humphrey-Hawkins',
#  'IA-ECOSOC',
#  'II-has',
#  'III-C',
#  'INTER-AMERICAN',
#  'INTERSTATE-COMMERCE',
#  'Indian-school',
#  'Indo-China',
#  'Indo-Chinese',
#  'Indonesian-Malaysian',
#  'Inspector-General',
#  'Inter-American',
#  'Inter-Departmental',
#  'Intermediate-Range',
#  'Internal-Revenue',
#  'Internal-revenue',
#  'Iran-Iraq',
#  'Iraqi-led',
#  'Irish-American',
#  'Irish-Catholic',
#  'Irish-Protestant',
#  'Israeli-Jordanian',
#  'Israeli-Palestinian',
#  'Italian-Americans',
#  'J-58',
#  'Jackson-Vanik',
#  'Jaish-e-Mohammed',
#  'Japanese-American',
#  'Jefferson-like',
#  'Jewish-Americans',
#  'Job-killing',
#  'Johnson-Humphrey',
#  'Judas-like',
#  'Judge-Advocate-General',
#  'Judge-Advocates',
#  'Kassebaum-Kennedy',
#  'Kellogg-Briand',
#  'Kemp-Roth',
#  'Kennedy-Johnson',
#  'Kennedy-Kassebaum',
#  'Kennedy-McCarthy',
#  'Key-Stone',
#  'Kiao-chow',
#  'Klan-minded',
#  'LATIN-AMERICAN',
#  'LAW-THE',
#  'LIGHT-HOUSE',
#  'LIGHT-HOUSES',
#  'LONG-STANDING',
#  'Labor-Management',
#  'Lakes-St',
#  'Lao-tzu',
#  'Laos-regained',
#  'Large-scale',
#  'Latter-day',
#  'Law-abiding',
#  'Law-clerk',
#  'Lieutenant-Colonel',
#  'Lieutenant-Commander',
#  'Lieutenant-General',
#  'Life-Saving',
#  'Light-House',
#  'Light-houses',
#  'Lincoln\'s-"Let',
#  'Long-term',
#  'Low-income',
#  'Low-tax',
#  'M-1',
#  'MI-8',
#  'MS-13',
#  'Major-General',
#  'Man-of-war',
#  'Manila-Hongkong',
#  'Mansfield-Scott',
#  'Marine-Hospital',
#  'Marquez-Greene',
#  'Marxism-Leninism',
#  'Marxist-Leninism',
#  'Marxist-Leninist',
#  'Marxist-Leninists',
#  'Mason-Dixon',
#  'Mazar-e-Sharif',
#  'McCain-Feingold',
#  'Mecklenburg-Schwerin',
#  'Medicare-approved',
#  'Medicare-rarely',
#  'Meuse-Argonne',
#  'Mid-Atlantic',
#  'Middle-class',
#  'Middleton-Doctor',
#  'Mig-23',
#  'Mm-hmm',
#  'Modern-day',
#  'Money-Order',
#  'Moore-Brown',
#  'Muslim-majority',
#  'Mustering-out',
#  'NAVY-YARDS',
#  'Nation-wide',
#  'Nations-and',
#  'Nations-led',
#  'Navy-Yard',
#  'Nazi-dominated',
#  'Nazi-ism',
#  'Nebraska-Kansas',
#  'New-England',
#  'New-Jersey',
#  'New-Orleans',
#  'New-York',
#  'Night-inspector',
#  'Nine-eleven',
#  'Nixon-16',
#  'Nixon-Ford',
#  'Non-Discrimination',
#  'Non-Proliferation',
#  'Non-intervention',
#  'North-Carolina',
#  'North-South',
#  'North-West',
#  'North-Western',
#  'Nuclear-Test-Ban',
#  'OB-GYN',
#  'Oil-producing',
#  'Old-fashioned',
#  'On-site',
#  'Once-bitter',
#  'One-eighth',
#  'One-fourth',
#  'One-half',
#  'One-third',
#  'Ottoman-born',
#  'P-Tech',
#  'PANAMA-PACIFIC',
#  'POST-OFFICE',
#  'POSTAL-SAVINGS',
#  'PURE-FOOD',
#  'Pacific-cable',
#  'Pago-Pago',
#  'Pakistan-600',
#  'Pan-Amencan',
#  'Pan-American',
#  'Pan-Americanism',
#  'Panama-Pacific',
#  'Paper-covered',
#  'Paymaster-General',
#  'Paymaster-General.3',
#  'Payne-Aldrich',
#  'Pei-Ho',
#  'Peit-sang',
#  'Pent-up',
#  'Peru-Bolivian',
#  'Port-au-Prince',
#  'Post-9/11',
#  'Post-Dispatch',
#  'Post-Office',
#  'Post-OfficeDepartment',
#  'Post-Roads',
#  'Post-office',
#  'Post-offices',
#  'Post-roads',
#  'PostMaster-General',
#  'Postmaster-General',
#  'Postmaster-Generalagainst',
#  'Postmaster-Generals',
#  'Pre-K',
#  'President-Elect',
#  'President-and',
#  'President-as',
#  'President-some',
#  'President-that',
#  'President-to-be',
#  'President-tried',
#  'President-with',
#  'Presidents-President',
#  'Prize-winning',
#  'Provost-Marshal-General',
#  'Qaeda-Iraq',
#  'Quartermaster-General',
#  'R-U',
#  'R-e-g-a-n',
#  'RC-135',
#  'RICA-COLOMBIA',
#  'RS-70',
#  'Ranger-type',
#  'Re-Election',
#  'Re-employment',
#  'Re-enlistment',
#  'Reagan-Bush',
#  'Reagan-Kemp-Roth',
#  'Rear-Admiral',
#  'Revenue-Cutter',
#  'Richmond-based',
#  'Rip-Rap',
#  'Rush-Bagot',
#  'Russo-American',
#  'Russo-Japanese',
#  'SECOND-CLASS',
#  'SELF-DEFENSE',
#  'SEMI-CENTENNIAL',
#  'SLAVE-DEALER',
#  'SR-71',
#  'SR-7I',
#  'SS-18',
#  'SS-20',
#  'SS-20s',
#  'SS-21',
#  'SS-4',
#  'SS-4s',
#  'SS-5',
#  'STABT-Strategic',
#  'Sabbath-Sunday',
#  'Sai-shek',
#  'Sam-whoever',
#  'Saxe-Coburg',
#  'Schleswig-Holstein',
#  'Scotch-Irish',
#  'Scripps-Howard',
#  'Scud-type',
#  'Secret-Service',
#  'Secretary-General',
#  'Secretary-then-Regan',
#  'Self-defense',
#  'Self-determination',
#  'Self-governed',
#  'Self-government',
#  'Self-interest',
#  'Self-preservation',
#  'Self-reliance',
#  'Self-restraint',
#  'Seong-ho',
#  'September-immediately',
#  'Seventy-Fifth',
#  'Shan-tung',
#  'Sheppard-Towner',
#  'Short-term',
#  'Signal-Service',
#  'Simpson-Bowles',
#  'Simpson-Mazzoli',
#  'Sino-American',
#  'Sino-Soviet',
#  'Sixty-eighth',
#  'Slave-Code',
#  'Small-business',
#  'Smoot-Haw',
#  'Solicitor-General',
#  'South-Carolina',
#  'South-west',
#  'Soviet-American',
#  'Soviet-Chinese',
#  'Soviet-Cuban',
#  'Soviet-U.S.',
#  'Soviet-built',
#  'Soviet-made',
#  'Soviet-occupied',
#  'Soviet-sponsored',
#  'Soviet-supported',
#  'Spanish-American',
#  'Spanish-speaking',
#  'Speaker-elect',
#  'Star-Spangled',
#  'Star-Warring',
#  'State-administered',
#  'State-an',
#  'State-bank',
#  'State-controlled',
#  'State-directed',
#  'State-owned',
#  'State-sponsored',
#  'State-supported',
#  'States-Mexican',
#  'States-a',
#  'States-besides',
#  'Steamboat-Inspection',
#  'Sung-pu',
#  'Surgeon-General',
#  'Suz-ahn',
#  'Syrian-backed',
#  'Sze-chuen',
#  'TACNA-ARICA',
#  'Ta-lien-wan',
#  'Tacna-Arica',
#  'Taft-Ellender-Wagner',
#  'Tax-exempt',
#  'Ten-forties',
#  'The-world',
#  'Thirty-eighth',
#  'Thirty-fifth',
#  'Thirty-ninth',
#  'Thomas-Anita',
#  'Three-fourths',
#  'Three-quarters',
#  'Tien-Tsin',
#  'Tien-tsin',
#  'Ting-fang',
#  'To-day',
#  'To-morrow',
#  'Trans-Missouri',
#  'Trans-Pacific',
#  'Trenton-Princeton',
#  'Truman-Acheson',
#  'Trump-Pence',
#  'Tsai-Hsun',
#  'Tsai-tao',
#  'Tse-tung',
#  'Tsing-tao',
#  'Tsung-li',
#  'Twenty-fifth',
#  'Two-thirds',
#  'U-2',
#  'U-Boats',
#  'U-boats',
#  'U.S.-Canadian',
#  'U.S.-Japan',
#  'U.S.-Korea',
#  'U.S.-Mexico',
#  'U.S.-Mexico-Canada',
#  'U.S.-Panamanian',
#  'Ukrainian-Americans',
#  'Union-for',
#  'Union-loving',
#  'Union-men',
#  'Union-saving',
#  'Union-supporting',
#  'V-1',
#  'V-2',
#  'V-J',
#  'V-chip',
#  'Vice-Presidency',
#  'Vice-President',
#  'Vice-Presidential',
#  'Viet-Nam',
#  'Vietnam-and',
#  'Vietnam-apply',
#  'Vietnam-backed',
#  'W-GDP',
#  'Wage-workers',
#  'Wagner-Ellender-Taft',
#  'War-would',
#  'Washington-based',
#  'Web-feet',
#  'Wei-hai-wei',
#  'Well-considered',
#  'Well-founded',
#  'Well-trained',
#  'Western-proposed',
#  'Western-type',
#  'Wilkes-Barre',
#  'X-rated',
#  'Yang-Tse',
#  'Yen-hoon',
#  'Zero-Option',
#  'Zimbabwe-Rhodesia',
#  'able-bodied',
#  'above-cited',
#  'above-estimated',
#  'above-mentioned',
#  'above-named',
#  'above-recited',
#  'academy-type',
#  'across-the-board',
#  'act-$350,000,000',
#  'add-ons',
#  'adjusted-service',
#  'administration-helped',
#  'administration-laws',
#  'administration-tried',
#  'advanced-placement',
#  "afflicted-they've",
#  'after-dinner',
#  'after-effect',
#  'after-effects',
#  'after-school',
#  'after-tax',
#  'age-long',
#  'age-old',
#  'ago-ideas',
#  'ago-passed',
#  'agreements-agreements',
#  'agricultural-college',
#  'ahead-immediately',
#  'aid-to-democracies',
#  'air-based',
#  'air-landing',
#  'air-lane',
#  'air-lift',
#  'air-mail',
#  'air-raid',
#  'air-to-air',
#  'al-Assad',
#  'al-Baghdadi',
#  "al-Qa'ida",
#  'al-Qaeda',
#  'al-Sabah',
#  'al-Suhail',
#  'all-American',
#  'all-Asian',
#  'all-German',
#  'all-Indochina',
#  'all-absorbing',
#  'all-black',
#  'all-embracing',
#  'all-engrossing',
#  'all-important',
#  'all-inclusive',
#  'all-male',
#  'all-merciful',
#  'all-military',
#  'all-of-the-above',
#  'all-or-nothing',
#  'all-pervading',
#  'all-powerful',
#  'all-round',
#  'all-solar',
#  'all-time',
#  'all-volunteer',
#  'all-weather',
#  'all-wind',
#  'all-wise',
#  'alliance-building',
#  'and-towns',
#  'andlaw-abiding',
#  'anever-increasing',
#  'animal-killers',
#  'anniversary-let',
#  'ante-revolutionary',
#  'anti-American',
#  'anti-Catholic',
#  'anti-Communism',
#  'anti-Communist',
#  'anti-Fascist',
#  'anti-Nazi',
#  'anti-Semitic',
#  'anti-Semitism',
#  'anti-Somoza',
#  'anti-Soviet',
#  'anti-U.S.',
#  'anti-Vietnam',
#  'anti-Washington',
#  'anti-aircraft',
#  'anti-bullying',
#  'anti-business',
#  'anti-climb',
#  'anti-communism',
#  'anti-corruption',
#  'anti-craft',
#  'anti-crime',
#  'anti-drug-trafficking',
#  'anti-energy',
#  'anti-fraud',
#  'anti-government',
#  'anti-guerrilla',
#  'anti-inflation',
#  'anti-inflationary',
#  'anti-intellectualism',
#  'anti-military',
#  'anti-narcotic',
#  'anti-philosophers',
#  'anti-pollution',
#  'anti-poverty',
#  'anti-recession',
#  'anti-retroviral',
#  'anti-semitic',
#  'anti-slavery',
#  'anti-submarine',
#  'anti-tank',
#  'anti-terrorism',
#  'anti-terrorist',
#  'anti-trust',
#  'anti-worker',
#  'antici-pations',
#  'apple-selling',
#  'areas-new',
#  'arm-in-arm',
#  'armor-piercing',
#  'armor-plate',
#  'arms-Mother',
#  'asylum-seekers',
#  'at-risk',
#  'atomic-missile',
#  'attack,-dangers',
#  'attorney-client',
#  'attorney-general',
#  'awe-inspiring',
#  'back-alley',
#  'back-and-forth',
#  'back-to-back',
#  'back-to-school',
#  'balance-of-payments',
#  'ballot-box',
#  'bally-ho',
#  'bank-note',
#  'barbed-wire',
#  'base-loaded',
#  'battle-cry',
#  'battle-field',
#  'battle-lines',
#  'battle-ravaged',
#  'battle-ship',
#  'battle-ships',
#  'beach-head',
#  'beacon-light',
#  'bed-fellows',
#  'beef-packing',
#  'been-abandoned',
#  'beet-sugar',
#  'before-mentioned',
#  'before-named',
#  'before-recited',
#  'behind-the-scenes',
#  'best-connected',
#  'best-informed',
#  'best-selling',
#  'better-equipped',
#  'better-positioned',
#  'between-decks',
#  'bi-partisan',
#  'big-city',
#  'big-hearted',
#  'big-money',
#  'big-power',
#  'big-shots',
#  'big-time',
#  'bill-holders',
#  'billion-dollar',
#  'billion-plus',
#  'bio-based',
#  'bio-fuels',
#  'black-and-white',
#  'block-signal',
#  'blockade-breaking',
#  'blood-filled',
#  ...]

# %% [markdown]
# >> #### 7.1 Problem: Compound adjectives have hyphens and do not need to be cleaned
# >> - noun + adjective
# - noun + participle
# - adjective + participle

# %%
pattern = '^[a-z][a-z]+-[^-A-Z0-9]+$'
hyphens_before = [re.search(pattern, token)[0] for token in hyphen_tokens if re.search(pattern, token)]
hyphens_before
# Out:
# ['able-bodied',
#  'above-cited',
#  'above-estimated',
#  'above-mentioned',
#  'above-named',
#  'above-recited',
#  'academy-type',
#  'add-ons',
#  'adjusted-service',
#  'administration-helped',
#  'administration-laws',
#  'administration-tried',
#  'advanced-placement',
#  "afflicted-they've",
#  'after-dinner',
#  'after-effect',
#  'after-effects',
#  'after-school',
#  'after-tax',
#  'age-long',
#  'age-old',
#  'ago-ideas',
#  'ago-passed',
#  'agreements-agreements',
#  'agricultural-college',
#  'ahead-immediately',
#  'air-based',
#  'air-landing',
#  'air-lane',
#  'air-lift',
#  'air-mail',
#  'air-raid',
#  'all-absorbing',
#  'all-black',
#  'all-embracing',
#  'all-engrossing',
#  'all-important',
#  'all-inclusive',
#  'all-male',
#  'all-merciful',
#  'all-military',
#  'all-pervading',
#  'all-powerful',
#  'all-round',
#  'all-solar',
#  'all-time',
#  'all-volunteer',
#  'all-weather',
#  'all-wind',
#  'all-wise',
#  'alliance-building',
#  'and-towns',
#  'andlaw-abiding',
#  'anever-increasing',
#  'animal-killers',
#  'anniversary-let',
#  'ante-revolutionary',
#  'anti-aircraft',
#  'anti-bullying',
#  'anti-business',
#  'anti-climb',
#  'anti-communism',
#  'anti-corruption',
#  'anti-craft',
#  'anti-crime',
#  'anti-energy',
#  'anti-fraud',
#  'anti-government',
#  'anti-guerrilla',
#  'anti-inflation',
#  'anti-inflationary',
#  'anti-intellectualism',
#  'anti-military',
#  'anti-narcotic',
#  'anti-philosophers',
#  'anti-pollution',
#  'anti-poverty',
#  'anti-recession',
#  'anti-retroviral',
#  'anti-semitic',
#  'anti-slavery',
#  'anti-submarine',
#  'anti-tank',
#  'anti-terrorism',
#  'anti-terrorist',
#  'anti-trust',
#  'anti-worker',
#  'antici-pations',
#  'apple-selling',
#  'areas-new',
#  'armor-piercing',
#  'armor-plate',
#  'asylum-seekers',
#  'at-risk',
#  'atomic-missile',
#  'attorney-client',
#  'attorney-general',
#  'awe-inspiring',
#  'back-alley',
#  'ballot-box',
#  'bally-ho',
#  'bank-note',
#  'barbed-wire',
#  'base-loaded',
#  'battle-cry',
#  'battle-field',
#  'battle-lines',
#  'battle-ravaged',
#  'battle-ship',
#  'battle-ships',
#  'beach-head',
#  'beacon-light',
#  'bed-fellows',
#  'beef-packing',
#  'been-abandoned',
#  'beet-sugar',
#  'before-mentioned',
#  'before-named',
#  'before-recited',
#  'best-connected',
#  'best-informed',
#  'best-selling',
#  'better-equipped',
#  'better-positioned',
#  'between-decks',
#  'bi-partisan',
#  'big-city',
#  'big-hearted',
#  'big-money',
#  'big-power',
#  'big-shots',
#  'big-time',
#  'bill-holders',
#  'billion-dollar',
#  'billion-plus',
#  'bio-based',
#  'bio-fuels',
#  'block-signal',
#  'blockade-breaking',
#  'blood-filled',
#  'blood-soaked',
#  'blood-thirsty',
#  'blue-collar',
#  'body-politic',
#  'boll-weevil',
#  'bomb-detection',
#  'bomb-heavy',
#  'bomb-proof',
#  'bona-fide',
#  'bond-aided',
#  'bond-issuing',
#  'bond-paying',
#  'bone-tired',
#  'bonfire-light',
#  'booby-trapped',
#  'book-law',
#  'boundary-survey',
#  'bounty-land',
#  'bowie-knives',
#  'bracket-creep',
#  'branch-banking',
#  'brand-new',
#  'bread-winning',
#  'break-water',
#  'breech-loading',
#  'bribe-giver',
#  'bribe-taker',
#  'brigadier-general',
#  'brigadier-generals',
#  'broad-based',
#  'broad-gauged',
#  'broad-minded',
#  'broadcast-particularly',
#  'budget-cutting',
#  'build-ups',
#  'bullion-producing',
#  'bumper-sticker',
#  'business-community',
#  'business-like',
#  'by-laws',
#  'by-private',
#  'by-product',
#  'by-products',
#  'by-word',
#  'calamity-howlers',
#  'calamity-howling',
#  'campaign-weary',
#  'cancer-free',
#  'capital-intensive',
#  'card-carrying',
#  'carefully-drafted',
#  'carpet-bomb',
#  'carrier-delivery',
#  'cash-strapped',
#  'cast-iron',
#  'cattle-transportation',
#  'centuries-long',
#  'centuries-old',
#  'century-old',
#  'chain-link',
#  'cheap-postage',
#  'check-dams',
#  'check-ups',
#  'cherry-picking',
#  'chest-high',
#  'child-care',
#  'child-labor',
#  'church-state',
#  'church-supported',
#  'citizens-farmers',
#  'city-states',
#  'civil-service',
#  'civilian-military',
#  'class-minded',
#  'clean-cut',
#  'clear-cut',
#  'clear-eyed',
#  'clear-minded',
#  'clear-sighted',
#  'clear-thinking',
#  'close-knit',
#  'co-chairs',
#  'co-equal',
#  'co-inciding',
#  'co-op',
#  'co-operate',
#  'co-operated',
#  'co-operates',
#  'co-operating',
#  'co-operation',
#  'co-operations',
#  'co-operationwith',
#  'co-operative',
#  'co-operatively',
#  'co-operatives',
#  'co-ordination',
#  'co-payment',
#  'co-payments',
#  'co-pays',
#  'co-relation',
#  'co-tenants',
#  'coal-bearing',
#  'coal-burning',
#  'coal-fired',
#  'coal-land',
#  'coarse-ground',
#  'coast-defense',
#  'coast-line',
#  'code-talkers',
#  'coin-operated',
#  'cold-blooded',
#  'college-trained',
#  'colored-came',
#  'combat-equipped',
#  'commissary-sergeants',
#  'commissioner-general',
#  'committed-including',
#  'common-law',
#  'common-school',
#  'common-sense',
#  'common-sensical',
#  'community-based',
#  'community-involving',
#  'comp-time',
#  'compound-interest',
#  'computer-controlled',
#  'computer-literate',
#  'computer-smart',
#  'conflict-torn',
#  'conscience-impelled',
#  'consul-general',
#  'consulate-general',
#  'consumer-conscious',
#  'contract-labor',
#  'control-moves',
#  'conventional-type',
#  'cool-headed',
#  'coolie-tilled',
#  'cooperation-government',
#  'cop-killer',
#  'corn-hog',
#  'cost-conscious',
#  'cost-cutting',
#  'cost-free',
#  'cotton-goods',
#  'cotton-growing',
#  'cotton-producing',
#  'council-chambers',
#  'counter-attacks',
#  'counter-balanced',
#  'counter-guerrilla',
#  'counter-invasion',
#  'counter-offensive',
#  'counter-revolution',
#  'counter-terrorism',
#  'counter-weapon',
#  'counter-weapons',
#  'country-man',
#  'country-men',
#  'country-promoting',
#  'county-free',
#  'court-appointed',
#  'court-house',
#  'court-houses',
#  'court-martial',
#  'court-ordered',
#  'courts-martial',
#  'credit-bonds',
#  'crime-infested',
#  'crime-mapping',
#  'crime-ridden',
#  'criminal-law',
#  'crop-harvesting',
#  'crop-moving',
#  'crop-reporting',
#  'cross-border',
#  'cross-checking',
#  'cross-examination',
#  'cross-examine',
#  'cross-examined',
#  'cross-examining',
#  'cross-posts',
#  'cross-purposes',
#  'cross-section',
#  'cure-alls',
#  'custom-house',
#  'custom-houses',
#  'customs-revenue',
#  'cut-throat',
#  'cutting-edge',
#  'cyber-attacks',
#  'cyber-threats',
#  'danger-filled',
#  'dark-stained',
#  'day-inspector',
#  'de-emphasize',
#  'de-escalate',
#  'de-escalation',
#  'de-moralize',
#  'de-nuke',
#  'de-segregate',
#  'dead-end',
#  'dead-level',
#  'deal-making',
#  'death-dealing',
#  'death-defying',
#  'death-rate',
#  'death-wish',
#  'debt-bearing',
#  'debt-free',
#  'debt-paying',
#  'decades-long',
#  'decent-living',
#  'decision-making',
#  'deep-graven',
#  'deep-rooted',
#  'deep-seated',
#  'defense-oriented',
#  'defense-related',
#  'defied-pledges',
#  'democratic-republican',
#  'department-store',
#  'dependent-pension',
#  'desert-land',
#  'destruction-constitutes',
#  'destruction-meaning',
#  'dictatorship-clearly',
#  'die-hards',
#  'dilly-dallying',
#  'diplomacy-protect',
#  'diplomatic-service',
#  'dis-armed',
#  'dis-unionists',
#  'disability-pension',
#  'disarmament-true',
#  'disease-bearing',
#  'disease-ridden',
#  'dive-bomber',
#  'do-gooders',
#  'doctor-patient',
#  'domestic-slavery',
#  'door-keeper',
#  'double-digit',
#  'double-edged',
#  'double-talk',
#  'double-tracking',
#  'double-turret',
#  'double-turreted',
#  'draw-backs',
#  'drug-free',
#  'drug-related',
#  'drug-resistant',
#  'dry-dock',
#  'dry-land',
#  'duty-free',
#  'early-childhood',
#  'early-stage',
#  'earned-income',
#  'economy-wide',
#  'eight-hour',
#  'eight-story',
#  'eighth-grade',
#  'eighty-ninth',
#  'election-year',
#  'eleventh-hour',
#  'emissions-free',
#  'employer-based',
#  'employer-employee',
#  'employer-provided',
#  'energy-consuming',
#  'energy-efficient',
#  'energy-poor',
#  'energy-producing',
#  'energy-related',
#  'energy-rich',
#  'energy-saving',
#  'energy-wise',
#  'engine-rooms',
#  'entry-level',
#  'epoch-making',
#  'equal-handed',
#  'equal-rights',
#  'even-handed',
#  'ever-active',
#  'ever-advancing',
#  'ever-broadening',
#  'ever-closer',
#  'ever-enduring',
#  'ever-expanding',
#  'ever-favorite',
#  'ever-glorious',
#  'ever-growing',
#  'ever-higher',
#  'ever-increasing',
#  'ever-larger',
#  'ever-living',
#  'ever-mounting',
#  'ever-present',
#  'ever-ready',
#  'ever-recurring',
#  'ever-richer',
#  'ever-rising',
#  'ever-shifting',
#  'ever-varying',
#  'ever-watchful',
#  'ever-widening',
#  'every-day',
#  'everything-including',
#  'evil-disposed',
#  'evil-doers',
#  'ex-army',
#  'ex-marines',
#  'ex-officio',
#  'ex-post',
#  'ex-sailors',
#  'ex-service',
#  'ex-soldiers',
#  'exact-percent',
#  'examination-excepted',
#  'excess-profits',
#  'experimental-station',
#  'export-import',
#  'export-minded',
#  'extended-family',
#  'extra-territorial',
#  'eye-opening',
#  'eye-witnesses',
#  'fact-finding',
#  'fact-seeking',
#  'factories-textile',
#  'factory-inspection',
#  'faint-hearted',
#  'faint-heartedly',
#  'fair-dealing',
#  'fair-headed',
#  'fair-minded',
#  'fair-mindedness',
#  'fair-share',
#  'faith-based',
#  'fake-news',
#  'family-friendly',
#  'family-owned',
#  'family-wage',
#  'far-distant',
#  'far-famed',
#  'far-flung',
#  'far-left',
#  'far-reaching',
#  'far-removed',
#  'far-seeing',
#  'far-sighted',
#  'farmer-controlled',
#  'farmer-managed',
#  'farmer-owned',
#  'farnorth-west',
#  'fast-changing',
#  'fast-food',
#  'fast-growing',
#  'fast-spreading',
#  'fast-track',
#  'fastest-growing',
#  'father-land',
#  'fault-finding',
#  'favored-nation',
#  'federal-local',
#  'federally-aided',
#  'federally-funded',
#  'fee-simple',
#  'feel-good',
#  'fees-consular',
#  'fellow-beings',
#  'fellow-citizen',
#  'fellow-citizens',
#  'fellow-citizensa',
#  'fellow-citizensin',
#  'fellow-countrymen',
#  'fellow-farmer',
#  'fellow-magistrates',
#  'fellow-man',
#  'fellow-men',
#  'fellow-rioters',
#  'fellow-servant',
#  'fellow-servants',
#  'fiber-optic',
#  'field-matron',
#  'field-work',
#  'fifteen-foldwithin',
#  'fifty-dollar',
#  'fifty-fifth',
#  'fig-fertilizing',
#  'figure-head',
#  'fine-goods',
#  'fine-tuned',
#  'finger-pointing',
#  'fire-arm',
#  'fire-proof',
#  'fireside-chat',
#  'firm-set',
#  'first-aid',
#  'first-class',
#  'first-generation',
#  'first-hand',
#  'first-mentioned',
#  'first-mortgage',
#  'first-rate',
#  'first-responders',
#  'first-step',
#  'first-strike',
#  'first-time',
#  'first-year',
#  'five-day',
#  'five-hour',
#  'five-nation',
#  'five-page',
#  'five-point',
#  'five-sixths',
#  'five-star',
#  'five-twenties',
#  'five-year',
#  'fixed-income',
#  'flag-draped',
#  'flex-time',
#  'flight-test',
#  'flights-commercial',
#  'flint-lock',
#  'flood-control',
#  'flower-clad',
#  'following-named',
#  'food-producing',
#  'food-stuffs',
#  'foot-steps',
#  'force-force',
#  'fore-fathers',
#  'foreign-assistance',
#  'foreign-born',
#  'foreign-service',
#  'forest-reserve',
#  'forest-reserves',
#  'forty-eighth',
#  'forty-fifth',
#  'forty-ninth',
#  'forward-leaning',
#  'forward-looking',
#  'forward-moving',
#  'foundation-stone',
#  'four-engine',
#  'four-fifths',
#  'four-hour',
#  'four-point',
#  'four-power',
#  'four-square',
#  'four-star',
#  'four-story',
#  'four-tenths',
#  'four-thirty',
#  'four-word',
#  'four-year',
#  'fourth-class',
#  'fourth-rate',
#  'free-born',
#  'free-delivery',
#  'free-handed',
#  'free-hearted',
#  'free-market',
#  'free-men',
#  'free-spending',
#  'free-thinking',
#  'free-trade',
#  'freedom-fighters',
#  'freedom-loving',
#  'freeze-frame',
#  'freight-carrying',
#  'freight-rate',
#  'fresh-faced',
#  'fresh-water',
#  'friendship-exercising',
#  'front-line',
#  'front-page',
#  'front-row',
#  'fruit-growing',
#  'fuel-efficiency',
#  'fuel-efficient',
#  'fuel-switching',
#  'fugitive-slave',
#  'full-blown',
#  'full-caliber',
#  'full-fledged',
#  'full-grown',
#  'full-leg',
#  'full-rounded',
#  'full-scale',
#  'fund-raising',
#  'fur-bearing',
#  'fur-seal',
#  'gang-violence',
#  'general-delivery',
#  'generation-long',
#  'gill-net',
#  'go-ahead',
#  'gold-bearing',
#  'gold-demand',
#  'gold-standard',
#  'good-bye',
#  'good-fellowship',
#  'good-fortune',
#  'good-hearted',
#  'good-looking',
#  'good-natured',
#  'good-paying',
#  'goose-stepping',
#  'government-approved',
#  'government-funded',
#  'government-national',
#  'government-ordered',
#  'government-owned',
#  'government-related',
#  'government-required',
#  'government-run',
#  'government-sponsored',
#  'government-wide',
#  'grain-exporting',
#  'grain-milling',
#  'great-grandchildren',
#  'great-granddaughter',
#  'great-grandfather',
#  'great-grandparents',
#  'ground-breaking',
#  'ground-launch',
#  'ground-launched',
#  'ground-work',
#  'growth-oriented',
#  'gun-adept',
#  'gun-boat',
#  'gun-boats',
#  'gun-factory',
#  'gun-free',
#  'gun-racks',
#  'gur-reat',
#  'gut-wrenching',
#  'habit-forming',
#  'hair-splitters',
#  'hair-splitting',
#  'half-billion',
#  'half-breeds',
#  'half-burned',
#  'half-century',
#  'half-circle',
#  'half-clad',
#  'half-dismes',
#  'half-free',
#  'half-hearted',
#  'half-holidays',
#  'half-hour',
#  'half-mast',
#  'half-million',
#  'half-slave',
#  'half-way',
#  'half-won',
#  'half-yearly',
#  'hand-carried',
#  'hand-held',
#  'hand-maiden',
#  'hand-wringing',
#  'harbor-defense',
#  'hard-core',
#  'hard-earned',
#  'hard-fought',
#  'hard-headed',
#  'hard-hit',
#  'hard-hitting',
#  'hard-nosed',
#  'hard-pressed',
#  'hard-won',
#  'hard-working',
#  'hardest-hit',
#  'hardest-working',
#  'have-nots',
#  'havoc-breaking',
#  'health-care',
#  'health-related',
#  'heart-breaking',
#  'heart-felt',
#  'heart-rending',
#  'heart-throbbing',
#  'heart-warming',
#  'heart-wrenching',
#  'heat-seeking',
#  'hemp-growing',
#  'heretofore-recognized',
#  'higgledy-piggledy',
#  'high-crime',
#  'high-grade',
#  'high-growth',
#  'high-handed',
#  'high-license',
#  'high-minded',
#  'high-paying',
#  'high-power',
#  'high-powered',
#  'high-priced',
#  'high-priority',
#  'high-profile',
#  'high-quality',
#  'high-ranking',
#  'high-school',
#  'high-skilled',
#  'high-sounding',
#  'high-speed',
#  'high-strength',
#  'high-tech',
#  'high-technology',
#  'high-unemployment',
#  'high-value',
#  'high-wage',
#  'high-water',
#  'higher-level',
#  'higher-paying',
#  'higher-priced',
#  'highest-ranking',
#  'highly-leveraged',
#  'highly-paid',
#  'highly-skilled',
#  'hip-hop',
#  'history-making',
#  'home-loan',
#  'home-maker',
#  'home-makers',
#  'home-making',
#  'horse-trading',
#  'host-nation',
#  'hostage-taking',
#  'hot-bed',
#  'hot-headed',
#  'human-animal',
#  'hundred-dollar',
#  'hundred-yard',
#  'hundred-year',
#  'husband-man',
#  'hydroelectric-power',
#  'hydrogen-fueled',
#  'hydrogen-powered',
#  'hypo-rhetorical',
#  'ice-free',
#  'ill-advised',
#  'ill-assorted',
#  'ill-balanced',
#  'ill-clad',
#  'ill-concerted',
#  'ill-conduct',
#  'ill-considered',
#  'ill-defined',
#  'ill-directed',
#  'ill-feeling',
#  'ill-fitting',
#  'ill-founded',
#  'ill-health',
#  'ill-housed',
#  'ill-informed',
#  'ill-nourished',
#  'ill-prepared',
#  'ill-regulated',
#  'ill-rounded',
#  'ill-suited',
#  'ill-timed',
#  'in-[inaudible',
#  'in-demand',
#  'in-fighting',
#  'in-land',
#  'in-roads',
#  'in-trenched',
#  'income-producing',
#  'income-tax',
#  'independence-loving',
#  'independent-treasury',
#  'industrial-military',
#  'inflation-fighting',
#  'inflation-produced',
#  'influence-economic',
#  'inheritance-tax',
#  'ink-stained',
#  'inner-city',
#  'intelligence-sharing',
#  'inter-communication',
#  'inter-fere',
#  'inter-island',
#  'inter-oceanic',
#  'inter-service',
#  'interest-bearing',
#  'interest-sensitive',
#  'intermediate-range',
#  'internal-improvement',
#  'internal-revenue',
#  'internal-tax',
#  'international-affairs',
#  'interstate-commerce',
#  'interstate-railway',
#  'inward-bound',
#  'jet-age',
#  'job-creating',
#  'job-creation',
#  'job-killing',
#  'job-producing',
#  'job-ready',
#  'job-training',
#  'joint-stock',
#  'judge-advocates',
#  'jungle-covered',
#  'junior-grade',
#  'justice-justice',
#  'kind-heartedness',
#  'klieg-lights',
#  'labor-management',
#  'labor-saving',
#  'laboring-man',
#  'lake-bed',
#  'land-based',
#  'land-grant',
#  'land-laws',
#  'land-proceeds',
#  'large-handed',
#  'large-heartedness',
#  'large-scale',
#  'last-ditch',
#  'last-mentioned',
#  'last-minute',
#  'last-named',
#  'latter-mentioned',
#  'latter-named',
#  'law-abiding',
#  'law-defying',
#  'law-enforcement',
#  'law-honesty',
#  'law-maker',
#  'law-makers',
#  'law-making',
#  'law-recommendations',
#  'law-respecting',
#  'laws-strengthening',
#  'lead-time',
#  'leading-edge',
#  'leaf-eating',
#  'leave-taking',
#  'left-wing',
#  'legal-tenders',
#  'lemon-box',
#  'lend-lease',
#  'less-developed',
#  'less-favored',
#  'less-fortunate',
#  'level-best',
#  'liberal-minded',
#  'liberty-loving',
#  'lieutenant-colonel',
#  'lieutenant-colonels',
#  'lieutenant-commander',
#  'lieutenant-commanders',
#  'lieutenant-general',
#  'lieutenant-governor',
#  'life-blood',
#  'life-changing',
#  'life-enhancing',
#  'life-extending',
#  'life-insurance',
#  'life-long',
#  'life-saving',
#  'life-threatening',
#  'life-time',
#  'light-draft',
#  'light-hearted',
#  'light-house',
#  'light-houses',
#  'light-rainfall',
#  'like-minded',
#  'line-item',
#  'lip-service',
#  'listen-let',
#  'little-known',
#  'live-oak',
#  'live-stock',
#  'log-line',
#  'log-rolling',
#  'long-awaited',
#  'long-buried',
#  'long-cherished',
#  'long-continued',
#  'long-deferred',
#  'long-delayed',
#  'long-developed',
#  'long-disputed',
#  'long-enduring',
#  'long-existing',
#  'long-extended',
#  'long-felt',
#  'long-fourteen',
#  'long-held',
#  'long-ignored',
#  'long-indulged',
#  'long-isolated',
#  'long-lasting',
#  'long-lost',
#  'long-maintained',
#  'long-needed',
#  'long-neglected',
#  'long-overdue',
#  'long-pending',
#  'long-playing',
#  'long-protracted',
#  'long-range',
#  'long-reaching',
#  'long-run',
#  'long-running',
#  'long-settled',
#  'long-sought',
#  'long-standing',
#  'long-staple',
#  'long-subsisting',
#  'long-suffering',
#  'long-time',
#  'long-vexed',
#  'long-view',
#  'longer-term',
#  'longest-serving',
#  'longest-suffering',
#  'loosely-monitored',
#  'loud-mouthed',
#  'low-birth',
#  'low-carbon',
#  'low-cost',
#  'low-demand',
#  'low-enriched',
#  'low-income',
#  'low-interest',
#  'low-key',
#  'low-lived',
#  'low-lying',
#  'low-paying',
#  'low-priced',
#  'low-rent',
#  'low-rental',
#  'low-sulfur',
#  'low-tariff',
#  'low-wage',
#  'low-water',
#  'lower-income',
#  'lower-middle',
#  'lower-paid',
#  'lower-priced',
#  'lower-skilled',
#  'lower-wage',
#  'lowest-paid',
#  'lungs-clean',
#  'luxuries-perfumes',
#  'machine-gun',
#  'machine-gunned',
#  'mail-carrying',
#  'mail-messenger',
#  'mail-order',
#  'main-line',
#  'major-generals',
#  'make-believe',
#  ...]

# %% [markdown]
# >> #### 7.2 Solution: Remove hyphens from words that do not require hyphens

# %%
hyphens_after = list(nlp.pipe([token.replace('-', ' ') for token in hyphens_before]))
hyphens_after = [token.text.replace(' ', '-') for token in hyphens_after if is_compound(token, 'NOUN', 'ADJ', 'pp') or is_compound(token, 'NOUN', 'VBG', 'pt') or is_compound(token, 'NOUN', 'VBN', 'pt') or is_compound(token, 'ADJ', 'VGB', 'pt') or is_compound(token, 'ADJ', 'VBN', 'pt')]
hyphens_after
# Out:
# ['age-old',
#  'air-based',
#  'blockade-breaking',
#  'blood-thirsty',
#  'bond-paying',
#  'bone-tired',
#  'bread-winning',
#  'bullion-producing',
#  'cancer-free',
#  'centuries-old',
#  'combat-equipped',
#  'community-based',
#  'community-involving',
#  'computer-controlled',
#  'conflict-torn',
#  'consumer-conscious',
#  'cost-conscious',
#  'cotton-growing',
#  'cotton-producing',
#  'country-promoting',
#  'courts-martial',
#  'crime-infested',
#  'crop-moving',
#  'cross-examining',
#  'deal-making',
#  'death-defying',
#  'debt-free',
#  'debt-paying',
#  'double-turreted',
#  'drug-free',
#  'drug-related',
#  'drug-resistant',
#  'duty-free',
#  'economy-wide',
#  'emissions-free',
#  'employer-based',
#  'energy-consuming',
#  'energy-efficient',
#  'energy-producing',
#  'examination-excepted',
#  'fact-seeking',
#  'faith-based',
#  'family-friendly',
#  'fees-consular',
#  'flag-draped',
#  'food-producing',
#  'friendship-exercising',
#  'fruit-growing',
#  'fuel-efficient',
#  'habit-forming',
#  'half-burned',
#  'heart-rending',
#  'heart-wrenching',
#  'higher-priced',
#  'home-making',
#  'income-producing',
#  'interest-sensitive',
#  'job-creating',
#  'job-producing',
#  'land-based',
#  'last-named',
#  'law-defying',
#  'laws-strengthening',
#  'life-changing',
#  'life-extending',
#  'life-threatening',
#  'lungs-clean',
#  'man-eating',
#  'market-based',
#  'merit-based',
#  'mind-boggling',
#  'missile-related',
#  'money-dealing',
#  'money-making',
#  'name-calling',
#  'night-flying',
#  'oil-consuming',
#  'oil-exporting',
#  'oil-producing',
#  'others-free',
#  'panic-stricken',
#  'peace-pursuing',
#  'penalty-free',
#  'people-consistent',
#  'percentage-wise',
#  'petroleum-based',
#  'point-scoring',
#  'pollution-free',
#  'power-hungry',
#  'power-starved',
#  'preference-claiming',
#  'principles-substantial',
#  'problem-solving',
#  'promise-performing',
#  're-fighting',
#  'recession-depressed',
#  'risk-free',
#  'risk-taking',
#  'rule-based',
#  'rule-making',
#  'sea-based',
#  'self-confident',
#  'self-defeating',
#  'self-dependent',
#  'self-destroying',
#  'self-destructive',
#  'self-extending',
#  'self-protecting',
#  'self-respecting',
#  'self-seeking',
#  'self-serving',
#  'self-sufficient',
#  'self-supporting',
#  'self-sustaining',
#  'seventies-soaring',
#  'short-sighted',
#  'single-turreted',
#  'sky-rocketing',
#  'slave-holding',
#  'smoke-filled',
#  'soul-searching',
#  'soul-stifling',
#  'space-based',
#  'space-faring',
#  'state-controlled',
#  'state-funded',
#  'state-owned',
#  'stock-growing',
#  'storm-beaten',
#  'storms-joint',
#  'surveyors-general',
#  'tank-producing',
#  'tax-exempt',
#  'tax-free',
#  'tax-paying',
#  'tax-supported',
#  'tenant-farmed',
#  'thanks-giving',
#  'things-stubborn',
#  'time-worn',
#  'toll-free',
#  'treaty-making',
#  'value-free',
#  'vote-seeking',
#  'war-declaring',
#  'war-making',
#  'war-seeking',
#  'war-worn',
#  'wealth-producing',
#  'wonder-working',
#  'world-seeking',
#  'world-shaking',
#  'world-wide',
#  'year-old']

# %% [markdown]
# >> #### 7.3 Prepare token pairs

# %%
hyphen_tokens = sorted(list(set(hyphen_tokens).difference(set(hyphens_after))))
hyphen_tokens
# Out:
# ['1,500-a-year',
#  '1-day',
#  '1-in-20',
#  '1-yard',
#  '1-year',
#  '1-year-old',
#  '1/2-inch',
#  '1/2-percent',
#  '10,000-foot',
#  '10,000-page',
#  '10,000-ton',
#  '10-day',
#  '10-inch',
#  '10-man',
#  '10-minute',
#  '10-percent',
#  '10-round',
#  '10-to-1',
#  '10-year',
#  '10-year-old',
#  '100-cent',
#  '11-year-old',
#  '12-hour',
#  '12-inch',
#  '12-month',
#  '12-year-old',
#  '122-foot',
#  '122-percent',
#  '13-year-old',
#  '13Ѕ-inch',
#  '14-percent',
#  '14-point',
#  '14-to-1',
#  '14-year',
#  '14-year-old',
#  '15-percent',
#  '15-year-olds',
#  '152-millimeter',
#  '16-inch',
#  '16-inch-type',
#  '16-year-old',
#  '167-page',
#  '17-year',
#  '17-year-low',
#  '17-year-old',
#  '18-hour',
#  '18-nation',
#  '18-percent',
#  '18-wheelers',
#  '18-year-old',
#  '18-year-olds',
#  '180-odd',
#  '19-foot',
#  '19-year-old',
#  '19-year-olds',
#  '190-year',
#  '1970s-era',
#  '19th-century',
#  '2,000-foot',
#  '2,000-mile',
#  '2-in-3',
#  '2-is',
#  '2-minute',
#  '2-percent',
#  '2-year',
#  '2-year-old',
#  '2-year-olds',
#  '20-knot',
#  '20-percent',
#  '20-point',
#  '20-year',
#  '20-year-old',
#  '200-mile',
#  '200-year',
#  '200-year-old',
#  '21st-century',
#  '22,000-word',
#  '22-month',
#  '22-percent',
#  '23-knot',
#  '24-hour',
#  '24-knot',
#  '24-year',
#  '25-percent',
#  '25-year',
#  '250-bed',
#  '26-year-old',
#  '28-minute',
#  '28-percent',
#  '28-square-mile',
#  '3-day',
#  '3-inch',
#  '3-mile',
#  '3-minute',
#  '3-point',
#  '3-to-1',
#  '3-year',
#  '3/4-year',
#  '30-cent',
#  '30-day',
#  '30-minute',
#  '30-odd',
#  '30-percent',
#  '30-second',
#  '30-year',
#  '35-day',
#  '35-hour',
#  '35-percent',
#  '36-percent',
#  '37-point',
#  '3D-print',
#  '3rd-grade',
#  '4-or',
#  '4-percent',
#  '4-point',
#  '4-something',
#  '4-star',
#  '4-year',
#  '4-year-old',
#  '4.8-percent',
#  '40,000-odd',
#  '40-nation',
#  '40-percent',
#  '40-some',
#  '40-yard',
#  '40-year',
#  '45-second',
#  '45-year',
#  '47-year-old',
#  '48-story',
#  '49-year-old',
#  '5-ambulatory',
#  '5-day',
#  '5-letter',
#  '5-percent',
#  '5-power',
#  '5-year',
#  '5-year-old',
#  '50,000-a-year',
#  '50-cent',
#  '50-cent-a-gallon',
#  '50-hour',
#  '50-percent',
#  '50-year',
#  '500-billion',
#  '500-million',
#  '500-per-child',
#  '500-year',
#  '55-mile',
#  '5?-percent',
#  '6-day',
#  '6-inch',
#  '6-month',
#  '6-months',
#  '6-percent',
#  '6-point',
#  '6-pounder',
#  '6-year',
#  '60,000-plus',
#  '60-day',
#  '60-second',
#  '600,000-man',
#  '600-page',
#  '600-percent',
#  '600-ship',
#  '62-year-olders',
#  '65-year',
#  '650-billion-a-year',
#  '7-day',
#  '7-percent',
#  '7-year',
#  '7-year-long',
#  '70-million',
#  '70-percent',
#  '73-percent',
#  '75-bed',
#  '75-page',
#  '75-year-old',
#  '77-percent',
#  '8-inch',
#  '8-year',
#  '8-year-old',
#  '8-year-olds',
#  '800-HELPNOW',
#  '800-some',
#  '81-which',
#  '85-foot',
#  '88-year-old',
#  '9,000-men',
#  '9-foot',
#  '9-hour',
#  '9-millimeter',
#  '9-year-olds',
#  '9.2-percent',
#  '90-day',
#  '90-minute',
#  '90-second',
#  '900,000-$900,000',
#  '91-to-1',
#  '960-acre',
#  'A-11',
#  'A-6F',
#  'A-grade',
#  'A-plus',
#  'ACT-UP',
#  'ADJUTANT-GENERAL',
#  'AIDS-free',
#  'AK-47s',
#  'AMERICA-HONDURAS',
#  'ANTI-TRUST',
#  'ARBITRATIONS-PANAMA',
#  'Adjutant-General',
#  'Administration-Mr',
#  'African-American',
#  'African-Americans',
#  'African-owned',
#  'Ah-h-h',
#  'Aigner-Clark',
#  'Aix-la-Chapelle',
#  'Al-Azhar',
#  'Alaskan-Yukon-Pacific',
#  'All-merciful',
#  'All-powerful',
#  'All-time',
#  'Allies-in',
#  'Alsace-Lorraine',
#  'Amazon-Washington',
#  'Ambassador-Mr',
#  'America-in',
#  'America-the',
#  'American-British',
#  'American-Hellenic',
#  'American-Soviet',
#  'American-born',
#  'American-built',
#  'American-made',
#  'American-mediated',
#  'American-owned',
#  'Americans-to',
#  'Americas-the',
#  'An-tung',
#  'Anglo-Saxon',
#  'Anglo-Venezuelan',
#  'Anti-Trust',
#  'Antung-Mukden',
#  'Apollo-Gemini',
#  'Arab-Israeli',
#  'Armenian-Americans',
#  'As-salaamu',
#  'Asia-Pacific',
#  'Asia-and',
#  'Asia-which',
#  'Asian-American',
#  'Asian-Americans',
#  'Assembly-have',
#  'Atlantic-Mississippi',
#  'Attorney-General',
#  'Attorneys-General',
#  'Austro-Hungarian',
#  'B-1',
#  'B-1B',
#  'B-2',
#  'B-22',
#  'B-29',
#  'B-47',
#  'B-52',
#  'B-l',
#  'BUNAU-VARILLA',
#  'Baltic-Americans',
#  'Band-Aid',
#  'Band-aid',
#  'Berlin-and',
#  'Big-Brother-is-watching-you',
#  'Big-hearted',
#  'Black-owned',
#  'Blue-collar',
#  'Boo-o-o',
#  'Bosnia-wide',
#  'Boutros-Ghali',
#  'Brest-Litovsk',
#  'Briand-Kellogg',
#  'Brigadier-General',
#  'British-American',
#  'Bunau-Varilla',
#  'Bush-McCain',
#  'C-1',
#  'C-SPAN',
#  'C-minus',
#  'CAPITAL-GAINS',
#  'CIVIL-SERVICE',
#  'CONFERENCE-UNFORTUNATE',
#  'CONSULATE-GENERAL',
#  'Cabinet-level',
#  'Cambodian-Vietnam',
#  'Capper-Ketcham',
#  'Capper-Volstead',
#  'Captain-General',
#  'Captain-Generalto',
#  'Carter-Mondale',
#  'Catch-and-release',
#  'Census-we',
#  'Cha-Cha-Cha',
#  'Chamber-the',
#  'Chi-li',
#  'China-U.S.',
#  'Chinchow-Aigun',
#  'Chinese-American',
#  'Chinese-Japanese',
#  'Chinese-made',
#  'Christ-like',
#  'Civil-Service',
#  'Civil-service',
#  'Clayton-Bulwer',
#  'Clear-eyed',
#  'Co-operation',
#  'Coal-land',
#  'Coleman-Singleton',
#  'Columbia-it',
#  'Commander-in-Chief',
#  'Commissary-General',
#  'Commissioner-General',
#  'Communist-controlled',
#  'Communist-directed',
#  'Communist-dominated',
#  'Communist-inspired',
#  'Communist-supplied',
#  'Communist-supported',
#  'Conable-Hanee',
#  'Congo-Adoula',
#  'Congo-Kinshasa',
#  'Congress-and',
#  'Congress-by',
#  'Congress-through',
#  'Consul-General',
#  'Convention-my',
#  'Corps]-type',
#  'Cuban-Soviet',
#  'D-day',
#  'DECISION-MERELY',
#  'Dar-Es-Salaam',
#  'Day-inspector',
#  'Dead-Letter',
#  'Democratic-controlled',
#  'Director-General',
#  'Disarmament-Canada',
#  'Double-digit',
#  'Douglas-Home',
#  'Drug-Free',
#  'E-rate',
#  'EIGHT-HOUR',
#  'ELECTRICAL-POWER',
#  'Earth-based',
#  'East-West',
#  'East-mark',
#  'East-there',
#  'Egypt-Saudi',
#  'Egyptian-Israeli',
#  'Eisenhower-and',
#  'Eisenhower-they',
#  'Elizabeth-City',
#  'Empress-Queen',
#  'English-speaking',
#  'Entente-Allies',
#  'Establishment-this',
#  'Europe-the',
#  'Ex-Corporal',
#  'Export-Import',
#  'Eyre-Cragin',
#  'F-1',
#  'F-14',
#  'F-14s',
#  'F-15',
#  'F-35',
#  'F1a.-there',
#  'FBI-in',
#  'FELLOW-CITIZENS',
#  'FUR-SEAL',
#  'Fair-minded',
#  'Faith-Based',
#  'Faith-based',
#  'Far-reaching',
#  'Farmer-Labor',
#  'Federal-State',
#  'Federal-assisted',
#  'Federal-highway',
#  'Federally-funded',
#  'Fellow-Citizens',
#  'Fellow-Countrymen',
#  'Fellow-citizens',
#  'Fiat-Chrysler',
#  'Fifty-eighth',
#  'Fifty-fifth',
#  'Fifty-four-forty',
#  'Fish-Culture',
#  'Five-Year',
#  'Five-twenties',
#  'Fix-It-First',
#  'Flat-head',
#  'Follow-up',
#  'Foo-Choo-Foo',
#  'Food-for-Peace',
#  'Fordney-McCumber',
#  'Forty-fifth',
#  'Forty-ninth',
#  'Four-Power',
#  'Four-fifths',
#  'Franco-American',
#  'Frankfort-on-the-Main',
#  'Franklin-leaning',
#  'Free-Soilers',
#  'Free-State',
#  'Free-delivery',
#  'Free-market',
#  'G-20',
#  'G-8',
#  'GS-12',
#  'GS-18',
#  'Gall-lard',
#  'Garner-Rainey',
#  'Germany-the',
#  'Germany-voting',
#  'God-awful',
#  'God-blessed',
#  'God-fearing',
#  'God-given',
#  'God-imposed',
#  'Government-improved',
#  'Government-its',
#  'Government-led',
#  'Government-owned',
#  'Government-regulated',
#  'Government-the',
#  'Government-under',
#  'Government-wide',
#  'Governments-Germany',
#  'Governor-General',
#  'Governor-to',
#  'Gramm-Rudman',
#  'Gramm-Rudman-Hollings',
#  'Grant-in-aid',
#  'Greek-Turkish',
#  'H-43',
#  'H-bomb',
#  'HIV-positive',
#  'HOME-LOAN',
#  'Haitian-Americans',
#  'Haitian-Dominican',
#  'Half-hearted',
#  'Hard-headedness',
#  'Harley-Davidson',
#  'Harvard-trained',
#  'Hawaiian-Japanese',
#  'Hawley-Smoot',
#  'Hay-Herran',
#  'Hay-Pauncefote',
#  'Heaven-favored',
#  'Heavy-armed',
#  'Hesse-Darmstadt',
#  'High-ranking',
#  'High-wage',
#  'Hill-Burton',
#  'Hispanic-Americans',
#  'Hiss-Chambers',
#  'Hitler-dominated',
#  'Ho-si-woo',
#  'Hope-renewed',
#  'House-business',
#  'Hsiao-ping',
#  'Hudson-Fulton',
#  'Humphrey-Hawkins',
#  'IA-ECOSOC',
#  'II-has',
#  'III-C',
#  'INTER-AMERICAN',
#  'INTERSTATE-COMMERCE',
#  'Indian-school',
#  'Indo-China',
#  'Indo-Chinese',
#  'Indonesian-Malaysian',
#  'Inspector-General',
#  'Inter-American',
#  'Inter-Departmental',
#  'Intermediate-Range',
#  'Internal-Revenue',
#  'Internal-revenue',
#  'Iran-Iraq',
#  'Iraqi-led',
#  'Irish-American',
#  'Irish-Catholic',
#  'Irish-Protestant',
#  'Israeli-Jordanian',
#  'Israeli-Palestinian',
#  'Italian-Americans',
#  'J-58',
#  'Jackson-Vanik',
#  'Jaish-e-Mohammed',
#  'Japanese-American',
#  'Jefferson-like',
#  'Jewish-Americans',
#  'Job-killing',
#  'Johnson-Humphrey',
#  'Judas-like',
#  'Judge-Advocate-General',
#  'Judge-Advocates',
#  'Kassebaum-Kennedy',
#  'Kellogg-Briand',
#  'Kemp-Roth',
#  'Kennedy-Johnson',
#  'Kennedy-Kassebaum',
#  'Kennedy-McCarthy',
#  'Key-Stone',
#  'Kiao-chow',
#  'Klan-minded',
#  'LATIN-AMERICAN',
#  'LAW-THE',
#  'LIGHT-HOUSE',
#  'LIGHT-HOUSES',
#  'LONG-STANDING',
#  'Labor-Management',
#  'Lakes-St',
#  'Lao-tzu',
#  'Laos-regained',
#  'Large-scale',
#  'Latter-day',
#  'Law-abiding',
#  'Law-clerk',
#  'Lieutenant-Colonel',
#  'Lieutenant-Commander',
#  'Lieutenant-General',
#  'Life-Saving',
#  'Light-House',
#  'Light-houses',
#  'Lincoln\'s-"Let',
#  'Long-term',
#  'Low-income',
#  'Low-tax',
#  'M-1',
#  'MI-8',
#  'MS-13',
#  'Major-General',
#  'Man-of-war',
#  'Manila-Hongkong',
#  'Mansfield-Scott',
#  'Marine-Hospital',
#  'Marquez-Greene',
#  'Marxism-Leninism',
#  'Marxist-Leninism',
#  'Marxist-Leninist',
#  'Marxist-Leninists',
#  'Mason-Dixon',
#  'Mazar-e-Sharif',
#  'McCain-Feingold',
#  'Mecklenburg-Schwerin',
#  'Medicare-approved',
#  'Medicare-rarely',
#  'Meuse-Argonne',
#  'Mid-Atlantic',
#  'Middle-class',
#  'Middleton-Doctor',
#  'Mig-23',
#  'Mm-hmm',
#  'Modern-day',
#  'Money-Order',
#  'Moore-Brown',
#  'Muslim-majority',
#  'Mustering-out',
#  'NAVY-YARDS',
#  'Nation-wide',
#  'Nations-and',
#  'Nations-led',
#  'Navy-Yard',
#  'Nazi-dominated',
#  'Nazi-ism',
#  'Nebraska-Kansas',
#  'New-England',
#  'New-Jersey',
#  'New-Orleans',
#  'New-York',
#  'Night-inspector',
#  'Nine-eleven',
#  'Nixon-16',
#  'Nixon-Ford',
#  'Non-Discrimination',
#  'Non-Proliferation',
#  'Non-intervention',
#  'North-Carolina',
#  'North-South',
#  'North-West',
#  'North-Western',
#  'Nuclear-Test-Ban',
#  'OB-GYN',
#  'Oil-producing',
#  'Old-fashioned',
#  'On-site',
#  'Once-bitter',
#  'One-eighth',
#  'One-fourth',
#  'One-half',
#  'One-third',
#  'Ottoman-born',
#  'P-Tech',
#  'PANAMA-PACIFIC',
#  'POST-OFFICE',
#  'POSTAL-SAVINGS',
#  'PURE-FOOD',
#  'Pacific-cable',
#  'Pago-Pago',
#  'Pakistan-600',
#  'Pan-Amencan',
#  'Pan-American',
#  'Pan-Americanism',
#  'Panama-Pacific',
#  'Paper-covered',
#  'Paymaster-General',
#  'Paymaster-General.3',
#  'Payne-Aldrich',
#  'Pei-Ho',
#  'Peit-sang',
#  'Pent-up',
#  'Peru-Bolivian',
#  'Port-au-Prince',
#  'Post-9/11',
#  'Post-Dispatch',
#  'Post-Office',
#  'Post-OfficeDepartment',
#  'Post-Roads',
#  'Post-office',
#  'Post-offices',
#  'Post-roads',
#  'PostMaster-General',
#  'Postmaster-General',
#  'Postmaster-Generalagainst',
#  'Postmaster-Generals',
#  'Pre-K',
#  'President-Elect',
#  'President-and',
#  'President-as',
#  'President-some',
#  'President-that',
#  'President-to-be',
#  'President-tried',
#  'President-with',
#  'Presidents-President',
#  'Prize-winning',
#  'Provost-Marshal-General',
#  'Qaeda-Iraq',
#  'Quartermaster-General',
#  'R-U',
#  'R-e-g-a-n',
#  'RC-135',
#  'RICA-COLOMBIA',
#  'RS-70',
#  'Ranger-type',
#  'Re-Election',
#  'Re-employment',
#  'Re-enlistment',
#  'Reagan-Bush',
#  'Reagan-Kemp-Roth',
#  'Rear-Admiral',
#  'Revenue-Cutter',
#  'Richmond-based',
#  'Rip-Rap',
#  'Rush-Bagot',
#  'Russo-American',
#  'Russo-Japanese',
#  'SECOND-CLASS',
#  'SELF-DEFENSE',
#  'SEMI-CENTENNIAL',
#  'SLAVE-DEALER',
#  'SR-71',
#  'SR-7I',
#  'SS-18',
#  'SS-20',
#  'SS-20s',
#  'SS-21',
#  'SS-4',
#  'SS-4s',
#  'SS-5',
#  'STABT-Strategic',
#  'Sabbath-Sunday',
#  'Sai-shek',
#  'Sam-whoever',
#  'Saxe-Coburg',
#  'Schleswig-Holstein',
#  'Scotch-Irish',
#  'Scripps-Howard',
#  'Scud-type',
#  'Secret-Service',
#  'Secretary-General',
#  'Secretary-then-Regan',
#  'Self-defense',
#  'Self-determination',
#  'Self-governed',
#  'Self-government',
#  'Self-interest',
#  'Self-preservation',
#  'Self-reliance',
#  'Self-restraint',
#  'Seong-ho',
#  'September-immediately',
#  'Seventy-Fifth',
#  'Shan-tung',
#  'Sheppard-Towner',
#  'Short-term',
#  'Signal-Service',
#  'Simpson-Bowles',
#  'Simpson-Mazzoli',
#  'Sino-American',
#  'Sino-Soviet',
#  'Sixty-eighth',
#  'Slave-Code',
#  'Small-business',
#  'Smoot-Haw',
#  'Solicitor-General',
#  'South-Carolina',
#  'South-west',
#  'Soviet-American',
#  'Soviet-Chinese',
#  'Soviet-Cuban',
#  'Soviet-U.S.',
#  'Soviet-built',
#  'Soviet-made',
#  'Soviet-occupied',
#  'Soviet-sponsored',
#  'Soviet-supported',
#  'Spanish-American',
#  'Spanish-speaking',
#  'Speaker-elect',
#  'Star-Spangled',
#  'Star-Warring',
#  'State-administered',
#  'State-an',
#  'State-bank',
#  'State-controlled',
#  'State-directed',
#  'State-owned',
#  'State-sponsored',
#  'State-supported',
#  'States-Mexican',
#  'States-a',
#  'States-besides',
#  'Steamboat-Inspection',
#  'Sung-pu',
#  'Surgeon-General',
#  'Suz-ahn',
#  'Syrian-backed',
#  'Sze-chuen',
#  'TACNA-ARICA',
#  'Ta-lien-wan',
#  'Tacna-Arica',
#  'Taft-Ellender-Wagner',
#  'Tax-exempt',
#  'Ten-forties',
#  'The-world',
#  'Thirty-eighth',
#  'Thirty-fifth',
#  'Thirty-ninth',
#  'Thomas-Anita',
#  'Three-fourths',
#  'Three-quarters',
#  'Tien-Tsin',
#  'Tien-tsin',
#  'Ting-fang',
#  'To-day',
#  'To-morrow',
#  'Trans-Missouri',
#  'Trans-Pacific',
#  'Trenton-Princeton',
#  'Truman-Acheson',
#  'Trump-Pence',
#  'Tsai-Hsun',
#  'Tsai-tao',
#  'Tse-tung',
#  'Tsing-tao',
#  'Tsung-li',
#  'Twenty-fifth',
#  'Two-thirds',
#  'U-2',
#  'U-Boats',
#  'U-boats',
#  'U.S.-Canadian',
#  'U.S.-Japan',
#  'U.S.-Korea',
#  'U.S.-Mexico',
#  'U.S.-Mexico-Canada',
#  'U.S.-Panamanian',
#  'Ukrainian-Americans',
#  'Union-for',
#  'Union-loving',
#  'Union-men',
#  'Union-saving',
#  'Union-supporting',
#  'V-1',
#  'V-2',
#  'V-J',
#  'V-chip',
#  'Vice-Presidency',
#  'Vice-President',
#  'Vice-Presidential',
#  'Viet-Nam',
#  'Vietnam-and',
#  'Vietnam-apply',
#  'Vietnam-backed',
#  'W-GDP',
#  'Wage-workers',
#  'Wagner-Ellender-Taft',
#  'War-would',
#  'Washington-based',
#  'Web-feet',
#  'Wei-hai-wei',
#  'Well-considered',
#  'Well-founded',
#  'Well-trained',
#  'Western-proposed',
#  'Western-type',
#  'Wilkes-Barre',
#  'X-rated',
#  'Yang-Tse',
#  'Yen-hoon',
#  'Zero-Option',
#  'Zimbabwe-Rhodesia',
#  'able-bodied',
#  'above-cited',
#  'above-estimated',
#  'above-mentioned',
#  'above-named',
#  'above-recited',
#  'academy-type',
#  'across-the-board',
#  'act-$350,000,000',
#  'add-ons',
#  'adjusted-service',
#  'administration-helped',
#  'administration-laws',
#  'administration-tried',
#  'advanced-placement',
#  "afflicted-they've",
#  'after-dinner',
#  'after-effect',
#  'after-effects',
#  'after-school',
#  'after-tax',
#  'age-long',
#  'ago-ideas',
#  'ago-passed',
#  'agreements-agreements',
#  'agricultural-college',
#  'ahead-immediately',
#  'aid-to-democracies',
#  'air-landing',
#  'air-lane',
#  'air-lift',
#  'air-mail',
#  'air-raid',
#  'air-to-air',
#  'al-Assad',
#  'al-Baghdadi',
#  "al-Qa'ida",
#  'al-Qaeda',
#  'al-Sabah',
#  'al-Suhail',
#  'all-American',
#  'all-Asian',
#  'all-German',
#  'all-Indochina',
#  'all-absorbing',
#  'all-black',
#  'all-embracing',
#  'all-engrossing',
#  'all-important',
#  'all-inclusive',
#  'all-male',
#  'all-merciful',
#  'all-military',
#  'all-of-the-above',
#  'all-or-nothing',
#  'all-pervading',
#  'all-powerful',
#  'all-round',
#  'all-solar',
#  'all-time',
#  'all-volunteer',
#  'all-weather',
#  'all-wind',
#  'all-wise',
#  'alliance-building',
#  'and-towns',
#  'andlaw-abiding',
#  'anever-increasing',
#  'animal-killers',
#  'anniversary-let',
#  'ante-revolutionary',
#  'anti-American',
#  'anti-Catholic',
#  'anti-Communism',
#  'anti-Communist',
#  'anti-Fascist',
#  'anti-Nazi',
#  'anti-Semitic',
#  'anti-Semitism',
#  'anti-Somoza',
#  'anti-Soviet',
#  'anti-U.S.',
#  'anti-Vietnam',
#  'anti-Washington',
#  'anti-aircraft',
#  'anti-bullying',
#  'anti-business',
#  'anti-climb',
#  'anti-communism',
#  'anti-corruption',
#  'anti-craft',
#  'anti-crime',
#  'anti-drug-trafficking',
#  'anti-energy',
#  'anti-fraud',
#  'anti-government',
#  'anti-guerrilla',
#  'anti-inflation',
#  'anti-inflationary',
#  'anti-intellectualism',
#  'anti-military',
#  'anti-narcotic',
#  'anti-philosophers',
#  'anti-pollution',
#  'anti-poverty',
#  'anti-recession',
#  'anti-retroviral',
#  'anti-semitic',
#  'anti-slavery',
#  'anti-submarine',
#  'anti-tank',
#  'anti-terrorism',
#  'anti-terrorist',
#  'anti-trust',
#  'anti-worker',
#  'antici-pations',
#  'apple-selling',
#  'areas-new',
#  'arm-in-arm',
#  'armor-piercing',
#  'armor-plate',
#  'arms-Mother',
#  'asylum-seekers',
#  'at-risk',
#  'atomic-missile',
#  'attack,-dangers',
#  'attorney-client',
#  'attorney-general',
#  'awe-inspiring',
#  'back-alley',
#  'back-and-forth',
#  'back-to-back',
#  'back-to-school',
#  'balance-of-payments',
#  'ballot-box',
#  'bally-ho',
#  'bank-note',
#  'barbed-wire',
#  'base-loaded',
#  'battle-cry',
#  'battle-field',
#  'battle-lines',
#  'battle-ravaged',
#  'battle-ship',
#  'battle-ships',
#  'beach-head',
#  'beacon-light',
#  'bed-fellows',
#  'beef-packing',
#  'been-abandoned',
#  'beet-sugar',
#  'before-mentioned',
#  'before-named',
#  'before-recited',
#  'behind-the-scenes',
#  'best-connected',
#  'best-informed',
#  'best-selling',
#  'better-equipped',
#  'better-positioned',
#  'between-decks',
#  'bi-partisan',
#  'big-city',
#  'big-hearted',
#  'big-money',
#  'big-power',
#  'big-shots',
#  'big-time',
#  'bill-holders',
#  'billion-dollar',
#  'billion-plus',
#  'bio-based',
#  'bio-fuels',
#  'black-and-white',
#  'block-signal',
#  'blood-filled',
#  'blood-soaked',
#  'blue-collar',
#  'body-politic',
#  ...]

# %% [markdown]
# >> #### 8.1 Problem: Remove hyphens from single hyphen words that do not require hyphens

# %%
pattern = '^[a-z]+-[^-A-Z0-9]+$'
hyphens_before = [re.search(pattern, token)[0] for token in hyphen_tokens if re.search(pattern, token)]
hyphens_before.remove('minimum-wage')
hyphens_before
# Out:
# ['able-bodied',
#  'above-cited',
#  'above-estimated',
#  'above-mentioned',
#  'above-named',
#  'above-recited',
#  'academy-type',
#  'add-ons',
#  'adjusted-service',
#  'administration-helped',
#  'administration-laws',
#  'administration-tried',
#  'advanced-placement',
#  "afflicted-they've",
#  'after-dinner',
#  'after-effect',
#  'after-effects',
#  'after-school',
#  'after-tax',
#  'age-long',
#  'ago-ideas',
#  'ago-passed',
#  'agreements-agreements',
#  'agricultural-college',
#  'ahead-immediately',
#  'air-landing',
#  'air-lane',
#  'air-lift',
#  'air-mail',
#  'air-raid',
#  'all-absorbing',
#  'all-black',
#  'all-embracing',
#  'all-engrossing',
#  'all-important',
#  'all-inclusive',
#  'all-male',
#  'all-merciful',
#  'all-military',
#  'all-pervading',
#  'all-powerful',
#  'all-round',
#  'all-solar',
#  'all-time',
#  'all-volunteer',
#  'all-weather',
#  'all-wind',
#  'all-wise',
#  'alliance-building',
#  'and-towns',
#  'andlaw-abiding',
#  'anever-increasing',
#  'animal-killers',
#  'anniversary-let',
#  'ante-revolutionary',
#  'anti-aircraft',
#  'anti-bullying',
#  'anti-business',
#  'anti-climb',
#  'anti-communism',
#  'anti-corruption',
#  'anti-craft',
#  'anti-crime',
#  'anti-energy',
#  'anti-fraud',
#  'anti-government',
#  'anti-guerrilla',
#  'anti-inflation',
#  'anti-inflationary',
#  'anti-intellectualism',
#  'anti-military',
#  'anti-narcotic',
#  'anti-philosophers',
#  'anti-pollution',
#  'anti-poverty',
#  'anti-recession',
#  'anti-retroviral',
#  'anti-semitic',
#  'anti-slavery',
#  'anti-submarine',
#  'anti-tank',
#  'anti-terrorism',
#  'anti-terrorist',
#  'anti-trust',
#  'anti-worker',
#  'antici-pations',
#  'apple-selling',
#  'areas-new',
#  'armor-piercing',
#  'armor-plate',
#  'asylum-seekers',
#  'at-risk',
#  'atomic-missile',
#  'attorney-client',
#  'attorney-general',
#  'awe-inspiring',
#  'back-alley',
#  'ballot-box',
#  'bally-ho',
#  'bank-note',
#  'barbed-wire',
#  'base-loaded',
#  'battle-cry',
#  'battle-field',
#  'battle-lines',
#  'battle-ravaged',
#  'battle-ship',
#  'battle-ships',
#  'beach-head',
#  'beacon-light',
#  'bed-fellows',
#  'beef-packing',
#  'been-abandoned',
#  'beet-sugar',
#  'before-mentioned',
#  'before-named',
#  'before-recited',
#  'best-connected',
#  'best-informed',
#  'best-selling',
#  'better-equipped',
#  'better-positioned',
#  'between-decks',
#  'bi-partisan',
#  'big-city',
#  'big-hearted',
#  'big-money',
#  'big-power',
#  'big-shots',
#  'big-time',
#  'bill-holders',
#  'billion-dollar',
#  'billion-plus',
#  'bio-based',
#  'bio-fuels',
#  'block-signal',
#  'blood-filled',
#  'blood-soaked',
#  'blue-collar',
#  'body-politic',
#  'boll-weevil',
#  'bomb-detection',
#  'bomb-heavy',
#  'bomb-proof',
#  'bona-fide',
#  'bond-aided',
#  'bond-issuing',
#  'bonfire-light',
#  'booby-trapped',
#  'book-law',
#  'boundary-survey',
#  'bounty-land',
#  'bowie-knives',
#  'bracket-creep',
#  'branch-banking',
#  'brand-new',
#  'break-water',
#  'breech-loading',
#  'bribe-giver',
#  'bribe-taker',
#  'brigadier-general',
#  'brigadier-generals',
#  'broad-based',
#  'broad-gauged',
#  'broad-minded',
#  'broadcast-particularly',
#  'budget-cutting',
#  'build-ups',
#  'bumper-sticker',
#  'business-community',
#  'business-like',
#  'by-laws',
#  'by-private',
#  'by-product',
#  'by-products',
#  'by-word',
#  'calamity-howlers',
#  'calamity-howling',
#  'campaign-weary',
#  'capital-intensive',
#  'card-carrying',
#  'carefully-drafted',
#  'carpet-bomb',
#  'carrier-delivery',
#  'cash-strapped',
#  'cast-iron',
#  'cattle-transportation',
#  'centuries-long',
#  'century-old',
#  'chain-link',
#  'cheap-postage',
#  'check-dams',
#  'check-ups',
#  'cherry-picking',
#  'chest-high',
#  'child-care',
#  'child-labor',
#  'church-state',
#  'church-supported',
#  'citizens-farmers',
#  'city-states',
#  'civil-service',
#  'civilian-military',
#  'class-minded',
#  'clean-cut',
#  'clear-cut',
#  'clear-eyed',
#  'clear-minded',
#  'clear-sighted',
#  'clear-thinking',
#  'close-knit',
#  'co-chairs',
#  'co-equal',
#  'co-inciding',
#  'co-op',
#  'co-operate',
#  'co-operated',
#  'co-operates',
#  'co-operating',
#  'co-operation',
#  'co-operations',
#  'co-operationwith',
#  'co-operative',
#  'co-operatively',
#  'co-operatives',
#  'co-ordination',
#  'co-payment',
#  'co-payments',
#  'co-pays',
#  'co-relation',
#  'co-tenants',
#  'coal-bearing',
#  'coal-burning',
#  'coal-fired',
#  'coal-land',
#  'coarse-ground',
#  'coast-defense',
#  'coast-line',
#  'code-talkers',
#  'coin-operated',
#  'cold-blooded',
#  'college-trained',
#  'colored-came',
#  'commissary-sergeants',
#  'commissioner-general',
#  'committed-including',
#  'common-law',
#  'common-school',
#  'common-sense',
#  'common-sensical',
#  'comp-time',
#  'compound-interest',
#  'computer-literate',
#  'computer-smart',
#  'conscience-impelled',
#  'consul-general',
#  'consulate-general',
#  'contract-labor',
#  'control-moves',
#  'conventional-type',
#  'cool-headed',
#  'coolie-tilled',
#  'cooperation-government',
#  'cop-killer',
#  'corn-hog',
#  'cost-cutting',
#  'cost-free',
#  'cotton-goods',
#  'council-chambers',
#  'counter-attacks',
#  'counter-balanced',
#  'counter-guerrilla',
#  'counter-invasion',
#  'counter-offensive',
#  'counter-revolution',
#  'counter-terrorism',
#  'counter-weapon',
#  'counter-weapons',
#  'country-man',
#  'country-men',
#  'county-free',
#  'court-appointed',
#  'court-house',
#  'court-houses',
#  'court-martial',
#  'court-ordered',
#  'credit-bonds',
#  'crime-mapping',
#  'crime-ridden',
#  'criminal-law',
#  'crop-harvesting',
#  'crop-reporting',
#  'cross-border',
#  'cross-checking',
#  'cross-examination',
#  'cross-examine',
#  'cross-examined',
#  'cross-posts',
#  'cross-purposes',
#  'cross-section',
#  'cure-alls',
#  'custom-house',
#  'custom-houses',
#  'customs-revenue',
#  'cut-throat',
#  'cutting-edge',
#  'cyber-attacks',
#  'cyber-threats',
#  'danger-filled',
#  'dark-stained',
#  'day-inspector',
#  'de-emphasize',
#  'de-escalate',
#  'de-escalation',
#  'de-moralize',
#  'de-nuke',
#  'de-segregate',
#  'dead-end',
#  'dead-level',
#  'death-dealing',
#  'death-rate',
#  'death-wish',
#  'debt-bearing',
#  'decades-long',
#  'decent-living',
#  'decision-making',
#  'deep-graven',
#  'deep-rooted',
#  'deep-seated',
#  'defense-oriented',
#  'defense-related',
#  'defied-pledges',
#  'democratic-republican',
#  'department-store',
#  'dependent-pension',
#  'desert-land',
#  'destruction-constitutes',
#  'destruction-meaning',
#  'dictatorship-clearly',
#  'die-hards',
#  'dilly-dallying',
#  'diplomacy-protect',
#  'diplomatic-service',
#  'dis-armed',
#  'dis-unionists',
#  'disability-pension',
#  'disarmament-true',
#  'disease-bearing',
#  'disease-ridden',
#  'dive-bomber',
#  'do-gooders',
#  'doctor-patient',
#  'domestic-slavery',
#  'door-keeper',
#  'double-digit',
#  'double-edged',
#  'double-talk',
#  'double-tracking',
#  'double-turret',
#  'draw-backs',
#  'dry-dock',
#  'dry-land',
#  'e-mails',
#  'early-childhood',
#  'early-stage',
#  'earned-income',
#  'eight-hour',
#  'eight-story',
#  'eighth-grade',
#  'eighty-ninth',
#  'election-year',
#  'eleventh-hour',
#  'employer-employee',
#  'employer-provided',
#  'energy-poor',
#  'energy-related',
#  'energy-rich',
#  'energy-saving',
#  'energy-wise',
#  'engine-rooms',
#  'entry-level',
#  'epoch-making',
#  'equal-handed',
#  'equal-rights',
#  'even-handed',
#  'ever-active',
#  'ever-advancing',
#  'ever-broadening',
#  'ever-closer',
#  'ever-enduring',
#  'ever-expanding',
#  'ever-favorite',
#  'ever-glorious',
#  'ever-growing',
#  'ever-higher',
#  'ever-increasing',
#  'ever-larger',
#  'ever-living',
#  'ever-mounting',
#  'ever-present',
#  'ever-ready',
#  'ever-recurring',
#  'ever-richer',
#  'ever-rising',
#  'ever-shifting',
#  'ever-varying',
#  'ever-watchful',
#  'ever-widening',
#  'every-day',
#  'everything-including',
#  'evil-disposed',
#  'evil-doers',
#  'ex-army',
#  'ex-marines',
#  'ex-officio',
#  'ex-post',
#  'ex-sailors',
#  'ex-service',
#  'ex-soldiers',
#  'exact-percent',
#  'excess-profits',
#  'experimental-station',
#  'export-import',
#  'export-minded',
#  'extended-family',
#  'extra-territorial',
#  'eye-opening',
#  'eye-witnesses',
#  'fact-finding',
#  'factories-textile',
#  'factory-inspection',
#  'faint-hearted',
#  'faint-heartedly',
#  'fair-dealing',
#  'fair-headed',
#  'fair-minded',
#  'fair-mindedness',
#  'fair-share',
#  'fake-news',
#  'family-owned',
#  'family-wage',
#  'far-distant',
#  'far-famed',
#  'far-flung',
#  'far-left',
#  'far-reaching',
#  'far-removed',
#  'far-seeing',
#  'far-sighted',
#  'farmer-controlled',
#  'farmer-managed',
#  'farmer-owned',
#  'farnorth-west',
#  'fast-changing',
#  'fast-food',
#  'fast-growing',
#  'fast-spreading',
#  'fast-track',
#  'fastest-growing',
#  'father-land',
#  'fault-finding',
#  'favored-nation',
#  'federal-local',
#  'federally-aided',
#  'federally-funded',
#  'fee-simple',
#  'feel-good',
#  'fellow-beings',
#  'fellow-citizen',
#  'fellow-citizens',
#  'fellow-citizensa',
#  'fellow-citizensin',
#  'fellow-countrymen',
#  'fellow-farmer',
#  'fellow-magistrates',
#  'fellow-man',
#  'fellow-men',
#  'fellow-rioters',
#  'fellow-servant',
#  'fellow-servants',
#  'fiber-optic',
#  'field-matron',
#  'field-work',
#  'fifteen-foldwithin',
#  'fifty-dollar',
#  'fifty-fifth',
#  'fig-fertilizing',
#  'figure-head',
#  'fine-goods',
#  'fine-tuned',
#  'finger-pointing',
#  'fire-arm',
#  'fire-proof',
#  'fireside-chat',
#  'firm-set',
#  'first-aid',
#  'first-class',
#  'first-generation',
#  'first-hand',
#  'first-mentioned',
#  'first-mortgage',
#  'first-rate',
#  'first-responders',
#  'first-step',
#  'first-strike',
#  'first-time',
#  'first-year',
#  'five-day',
#  'five-hour',
#  'five-nation',
#  'five-page',
#  'five-point',
#  'five-sixths',
#  'five-star',
#  'five-twenties',
#  'five-year',
#  'fixed-income',
#  'flex-time',
#  'flight-test',
#  'flights-commercial',
#  'flint-lock',
#  'flood-control',
#  'flower-clad',
#  'following-named',
#  'food-stuffs',
#  'foot-steps',
#  'force-force',
#  'fore-fathers',
#  'foreign-assistance',
#  'foreign-born',
#  'foreign-service',
#  'forest-reserve',
#  'forest-reserves',
#  'forty-eighth',
#  'forty-fifth',
#  'forty-ninth',
#  'forward-leaning',
#  'forward-looking',
#  'forward-moving',
#  'foundation-stone',
#  'four-engine',
#  'four-fifths',
#  'four-hour',
#  'four-point',
#  'four-power',
#  'four-square',
#  'four-star',
#  'four-story',
#  'four-tenths',
#  'four-thirty',
#  'four-word',
#  'four-year',
#  'fourth-class',
#  'fourth-rate',
#  'free-born',
#  'free-delivery',
#  'free-handed',
#  'free-hearted',
#  'free-market',
#  'free-men',
#  'free-spending',
#  'free-thinking',
#  'free-trade',
#  'freedom-fighters',
#  'freedom-loving',
#  'freeze-frame',
#  'freight-carrying',
#  'freight-rate',
#  'fresh-faced',
#  'fresh-water',
#  'front-line',
#  'front-page',
#  'front-row',
#  'fuel-efficiency',
#  'fuel-switching',
#  'fugitive-slave',
#  'full-blown',
#  'full-caliber',
#  'full-fledged',
#  'full-grown',
#  'full-leg',
#  'full-rounded',
#  'full-scale',
#  'fund-raising',
#  'fur-bearing',
#  'fur-seal',
#  'gang-violence',
#  'general-delivery',
#  'generation-long',
#  'gill-net',
#  'go-ahead',
#  'gold-bearing',
#  'gold-demand',
#  'gold-standard',
#  'good-bye',
#  'good-fellowship',
#  'good-fortune',
#  'good-hearted',
#  'good-looking',
#  'good-natured',
#  'good-paying',
#  'goose-stepping',
#  'government-approved',
#  'government-funded',
#  'government-national',
#  'government-ordered',
#  'government-owned',
#  'government-related',
#  'government-required',
#  'government-run',
#  'government-sponsored',
#  'government-wide',
#  'grain-exporting',
#  'grain-milling',
#  'great-grandchildren',
#  'great-granddaughter',
#  'great-grandfather',
#  'great-grandparents',
#  'ground-breaking',
#  'ground-launch',
#  'ground-launched',
#  'ground-work',
#  'growth-oriented',
#  'gun-adept',
#  'gun-boat',
#  'gun-boats',
#  'gun-factory',
#  'gun-free',
#  'gun-racks',
#  'gur-reat',
#  'gut-wrenching',
#  'hair-splitters',
#  'hair-splitting',
#  'half-billion',
#  'half-breeds',
#  'half-century',
#  'half-circle',
#  'half-clad',
#  'half-dismes',
#  'half-free',
#  'half-hearted',
#  'half-holidays',
#  'half-hour',
#  'half-mast',
#  'half-million',
#  'half-slave',
#  'half-way',
#  'half-won',
#  'half-yearly',
#  'hand-carried',
#  'hand-held',
#  'hand-maiden',
#  'hand-wringing',
#  'harbor-defense',
#  'hard-core',
#  'hard-earned',
#  'hard-fought',
#  'hard-headed',
#  'hard-hit',
#  'hard-hitting',
#  'hard-nosed',
#  'hard-pressed',
#  'hard-won',
#  'hard-working',
#  'hardest-hit',
#  'hardest-working',
#  'have-nots',
#  'havoc-breaking',
#  'health-care',
#  'health-related',
#  'heart-breaking',
#  'heart-felt',
#  'heart-throbbing',
#  'heart-warming',
#  'heat-seeking',
#  'hemp-growing',
#  'heretofore-recognized',
#  'higgledy-piggledy',
#  'high-crime',
#  'high-grade',
#  'high-growth',
#  'high-handed',
#  'high-license',
#  'high-minded',
#  'high-paying',
#  'high-power',
#  'high-powered',
#  'high-priced',
#  'high-priority',
#  'high-profile',
#  'high-quality',
#  'high-ranking',
#  'high-school',
#  'high-skilled',
#  'high-sounding',
#  'high-speed',
#  'high-strength',
#  'high-tech',
#  'high-technology',
#  'high-unemployment',
#  'high-value',
#  'high-wage',
#  'high-water',
#  'higher-level',
#  'higher-paying',
#  'highest-ranking',
#  'highly-leveraged',
#  'highly-paid',
#  'highly-skilled',
#  'hip-hop',
#  'history-making',
#  'home-loan',
#  'home-maker',
#  'home-makers',
#  'horse-trading',
#  'host-nation',
#  'hostage-taking',
#  'hot-bed',
#  'hot-headed',
#  'human-animal',
#  'hundred-dollar',
#  'hundred-yard',
#  'hundred-year',
#  'husband-man',
#  'hydroelectric-power',
#  'hydrogen-fueled',
#  'hydrogen-powered',
#  'hypo-rhetorical',
#  'ice-free',
#  'ill-advised',
#  'ill-assorted',
#  'ill-balanced',
#  'ill-clad',
#  'ill-concerted',
#  'ill-conduct',
#  'ill-considered',
#  'ill-defined',
#  'ill-directed',
#  'ill-feeling',
#  'ill-fitting',
#  'ill-founded',
#  'ill-health',
#  'ill-housed',
#  'ill-informed',
#  'ill-nourished',
#  'ill-prepared',
#  'ill-regulated',
#  'ill-rounded',
#  'ill-suited',
#  'ill-timed',
#  'in-[inaudible',
#  'in-demand',
#  'in-fighting',
#  'in-land',
#  'in-roads',
#  'in-trenched',
#  'income-tax',
#  'independence-loving',
#  'independent-treasury',
#  'industrial-military',
#  'inflation-fighting',
#  'inflation-produced',
#  'influence-economic',
#  'inheritance-tax',
#  'ink-stained',
#  'inner-city',
#  'intelligence-sharing',
#  'inter-communication',
#  'inter-fere',
#  'inter-island',
#  'inter-oceanic',
#  'inter-service',
#  'interest-bearing',
#  'intermediate-range',
#  'internal-improvement',
#  'internal-revenue',
#  'internal-tax',
#  'international-affairs',
#  'interstate-commerce',
#  'interstate-railway',
#  'inward-bound',
#  'jet-age',
#  'job-creation',
#  'job-killing',
#  'job-ready',
#  'job-training',
#  'joint-stock',
#  'judge-advocates',
#  'jungle-covered',
#  'junior-grade',
#  'justice-justice',
#  'kind-heartedness',
#  'klieg-lights',
#  'l-year',
#  'labor-management',
#  'labor-saving',
#  'laboring-man',
#  'lake-bed',
#  'land-grant',
#  'land-laws',
#  'land-proceeds',
#  'large-handed',
#  'large-heartedness',
#  'large-scale',
#  'last-ditch',
#  'last-mentioned',
#  'last-minute',
#  'latter-mentioned',
#  'latter-named',
#  'law-abiding',
#  'law-enforcement',
#  'law-honesty',
#  'law-maker',
#  'law-makers',
#  'law-making',
#  'law-recommendations',
#  'law-respecting',
#  'lead-time',
#  'leading-edge',
#  'leaf-eating',
#  'leave-taking',
#  'left-wing',
#  'legal-tenders',
#  'lemon-box',
#  'lend-lease',
#  'less-developed',
#  'less-favored',
#  'less-fortunate',
#  'level-best',
#  'liberal-minded',
#  'liberty-loving',
#  'lieutenant-colonel',
#  'lieutenant-colonels',
#  'lieutenant-commander',
#  'lieutenant-commanders',
#  'lieutenant-general',
#  'lieutenant-governor',
#  'life-blood',
#  'life-enhancing',
#  'life-insurance',
#  'life-long',
#  'life-saving',
#  'life-time',
#  'light-draft',
#  'light-hearted',
#  'light-house',
#  'light-houses',
#  'light-rainfall',
#  'like-minded',
#  'line-item',
#  'lip-service',
#  'listen-let',
#  'little-known',
#  'live-oak',
#  'live-stock',
#  'log-line',
#  'log-rolling',
#  'long-awaited',
#  'long-buried',
#  'long-cherished',
#  'long-continued',
#  'long-deferred',
#  'long-delayed',
#  'long-developed',
#  'long-disputed',
#  'long-enduring',
#  'long-existing',
#  'long-extended',
#  'long-felt',
#  'long-fourteen',
#  'long-held',
#  'long-ignored',
#  'long-indulged',
#  'long-isolated',
#  'long-lasting',
#  'long-lost',
#  'long-maintained',
#  'long-needed',
#  'long-neglected',
#  'long-overdue',
#  'long-pending',
#  'long-playing',
#  'long-protracted',
#  'long-range',
#  'long-reaching',
#  'long-run',
#  'long-running',
#  'long-settled',
#  'long-sought',
#  'long-standing',
#  'long-staple',
#  'long-subsisting',
#  'long-suffering',
#  'long-time',
#  'long-vexed',
#  'long-view',
#  'longer-term',
#  'longest-serving',
#  'longest-suffering',
#  'loosely-monitored',
#  'loud-mouthed',
#  'low-birth',
#  'low-carbon',
#  'low-cost',
#  'low-demand',
#  'low-enriched',
#  'low-income',
#  'low-interest',
#  'low-key',
#  'low-lived',
#  'low-lying',
#  'low-paying',
#  'low-priced',
#  'low-rent',
#  'low-rental',
#  'low-sulfur',
#  'low-tariff',
#  'low-wage',
#  'low-water',
#  'lower-income',
#  'lower-middle',
#  'lower-paid',
#  'lower-priced',
#  'lower-skilled',
#  'lower-wage',
#  'lowest-paid',
#  'luxuries-perfumes',
#  'machine-gun',
#  'machine-gunned',
#  'mail-carrying',
#  'mail-messenger',
#  'mail-order',
#  'main-line',
#  'major-generals',
#  'make-believe',
#  'make-work',
#  'malaria-related',
#  'man-days',
#  'man-hour',
#  'man-hours',
#  'man-kind',
#  'man-power',
#  'man-stealing',
#  'many-point',
#  'many-sided',
#  'many-sidedness',
#  'market-oriented',
#  'markets-price',
#  'marriage-penalty',
#  'mashed-potato',
#  'mass-meeting',
#  'master-race',
#  'mean-spirited',
#  'meat-food',
#  'meat-inspection',
#  'meat-packing',
#  'medium-size',
#  'medium-sized',
#  'men-change',
#  'merchant-men',
#  'mid-continental',
#  'middle-aged',
#  'middle-class',
#  'middle-ground',
#  'middle-income',
#  'middle-management',
#  'military-style',
#  'military-supersonic',
#  'mind-meld',
#  'minority-owned',
#  'mis-lead',
#  'misery-hunted',
#  'moderate-income',
#  'modern-day',
#  'moisture-laden',
#  'money-changer',
#  'money-changers',
#  'money-order',
#  'mortgage-backed',
#  'mortgage-discount',
#  'most-favored',
#  'motor-car',
#  'movie-goer',
#  'much-debated',
#  'much-desired',
#  'much-discussed',
#  'much-injured',
#  'much-loved',
#  'much-needed',
#  'multi-billion',
#  'multi-lateral',
#  'multi-layered',
#  'multi-millionaires',
#  'multi-party',
#  'multibillion-dollar',
#  'multimillion-dollar',
#  'multiple-line',
#  'multiple-use',
#  'multiple-warhead',
#  'muscle-bound',
#  ...]

# %% [markdown]
# >> #### 8.2 Solution: Remove hyphens from single hyphen words that do not require hyphens

# %%
hyphens_after = [token.replace('-', '') for token in hyphens_before]
hyphens_after = [token for token in tqdm(hyphens_after) if is_word(token) and token == is_word(token)]
hyphens_after
# Out:
# 100%|██████████| 2030/2030 [16:58<00:00,  1.99it/s]
# ['abovementioned',
#  'abovenamed',
#  'afterdinner',
#  'aftereffect',
#  'agelong',
#  'airlift',
#  'airmail',
#  'anterevolutionary',
#  'antiaircraft',
#  'antibusiness',
#  'antipollution',
#  'antiretroviral',
#  'antislavery',
#  'antitrust',
#  'banknote',
#  'battlefield',
#  'battleship',
#  'beachhead',
#  'bipartisan',
#  'bighearted',
#  'bombproof',
#  'breakwater',
#  'businesslike',
#  'byword',
#  'childcare',
#  'coequal',
#  'coop',
#  'cooperate',
#  'cooperation',
#  'cooperative',
#  'coordination',
#  'corelation',
#  'coastline',
#  'coolheaded',
#  'counterguerrilla',
#  'counterinvasion',
#  'counteroffensive',
#  'counterrevolution',
#  'counterterrorism',
#  'countryman',
#  'courthouse',
#  'customhouse',
#  'cutthroat',
#  'demoralize',
#  'desegregate',
#  'doorkeeper',
#  'dryland',
#  'evenhanded',
#  'everyday',
#  'extraterritorial',
#  'fainthearted',
#  'farseeing',
#  'farsighted',
#  'fatherland',
#  'faultfinding',
#  'fieldwork',
#  'figurehead',
#  'firearm',
#  'fireproof',
#  'firsthand',
#  'flextime',
#  'flintlock',
#  'foursquare',
#  'freeborn',
#  'freehanded',
#  'freehearted',
#  'freshwater',
#  'frontline',
#  'fundraising',
#  'gillnet',
#  'goodbye',
#  'groundbreaking',
#  'groundwork',
#  'gunboat',
#  'halfway',
#  'handheld',
#  'handmaiden',
#  'hardheaded',
#  'hardworking',
#  'heartbreaking',
#  'heartfelt',
#  'heartwarming',
#  'homemaker',
#  'hotbed',
#  'hotheaded',
#  'husbandman',
#  'infighting',
#  'inland',
#  'interfere',
#  'interisland',
#  'interoceanic',
#  'interservice',
#  'laborsaving',
#  'lawmaker',
#  'lifeblood',
#  'lifelong',
#  'lifesaving',
#  'lifetime',
#  'lighthearted',
#  'lighthouse',
#  'livestock',
#  'logrolling',
#  'longtime',
#  'loudmouthed',
#  'mainline',
#  'mankind',
#  'manstealing',
#  'meatpacking',
#  'mislead',
#  'motorcar',
#  'moviegoer',
#  'multibillion',
#  'multilateral',
#  'multilayered',
#  'multiparty',
#  'newborn',
#  'newfound',
#  'nonaction',
#  'nonaddictive',
#  'nonalcoholic',
#  'noncombat',
#  'noncommissioned',
#  'noncompetitive',
#  'nonearning',
#  'nonessential',
#  'nonexistence',
#  'nonexistent',
#  'nongovernmental',
#  'nonideological',
#  'nonimportation',
#  'nonintercourse',
#  'noninterference',
#  'nonintervention',
#  'nonliquid',
#  'nonmember',
#  'nonmilitary',
#  'nonnegotiable',
#  'nonnuclear',
#  'nonpartisan',
#  'nonpayment',
#  'nonpolitical',
#  'nonprofessional',
#  'nonprofit',
#  'nonproliferation',
#  'nonpublic',
#  'nonreligious',
#  'nonresident',
#  'nontidal',
#  'nonviolence',
#  'nonviolent',
#  'northeastern',
#  'northwest',
#  'northwestern',
#  'oceangoing',
#  'offspring',
#  'onetime',
#  'openhanded',
#  'otherwise',
#  'outbound',
#  'outbuild',
#  'outcompete',
#  'outgoing',
#  'outgun',
#  'outpatient',
#  'outproduce',
#  'outright',
#  'outstanding',
#  'outtrade',
#  'outwork',
#  'overanxious',
#  'overbalance',
#  'overbearing',
#  'overissue',
#  'overlong',
#  'overmastering',
#  'overnight',
#  'overoptimism',
#  'overprivileged',
#  'overproduction',
#  'overrate',
#  'overrated',
#  'oversanguine',
#  'overwork',
#  'overzealous',
#  'paramilitary',
#  'partway',
#  'passbook',
#  'passkey',
#  'pathbreaking',
#  'peacekeeping',
#  'peacetime',
#  'pleuropneumonia',
#  'postcard',
#  'postgraduate',
#  'postwar',
#  'predawn',
#  'preeminence',
#  'preeminent',
#  'preexisting',
#  'prewar',
#  'proabortion',
#  'proportion',
#  'quicklime',
#  'rathole',
#  'readopt',
#  'reappearance',
#  'reargument',
#  'reassert',
#  'recreate',
#  'recreation',
#  'redeposit',
#  'reenact',
#  'reenlist',
#  'reenter',
#  'reentry',
#  'reequip',
#  'reestablish',
#  'reexamination',
#  'reignite',
#  'reimpose',
#  'reinvestment',
#  'reissue',
#  'reopen',
#  'reread',
#  'restart',
#  'rethink',
#  'retool',
#  'retransfer',
#  'riverbed',
#  'roundtable',
#  'safekeeping',
#  'seaboard',
#  'seaborne',
#  'seacoast',
#  'seagoing',
#  'seakeeping',
#  'secondhand',
#  'semiarid',
#  'semiautomatic',
#  'semicivilized',
#  'semidetached',
#  'semimonthly',
#  'shellfish',
#  'shopworn',
#  'sidetrack',
#  'simpleminded',
#  'slaveholder',
#  'smallpox',
#  'softheaded',
#  'speechmaker',
#  'stopgap',
#  'straightforward',
#  'straitjacket',
#  'subcommittee',
#  'sugarcane',
#  'support',
#  'supergovernment',
#  'superrich',
#  'swampland',
#  'teamwork',
#  'thermonuclear',
#  'tidewater',
#  'tinfoil',
#  'tinplate',
#  'today',
#  'tomorrow',
#  'tonight',
#  'topflight',
#  'townsite',
#  'turntable',
#  'twelvefold',
#  'twelvemonth',
#  'twofold',
#  'uninspected',
#  'underconsumption',
#  'underdeveloped',
#  'underestimate',
#  'underpay',
#  'underrate',
#  'underrepresented',
#  'undersell',
#  'undertaking',
#  'upturn',
#  'vainglory',
#  'wageworker',
#  'warmhearted',
#  'waterborne',
#  'waterpower',
#  'weeklong',
#  'wellspring',
#  'wholehearted',
#  'widespread',
#  'wifebeater',
#  'wildcat',
#  'workweek',
#  'wrongheaded',
#  'yearlong',
#  'yearslong']

# %% [markdown]
# >> #### 8.3 Prepare token pairs and update dictionary

# %%
# Zip pairs into before and after tuples
hyphens = list(zip(hyphens_before, hyphens_after))

# Update dictionary and hyphen tokens
clean_dict = update_dict(clean_dict, hyphens)
hyphen_tokens = [token for token in hyphen_tokens if token not in clean_dict]

# %% [markdown]
# >> #### 9.1 Problem: Some hyphen tokens are compound verbs and can be removed

# %%
pattern = '^[a-z][a-z]+-[^-A-Z0-9]+$'
hyphens_before = [re.search(pattern, token)[0] for token in hyphen_tokens if re.search(pattern, token)]
hyphens_before
# Out:
# ['cross-purposes',
#  'cross-section',
#  'cure-alls',
#  'custom-house',
#  'custom-houses',
#  'customs-revenue',
#  'cut-throat',
#  'cutting-edge',
#  'cyber-attacks',
#  'cyber-threats',
#  'danger-filled',
#  'dark-stained',
#  'day-inspector',
#  'de-emphasize',
#  'de-escalate',
#  'de-escalation',
#  'de-moralize',
#  'de-nuke',
#  'de-segregate',
#  'dead-end',
#  'dead-level',
#  'death-dealing',
#  'death-rate',
#  'death-wish',
#  'debt-bearing',
#  'decades-long',
#  'decent-living',
#  'decision-making',
#  'deep-graven',
#  'deep-rooted',
#  'deep-seated',
#  'defense-oriented',
#  'defense-related',
#  'defied-pledges',
#  'democratic-republican',
#  'department-store',
#  'dependent-pension',
#  'desert-land',
#  'destruction-constitutes',
#  'destruction-meaning',
#  'dictatorship-clearly',
#  'die-hards',
#  'dilly-dallying',
#  'diplomacy-protect',
#  'diplomatic-service',
#  'dis-armed',
#  'dis-unionists',
#  'disability-pension',
#  'disarmament-true',
#  'disease-bearing',
#  'disease-ridden',
#  'dive-bomber',
#  'do-gooders',
#  'doctor-patient',
#  'domestic-slavery',
#  'door-keeper',
#  'double-digit',
#  'double-edged',
#  'double-talk',
#  'double-tracking',
#  'double-turret',
#  'draw-backs',
#  'dry-dock',
#  'dry-land',
#  'early-childhood',
#  'early-stage',
#  'earned-income',
#  'eight-hour',
#  'eight-story',
#  'eighth-grade',
#  'eighty-ninth',
#  'election-year',
#  'eleventh-hour',
#  'employer-employee',
#  'employer-provided',
#  'energy-poor',
#  'energy-related',
#  'energy-rich',
#  'energy-saving',
#  'energy-wise',
#  'engine-rooms',
#  'entry-level',
#  'epoch-making',
#  'equal-handed',
#  'equal-rights',
#  'even-handed',
#  'ever-active',
#  'ever-advancing',
#  'ever-broadening',
#  'ever-closer',
#  'ever-enduring',
#  'ever-expanding',
#  'ever-favorite',
#  'ever-glorious',
#  'ever-growing',
#  'ever-higher',
#  'ever-increasing',
#  'ever-larger',
#  'ever-living',
#  'ever-mounting',
#  'ever-present',
#  'ever-ready',
#  'ever-recurring',
#  'ever-richer',
#  'ever-rising',
#  'ever-shifting',
#  'ever-varying',
#  'ever-watchful',
#  'ever-widening',
#  'every-day',
#  'everything-including',
#  'evil-disposed',
#  'evil-doers',
#  'ex-army',
#  'ex-marines',
#  'ex-officio',
#  'ex-post',
#  'ex-sailors',
#  'ex-service',
#  'ex-soldiers',
#  'exact-percent',
#  'excess-profits',
#  'experimental-station',
#  'export-import',
#  'export-minded',
#  'extended-family',
#  'extra-territorial',
#  'eye-opening',
#  'eye-witnesses',
#  'fact-finding',
#  'factories-textile',
#  'factory-inspection',
#  'faint-hearted',
#  'faint-heartedly',
#  'fair-dealing',
#  'fair-headed',
#  'fair-minded',
#  'fair-mindedness',
#  'fair-share',
#  'fake-news',
#  'family-owned',
#  'family-wage',
#  'far-distant',
#  'far-famed',
#  'far-flung',
#  'far-left',
#  'far-reaching',
#  'far-removed',
#  'far-seeing',
#  'far-sighted',
#  'farmer-controlled',
#  'farmer-managed',
#  'farmer-owned',
#  'farnorth-west',
#  'fast-changing',
#  'fast-food',
#  'fast-growing',
#  'fast-spreading',
#  'fast-track',
#  'fastest-growing',
#  'father-land',
#  'fault-finding',
#  'favored-nation',
#  'federal-local',
#  'federally-aided',
#  'federally-funded',
#  'fee-simple',
#  'feel-good',
#  'fellow-beings',
#  'fellow-citizen',
#  'fellow-citizens',
#  'fellow-citizensa',
#  'fellow-citizensin',
#  'fellow-countrymen',
#  'fellow-farmer',
#  'fellow-magistrates',
#  'fellow-man',
#  'fellow-men',
#  'fellow-rioters',
#  'fellow-servant',
#  'fellow-servants',
#  'fiber-optic',
#  'field-matron',
#  'field-work',
#  'fifteen-foldwithin',
#  'fifty-dollar',
#  'fifty-fifth',
#  'fig-fertilizing',
#  'figure-head',
#  'fine-goods',
#  'fine-tuned',
#  'finger-pointing',
#  'fire-arm',
#  'fire-proof',
#  'fireside-chat',
#  'firm-set',
#  'first-aid',
#  'first-class',
#  'first-generation',
#  'first-hand',
#  'first-mentioned',
#  'first-mortgage',
#  'first-rate',
#  'first-responders',
#  'first-step',
#  'first-strike',
#  'first-time',
#  'first-year',
#  'five-day',
#  'five-hour',
#  'five-nation',
#  'five-page',
#  'five-point',
#  'five-sixths',
#  'five-star',
#  'five-twenties',
#  'five-year',
#  'fixed-income',
#  'flex-time',
#  'flight-test',
#  'flights-commercial',
#  'flint-lock',
#  'flood-control',
#  'flower-clad',
#  'following-named',
#  'food-stuffs',
#  'foot-steps',
#  'force-force',
#  'fore-fathers',
#  'foreign-assistance',
#  'foreign-born',
#  'foreign-service',
#  'forest-reserve',
#  'forest-reserves',
#  'forty-eighth',
#  'forty-fifth',
#  'forty-ninth',
#  'forward-leaning',
#  'forward-looking',
#  'forward-moving',
#  'foundation-stone',
#  'four-engine',
#  'four-fifths',
#  'four-hour',
#  'four-point',
#  'four-power',
#  'four-square',
#  'four-star',
#  'four-story',
#  'four-tenths',
#  'four-thirty',
#  'four-word',
#  'four-year',
#  'fourth-class',
#  'fourth-rate',
#  'free-born',
#  'free-delivery',
#  'free-handed',
#  'free-hearted',
#  'free-market',
#  'free-men',
#  'free-spending',
#  'free-thinking',
#  'free-trade',
#  'freedom-fighters',
#  'freedom-loving',
#  'freeze-frame',
#  'freight-carrying',
#  'freight-rate',
#  'fresh-faced',
#  'fresh-water',
#  'front-line',
#  'front-page',
#  'front-row',
#  'fuel-efficiency',
#  'fuel-switching',
#  'fugitive-slave',
#  'full-blown',
#  'full-caliber',
#  'full-fledged',
#  'full-grown',
#  'full-leg',
#  'full-rounded',
#  'full-scale',
#  'fund-raising',
#  'fur-bearing',
#  'fur-seal',
#  'gang-violence',
#  'general-delivery',
#  'generation-long',
#  'gill-net',
#  'go-ahead',
#  'gold-bearing',
#  'gold-demand',
#  'gold-standard',
#  'good-bye',
#  'good-fellowship',
#  'good-fortune',
#  'good-hearted',
#  'good-looking',
#  'good-natured',
#  'good-paying',
#  'goose-stepping',
#  'government-approved',
#  'government-funded',
#  'government-national',
#  'government-ordered',
#  'government-owned',
#  'government-related',
#  'government-required',
#  'government-run',
#  'government-sponsored',
#  'government-wide',
#  'grain-exporting',
#  'grain-milling',
#  'great-grandchildren',
#  'great-granddaughter',
#  'great-grandfather',
#  'great-grandparents',
#  'ground-breaking',
#  'ground-launch',
#  'ground-launched',
#  'ground-work',
#  'growth-oriented',
#  'gun-adept',
#  'gun-boat',
#  'gun-boats',
#  'gun-factory',
#  'gun-free',
#  'gun-racks',
#  'gur-reat',
#  'gut-wrenching',
#  'hair-splitters',
#  'hair-splitting',
#  'half-billion',
#  'half-breeds',
#  'half-century',
#  'half-circle',
#  'half-clad',
#  'half-dismes',
#  'half-free',
#  'half-hearted',
#  'half-holidays',
#  'half-hour',
#  'half-mast',
#  'half-million',
#  'half-slave',
#  'half-way',
#  'half-won',
#  'half-yearly',
#  'hand-carried',
#  'hand-held',
#  'hand-maiden',
#  'hand-wringing',
#  'harbor-defense',
#  'hard-core',
#  'hard-earned',
#  'hard-fought',
#  'hard-headed',
#  'hard-hit',
#  'hard-hitting',
#  'hard-nosed',
#  'hard-pressed',
#  'hard-won',
#  'hard-working',
#  'hardest-hit',
#  'hardest-working',
#  'have-nots',
#  'havoc-breaking',
#  'health-care',
#  'health-related',
#  'heart-breaking',
#  'heart-felt',
#  'heart-throbbing',
#  'heart-warming',
#  'heat-seeking',
#  'hemp-growing',
#  'heretofore-recognized',
#  'higgledy-piggledy',
#  'high-crime',
#  'high-grade',
#  'high-growth',
#  'high-handed',
#  'high-license',
#  'high-minded',
#  'high-paying',
#  'high-power',
#  'high-powered',
#  'high-priced',
#  'high-priority',
#  'high-profile',
#  'high-quality',
#  'high-ranking',
#  'high-school',
#  'high-skilled',
#  'high-sounding',
#  'high-speed',
#  'high-strength',
#  'high-tech',
#  'high-technology',
#  'high-unemployment',
#  'high-value',
#  'high-wage',
#  'high-water',
#  'higher-level',
#  'higher-paying',
#  'highest-ranking',
#  'highly-leveraged',
#  'highly-paid',
#  'highly-skilled',
#  'hip-hop',
#  'history-making',
#  'home-loan',
#  'home-maker',
#  'home-makers',
#  'horse-trading',
#  'host-nation',
#  'hostage-taking',
#  'hot-bed',
#  'hot-headed',
#  'human-animal',
#  'hundred-dollar',
#  'hundred-yard',
#  'hundred-year',
#  'husband-man',
#  'hydroelectric-power',
#  'hydrogen-fueled',
#  'hydrogen-powered',
#  'hypo-rhetorical',
#  'ice-free',
#  'ill-advised',
#  'ill-assorted',
#  'ill-balanced',
#  'ill-clad',
#  'ill-concerted',
#  'ill-conduct',
#  'ill-considered',
#  'ill-defined',
#  'ill-directed',
#  'ill-feeling',
#  'ill-fitting',
#  'ill-founded',
#  'ill-health',
#  'ill-housed',
#  'ill-informed',
#  'ill-nourished',
#  'ill-prepared',
#  'ill-regulated',
#  'ill-rounded',
#  'ill-suited',
#  'ill-timed',
#  'in-[inaudible',
#  'in-demand',
#  'in-fighting',
#  'in-land',
#  'in-roads',
#  'in-trenched',
#  'income-tax',
#  'independence-loving',
#  'independent-treasury',
#  'industrial-military',
#  'inflation-fighting',
#  'inflation-produced',
#  'influence-economic',
#  'inheritance-tax',
#  'ink-stained',
#  'inner-city',
#  'intelligence-sharing',
#  'inter-communication',
#  'inter-fere',
#  'inter-island',
#  'inter-oceanic',
#  'inter-service',
#  'interest-bearing',
#  'intermediate-range',
#  'internal-improvement',
#  'internal-revenue',
#  'internal-tax',
#  'international-affairs',
#  'interstate-commerce',
#  'interstate-railway',
#  'inward-bound',
#  'jet-age',
#  'job-creation',
#  'job-killing',
#  'job-ready',
#  'job-training',
#  'joint-stock',
#  'judge-advocates',
#  'jungle-covered',
#  'junior-grade',
#  'justice-justice',
#  'kind-heartedness',
#  'klieg-lights',
#  'labor-management',
#  'labor-saving',
#  'laboring-man',
#  'lake-bed',
#  'land-grant',
#  'land-laws',
#  'land-proceeds',
#  'large-handed',
#  'large-heartedness',
#  'large-scale',
#  'last-ditch',
#  'last-mentioned',
#  'last-minute',
#  'latter-mentioned',
#  'latter-named',
#  'law-abiding',
#  'law-enforcement',
#  'law-honesty',
#  'law-maker',
#  'law-makers',
#  'law-making',
#  'law-recommendations',
#  'law-respecting',
#  'lead-time',
#  'leading-edge',
#  'leaf-eating',
#  'leave-taking',
#  'left-wing',
#  'legal-tenders',
#  'lemon-box',
#  'lend-lease',
#  'less-developed',
#  'less-favored',
#  'less-fortunate',
#  'level-best',
#  'liberal-minded',
#  'liberty-loving',
#  'lieutenant-colonel',
#  'lieutenant-colonels',
#  'lieutenant-commander',
#  'lieutenant-commanders',
#  'lieutenant-general',
#  'lieutenant-governor',
#  'life-blood',
#  'life-enhancing',
#  'life-insurance',
#  'life-long',
#  'life-saving',
#  'life-time',
#  'light-draft',
#  'light-hearted',
#  'light-house',
#  'light-houses',
#  'light-rainfall',
#  'like-minded',
#  'line-item',
#  'lip-service',
#  'listen-let',
#  'little-known',
#  'live-oak',
#  'live-stock',
#  'log-line',
#  'log-rolling',
#  'long-awaited',
#  'long-buried',
#  'long-cherished',
#  'long-continued',
#  'long-deferred',
#  'long-delayed',
#  'long-developed',
#  'long-disputed',
#  'long-enduring',
#  'long-existing',
#  'long-extended',
#  'long-felt',
#  'long-fourteen',
#  'long-held',
#  'long-ignored',
#  'long-indulged',
#  'long-isolated',
#  'long-lasting',
#  'long-lost',
#  'long-maintained',
#  'long-needed',
#  'long-neglected',
#  'long-overdue',
#  'long-pending',
#  'long-playing',
#  'long-protracted',
#  'long-range',
#  'long-reaching',
#  'long-run',
#  'long-running',
#  'long-settled',
#  'long-sought',
#  'long-standing',
#  'long-staple',
#  'long-subsisting',
#  'long-suffering',
#  'long-time',
#  'long-vexed',
#  'long-view',
#  'longer-term',
#  'longest-serving',
#  'longest-suffering',
#  'loosely-monitored',
#  'loud-mouthed',
#  'low-birth',
#  'low-carbon',
#  'low-cost',
#  'low-demand',
#  'low-enriched',
#  'low-income',
#  'low-interest',
#  'low-key',
#  'low-lived',
#  'low-lying',
#  'low-paying',
#  'low-priced',
#  'low-rent',
#  'low-rental',
#  'low-sulfur',
#  'low-tariff',
#  'low-wage',
#  'low-water',
#  'lower-income',
#  'lower-middle',
#  'lower-paid',
#  'lower-priced',
#  'lower-skilled',
#  'lower-wage',
#  'lowest-paid',
#  'luxuries-perfumes',
#  'machine-gun',
#  'machine-gunned',
#  'mail-carrying',
#  'mail-messenger',
#  'mail-order',
#  'main-line',
#  'major-generals',
#  'make-believe',
#  'make-work',
#  'malaria-related',
#  'man-days',
#  'man-hour',
#  'man-hours',
#  'man-kind',
#  'man-power',
#  'man-stealing',
#  'many-point',
#  'many-sided',
#  'many-sidedness',
#  'market-oriented',
#  'markets-price',
#  'marriage-penalty',
#  'mashed-potato',
#  'mass-meeting',
#  'master-race',
#  'mean-spirited',
#  'meat-food',
#  'meat-inspection',
#  'meat-packing',
#  'medium-size',
#  'medium-sized',
#  'men-change',
#  'merchant-men',
#  'mid-continental',
#  'middle-aged',
#  'middle-class',
#  'middle-ground',
#  'middle-income',
#  'middle-management',
#  'military-style',
#  'military-supersonic',
#  'mind-meld',
#  'minimum-wage',
#  'minority-owned',
#  'mis-lead',
#  'misery-hunted',
#  'moderate-income',
#  'modern-day',
#  'moisture-laden',
#  'money-changer',
#  'money-changers',
#  'money-order',
#  'mortgage-backed',
#  'mortgage-discount',
#  'most-favored',
#  'motor-car',
#  'movie-goer',
#  'much-debated',
#  'much-desired',
#  'much-discussed',
#  'much-injured',
#  'much-loved',
#  'much-needed',
#  'multi-billion',
#  'multi-lateral',
#  'multi-layered',
#  'multi-millionaires',
#  'multi-party',
#  'multibillion-dollar',
#  'multimillion-dollar',
#  'multiple-line',
#  'multiple-use',
#  'multiple-warhead',
#  'muscle-bound',
#  'narrow-minded',
#  'narrow-purpose',
#  'nation-build',
#  'nation-building',
#  'nation-state',
#  'national-bank',
#  'national-banknotes',
#  'national-defense',
#  'national-park',
#  'nationally-aided',
#  'nations-allies',
#  'nations-prosperity',
#  'native-born',
#  'naval-defense',
#  'navy-yard',
#  'navy-yards',
#  'nay-sayers',
#  'near-limitless',
#  'near-lost',
#  'near-record',
#  'near-term',
#  'near-universal',
#  'negro-livery',
#  'never-ceasing',
#  'never-dying',
#  'never-ending',
#  'never-failing',
#  'new-born',
#  'new-found',
#  'new-world',
#  'newly-agreed',
#  'newly-enrolled',
#  'newly-expanded',
#  'newly-won',
#  'next-door',
#  'next-generation',
#  'nice-sized',
#  'nine-point',
#  'nine-rung',
#  'nine-tenths',
#  'ninety-fifth',
#  'ninety-ninth',
#  'no-bid',
#  'no-fly',
#  'no-nonsense',
#  'no-nothingness',
#  'no-progreso',
#  'no-strike',
#  'non-action',
#  'non-addictive',
#  'non-alcoholic',
#  'non-arrival',
#  'non-believers',
#  'non-combat',
#  'non-combatants',
#  'non-commissioned',
#  'non-competitive',
#  'non-discriminating',
#  'non-earning',
#  'non-essential',
#  'non-essentials',
#  'non-existence',
#  'non-existent',
#  'non-governmental',
#  'non-ideological',
#  'non-importation',
#  'non-inflation',
#  'non-intercourse',
#  'non-interference',
#  'non-intervention',
#  'non-liquid',
#  'non-member',
#  'non-militarized',
#  'non-military',
#  'non-negotiable',
#  'non-nuclear',
#  'non-partisan',
#  'non-payment',
#  'non-political',
#  'non-professional',
#  'non-profit',
#  'non-profits',
#  'non-proliferation',
#  'non-public',
#  'non-religious',
#  'non-resident',
#  'non-residents',
#  'non-secular',
#  'non-tidal',
#  'non-violence',
#  'non-violent',
#  'noninterest-bearing',
#  'north-eastern',
#  'north-west',
#  'north-western',
#  'not-emphasizing',
#  'note-takers',
#  'now-deceased',
#  'nuclear-armed',
#  'nuclear-capable',
#  'nuclear-free',
#  'nuclear-freeze',
#  'nuclear-testing',
#  'object-lesson',
#  'ocean-borne',
#  'ocean-girt',
#  'ocean-going',
#  'ocean-steamship',
#  'off-duty',
#  'off-limits',
#  'off-ramp',
#  'off-spring',
#  'offensive-power',
#  'office-seeker',
#  'ofill-considered',
#  'oft-recurring',
#  'oft-repeated',
#  'oft-stated',
#  'often-disproved',
#  'often-expressed',
#  'often-repeated',
#  'oil-burning',
#  'oil-drilling',
#  'oil-fired',
#  'oil-rich',
#  'old-age',
#  'old-boy',
#  'old-fashioned',
#  'old-named',
#  'old-style',
#  'old-time',
#  'old-timers',
#  'on-site',
#  'once-closed',
#  'once-distant',
#  'once-shuttered',
#  'one-eighteenth',
#  'one-eighth',
#  'one-fifteenth',
#  'one-fifth',
#  'one-fourth',
#  'one-half',
#  'one-hoss',
#  'one-hundredth',
#  'one-interest',
#  'one-liners',
#  'one-man',
#  'one-minute',
#  'one-ninth',
#  'one-party',
#  'one-quarter',
#  'one-room',
#  'one-seventh',
#  'one-sided',
#  'one-sixteenth',
#  'one-sixth',
#  'one-story',
#  'one-tenth',
#  'one-term',
#  'one-thirtieth',
#  'one-time',
#  'one-twelfth',
#  'one-way',
#  'one-world',
#  'open-door',
#  'open-ended',
#  'open-handed',
#  'open-minded',
#  'opioid-related',
#  'opium-exclusion',
#  'opportunity-unreserved',
#  'or-disadvantage',
#  'ordinary-sized',
#  'other-wise',
#  'out-bound',
#  'out-build',
#  'out-commercial',
#  'out-compete',
#  'out-educate',
#  'out-educated',
#  'out-going',
#  'out-gun',
#  'out-innovate',
#  'out-patient',
#  'out-produce',
#  'out-product',
#  'out-right',
#  'out-running',
#  'out-standing',
#  'out-stretched',
#  'out-teach',
#  'out-trade',
#  'out-traded',
#  'out-work',
#  'out-years',
#  'outward-bound',
#  'over-action',
#  'over-anxious',
#  'over-balance',
#  'over-bearing',
#  'over-burdened',
#  'over-capitalization',
#  'over-clouded',
#  'over-crowding',
#  'over-emphasizing',
#  'over-estimates',
#  'over-expansions',
#  'over-exposure',
#  'over-extended',
#  'over-extension',
#  'over-grazed',
#  'over-involvement',
#  'over-issue',
#  'over-issues',
#  'over-long',
#  'over-looked',
#  'over-looking',
#  'over-mastering',
#  'over-night',
#  'over-optimism',
#  'over-planted',
#  'over-powering',
#  'over-privileged',
#  'over-producing',
#  'over-production',
#  'over-rate',
#  'over-rated',
#  'over-reaching',
#  'over-regard',
#  'over-sanguine',
#  'over-simplified',
#  'over-speculation',
#  'over-strained',
#  'over-stressing',
#  'over-subscribed',
#  'over-work',
#  'over-working',
#  'over-zealous',
#  'overall-price',
#  'overdose-reversing',
#  'paper-money',
#  'paper-thin',
#  'para-military',
#  'parcel-post',
#  'parent-teacher',
#  'part-time',
#  'part-way',
#  'partial-birth',
#  'pass-book',
#  'pass-key',
#  'pass-keys',
#  'pass-throughs',
#  'past-time',
#  'path-breaking',
#  'pay-envelope',
#  'peace-keepers',
#  'peace-keeping',
#  'peace-time',
#  'people-housewives',
#  'peoples-depends',
#  'per-child',
#  'percent-adult',
#  'percent-permitting',
#  'performance-enhancing',
#  'physically-handicapped',
#  'pistol-shot',
#  'plain-speaking',
#  'planned-substantially',
#  'pleuro-pneumonia',
#  'policy-making',
#  'politico-geographical',
#  'poll-takers',
#  'pooh-poohed',
#  'popular-particularly',
#  'post-card',
#  'post-graduate',
#  'post-office',
#  'post-offices',
#  'post-poned',
#  'post-racial',
#  'post-road',
#  'post-roads',
#  'post-route',
#  'post-traumatic',
#  'post-war',
#  'postal-savings',
#  'postal-union',
#  'postmaster-ships',
#  'poverty-ridden',
#  'poverty-stricken',
#  'pre-dawn',
#  'pre-embryo',
#  'pre-eminence',
#  'pre-eminent',
#  'pre-eminently',
#  'pre-emptions',
#  'pre-existing',
#  'pre-k',
#  'pre-positioned',
#  ...]

# %% [markdown]
# >> #### 9.2 Solution: Remove compound from hyphen_tokens

# %%
hyphens_compound_verbs = list(nlp.pipe([token.replace('-', ' ') for token in hyphens_before]))
hyphens_compound_verbs = [token.text.replace(' ', '-') for token in hyphens_compound_verbs if is_compound(token, 'ADJ', 'NOUN', 'pp') or is_compound(token, 'NOUN', 'VERB', 'pp') or is_compound(token, 'ADV', 'VERB', 'pp')]
hyphens_compound_verbs
# Out:
# ['danger-filled',
#  'dead-level',
#  'decent-living',
#  'deep-rooted',
#  'deep-seated',
#  'dependent-pension',
#  'destruction-constitutes',
#  'dilly-dallying',
#  'diplomatic-service',
#  'dive-bomber',
#  'domestic-slavery',
#  'double-digit',
#  'double-edged',
#  'double-talk',
#  'double-tracking',
#  'double-turret',
#  'dry-dock',
#  'dry-land',
#  'early-childhood',
#  'early-stage',
#  'eighth-grade',
#  'eleventh-hour',
#  'employer-provided',
#  'equal-rights',
#  'even-handed',
#  'ever-advancing',
#  'ever-broadening',
#  'ever-enduring',
#  'ever-expanding',
#  'ever-growing',
#  'ever-increasing',
#  'ever-living',
#  'ever-mounting',
#  'ever-recurring',
#  'ever-rising',
#  'ever-shifting',
#  'ever-varying',
#  'ever-widening',
#  'evil-doers',
#  'exact-percent',
#  'excess-profits',
#  'extended-family',
#  'fair-dealing',
#  'fair-share',
#  'family-owned',
#  'far-famed',
#  'far-left',
#  'far-reaching',
#  'far-removed',
#  'far-seeing',
#  'far-sighted',
#  'fast-changing',
#  'fast-food',
#  'fast-growing',
#  'fast-track',
#  'federally-aided',
#  'federally-funded',
#  'fellow-beings',
#  'fellow-citizens',
#  'fellow-countrymen',
#  'fellow-magistrates',
#  'fellow-man',
#  'fellow-men',
#  'fellow-rioters',
#  'fellow-servant',
#  'fellow-servants',
#  'fine-goods',
#  'first-aid',
#  'first-class',
#  'first-generation',
#  'first-mentioned',
#  'first-mortgage',
#  'first-rate',
#  'first-step',
#  'first-strike',
#  'first-time',
#  'flex-time',
#  'foreign-assistance',
#  'forward-looking',
#  'forward-moving',
#  'fourth-rate',
#  'free-delivery',
#  'free-market',
#  'free-men',
#  'free-spending',
#  'free-thinking',
#  'fresh-water',
#  'front-line',
#  'front-page',
#  'fugitive-slave',
#  'full-caliber',
#  'full-grown',
#  'full-leg',
#  'full-scale',
#  'general-delivery',
#  'gold-demand',
#  'good-fellowship',
#  'good-fortune',
#  'good-looking',
#  'good-paying',
#  'government-approved',
#  'government-funded',
#  'government-ordered',
#  'government-owned',
#  'government-related',
#  'government-required',
#  'government-sponsored',
#  'great-grandparents',
#  'ground-launched',
#  'growth-oriented',
#  'half-century',
#  'half-circle',
#  'half-hour',
#  'half-slave',
#  'half-way',
#  'half-won',
#  'hard-earned',
#  'hard-headed',
#  'hard-hit',
#  'hard-hitting',
#  'hard-pressed',
#  'hard-working',
#  'hardest-hit',
#  'heart-felt',
#  'heretofore-recognized',
#  'high-crime',
#  'high-grade',
#  'high-growth',
#  'high-license',
#  'high-paying',
#  'high-power',
#  'high-priority',
#  'high-profile',
#  'high-quality',
#  'high-ranking',
#  'high-school',
#  'high-sounding',
#  'high-speed',
#  'high-strength',
#  'high-tech',
#  'high-technology',
#  'high-unemployment',
#  'high-value',
#  'high-wage',
#  'high-water',
#  'higher-level',
#  'higher-paying',
#  'highly-paid',
#  'hot-bed',
#  'human-animal',
#  'hydroelectric-power',
#  'ill-conduct',
#  'ill-feeling',
#  'industrial-military',
#  'inflation-produced',
#  'ink-stained',
#  'inner-city',
#  'internal-improvement',
#  'internal-revenue',
#  'internal-tax',
#  'joint-stock',
#  'junior-grade',
#  'large-heartedness',
#  'large-scale',
#  'last-ditch',
#  'last-minute',
#  'lead-time',
#  'left-wing',
#  'legal-tenders',
#  'light-draft',
#  'light-hearted',
#  'light-houses',
#  'light-rainfall',
#  'live-stock',
#  'long-awaited',
#  'long-buried',
#  'long-cherished',
#  'long-continued',
#  'long-deferred',
#  'long-delayed',
#  'long-developed',
#  'long-disputed',
#  'long-enduring',
#  'long-existing',
#  'long-held',
#  'long-ignored',
#  'long-indulged',
#  'long-isolated',
#  'long-lasting',
#  'long-lost',
#  'long-maintained',
#  'long-needed',
#  'long-neglected',
#  'long-pending',
#  'long-playing',
#  'long-protracted',
#  'long-range',
#  'long-reaching',
#  'long-running',
#  'long-settled',
#  'long-sought',
#  'long-standing',
#  'long-staple',
#  'long-suffering',
#  'long-time',
#  'long-view',
#  'longer-term',
#  'longest-serving',
#  'longest-suffering',
#  'loosely-monitored',
#  'low-birth',
#  'low-cost',
#  'low-demand',
#  'low-income',
#  'low-interest',
#  'low-lying',
#  'low-paying',
#  'low-rent',
#  'low-tariff',
#  'low-wage',
#  'low-water',
#  'lower-income',
#  'lower-middle',
#  'lower-paid',
#  'lower-priced',
#  'lower-wage',
#  'machine-gunned',
#  'main-line',
#  'major-generals',
#  'many-point',
#  'many-sidedness',
#  'market-oriented',
#  'mashed-potato',
#  'men-change',
#  'middle-income',
#  'military-style',
#  'minimum-wage',
#  'minority-owned',
#  'misery-hunted',
#  'moderate-income',
#  'money-changers',
#  'mortgage-backed',
#  'much-debated',
#  'much-desired',
#  'much-discussed',
#  'much-injured',
#  'much-loved',
#  'much-needed',
#  'multiple-line',
#  'multiple-use',
#  'narrow-purpose',
#  'nationally-aided',
#  'never-ceasing',
#  'never-dying',
#  'never-ending',
#  'never-failing',
#  'newly-agreed',
#  'newly-enrolled',
#  'newly-expanded',
#  'newly-won',
#  'next-door',
#  'next-generation',
#  'non-action',
#  'non-arrival',
#  'non-believers',
#  'non-combat',
#  'non-combatants',
#  'non-earning',
#  'non-essentials',
#  'non-existence',
#  'non-existent',
#  'non-importation',
#  'non-inflation',
#  'non-interference',
#  'non-intervention',
#  'non-payment',
#  'non-profit',
#  'non-profits',
#  'non-proliferation',
#  'non-residents',
#  'non-violence',
#  'nuclear-freeze',
#  'nuclear-testing',
#  'offensive-power',
#  'often-disproved',
#  'often-expressed',
#  'often-repeated',
#  'oil-fired',
#  'old-age',
#  'old-boy',
#  'old-style',
#  'old-time',
#  'old-timers',
#  'once-closed',
#  'once-shuttered',
#  'open-door',
#  'out-teach',
#  'out-traded',
#  'overall-price',
#  'partial-birth',
#  'past-time',
#  'people-housewives',
#  'peoples-depends',
#  'physically-handicapped',
#  'plain-speaking',
#  'poverty-ridden',
#  'pre-dawn',
#  'pre-emptions',
#  'present-day',
#  'present-year',
#  'private-car',
#  'private-sector',
#  'pro-abortion',
#  'pro-business',
#  'pro-education',
#  'pro-family',
#  'pro-growth',
#  'pro-life',
#  'pro-portion',
#  'pro-visions',
#  'pro-work',
#  'programs-balance',
#  'protective-tariff',
#  'public-building',
#  'public-land',
#  'public-spiritedness',
#  'pure-food',
#  'quick-acting',
#  'quick-lime',
#  'rabble-rousing',
#  'rapid-fire',
#  'rapidly-changing',
#  'rates-reflected',
#  'real-life',
#  'real-world',
#  'right-feeling',
#  'right-thinking',
#  'right-wing',
#  'rural-delivery',
#  'safe-deposit',
#  'safe-guarding',
#  'safe-keeping',
#  'same-day',
#  'same-sex',
#  'sand-covered',
#  'scandal-ridden',
#  'scandal-riddled',
#  'scientific-technological',
#  'scientifically-based',
#  'second-guessing',
#  'second-hand',
#  'second-rate',
#  'self-appointed',
#  'self-assured',
#  'self-centered',
#  'self-constituted',
#  'self-contained',
#  'self-controlled',
#  'self-created',
#  'self-described',
#  'self-disciplined',
#  'self-doubts',
#  'self-elected',
#  'self-governed',
#  'self-imposed',
#  'self-inflicted',
#  'self-invited',
#  'self-organized',
#  'self-possessed',
#  'self-proclaimed',
#  'self-propelled',
#  'self-styled',
#  'self-sustained',
#  'self-tormented',
#  'service-connected',
#  'seventh-ranking',
#  'short-cuts',
#  'short-notice',
#  'short-range',
#  'short-run',
#  'short-sightedness',
#  'short-staple',
#  'short-term',
#  'shorter-range',
#  'single-issue',
#  'single-line',
#  'single-mindedness',
#  'single-parent',
#  'single-payer',
#  'single-rate',
#  'single-turret',
#  'single-year',
#  'slow-burning',
#  'small-arms',
#  'small-business',
#  'small-pox',
#  'snow-capped',
#  'snow-covered',
#  'special-agency',
#  'special-delivery',
#  'special-improvement',
#  'special-interest',
#  'standard-bearer',
#  'state-led',
#  'state-sponsored',
#  'still-growing',
#  'straight-dealing',
#  'straight-line',
#  'straight-thinking',
#  'strife-torn',
#  'sub-districts',
#  'submarine-launched',
#  'super-government',
#  'sweated-labor',
#  'tax-deferred',
#  'tax-preferred',
#  'terminal-track',
#  'third-class',
#  'third-year',
#  'time-honored',
#  'tonight-expect',
#  'top-flight',
#  'top-level',
#  'tough-sounding',
#  'toxic-waste',
#  'twin-track',
#  'unpaid-interest',
#  'upper-level',
#  'value-added',
#  'victims-let',
#  'war-demoralized',
#  'war-inflated',
#  'war-ravaged',
#  'war-ravished',
#  'war-strained',
#  'war-torn',
#  'whistle-stop',
#  'wide-spread',
#  'wild-cat',
#  'worker-controlled',
#  'worst-kept',
#  'yesterday-indicates',
#  'young-man']

# %% [markdown]
# >> #### 9.3 Prepare token pairs

# %%
hyphen_tokens = sorted(list(set(hyphen_tokens).difference(set(hyphens_compound_verbs))))
print(len(hyphen_tokens))
hyphen_tokens
# Out:
# 2421
# ['1,500-a-year',
#  '1-day',
#  '1-in-20',
#  '1-yard',
#  '1-year',
#  '1-year-old',
#  '1/2-inch',
#  '1/2-percent',
#  '10,000-foot',
#  '10,000-page',
#  '10,000-ton',
#  '10-day',
#  '10-inch',
#  '10-man',
#  '10-minute',
#  '10-percent',
#  '10-round',
#  '10-to-1',
#  '10-year',
#  '10-year-old',
#  '100-cent',
#  '11-year-old',
#  '12-hour',
#  '12-inch',
#  '12-month',
#  '12-year-old',
#  '122-foot',
#  '122-percent',
#  '13-year-old',
#  '13Ѕ-inch',
#  '14-percent',
#  '14-point',
#  '14-to-1',
#  '14-year',
#  '14-year-old',
#  '15-percent',
#  '15-year-olds',
#  '152-millimeter',
#  '16-inch',
#  '16-inch-type',
#  '16-year-old',
#  '167-page',
#  '17-year',
#  '17-year-low',
#  '17-year-old',
#  '18-hour',
#  '18-nation',
#  '18-percent',
#  '18-wheelers',
#  '18-year-old',
#  '18-year-olds',
#  '180-odd',
#  '19-foot',
#  '19-year-old',
#  '19-year-olds',
#  '190-year',
#  '1970s-era',
#  '19th-century',
#  '2,000-foot',
#  '2,000-mile',
#  '2-in-3',
#  '2-is',
#  '2-minute',
#  '2-percent',
#  '2-year',
#  '2-year-old',
#  '2-year-olds',
#  '20-knot',
#  '20-percent',
#  '20-point',
#  '20-year',
#  '20-year-old',
#  '200-mile',
#  '200-year',
#  '200-year-old',
#  '21st-century',
#  '22,000-word',
#  '22-month',
#  '22-percent',
#  '23-knot',
#  '24-hour',
#  '24-knot',
#  '24-year',
#  '25-percent',
#  '25-year',
#  '250-bed',
#  '26-year-old',
#  '28-minute',
#  '28-percent',
#  '28-square-mile',
#  '3-day',
#  '3-inch',
#  '3-mile',
#  '3-minute',
#  '3-point',
#  '3-to-1',
#  '3-year',
#  '3/4-year',
#  '30-cent',
#  '30-day',
#  '30-minute',
#  '30-odd',
#  '30-percent',
#  '30-second',
#  '30-year',
#  '35-day',
#  '35-hour',
#  '35-percent',
#  '36-percent',
#  '37-point',
#  '3D-print',
#  '3rd-grade',
#  '4-or',
#  '4-percent',
#  '4-point',
#  '4-something',
#  '4-star',
#  '4-year',
#  '4-year-old',
#  '4.8-percent',
#  '40,000-odd',
#  '40-nation',
#  '40-percent',
#  '40-some',
#  '40-yard',
#  '40-year',
#  '45-second',
#  '45-year',
#  '47-year-old',
#  '48-story',
#  '49-year-old',
#  '5-ambulatory',
#  '5-day',
#  '5-letter',
#  '5-percent',
#  '5-power',
#  '5-year',
#  '5-year-old',
#  '50,000-a-year',
#  '50-cent',
#  '50-cent-a-gallon',
#  '50-hour',
#  '50-percent',
#  '50-year',
#  '500-billion',
#  '500-million',
#  '500-per-child',
#  '500-year',
#  '55-mile',
#  '5?-percent',
#  '6-day',
#  '6-inch',
#  '6-month',
#  '6-months',
#  '6-percent',
#  '6-point',
#  '6-pounder',
#  '6-year',
#  '60,000-plus',
#  '60-day',
#  '60-second',
#  '600,000-man',
#  '600-page',
#  '600-percent',
#  '600-ship',
#  '62-year-olders',
#  '65-year',
#  '650-billion-a-year',
#  '7-day',
#  '7-percent',
#  '7-year',
#  '7-year-long',
#  '70-million',
#  '70-percent',
#  '73-percent',
#  '75-bed',
#  '75-page',
#  '75-year-old',
#  '77-percent',
#  '8-inch',
#  '8-year',
#  '8-year-old',
#  '8-year-olds',
#  '800-HELPNOW',
#  '800-some',
#  '81-which',
#  '85-foot',
#  '88-year-old',
#  '9,000-men',
#  '9-foot',
#  '9-hour',
#  '9-millimeter',
#  '9-year-olds',
#  '9.2-percent',
#  '90-day',
#  '90-minute',
#  '90-second',
#  '900,000-$900,000',
#  '91-to-1',
#  '960-acre',
#  'A-11',
#  'A-6F',
#  'A-grade',
#  'A-plus',
#  'ACT-UP',
#  'ADJUTANT-GENERAL',
#  'AIDS-free',
#  'AK-47s',
#  'AMERICA-HONDURAS',
#  'ANTI-TRUST',
#  'ARBITRATIONS-PANAMA',
#  'Adjutant-General',
#  'Administration-Mr',
#  'African-American',
#  'African-Americans',
#  'African-owned',
#  'Ah-h-h',
#  'Aigner-Clark',
#  'Aix-la-Chapelle',
#  'Al-Azhar',
#  'Alaskan-Yukon-Pacific',
#  'All-merciful',
#  'All-powerful',
#  'All-time',
#  'Allies-in',
#  'Alsace-Lorraine',
#  'Amazon-Washington',
#  'Ambassador-Mr',
#  'America-in',
#  'America-the',
#  'American-British',
#  'American-Hellenic',
#  'American-Soviet',
#  'American-born',
#  'American-built',
#  'American-made',
#  'American-mediated',
#  'American-owned',
#  'Americans-to',
#  'Americas-the',
#  'An-tung',
#  'Anglo-Saxon',
#  'Anglo-Venezuelan',
#  'Anti-Trust',
#  'Antung-Mukden',
#  'Apollo-Gemini',
#  'Arab-Israeli',
#  'Armenian-Americans',
#  'As-salaamu',
#  'Asia-Pacific',
#  'Asia-and',
#  'Asia-which',
#  'Asian-American',
#  'Asian-Americans',
#  'Assembly-have',
#  'Atlantic-Mississippi',
#  'Attorney-General',
#  'Attorneys-General',
#  'Austro-Hungarian',
#  'B-1',
#  'B-1B',
#  'B-2',
#  'B-22',
#  'B-29',
#  'B-47',
#  'B-52',
#  'B-l',
#  'BUNAU-VARILLA',
#  'Baltic-Americans',
#  'Band-Aid',
#  'Band-aid',
#  'Berlin-and',
#  'Big-Brother-is-watching-you',
#  'Big-hearted',
#  'Black-owned',
#  'Blue-collar',
#  'Boo-o-o',
#  'Bosnia-wide',
#  'Boutros-Ghali',
#  'Brest-Litovsk',
#  'Briand-Kellogg',
#  'Brigadier-General',
#  'British-American',
#  'Bunau-Varilla',
#  'Bush-McCain',
#  'C-1',
#  'C-SPAN',
#  'C-minus',
#  'CAPITAL-GAINS',
#  'CIVIL-SERVICE',
#  'CONFERENCE-UNFORTUNATE',
#  'CONSULATE-GENERAL',
#  'Cabinet-level',
#  'Cambodian-Vietnam',
#  'Capper-Ketcham',
#  'Capper-Volstead',
#  'Captain-General',
#  'Captain-Generalto',
#  'Carter-Mondale',
#  'Catch-and-release',
#  'Census-we',
#  'Cha-Cha-Cha',
#  'Chamber-the',
#  'Chi-li',
#  'China-U.S.',
#  'Chinchow-Aigun',
#  'Chinese-American',
#  'Chinese-Japanese',
#  'Chinese-made',
#  'Christ-like',
#  'Civil-Service',
#  'Civil-service',
#  'Clayton-Bulwer',
#  'Clear-eyed',
#  'Co-operation',
#  'Coal-land',
#  'Coleman-Singleton',
#  'Columbia-it',
#  'Commander-in-Chief',
#  'Commissary-General',
#  'Commissioner-General',
#  'Communist-controlled',
#  'Communist-directed',
#  'Communist-dominated',
#  'Communist-inspired',
#  'Communist-supplied',
#  'Communist-supported',
#  'Conable-Hanee',
#  'Congo-Adoula',
#  'Congo-Kinshasa',
#  'Congress-and',
#  'Congress-by',
#  'Congress-through',
#  'Consul-General',
#  'Convention-my',
#  'Corps]-type',
#  'Cuban-Soviet',
#  'D-day',
#  'DECISION-MERELY',
#  'Dar-Es-Salaam',
#  'Day-inspector',
#  'Dead-Letter',
#  'Democratic-controlled',
#  'Director-General',
#  'Disarmament-Canada',
#  'Double-digit',
#  'Douglas-Home',
#  'Drug-Free',
#  'E-rate',
#  'EIGHT-HOUR',
#  'ELECTRICAL-POWER',
#  'Earth-based',
#  'East-West',
#  'East-mark',
#  'East-there',
#  'Egypt-Saudi',
#  'Egyptian-Israeli',
#  'Eisenhower-and',
#  'Eisenhower-they',
#  'Elizabeth-City',
#  'Empress-Queen',
#  'English-speaking',
#  'Entente-Allies',
#  'Establishment-this',
#  'Europe-the',
#  'Ex-Corporal',
#  'Export-Import',
#  'Eyre-Cragin',
#  'F-1',
#  'F-14',
#  'F-14s',
#  'F-15',
#  'F-35',
#  'F1a.-there',
#  'FBI-in',
#  'FELLOW-CITIZENS',
#  'FUR-SEAL',
#  'Fair-minded',
#  'Faith-Based',
#  'Faith-based',
#  'Far-reaching',
#  'Farmer-Labor',
#  'Federal-State',
#  'Federal-assisted',
#  'Federal-highway',
#  'Federally-funded',
#  'Fellow-Citizens',
#  'Fellow-Countrymen',
#  'Fellow-citizens',
#  'Fiat-Chrysler',
#  'Fifty-eighth',
#  'Fifty-fifth',
#  'Fifty-four-forty',
#  'Fish-Culture',
#  'Five-Year',
#  'Five-twenties',
#  'Fix-It-First',
#  'Flat-head',
#  'Follow-up',
#  'Foo-Choo-Foo',
#  'Food-for-Peace',
#  'Fordney-McCumber',
#  'Forty-fifth',
#  'Forty-ninth',
#  'Four-Power',
#  'Four-fifths',
#  'Franco-American',
#  'Frankfort-on-the-Main',
#  'Franklin-leaning',
#  'Free-Soilers',
#  'Free-State',
#  'Free-delivery',
#  'Free-market',
#  'G-20',
#  'G-8',
#  'GS-12',
#  'GS-18',
#  'Gall-lard',
#  'Garner-Rainey',
#  'Germany-the',
#  'Germany-voting',
#  'God-awful',
#  'God-blessed',
#  'God-fearing',
#  'God-given',
#  'God-imposed',
#  'Government-improved',
#  'Government-its',
#  'Government-led',
#  'Government-owned',
#  'Government-regulated',
#  'Government-the',
#  'Government-under',
#  'Government-wide',
#  'Governments-Germany',
#  'Governor-General',
#  'Governor-to',
#  'Gramm-Rudman',
#  'Gramm-Rudman-Hollings',
#  'Grant-in-aid',
#  'Greek-Turkish',
#  'H-43',
#  'H-bomb',
#  'HIV-positive',
#  'HOME-LOAN',
#  'Haitian-Americans',
#  'Haitian-Dominican',
#  'Half-hearted',
#  'Hard-headedness',
#  'Harley-Davidson',
#  'Harvard-trained',
#  'Hawaiian-Japanese',
#  'Hawley-Smoot',
#  'Hay-Herran',
#  'Hay-Pauncefote',
#  'Heaven-favored',
#  'Heavy-armed',
#  'Hesse-Darmstadt',
#  'High-ranking',
#  'High-wage',
#  'Hill-Burton',
#  'Hispanic-Americans',
#  'Hiss-Chambers',
#  'Hitler-dominated',
#  'Ho-si-woo',
#  'Hope-renewed',
#  'House-business',
#  'Hsiao-ping',
#  'Hudson-Fulton',
#  'Humphrey-Hawkins',
#  'IA-ECOSOC',
#  'II-has',
#  'III-C',
#  'INTER-AMERICAN',
#  'INTERSTATE-COMMERCE',
#  'Indian-school',
#  'Indo-China',
#  'Indo-Chinese',
#  'Indonesian-Malaysian',
#  'Inspector-General',
#  'Inter-American',
#  'Inter-Departmental',
#  'Intermediate-Range',
#  'Internal-Revenue',
#  'Internal-revenue',
#  'Iran-Iraq',
#  'Iraqi-led',
#  'Irish-American',
#  'Irish-Catholic',
#  'Irish-Protestant',
#  'Israeli-Jordanian',
#  'Israeli-Palestinian',
#  'Italian-Americans',
#  'J-58',
#  'Jackson-Vanik',
#  'Jaish-e-Mohammed',
#  'Japanese-American',
#  'Jefferson-like',
#  'Jewish-Americans',
#  'Job-killing',
#  'Johnson-Humphrey',
#  'Judas-like',
#  'Judge-Advocate-General',
#  'Judge-Advocates',
#  'Kassebaum-Kennedy',
#  'Kellogg-Briand',
#  'Kemp-Roth',
#  'Kennedy-Johnson',
#  'Kennedy-Kassebaum',
#  'Kennedy-McCarthy',
#  'Key-Stone',
#  'Kiao-chow',
#  'Klan-minded',
#  'LATIN-AMERICAN',
#  'LAW-THE',
#  'LIGHT-HOUSE',
#  'LIGHT-HOUSES',
#  'LONG-STANDING',
#  'Labor-Management',
#  'Lakes-St',
#  'Lao-tzu',
#  'Laos-regained',
#  'Large-scale',
#  'Latter-day',
#  'Law-abiding',
#  'Law-clerk',
#  'Lieutenant-Colonel',
#  'Lieutenant-Commander',
#  'Lieutenant-General',
#  'Life-Saving',
#  'Light-House',
#  'Light-houses',
#  'Lincoln\'s-"Let',
#  'Long-term',
#  'Low-income',
#  'Low-tax',
#  'M-1',
#  'MI-8',
#  'MS-13',
#  'Major-General',
#  'Man-of-war',
#  'Manila-Hongkong',
#  'Mansfield-Scott',
#  'Marine-Hospital',
#  'Marquez-Greene',
#  'Marxism-Leninism',
#  'Marxist-Leninism',
#  'Marxist-Leninist',
#  'Marxist-Leninists',
#  'Mason-Dixon',
#  'Mazar-e-Sharif',
#  'McCain-Feingold',
#  'Mecklenburg-Schwerin',
#  'Medicare-approved',
#  'Medicare-rarely',
#  'Meuse-Argonne',
#  'Mid-Atlantic',
#  'Middle-class',
#  'Middleton-Doctor',
#  'Mig-23',
#  'Mm-hmm',
#  'Modern-day',
#  'Money-Order',
#  'Moore-Brown',
#  'Muslim-majority',
#  'Mustering-out',
#  'NAVY-YARDS',
#  'Nation-wide',
#  'Nations-and',
#  'Nations-led',
#  'Navy-Yard',
#  'Nazi-dominated',
#  'Nazi-ism',
#  'Nebraska-Kansas',
#  'New-England',
#  'New-Jersey',
#  'New-Orleans',
#  'New-York',
#  'Night-inspector',
#  'Nine-eleven',
#  'Nixon-16',
#  'Nixon-Ford',
#  'Non-Discrimination',
#  'Non-Proliferation',
#  'Non-intervention',
#  'North-Carolina',
#  'North-South',
#  'North-West',
#  'North-Western',
#  'Nuclear-Test-Ban',
#  'OB-GYN',
#  'Oil-producing',
#  'Old-fashioned',
#  'On-site',
#  'Once-bitter',
#  'One-eighth',
#  'One-fourth',
#  'One-half',
#  'One-third',
#  'Ottoman-born',
#  'P-Tech',
#  'PANAMA-PACIFIC',
#  'POST-OFFICE',
#  'POSTAL-SAVINGS',
#  'PURE-FOOD',
#  'Pacific-cable',
#  'Pago-Pago',
#  'Pakistan-600',
#  'Pan-Amencan',
#  'Pan-American',
#  'Pan-Americanism',
#  'Panama-Pacific',
#  'Paper-covered',
#  'Paymaster-General',
#  'Paymaster-General.3',
#  'Payne-Aldrich',
#  'Pei-Ho',
#  'Peit-sang',
#  'Pent-up',
#  'Peru-Bolivian',
#  'Port-au-Prince',
#  'Post-9/11',
#  'Post-Dispatch',
#  'Post-Office',
#  'Post-OfficeDepartment',
#  'Post-Roads',
#  'Post-office',
#  'Post-offices',
#  'Post-roads',
#  'PostMaster-General',
#  'Postmaster-General',
#  'Postmaster-Generalagainst',
#  'Postmaster-Generals',
#  'Pre-K',
#  'President-Elect',
#  'President-and',
#  'President-as',
#  'President-some',
#  'President-that',
#  'President-to-be',
#  'President-tried',
#  'President-with',
#  'Presidents-President',
#  'Prize-winning',
#  'Provost-Marshal-General',
#  'Qaeda-Iraq',
#  'Quartermaster-General',
#  'R-U',
#  'R-e-g-a-n',
#  'RC-135',
#  'RICA-COLOMBIA',
#  'RS-70',
#  'Ranger-type',
#  'Re-Election',
#  'Re-employment',
#  'Re-enlistment',
#  'Reagan-Bush',
#  'Reagan-Kemp-Roth',
#  'Rear-Admiral',
#  'Revenue-Cutter',
#  'Richmond-based',
#  'Rip-Rap',
#  'Rush-Bagot',
#  'Russo-American',
#  'Russo-Japanese',
#  'SECOND-CLASS',
#  'SELF-DEFENSE',
#  'SEMI-CENTENNIAL',
#  'SLAVE-DEALER',
#  'SR-71',
#  'SR-7I',
#  'SS-18',
#  'SS-20',
#  'SS-20s',
#  'SS-21',
#  'SS-4',
#  'SS-4s',
#  'SS-5',
#  'STABT-Strategic',
#  'Sabbath-Sunday',
#  'Sai-shek',
#  'Sam-whoever',
#  'Saxe-Coburg',
#  'Schleswig-Holstein',
#  'Scotch-Irish',
#  'Scripps-Howard',
#  'Scud-type',
#  'Secret-Service',
#  'Secretary-General',
#  'Secretary-then-Regan',
#  'Self-defense',
#  'Self-determination',
#  'Self-governed',
#  'Self-government',
#  'Self-interest',
#  'Self-preservation',
#  'Self-reliance',
#  'Self-restraint',
#  'Seong-ho',
#  'September-immediately',
#  'Seventy-Fifth',
#  'Shan-tung',
#  'Sheppard-Towner',
#  'Short-term',
#  'Signal-Service',
#  'Simpson-Bowles',
#  'Simpson-Mazzoli',
#  'Sino-American',
#  'Sino-Soviet',
#  'Sixty-eighth',
#  'Slave-Code',
#  'Small-business',
#  'Smoot-Haw',
#  'Solicitor-General',
#  'South-Carolina',
#  'South-west',
#  'Soviet-American',
#  'Soviet-Chinese',
#  'Soviet-Cuban',
#  'Soviet-U.S.',
#  'Soviet-built',
#  'Soviet-made',
#  'Soviet-occupied',
#  'Soviet-sponsored',
#  'Soviet-supported',
#  'Spanish-American',
#  'Spanish-speaking',
#  'Speaker-elect',
#  'Star-Spangled',
#  'Star-Warring',
#  'State-administered',
#  'State-an',
#  'State-bank',
#  'State-controlled',
#  'State-directed',
#  'State-owned',
#  'State-sponsored',
#  'State-supported',
#  'States-Mexican',
#  'States-a',
#  'States-besides',
#  'Steamboat-Inspection',
#  'Sung-pu',
#  'Surgeon-General',
#  'Suz-ahn',
#  'Syrian-backed',
#  'Sze-chuen',
#  'TACNA-ARICA',
#  'Ta-lien-wan',
#  'Tacna-Arica',
#  'Taft-Ellender-Wagner',
#  'Tax-exempt',
#  'Ten-forties',
#  'The-world',
#  'Thirty-eighth',
#  'Thirty-fifth',
#  'Thirty-ninth',
#  'Thomas-Anita',
#  'Three-fourths',
#  'Three-quarters',
#  'Tien-Tsin',
#  'Tien-tsin',
#  'Ting-fang',
#  'To-day',
#  'To-morrow',
#  'Trans-Missouri',
#  'Trans-Pacific',
#  'Trenton-Princeton',
#  'Truman-Acheson',
#  'Trump-Pence',
#  'Tsai-Hsun',
#  'Tsai-tao',
#  'Tse-tung',
#  'Tsing-tao',
#  'Tsung-li',
#  'Twenty-fifth',
#  'Two-thirds',
#  'U-2',
#  'U-Boats',
#  'U-boats',
#  'U.S.-Canadian',
#  'U.S.-Japan',
#  'U.S.-Korea',
#  'U.S.-Mexico',
#  'U.S.-Mexico-Canada',
#  'U.S.-Panamanian',
#  'Ukrainian-Americans',
#  'Union-for',
#  'Union-loving',
#  'Union-men',
#  'Union-saving',
#  'Union-supporting',
#  'V-1',
#  'V-2',
#  'V-J',
#  'V-chip',
#  'Vice-Presidency',
#  'Vice-President',
#  'Vice-Presidential',
#  'Viet-Nam',
#  'Vietnam-and',
#  'Vietnam-apply',
#  'Vietnam-backed',
#  'W-GDP',
#  'Wage-workers',
#  'Wagner-Ellender-Taft',
#  'War-would',
#  'Washington-based',
#  'Web-feet',
#  'Wei-hai-wei',
#  'Well-considered',
#  'Well-founded',
#  'Well-trained',
#  'Western-proposed',
#  'Western-type',
#  'Wilkes-Barre',
#  'X-rated',
#  'Yang-Tse',
#  'Yen-hoon',
#  'Zero-Option',
#  'Zimbabwe-Rhodesia',
#  'across-the-board',
#  'act-$350,000,000',
#  'aid-to-democracies',
#  'air-to-air',
#  'al-Assad',
#  'al-Baghdadi',
#  "al-Qa'ida",
#  'al-Qaeda',
#  'al-Sabah',
#  'al-Suhail',
#  'all-American',
#  'all-Asian',
#  'all-German',
#  'all-Indochina',
#  'all-of-the-above',
#  'all-or-nothing',
#  'anti-American',
#  'anti-Catholic',
#  'anti-Communism',
#  'anti-Communist',
#  'anti-Fascist',
#  'anti-Nazi',
#  'anti-Semitic',
#  'anti-Semitism',
#  'anti-Somoza',
#  'anti-Soviet',
#  'anti-U.S.',
#  'anti-Vietnam',
#  'anti-Washington',
#  'anti-drug-trafficking',
#  'arm-in-arm',
#  'arms-Mother',
#  'attack,-dangers',
#  'back-and-forth',
#  'back-to-back',
#  'back-to-school',
#  'balance-of-payments',
#  'behind-the-scenes',
#  'black-and-white',
#  'brothers-in-arms',
#  "bull's-eye",
#  'business-I',
#  'cap-and-trade',
#  'case-by-case',
#  'catch-22',
#  'catch-and-release',
#  'cities-America',
#  'cities-Rome',
#  'co-States',
#  'coal-I',
#  'command-and-control',
#  'commander-in-chief',
#  'comrades-in-arms',
#  'cost-of-living',
#  'cost-plus-fixed',
#  'cross-Channel',
#  'cross-examination-type',
#  'cross-purposes',
#  'cross-section',
#  'cure-alls',
#  'custom-house',
#  'custom-houses',
#  'customs-revenue',
#  'cut-three-quarters',
#  'cut-throat',
#  'cutting-edge',
#  'cyber-attacks',
#  'cyber-threats',
#  'dark-stained',
#  'day-General',
#  'day-by-day',
#  'day-inspector',
#  'day-to-day',
#  "de-Ba'athification",
#  'de-Baathification',
#  'de-emphasize',
#  'de-escalate',
#  'de-escalation',
#  'de-moralize',
#  'de-nuke',
#  'de-segregate',
#  'dead-end',
#  'death-dealing',
#  'death-rate',
#  'death-wish',
#  'debt-bearing',
#  'decades-long',
#  'decision-making',
#  'deep-graven',
#  'defense-oriented',
#  'defense-related',
#  'defied-pledges',
#  'delegation-Admiral',
#  'democratic-republican',
#  'department-store',
#  'desert-land',
#  'destruction-meaning',
#  'devil-take-the-hind-most',
#  'dictatorship-clearly',
#  'die-hards',
#  'dime-by-dime',
#  'diplomacy-protect',
#  'dis-armed',
#  'dis-unionists',
#  'disability-pension',
#  'disarmament-true',
#  'disease-bearing',
#  'disease-ridden',
#  'do-gooders',
#  'do-it-yourself',
#  'do-or-die',
#  'doctor-patient',
#  'door-keeper',
#  'door-to-door',
#  'down-the-middle',
#  'down-to-earth',
#  'draw-backs',
#  'e-mails',
#  'earned-income',
#  'eight-hour',
#  'eight-story',
#  'eight-year-old',
#  'eighty-ninth',
#  'elbow-to-elbow',
#  'election-year',
#  "employer's-liability",
#  'employer-employee',
#  'end-of-the-year',
#  'energy-poor',
#  'energy-related',
#  'energy-rich',
#  'energy-saving',
#  'energy-wise',
#  'engine-rooms',
#  'entry-level',
#  'epoch-making',
#  'equal-handed',
#  'ever-active',
#  'ever-closer',
#  'ever-favorite',
#  'ever-glorious',
#  'ever-higher',
#  'ever-larger',
#  'ever-present',
#  'ever-ready',
#  'ever-richer',
#  'ever-watchful',
#  'every-4-year',
#  'every-day',
#  'everything-including',
#  'evil-disposed',
#  'ex-Bashaw',
#  'ex-Corporal',
#  'ex-GI',
#  'ex-President',
#  'ex-Senator',
#  'ex-Union',
#  'ex-army',
#  'ex-marines',
#  'ex-officio',
#  'ex-post',
#  'ex-sailors',
#  'ex-service',
#  'ex-soldiers',
#  'experimental-station',
#  'export-import',
#  'export-minded',
#  'extra-territorial',
#  'eye-and-a-half',
#  'eye-opening',
#  'eye-witnesses',
#  'face-to-face',
#  'fact-finding',
#  'factories-textile',
#  'factory-inspection',
#  'faint-hearted',
#  'faint-heartedly',
#  'fair-headed',
#  'fair-minded',
#  ...]

# %% [markdown]
# >> #### 10.1 Problem: Some hyphenated words are formed from non-words

# %%
pattern = '^[a-z]+-[^-A-Z0-9]+$'
hyphens_before = [re.search(pattern, token)[0] for token in hyphen_tokens if re.search(pattern, token)]
hyphens_before
# Out:
# ['cross-purposes',
#  'cross-section',
#  'cure-alls',
#  'custom-house',
#  'custom-houses',
#  'customs-revenue',
#  'cut-throat',
#  'cutting-edge',
#  'cyber-attacks',
#  'cyber-threats',
#  'dark-stained',
#  'day-inspector',
#  'de-emphasize',
#  'de-escalate',
#  'de-escalation',
#  'de-moralize',
#  'de-nuke',
#  'de-segregate',
#  'dead-end',
#  'death-dealing',
#  'death-rate',
#  'death-wish',
#  'debt-bearing',
#  'decades-long',
#  'decision-making',
#  'deep-graven',
#  'defense-oriented',
#  'defense-related',
#  'defied-pledges',
#  'democratic-republican',
#  'department-store',
#  'desert-land',
#  'destruction-meaning',
#  'dictatorship-clearly',
#  'die-hards',
#  'diplomacy-protect',
#  'dis-armed',
#  'dis-unionists',
#  'disability-pension',
#  'disarmament-true',
#  'disease-bearing',
#  'disease-ridden',
#  'do-gooders',
#  'doctor-patient',
#  'door-keeper',
#  'draw-backs',
#  'e-mails',
#  'earned-income',
#  'eight-hour',
#  'eight-story',
#  'eighty-ninth',
#  'election-year',
#  'employer-employee',
#  'energy-poor',
#  'energy-related',
#  'energy-rich',
#  'energy-saving',
#  'energy-wise',
#  'engine-rooms',
#  'entry-level',
#  'epoch-making',
#  'equal-handed',
#  'ever-active',
#  'ever-closer',
#  'ever-favorite',
#  'ever-glorious',
#  'ever-higher',
#  'ever-larger',
#  'ever-present',
#  'ever-ready',
#  'ever-richer',
#  'ever-watchful',
#  'every-day',
#  'everything-including',
#  'evil-disposed',
#  'ex-army',
#  'ex-marines',
#  'ex-officio',
#  'ex-post',
#  'ex-sailors',
#  'ex-service',
#  'ex-soldiers',
#  'experimental-station',
#  'export-import',
#  'export-minded',
#  'extra-territorial',
#  'eye-opening',
#  'eye-witnesses',
#  'fact-finding',
#  'factories-textile',
#  'factory-inspection',
#  'faint-hearted',
#  'faint-heartedly',
#  'fair-headed',
#  'fair-minded',
#  'fair-mindedness',
#  'fake-news',
#  'family-wage',
#  'far-distant',
#  'far-flung',
#  'farmer-controlled',
#  'farmer-managed',
#  'farmer-owned',
#  'farnorth-west',
#  'fast-spreading',
#  'fastest-growing',
#  'father-land',
#  'fault-finding',
#  'favored-nation',
#  'federal-local',
#  'fee-simple',
#  'feel-good',
#  'fellow-citizen',
#  'fellow-citizensa',
#  'fellow-citizensin',
#  'fellow-farmer',
#  'fiber-optic',
#  'field-matron',
#  'field-work',
#  'fifteen-foldwithin',
#  'fifty-dollar',
#  'fifty-fifth',
#  'fig-fertilizing',
#  'figure-head',
#  'fine-tuned',
#  'finger-pointing',
#  'fire-arm',
#  'fire-proof',
#  'fireside-chat',
#  'firm-set',
#  'first-hand',
#  'first-responders',
#  'first-year',
#  'five-day',
#  'five-hour',
#  'five-nation',
#  'five-page',
#  'five-point',
#  'five-sixths',
#  'five-star',
#  'five-twenties',
#  'five-year',
#  'fixed-income',
#  'flight-test',
#  'flights-commercial',
#  'flint-lock',
#  'flood-control',
#  'flower-clad',
#  'following-named',
#  'food-stuffs',
#  'foot-steps',
#  'force-force',
#  'fore-fathers',
#  'foreign-born',
#  'foreign-service',
#  'forest-reserve',
#  'forest-reserves',
#  'forty-eighth',
#  'forty-fifth',
#  'forty-ninth',
#  'forward-leaning',
#  'foundation-stone',
#  'four-engine',
#  'four-fifths',
#  'four-hour',
#  'four-point',
#  'four-power',
#  'four-square',
#  'four-star',
#  'four-story',
#  'four-tenths',
#  'four-thirty',
#  'four-word',
#  'four-year',
#  'fourth-class',
#  'free-born',
#  'free-handed',
#  'free-hearted',
#  'free-trade',
#  'freedom-fighters',
#  'freedom-loving',
#  'freeze-frame',
#  'freight-carrying',
#  'freight-rate',
#  'fresh-faced',
#  'front-row',
#  'fuel-efficiency',
#  'fuel-switching',
#  'full-blown',
#  'full-fledged',
#  'full-rounded',
#  'fund-raising',
#  'fur-bearing',
#  'fur-seal',
#  'gang-violence',
#  'generation-long',
#  'gill-net',
#  'go-ahead',
#  'gold-bearing',
#  'gold-standard',
#  'good-bye',
#  'good-hearted',
#  'good-natured',
#  'goose-stepping',
#  'government-national',
#  'government-run',
#  'government-wide',
#  'grain-exporting',
#  'grain-milling',
#  'great-grandchildren',
#  'great-granddaughter',
#  'great-grandfather',
#  'ground-breaking',
#  'ground-launch',
#  'ground-work',
#  'gun-adept',
#  'gun-boat',
#  'gun-boats',
#  'gun-factory',
#  'gun-free',
#  'gun-racks',
#  'gur-reat',
#  'gut-wrenching',
#  'hair-splitters',
#  'hair-splitting',
#  'half-billion',
#  'half-breeds',
#  'half-clad',
#  'half-dismes',
#  'half-free',
#  'half-hearted',
#  'half-holidays',
#  'half-mast',
#  'half-million',
#  'half-yearly',
#  'hand-carried',
#  'hand-held',
#  'hand-maiden',
#  'hand-wringing',
#  'harbor-defense',
#  'hard-core',
#  'hard-fought',
#  'hard-nosed',
#  'hard-won',
#  'hardest-working',
#  'have-nots',
#  'havoc-breaking',
#  'health-care',
#  'health-related',
#  'heart-breaking',
#  'heart-throbbing',
#  'heart-warming',
#  'heat-seeking',
#  'hemp-growing',
#  'higgledy-piggledy',
#  'high-handed',
#  'high-minded',
#  'high-powered',
#  'high-priced',
#  'high-skilled',
#  'highest-ranking',
#  'highly-leveraged',
#  'highly-skilled',
#  'hip-hop',
#  'history-making',
#  'home-loan',
#  'home-maker',
#  'home-makers',
#  'horse-trading',
#  'host-nation',
#  'hostage-taking',
#  'hot-headed',
#  'hundred-dollar',
#  'hundred-yard',
#  'hundred-year',
#  'husband-man',
#  'hydrogen-fueled',
#  'hydrogen-powered',
#  'hypo-rhetorical',
#  'ice-free',
#  'ill-advised',
#  'ill-assorted',
#  'ill-balanced',
#  'ill-clad',
#  'ill-concerted',
#  'ill-considered',
#  'ill-defined',
#  'ill-directed',
#  'ill-fitting',
#  'ill-founded',
#  'ill-health',
#  'ill-housed',
#  'ill-informed',
#  'ill-nourished',
#  'ill-prepared',
#  'ill-regulated',
#  'ill-rounded',
#  'ill-suited',
#  'ill-timed',
#  'in-[inaudible',
#  'in-demand',
#  'in-fighting',
#  'in-land',
#  'in-roads',
#  'in-trenched',
#  'income-tax',
#  'independence-loving',
#  'independent-treasury',
#  'inflation-fighting',
#  'influence-economic',
#  'inheritance-tax',
#  'intelligence-sharing',
#  'inter-communication',
#  'inter-fere',
#  'inter-island',
#  'inter-oceanic',
#  'inter-service',
#  'interest-bearing',
#  'intermediate-range',
#  'international-affairs',
#  'interstate-commerce',
#  'interstate-railway',
#  'inward-bound',
#  'jet-age',
#  'job-creation',
#  'job-killing',
#  'job-ready',
#  'job-training',
#  'judge-advocates',
#  'jungle-covered',
#  'justice-justice',
#  'kind-heartedness',
#  'klieg-lights',
#  'l-year',
#  'labor-management',
#  'labor-saving',
#  'laboring-man',
#  'lake-bed',
#  'land-grant',
#  'land-laws',
#  'land-proceeds',
#  'large-handed',
#  'last-mentioned',
#  'latter-mentioned',
#  'latter-named',
#  'law-abiding',
#  'law-enforcement',
#  'law-honesty',
#  'law-maker',
#  'law-makers',
#  'law-making',
#  'law-recommendations',
#  'law-respecting',
#  'leading-edge',
#  'leaf-eating',
#  'leave-taking',
#  'lemon-box',
#  'lend-lease',
#  'less-developed',
#  'less-favored',
#  'less-fortunate',
#  'level-best',
#  'liberal-minded',
#  'liberty-loving',
#  'lieutenant-colonel',
#  'lieutenant-colonels',
#  'lieutenant-commander',
#  'lieutenant-commanders',
#  'lieutenant-general',
#  'lieutenant-governor',
#  'life-blood',
#  'life-enhancing',
#  'life-insurance',
#  'life-long',
#  'life-saving',
#  'life-time',
#  'light-house',
#  'like-minded',
#  'line-item',
#  'lip-service',
#  'listen-let',
#  'little-known',
#  'live-oak',
#  'log-line',
#  'log-rolling',
#  'long-extended',
#  'long-felt',
#  'long-fourteen',
#  'long-overdue',
#  'long-run',
#  'long-subsisting',
#  'long-vexed',
#  'loud-mouthed',
#  'low-carbon',
#  'low-enriched',
#  'low-key',
#  'low-lived',
#  'low-priced',
#  'low-rental',
#  'low-sulfur',
#  'lower-skilled',
#  'lowest-paid',
#  'luxuries-perfumes',
#  'machine-gun',
#  'mail-carrying',
#  'mail-messenger',
#  'mail-order',
#  'make-believe',
#  'make-work',
#  'malaria-related',
#  'man-days',
#  'man-hour',
#  'man-hours',
#  'man-kind',
#  'man-power',
#  'man-stealing',
#  'many-sided',
#  'markets-price',
#  'marriage-penalty',
#  'mass-meeting',
#  'master-race',
#  'mean-spirited',
#  'meat-food',
#  'meat-inspection',
#  'meat-packing',
#  'medium-size',
#  'medium-sized',
#  'merchant-men',
#  'mid-continental',
#  'middle-aged',
#  'middle-class',
#  'middle-ground',
#  'middle-management',
#  'military-supersonic',
#  'mind-meld',
#  'mis-lead',
#  'modern-day',
#  'moisture-laden',
#  'money-changer',
#  'money-order',
#  'mortgage-discount',
#  'most-favored',
#  'motor-car',
#  'movie-goer',
#  'multi-billion',
#  'multi-lateral',
#  'multi-layered',
#  'multi-millionaires',
#  'multi-party',
#  'multibillion-dollar',
#  'multimillion-dollar',
#  'multiple-warhead',
#  'muscle-bound',
#  'narrow-minded',
#  'nation-build',
#  'nation-building',
#  'nation-state',
#  'national-bank',
#  'national-banknotes',
#  'national-defense',
#  'national-park',
#  'nations-allies',
#  'nations-prosperity',
#  'native-born',
#  'naval-defense',
#  'navy-yard',
#  'navy-yards',
#  'nay-sayers',
#  'near-limitless',
#  'near-lost',
#  'near-record',
#  'near-term',
#  'near-universal',
#  'negro-livery',
#  'new-born',
#  'new-found',
#  'new-world',
#  'nice-sized',
#  'nine-point',
#  'nine-rung',
#  'nine-tenths',
#  'ninety-fifth',
#  'ninety-ninth',
#  'no-bid',
#  'no-fly',
#  'no-nonsense',
#  'no-nothingness',
#  'no-progreso',
#  'no-strike',
#  'non-addictive',
#  'non-alcoholic',
#  'non-commissioned',
#  'non-competitive',
#  'non-discriminating',
#  'non-essential',
#  'non-governmental',
#  'non-ideological',
#  'non-intercourse',
#  'non-liquid',
#  'non-member',
#  'non-militarized',
#  'non-military',
#  'non-negotiable',
#  'non-nuclear',
#  'non-partisan',
#  'non-political',
#  'non-professional',
#  'non-public',
#  'non-religious',
#  'non-resident',
#  'non-secular',
#  'non-tidal',
#  'non-violent',
#  'noninterest-bearing',
#  'north-eastern',
#  'north-west',
#  'north-western',
#  'not-emphasizing',
#  'note-takers',
#  'now-deceased',
#  'nuclear-armed',
#  'nuclear-capable',
#  'nuclear-free',
#  'object-lesson',
#  'ocean-borne',
#  'ocean-girt',
#  'ocean-going',
#  'ocean-steamship',
#  'off-duty',
#  'off-limits',
#  'off-ramp',
#  'off-spring',
#  'office-seeker',
#  'ofill-considered',
#  'oft-recurring',
#  'oft-repeated',
#  'oft-stated',
#  'oil-burning',
#  'oil-drilling',
#  'oil-rich',
#  'old-fashioned',
#  'old-named',
#  'on-site',
#  'once-distant',
#  'one-eighteenth',
#  'one-eighth',
#  'one-fifteenth',
#  'one-fifth',
#  'one-fourth',
#  'one-half',
#  'one-hoss',
#  'one-hundredth',
#  'one-interest',
#  'one-liners',
#  'one-man',
#  'one-minute',
#  'one-ninth',
#  'one-party',
#  'one-quarter',
#  'one-room',
#  'one-seventh',
#  'one-sided',
#  'one-sixteenth',
#  'one-sixth',
#  'one-story',
#  'one-tenth',
#  'one-term',
#  'one-thirtieth',
#  'one-time',
#  'one-twelfth',
#  'one-way',
#  'one-world',
#  'open-ended',
#  'open-handed',
#  'open-minded',
#  'opioid-related',
#  'opium-exclusion',
#  'opportunity-unreserved',
#  'or-disadvantage',
#  'ordinary-sized',
#  'other-wise',
#  'out-bound',
#  'out-build',
#  'out-commercial',
#  'out-compete',
#  'out-educate',
#  'out-educated',
#  'out-going',
#  'out-gun',
#  'out-innovate',
#  'out-patient',
#  'out-produce',
#  'out-product',
#  'out-right',
#  'out-running',
#  'out-standing',
#  'out-stretched',
#  'out-trade',
#  'out-work',
#  'out-years',
#  'outward-bound',
#  'over-action',
#  'over-anxious',
#  'over-balance',
#  'over-bearing',
#  'over-burdened',
#  'over-capitalization',
#  'over-clouded',
#  'over-crowding',
#  'over-emphasizing',
#  'over-estimates',
#  'over-expansions',
#  'over-exposure',
#  'over-extended',
#  'over-extension',
#  'over-grazed',
#  'over-involvement',
#  'over-issue',
#  'over-issues',
#  'over-long',
#  'over-looked',
#  'over-looking',
#  'over-mastering',
#  'over-night',
#  'over-optimism',
#  'over-planted',
#  'over-powering',
#  'over-privileged',
#  'over-producing',
#  'over-production',
#  'over-rate',
#  'over-rated',
#  'over-reaching',
#  'over-regard',
#  'over-sanguine',
#  'over-simplified',
#  'over-speculation',
#  'over-strained',
#  'over-stressing',
#  'over-subscribed',
#  'over-work',
#  'over-working',
#  'over-zealous',
#  'overdose-reversing',
#  'paper-money',
#  'paper-thin',
#  'para-military',
#  'parcel-post',
#  'parent-teacher',
#  'part-time',
#  'part-way',
#  'pass-book',
#  'pass-key',
#  'pass-keys',
#  'pass-throughs',
#  'path-breaking',
#  'pay-envelope',
#  'peace-keepers',
#  'peace-keeping',
#  'peace-time',
#  'per-child',
#  'percent-adult',
#  'percent-permitting',
#  'performance-enhancing',
#  'pistol-shot',
#  'planned-substantially',
#  'pleuro-pneumonia',
#  'policy-making',
#  'politico-geographical',
#  'poll-takers',
#  'pooh-poohed',
#  'popular-particularly',
#  'post-card',
#  'post-graduate',
#  'post-office',
#  'post-offices',
#  'post-poned',
#  'post-racial',
#  'post-road',
#  'post-roads',
#  'post-route',
#  'post-traumatic',
#  'post-war',
#  'postal-savings',
#  'postal-union',
#  'postmaster-ships',
#  'poverty-stricken',
#  'pre-embryo',
#  'pre-eminence',
#  'pre-eminent',
#  'pre-eminently',
#  'pre-existing',
#  'pre-k',
#  'pre-positioned',
#  'pre-war',
#  'president-elect',
#  'price-depressing',
#  'price-fixing',
#  'price-wage',
#  'print-paper',
#  'prize-men',
#  'pro-civil',
#  'pro-economic',
#  'product-liability',
#  'products-inasmuch',
#  'profit-maker',
#  'profit-sharing',
#  'programs-jobs',
#  'progress-alianza',
#  'progress-maximum',
#  'progressive-minded',
#  'proposed-simple',
#  'provost-marshals',
#  'pseudo-philanthropy',
#  'pseudo-religions',
#  'public-private',
#  'public-school',
#  'pur-rinciple',
#  'quarter-mile',
#  'quarter-million',
#  'quasi-judicial',
#  'quasi-legislative',
#  'quasi-official',
#  'rah-rah',
#  'rat-hole',
#  'rate-making',
#  're-adopt',
#  're-appearance',
#  're-argument',
#  're-assert',
#  're-corded',
#  're-create',
#  're-creation',
#  're-defined',
#  're-deposit',
#  're-echoed',
#  're-elected',
#  're-eligibility',
#  're-embarked',
#  're-employed',
#  're-employment',
#  're-enact',
#  're-enactment',
#  're-enforced',
#  're-enlist',
#  're-enter',
#  're-entering',
#  're-entry',
#  're-equip',
#  're-establish',
#  're-establishment',
#  're-examination',
#  're-hearings',
#  're-ignite',
#  're-impose',
#  're-imposing',
#  're-investment',
#  're-issue',
#  're-issued',
#  're-open',
#  're-processing',
#  're-read',
#  're-refining',
#  're-settling',
#  're-shipped',
#  're-start',
#  're-think',
#  're-tool',
#  're-transfer',
#  're-written',
#  'rear-admiral',
#  'record-keeping',
#  'red-blooded',
#  'reduced-cost',
#  'regime-controlled',
#  'relation-ships',
#  'rent-payers',
#  'repair-shop',
#  'reports-accelerations',
#  'resources-militarily',
#  'revenue-cutter',
#  'ribbon-cuttings',
#  'rice-growing',
#  'right-minded',
#  'risk-adverse',
#  'risk-taker',
#  'risk-takers',
#  'river-bed',
#  'rock-solid',
#  'rock-waste',
#  'roof-raising',
#  'rose-colored',
#  'round-table',
#  'rubber-check',
#  'rubber-stamp',
#  'rumor-mongers',
#  'sacrifice-faith',
#  'safe-guarded',
#  'safety-appliance',
#  'save-later',
#  'scale-insects',
#  'scandal-mongers',
#  'school-age',
#  'school-teachers',
#  'sea-board',
#  'sea-boards',
#  'sea-borne',
#  'sea-carrying',
#  'sea-coast',
#  'sea-going',
#  'sea-keeping',
#  'sea-level',
#  'sea-vessels',
#  'second-class',
#  'second-guess',
#  'second-guessed',
#  'second-largest',
#  'second-tier',
#  'secondhand-book',
#  'secret-service',
#  'security-security',
#  'self-administering',
#  'self-aggrandizement',
#  'self-chosen',
#  'self-complacency',
#  'self-comprehension',
#  'self-confidence',
#  'self-congratulation',
#  'self-conscious',
#  'self-constituting',
#  'self-constitution',
#  'self-containment',
#  'self-control',
#  'self-correction',
#  'self-critical',
#  'self-criticism',
#  'self-deceit',
#  'self-deception',
#  'self-defence',
#  'self-defense',
#  'self-definition',
#  'self-delusion',
#  'self-denial',
#  'self-denying',
#  'self-destruction',
#  'self-devotion',
#  'self-discipline',
#  'self-education',
#  'self-employed',
#  'self-esteem',
#  'self-evident',
#  'self-examination',
#  'self-executing',
#  'self-expatriation',
#  'self-expression',
#  'self-goverment',
#  'self-governing',
#  'self-government',
#  'self-governmentthroughout',
#  'self-healing',
#  'self-image',
#  'self-improvement',
#  'self-indulgence',
#  'self-indulgent',
#  'self-inspection',
#  'self-interest',
#  'self-interested',
#  'self-interests',
#  'self-liquidating',
#  'self-maintenance',
#  'self-mastery',
#  'self-necessity',
#  'self-pity',
#  'self-possession',
#  'self-preservation',
#  'self-protection',
#  'self-redress',
#  'self-reform',
#  'self-reliant',
#  'self-respect',
#  'self-restraint',
#  'self-righteous',
#  'self-righteousness',
#  'self-rule',
#  'self-sacrifice',
#  'self-sacrificing',
#  'self-sacrificingpatriotism',
#  'self-satisfaction',
#  'self-seekers',
#  'self-selection',
#  'self-sufficiency',
#  'self-sufficing',
#  'self-support',
#  'semi-arid',
#  'semi-automatic',
#  'semi-barbarous',
#  'semi-civilized',
#  'semi-detached',
#  'semi-independent',
#  'semi-judicial',
#  'semi-luxury',
#  'semi-monthly',
#  'semi-necessities',
#  'semi-necessity',
#  'sensation-mongers',
#  'sentencing-mandatory',
#  'serf-respecting',
#  'service-pension',
#  'set-aside',
#  'set-asides',
#  'set-backs',
#  'set-tier',
#  'seven-eighths',
#  'seven-headed',
#  'seven-point',
#  'seven-thirty',
#  'seventy-eighth',
#  'seventy-fifth',
#  'shadow-boxers',
#  'shaggy-maned',
#  'shell-fish',
#  'ship-building',
#  'ship-canal',
#  'ship-owners',
#  'shop-worn',
#  'short-changed',
#  'short-lived',
#  'side-track',
#  'silver-act',
#  'silver-bearing',
#  'silver-bullion',
#  'silver-coinage',
#  'silver-dollar',
#  'silver-purchasing',
#  'silver-standard',
#  'simple-minded',
#  'single-handed',
#  'single-headed',
#  'single-minded',
#  'sinking-fund',
#  'six-month',
#  'six-party',
#  'six-shooters',
#  'six-tenths',
#  'six-times',
#  'sixty-mile',
#  'slack-water',
#  'slave-dealers',
#  'slave-holder',
#  'slave-holders',
#  'slave-masters',
#  'slave-owners',
#  'slave-trade',
#  'slave-trader',
#  'slow-growing',
#  'small-park',
#  'smoke-screen',
#  'smoking-related',
#  'smoking-tobacco',
#  'smooth-shaven',
#  'so-called',
#  'sober-minded',
#  'society-citizens',
#  'soft-headed',
#  'soldier-voting',
#  'somehow-amid',
#  'someone-wondering',
#  'sorghum-sugar',
#  'sound-good',
#  'special-unsung',
#  'specie-paying',
#  'speech-maker',
#  'spell-check',
#  'spirit-filled',
#  'split-second',
#  'spray-painted',
#  'star-chamber',
#  'star-route',
#  'star-spangled',
#  'starry-eyed',
#  'start-ups',
#  'statesman-politician',
#  'statesmen-authors',
#  'steam-shovel',
#  'steel-mill',
#  'stepping-stone',
#  'stepping-stones',
#  'stir-reliance',
#  'stock-gambling',
#  'stock-holders',
#  'stock-market',
#  'stock-watering',
#  'stop-gap',
#  'stop-press',
#  'straight-backed',
#  'straight-forward',
#  'strait-jacket',
#  'strip-mining',
#  'sub-agencies',
#  'sub-committee',
#  ...]

# %% [markdown]
# >> #### 10.2 Solution: Find all tokens that only contain valid words and remove them from consideration to be cleaned

# %%
hyphens_after = [token for token in tqdm(hyphens_before) if is_valid_hyphen_word(token)]
hyphens_after
# Out:
# 100%|██████████| 1290/1290 [17:54<00:00,  1.20it/s]
# ['cross-purposes',
#  'cross-section',
#  'cure-alls',
#  'custom-house',
#  'custom-houses',
#  'customs-revenue',
#  'cut-throat',
#  'cutting-edge',
#  'cyber-attacks',
#  'cyber-threats',
#  'dark-stained',
#  'day-inspector',
#  'de-emphasize',
#  'de-escalate',
#  'de-escalation',
#  'de-moralize',
#  'de-nuke',
#  'de-segregate',
#  'dead-end',
#  'death-dealing',
#  'death-rate',
#  'death-wish',
#  'debt-bearing',
#  'decades-long',
#  'decision-making',
#  'deep-graven',
#  'defense-oriented',
#  'defense-related',
#  'defied-pledges',
#  'democratic-republican',
#  'department-store',
#  'desert-land',
#  'destruction-meaning',
#  'dictatorship-clearly',
#  'die-hards',
#  'diplomacy-protect',
#  'dis-armed',
#  'dis-unionists',
#  'disability-pension',
#  'disarmament-true',
#  'disease-bearing',
#  'disease-ridden',
#  'doctor-patient',
#  'door-keeper',
#  'draw-backs',
#  'e-mails',
#  'earned-income',
#  'eight-hour',
#  'eight-story',
#  'eighty-ninth',
#  'election-year',
#  'employer-employee',
#  'energy-poor',
#  'energy-related',
#  'energy-rich',
#  'energy-saving',
#  'energy-wise',
#  'engine-rooms',
#  'entry-level',
#  'epoch-making',
#  'equal-handed',
#  'ever-active',
#  'ever-closer',
#  'ever-favorite',
#  'ever-glorious',
#  'ever-higher',
#  'ever-larger',
#  'ever-present',
#  'ever-ready',
#  'ever-richer',
#  'ever-watchful',
#  'every-day',
#  'everything-including',
#  'evil-disposed',
#  'ex-army',
#  'ex-marines',
#  'ex-officio',
#  'ex-post',
#  'ex-sailors',
#  'ex-service',
#  'ex-soldiers',
#  'experimental-station',
#  'export-import',
#  'export-minded',
#  'extra-territorial',
#  'eye-opening',
#  'eye-witnesses',
#  'fact-finding',
#  'factories-textile',
#  'factory-inspection',
#  'faint-hearted',
#  'fair-headed',
#  'fair-minded',
#  'fair-mindedness',
#  'fake-news',
#  'family-wage',
#  'far-distant',
#  'far-flung',
#  'farmer-controlled',
#  'farmer-managed',
#  'farmer-owned',
#  'fast-spreading',
#  'fastest-growing',
#  'father-land',
#  'fault-finding',
#  'favored-nation',
#  'federal-local',
#  'fee-simple',
#  'feel-good',
#  'fellow-citizen',
#  'fellow-farmer',
#  'fiber-optic',
#  'field-matron',
#  'field-work',
#  'fifty-dollar',
#  'fifty-fifth',
#  'fig-fertilizing',
#  'figure-head',
#  'fine-tuned',
#  'finger-pointing',
#  'fire-arm',
#  'fire-proof',
#  'fireside-chat',
#  'firm-set',
#  'first-hand',
#  'first-responders',
#  'first-year',
#  'five-day',
#  'five-hour',
#  'five-nation',
#  'five-page',
#  'five-point',
#  'five-sixths',
#  'five-star',
#  'five-twenties',
#  'five-year',
#  'fixed-income',
#  'flight-test',
#  'flights-commercial',
#  'flint-lock',
#  'flood-control',
#  'flower-clad',
#  'following-named',
#  'food-stuffs',
#  'foot-steps',
#  'force-force',
#  'fore-fathers',
#  'foreign-born',
#  'foreign-service',
#  'forest-reserve',
#  'forest-reserves',
#  'forty-eighth',
#  'forty-fifth',
#  'forty-ninth',
#  'forward-leaning',
#  'foundation-stone',
#  'four-engine',
#  'four-fifths',
#  'four-hour',
#  'four-point',
#  'four-power',
#  'four-square',
#  'four-star',
#  'four-story',
#  'four-tenths',
#  'four-thirty',
#  'four-word',
#  'four-year',
#  'fourth-class',
#  'free-born',
#  'free-handed',
#  'free-hearted',
#  'free-trade',
#  'freedom-fighters',
#  'freedom-loving',
#  'freeze-frame',
#  'freight-carrying',
#  'freight-rate',
#  'fresh-faced',
#  'front-row',
#  'fuel-efficiency',
#  'fuel-switching',
#  'full-blown',
#  'full-fledged',
#  'full-rounded',
#  'fund-raising',
#  'fur-bearing',
#  'fur-seal',
#  'gang-violence',
#  'generation-long',
#  'gill-net',
#  'go-ahead',
#  'gold-bearing',
#  'gold-standard',
#  'good-bye',
#  'good-hearted',
#  'good-natured',
#  'goose-stepping',
#  'government-national',
#  'government-run',
#  'government-wide',
#  'grain-exporting',
#  'grain-milling',
#  'great-grandchildren',
#  'great-granddaughter',
#  'great-grandfather',
#  'ground-breaking',
#  'ground-launch',
#  'ground-work',
#  'gun-adept',
#  'gun-boat',
#  'gun-boats',
#  'gun-factory',
#  'gun-free',
#  'gun-racks',
#  'gut-wrenching',
#  'hair-splitters',
#  'hair-splitting',
#  'half-billion',
#  'half-breeds',
#  'half-clad',
#  'half-dismes',
#  'half-free',
#  'half-hearted',
#  'half-holidays',
#  'half-mast',
#  'half-million',
#  'half-yearly',
#  'hand-carried',
#  'hand-held',
#  'hand-maiden',
#  'hand-wringing',
#  'harbor-defense',
#  'hard-core',
#  'hard-fought',
#  'hard-nosed',
#  'hard-won',
#  'hardest-working',
#  'have-nots',
#  'havoc-breaking',
#  'health-care',
#  'health-related',
#  'heart-breaking',
#  'heart-throbbing',
#  'heart-warming',
#  'heat-seeking',
#  'hemp-growing',
#  'higgledy-piggledy',
#  'high-handed',
#  'high-minded',
#  'high-powered',
#  'high-priced',
#  'high-skilled',
#  'highest-ranking',
#  'highly-leveraged',
#  'highly-skilled',
#  'hip-hop',
#  'history-making',
#  'home-loan',
#  'home-maker',
#  'home-makers',
#  'horse-trading',
#  'host-nation',
#  'hostage-taking',
#  'hot-headed',
#  'hundred-dollar',
#  'hundred-yard',
#  'hundred-year',
#  'husband-man',
#  'hydrogen-fueled',
#  'hydrogen-powered',
#  'hypo-rhetorical',
#  'ice-free',
#  'ill-advised',
#  'ill-assorted',
#  'ill-balanced',
#  'ill-clad',
#  'ill-concerted',
#  'ill-considered',
#  'ill-defined',
#  'ill-directed',
#  'ill-fitting',
#  'ill-founded',
#  'ill-health',
#  'ill-housed',
#  'ill-informed',
#  'ill-nourished',
#  'ill-prepared',
#  'ill-regulated',
#  'ill-rounded',
#  'ill-suited',
#  'ill-timed',
#  'in-[inaudible',
#  'in-demand',
#  'in-fighting',
#  'in-land',
#  'in-roads',
#  'in-trenched',
#  'income-tax',
#  'independence-loving',
#  'independent-treasury',
#  'inflation-fighting',
#  'influence-economic',
#  'inheritance-tax',
#  'intelligence-sharing',
#  'inter-communication',
#  'inter-fere',
#  'inter-island',
#  'inter-oceanic',
#  'inter-service',
#  'interest-bearing',
#  'intermediate-range',
#  'international-affairs',
#  'interstate-commerce',
#  'interstate-railway',
#  'inward-bound',
#  'jet-age',
#  'job-creation',
#  'job-killing',
#  'job-ready',
#  'job-training',
#  'judge-advocates',
#  'jungle-covered',
#  'justice-justice',
#  'kind-heartedness',
#  'klieg-lights',
#  'l-year',
#  'labor-management',
#  'labor-saving',
#  'laboring-man',
#  'lake-bed',
#  'land-grant',
#  'land-laws',
#  'land-proceeds',
#  'large-handed',
#  'last-mentioned',
#  'latter-mentioned',
#  'latter-named',
#  'law-abiding',
#  'law-enforcement',
#  'law-honesty',
#  'law-maker',
#  'law-makers',
#  'law-making',
#  'law-recommendations',
#  'law-respecting',
#  'leading-edge',
#  'leaf-eating',
#  'leave-taking',
#  'lemon-box',
#  'lend-lease',
#  'less-developed',
#  'less-favored',
#  'less-fortunate',
#  'level-best',
#  'liberal-minded',
#  'liberty-loving',
#  'lieutenant-colonel',
#  'lieutenant-colonels',
#  'lieutenant-commander',
#  'lieutenant-commanders',
#  'lieutenant-general',
#  'lieutenant-governor',
#  'life-blood',
#  'life-enhancing',
#  'life-insurance',
#  'life-long',
#  'life-saving',
#  'life-time',
#  'light-house',
#  'like-minded',
#  'line-item',
#  'lip-service',
#  'listen-let',
#  'little-known',
#  'live-oak',
#  'log-line',
#  'log-rolling',
#  'long-extended',
#  'long-felt',
#  'long-fourteen',
#  'long-overdue',
#  'long-run',
#  'long-subsisting',
#  'long-vexed',
#  'loud-mouthed',
#  'low-carbon',
#  'low-enriched',
#  'low-key',
#  'low-lived',
#  'low-priced',
#  'low-rental',
#  'low-sulfur',
#  'lower-skilled',
#  'lowest-paid',
#  'luxuries-perfumes',
#  'machine-gun',
#  'mail-carrying',
#  'mail-messenger',
#  'mail-order',
#  'make-believe',
#  'make-work',
#  'malaria-related',
#  'man-days',
#  'man-hour',
#  'man-hours',
#  'man-kind',
#  'man-power',
#  'man-stealing',
#  'many-sided',
#  'markets-price',
#  'marriage-penalty',
#  'mass-meeting',
#  'master-race',
#  'mean-spirited',
#  'meat-food',
#  'meat-inspection',
#  'meat-packing',
#  'medium-size',
#  'medium-sized',
#  'merchant-men',
#  'mid-continental',
#  'middle-aged',
#  'middle-class',
#  'middle-ground',
#  'middle-management',
#  'military-supersonic',
#  'mind-meld',
#  'mis-lead',
#  'modern-day',
#  'moisture-laden',
#  'money-changer',
#  'money-order',
#  'mortgage-discount',
#  'most-favored',
#  'motor-car',
#  'movie-goer',
#  'multi-billion',
#  'multi-lateral',
#  'multi-layered',
#  'multi-millionaires',
#  'multi-party',
#  'multibillion-dollar',
#  'multimillion-dollar',
#  'multiple-warhead',
#  'muscle-bound',
#  'narrow-minded',
#  'nation-build',
#  'nation-building',
#  'nation-state',
#  'national-bank',
#  'national-banknotes',
#  'national-defense',
#  'national-park',
#  'nations-allies',
#  'nations-prosperity',
#  'native-born',
#  'naval-defense',
#  'navy-yard',
#  'navy-yards',
#  'nay-sayers',
#  'near-limitless',
#  'near-lost',
#  'near-record',
#  'near-term',
#  'near-universal',
#  'negro-livery',
#  'new-born',
#  'new-found',
#  'new-world',
#  'nice-sized',
#  'nine-point',
#  'nine-rung',
#  'nine-tenths',
#  'ninety-fifth',
#  'ninety-ninth',
#  'no-bid',
#  'no-fly',
#  'no-nonsense',
#  'no-nothingness',
#  'no-progreso',
#  'no-strike',
#  'non-addictive',
#  'non-alcoholic',
#  'non-commissioned',
#  'non-competitive',
#  'non-discriminating',
#  'non-essential',
#  'non-governmental',
#  'non-ideological',
#  'non-intercourse',
#  'non-liquid',
#  'non-member',
#  'non-militarized',
#  'non-military',
#  'non-negotiable',
#  'non-nuclear',
#  'non-partisan',
#  'non-political',
#  'non-professional',
#  'non-public',
#  'non-religious',
#  'non-resident',
#  'non-secular',
#  'non-tidal',
#  'non-violent',
#  'noninterest-bearing',
#  'north-eastern',
#  'north-west',
#  'north-western',
#  'not-emphasizing',
#  'note-takers',
#  'now-deceased',
#  'nuclear-armed',
#  'nuclear-capable',
#  'nuclear-free',
#  'object-lesson',
#  'ocean-borne',
#  'ocean-girt',
#  'ocean-going',
#  'ocean-steamship',
#  'off-duty',
#  'off-limits',
#  'off-ramp',
#  'off-spring',
#  'office-seeker',
#  'ofill-considered',
#  'oft-recurring',
#  'oft-repeated',
#  'oft-stated',
#  'oil-burning',
#  'oil-drilling',
#  'oil-rich',
#  'old-fashioned',
#  'old-named',
#  'on-site',
#  'once-distant',
#  'one-eighteenth',
#  'one-eighth',
#  'one-fifteenth',
#  'one-fifth',
#  'one-fourth',
#  'one-half',
#  'one-hundredth',
#  'one-interest',
#  'one-liners',
#  'one-man',
#  'one-minute',
#  'one-ninth',
#  'one-party',
#  'one-quarter',
#  'one-room',
#  'one-seventh',
#  'one-sided',
#  'one-sixteenth',
#  'one-sixth',
#  'one-story',
#  'one-tenth',
#  'one-term',
#  'one-thirtieth',
#  'one-time',
#  'one-twelfth',
#  'one-way',
#  'one-world',
#  'open-ended',
#  'open-handed',
#  'open-minded',
#  'opioid-related',
#  'opium-exclusion',
#  'opportunity-unreserved',
#  'or-disadvantage',
#  'ordinary-sized',
#  'other-wise',
#  'out-bound',
#  'out-build',
#  'out-commercial',
#  'out-compete',
#  'out-educate',
#  'out-educated',
#  'out-going',
#  'out-gun',
#  'out-innovate',
#  'out-patient',
#  'out-produce',
#  'out-product',
#  'out-right',
#  'out-running',
#  'out-standing',
#  'out-stretched',
#  'out-trade',
#  'out-work',
#  'out-years',
#  'outward-bound',
#  'over-action',
#  'over-anxious',
#  'over-balance',
#  'over-bearing',
#  'over-burdened',
#  'over-capitalization',
#  'over-clouded',
#  'over-crowding',
#  'over-emphasizing',
#  'over-estimates',
#  'over-expansions',
#  'over-exposure',
#  'over-extended',
#  'over-extension',
#  'over-grazed',
#  'over-involvement',
#  'over-issue',
#  'over-issues',
#  'over-long',
#  'over-looked',
#  'over-looking',
#  'over-mastering',
#  'over-night',
#  'over-optimism',
#  'over-planted',
#  'over-powering',
#  'over-privileged',
#  'over-producing',
#  'over-production',
#  'over-rate',
#  'over-rated',
#  'over-reaching',
#  'over-regard',
#  'over-sanguine',
#  'over-simplified',
#  'over-speculation',
#  'over-strained',
#  'over-stressing',
#  'over-subscribed',
#  'over-work',
#  'over-working',
#  'over-zealous',
#  'overdose-reversing',
#  'paper-money',
#  'paper-thin',
#  'para-military',
#  'parcel-post',
#  'parent-teacher',
#  'part-time',
#  'part-way',
#  'pass-book',
#  'pass-key',
#  'pass-keys',
#  'pass-throughs',
#  'path-breaking',
#  'pay-envelope',
#  'peace-keepers',
#  'peace-keeping',
#  'peace-time',
#  'per-child',
#  'percent-adult',
#  'percent-permitting',
#  'performance-enhancing',
#  'pistol-shot',
#  'planned-substantially',
#  'pleuro-pneumonia',
#  'policy-making',
#  'politico-geographical',
#  'poll-takers',
#  'pooh-poohed',
#  'popular-particularly',
#  'post-card',
#  'post-graduate',
#  'post-office',
#  'post-offices',
#  'post-racial',
#  'post-road',
#  'post-roads',
#  'post-route',
#  'post-traumatic',
#  'post-war',
#  'postal-savings',
#  'postal-union',
#  'postmaster-ships',
#  'poverty-stricken',
#  'pre-embryo',
#  'pre-eminence',
#  'pre-eminent',
#  'pre-eminently',
#  'pre-existing',
#  'pre-k',
#  'pre-positioned',
#  'pre-war',
#  'president-elect',
#  'price-depressing',
#  'price-fixing',
#  'price-wage',
#  'print-paper',
#  'prize-men',
#  'pro-civil',
#  'pro-economic',
#  'product-liability',
#  'products-inasmuch',
#  'profit-maker',
#  'profit-sharing',
#  'programs-jobs',
#  'progress-maximum',
#  'progressive-minded',
#  'proposed-simple',
#  'provost-marshals',
#  'pseudo-philanthropy',
#  'pseudo-religions',
#  'public-private',
#  'public-school',
#  'quarter-mile',
#  'quarter-million',
#  'quasi-judicial',
#  'quasi-legislative',
#  'quasi-official',
#  'rah-rah',
#  'rat-hole',
#  'rate-making',
#  're-adopt',
#  're-appearance',
#  're-argument',
#  're-assert',
#  're-corded',
#  're-create',
#  're-creation',
#  're-defined',
#  're-deposit',
#  're-echoed',
#  're-elected',
#  're-eligibility',
#  're-embarked',
#  're-employed',
#  're-employment',
#  're-enact',
#  're-enactment',
#  're-enforced',
#  're-enlist',
#  're-enter',
#  're-entering',
#  're-entry',
#  're-equip',
#  're-establish',
#  're-establishment',
#  're-examination',
#  're-hearings',
#  're-ignite',
#  're-impose',
#  're-imposing',
#  're-investment',
#  're-issue',
#  're-issued',
#  're-open',
#  're-processing',
#  're-read',
#  're-refining',
#  're-settling',
#  're-shipped',
#  're-start',
#  're-think',
#  're-tool',
#  're-transfer',
#  're-written',
#  'rear-admiral',
#  'record-keeping',
#  'red-blooded',
#  'reduced-cost',
#  'regime-controlled',
#  'relation-ships',
#  'rent-payers',
#  'repair-shop',
#  'reports-accelerations',
#  'resources-militarily',
#  'revenue-cutter',
#  'ribbon-cuttings',
#  'rice-growing',
#  'right-minded',
#  'risk-adverse',
#  'risk-taker',
#  'risk-takers',
#  'river-bed',
#  'rock-solid',
#  'rock-waste',
#  'roof-raising',
#  'rose-colored',
#  'round-table',
#  'rubber-check',
#  'rubber-stamp',
#  'rumor-mongers',
#  'sacrifice-faith',
#  'safe-guarded',
#  'safety-appliance',
#  'save-later',
#  'scale-insects',
#  'scandal-mongers',
#  'school-age',
#  'school-teachers',
#  'sea-board',
#  'sea-boards',
#  'sea-borne',
#  'sea-carrying',
#  'sea-coast',
#  'sea-going',
#  'sea-keeping',
#  'sea-level',
#  'sea-vessels',
#  'second-class',
#  'second-guess',
#  'second-guessed',
#  'second-largest',
#  'second-tier',
#  'secondhand-book',
#  'secret-service',
#  'security-security',
#  'self-administering',
#  'self-aggrandizement',
#  'self-chosen',
#  'self-complacency',
#  'self-comprehension',
#  'self-confidence',
#  'self-congratulation',
#  'self-conscious',
#  'self-constituting',
#  'self-constitution',
#  'self-containment',
#  'self-control',
#  'self-correction',
#  'self-critical',
#  'self-criticism',
#  'self-deceit',
#  'self-deception',
#  'self-defence',
#  'self-defense',
#  'self-definition',
#  'self-delusion',
#  'self-denial',
#  'self-denying',
#  'self-destruction',
#  'self-devotion',
#  'self-discipline',
#  'self-education',
#  'self-employed',
#  'self-esteem',
#  'self-evident',
#  'self-examination',
#  'self-executing',
#  'self-expatriation',
#  'self-expression',
#  'self-governing',
#  'self-government',
#  'self-healing',
#  'self-image',
#  'self-improvement',
#  'self-indulgence',
#  'self-indulgent',
#  'self-inspection',
#  'self-interest',
#  'self-interested',
#  'self-interests',
#  'self-liquidating',
#  'self-maintenance',
#  'self-mastery',
#  'self-necessity',
#  'self-pity',
#  'self-possession',
#  'self-preservation',
#  'self-protection',
#  'self-redress',
#  'self-reform',
#  'self-reliant',
#  'self-respect',
#  'self-restraint',
#  'self-righteous',
#  'self-righteousness',
#  'self-rule',
#  'self-sacrifice',
#  'self-sacrificing',
#  'self-satisfaction',
#  'self-seekers',
#  'self-selection',
#  'self-sufficiency',
#  'self-sufficing',
#  'self-support',
#  'semi-arid',
#  'semi-automatic',
#  'semi-barbarous',
#  'semi-civilized',
#  'semi-detached',
#  'semi-independent',
#  'semi-judicial',
#  'semi-luxury',
#  'semi-monthly',
#  'semi-necessities',
#  'semi-necessity',
#  'sensation-mongers',
#  'sentencing-mandatory',
#  'serf-respecting',
#  'service-pension',
#  'set-aside',
#  'set-asides',
#  'set-backs',
#  'set-tier',
#  'seven-eighths',
#  'seven-headed',
#  'seven-point',
#  'seven-thirty',
#  'seventy-eighth',
#  'seventy-fifth',
#  'shadow-boxers',
#  'shaggy-maned',
#  'shell-fish',
#  'ship-building',
#  'ship-canal',
#  'ship-owners',
#  'shop-worn',
#  'short-changed',
#  'short-lived',
#  'side-track',
#  'silver-act',
#  'silver-bearing',
#  'silver-bullion',
#  'silver-coinage',
#  'silver-dollar',
#  'silver-purchasing',
#  'silver-standard',
#  'simple-minded',
#  'single-handed',
#  'single-headed',
#  'single-minded',
#  'sinking-fund',
#  'six-month',
#  'six-party',
#  'six-shooters',
#  'six-tenths',
#  'six-times',
#  'sixty-mile',
#  'slack-water',
#  'slave-dealers',
#  'slave-holder',
#  'slave-holders',
#  'slave-masters',
#  'slave-owners',
#  'slave-trade',
#  'slave-trader',
#  'slow-growing',
#  'small-park',
#  'smoke-screen',
#  'smoking-related',
#  'smoking-tobacco',
#  'smooth-shaven',
#  'so-called',
#  'sober-minded',
#  'society-citizens',
#  'soft-headed',
#  'soldier-voting',
#  'somehow-amid',
#  'someone-wondering',
#  'sorghum-sugar',
#  'sound-good',
#  'special-unsung',
#  'specie-paying',
#  'speech-maker',
#  'spell-check',
#  'spirit-filled',
#  'split-second',
#  'spray-painted',
#  'star-chamber',
#  'star-route',
#  'star-spangled',
#  'starry-eyed',
#  'start-ups',
#  'statesman-politician',
#  'statesmen-authors',
#  'steam-shovel',
#  'steel-mill',
#  'stepping-stone',
#  'stepping-stones',
#  'stir-reliance',
#  'stock-gambling',
#  'stock-holders',
#  'stock-market',
#  'stock-watering',
#  'stop-gap',
#  'stop-press',
#  'straight-backed',
#  'straight-forward',
#  'strait-jacket',
#  'strip-mining',
#  'sub-agencies',
#  'sub-committee',
#  'sub-limited',
#  'subject-matter',
#  'subjects-matter',
#  'submarine-torpedo',
#  'sugar-beet',
#  'sugar-cane',
#  'sugar-producing',
#  'sugar-refining',
#  'sup-port',
#  'super-added',
#  'super-intending',
#  'super-lefts',
#  'super-legislature',
#  'super-rich',
#  ...]

# %% [markdown]
# >> #### 10.3 Prepare token pairs

# %%
hyphen_tokens = sorted(list(set(hyphen_tokens).difference(set(hyphens_after))))
print(len(hyphen_tokens))
hyphen_tokens
# Out:
# 1151
# ['1,500-a-year',
#  '1-day',
#  '1-in-20',
#  '1-yard',
#  '1-year',
#  '1-year-old',
#  '1/2-inch',
#  '1/2-percent',
#  '10,000-foot',
#  '10,000-page',
#  '10,000-ton',
#  '10-day',
#  '10-inch',
#  '10-man',
#  '10-minute',
#  '10-percent',
#  '10-round',
#  '10-to-1',
#  '10-year',
#  '10-year-old',
#  '100-cent',
#  '11-year-old',
#  '12-hour',
#  '12-inch',
#  '12-month',
#  '12-year-old',
#  '122-foot',
#  '122-percent',
#  '13-year-old',
#  '13Ѕ-inch',
#  '14-percent',
#  '14-point',
#  '14-to-1',
#  '14-year',
#  '14-year-old',
#  '15-percent',
#  '15-year-olds',
#  '152-millimeter',
#  '16-inch',
#  '16-inch-type',
#  '16-year-old',
#  '167-page',
#  '17-year',
#  '17-year-low',
#  '17-year-old',
#  '18-hour',
#  '18-nation',
#  '18-percent',
#  '18-wheelers',
#  '18-year-old',
#  '18-year-olds',
#  '180-odd',
#  '19-foot',
#  '19-year-old',
#  '19-year-olds',
#  '190-year',
#  '1970s-era',
#  '19th-century',
#  '2,000-foot',
#  '2,000-mile',
#  '2-in-3',
#  '2-is',
#  '2-minute',
#  '2-percent',
#  '2-year',
#  '2-year-old',
#  '2-year-olds',
#  '20-knot',
#  '20-percent',
#  '20-point',
#  '20-year',
#  '20-year-old',
#  '200-mile',
#  '200-year',
#  '200-year-old',
#  '21st-century',
#  '22,000-word',
#  '22-month',
#  '22-percent',
#  '23-knot',
#  '24-hour',
#  '24-knot',
#  '24-year',
#  '25-percent',
#  '25-year',
#  '250-bed',
#  '26-year-old',
#  '28-minute',
#  '28-percent',
#  '28-square-mile',
#  '3-day',
#  '3-inch',
#  '3-mile',
#  '3-minute',
#  '3-point',
#  '3-to-1',
#  '3-year',
#  '3/4-year',
#  '30-cent',
#  '30-day',
#  '30-minute',
#  '30-odd',
#  '30-percent',
#  '30-second',
#  '30-year',
#  '35-day',
#  '35-hour',
#  '35-percent',
#  '36-percent',
#  '37-point',
#  '3D-print',
#  '3rd-grade',
#  '4-or',
#  '4-percent',
#  '4-point',
#  '4-something',
#  '4-star',
#  '4-year',
#  '4-year-old',
#  '4.8-percent',
#  '40,000-odd',
#  '40-nation',
#  '40-percent',
#  '40-some',
#  '40-yard',
#  '40-year',
#  '45-second',
#  '45-year',
#  '47-year-old',
#  '48-story',
#  '49-year-old',
#  '5-ambulatory',
#  '5-day',
#  '5-letter',
#  '5-percent',
#  '5-power',
#  '5-year',
#  '5-year-old',
#  '50,000-a-year',
#  '50-cent',
#  '50-cent-a-gallon',
#  '50-hour',
#  '50-percent',
#  '50-year',
#  '500-billion',
#  '500-million',
#  '500-per-child',
#  '500-year',
#  '55-mile',
#  '5?-percent',
#  '6-day',
#  '6-inch',
#  '6-month',
#  '6-months',
#  '6-percent',
#  '6-point',
#  '6-pounder',
#  '6-year',
#  '60,000-plus',
#  '60-day',
#  '60-second',
#  '600,000-man',
#  '600-page',
#  '600-percent',
#  '600-ship',
#  '62-year-olders',
#  '65-year',
#  '650-billion-a-year',
#  '7-day',
#  '7-percent',
#  '7-year',
#  '7-year-long',
#  '70-million',
#  '70-percent',
#  '73-percent',
#  '75-bed',
#  '75-page',
#  '75-year-old',
#  '77-percent',
#  '8-inch',
#  '8-year',
#  '8-year-old',
#  '8-year-olds',
#  '800-HELPNOW',
#  '800-some',
#  '81-which',
#  '85-foot',
#  '88-year-old',
#  '9,000-men',
#  '9-foot',
#  '9-hour',
#  '9-millimeter',
#  '9-year-olds',
#  '9.2-percent',
#  '90-day',
#  '90-minute',
#  '90-second',
#  '900,000-$900,000',
#  '91-to-1',
#  '960-acre',
#  'A-11',
#  'A-6F',
#  'A-grade',
#  'A-plus',
#  'ACT-UP',
#  'ADJUTANT-GENERAL',
#  'AIDS-free',
#  'AK-47s',
#  'AMERICA-HONDURAS',
#  'ANTI-TRUST',
#  'ARBITRATIONS-PANAMA',
#  'Adjutant-General',
#  'Administration-Mr',
#  'African-American',
#  'African-Americans',
#  'African-owned',
#  'Ah-h-h',
#  'Aigner-Clark',
#  'Aix-la-Chapelle',
#  'Al-Azhar',
#  'Alaskan-Yukon-Pacific',
#  'All-merciful',
#  'All-powerful',
#  'All-time',
#  'Allies-in',
#  'Alsace-Lorraine',
#  'Amazon-Washington',
#  'Ambassador-Mr',
#  'America-in',
#  'America-the',
#  'American-British',
#  'American-Hellenic',
#  'American-Soviet',
#  'American-born',
#  'American-built',
#  'American-made',
#  'American-mediated',
#  'American-owned',
#  'Americans-to',
#  'Americas-the',
#  'An-tung',
#  'Anglo-Saxon',
#  'Anglo-Venezuelan',
#  'Anti-Trust',
#  'Antung-Mukden',
#  'Apollo-Gemini',
#  'Arab-Israeli',
#  'Armenian-Americans',
#  'As-salaamu',
#  'Asia-Pacific',
#  'Asia-and',
#  'Asia-which',
#  'Asian-American',
#  'Asian-Americans',
#  'Assembly-have',
#  'Atlantic-Mississippi',
#  'Attorney-General',
#  'Attorneys-General',
#  'Austro-Hungarian',
#  'B-1',
#  'B-1B',
#  'B-2',
#  'B-22',
#  'B-29',
#  'B-47',
#  'B-52',
#  'B-l',
#  'BUNAU-VARILLA',
#  'Baltic-Americans',
#  'Band-Aid',
#  'Band-aid',
#  'Berlin-and',
#  'Big-Brother-is-watching-you',
#  'Big-hearted',
#  'Black-owned',
#  'Blue-collar',
#  'Boo-o-o',
#  'Bosnia-wide',
#  'Boutros-Ghali',
#  'Brest-Litovsk',
#  'Briand-Kellogg',
#  'Brigadier-General',
#  'British-American',
#  'Bunau-Varilla',
#  'Bush-McCain',
#  'C-1',
#  'C-SPAN',
#  'C-minus',
#  'CAPITAL-GAINS',
#  'CIVIL-SERVICE',
#  'CONFERENCE-UNFORTUNATE',
#  'CONSULATE-GENERAL',
#  'Cabinet-level',
#  'Cambodian-Vietnam',
#  'Capper-Ketcham',
#  'Capper-Volstead',
#  'Captain-General',
#  'Captain-Generalto',
#  'Carter-Mondale',
#  'Catch-and-release',
#  'Census-we',
#  'Cha-Cha-Cha',
#  'Chamber-the',
#  'Chi-li',
#  'China-U.S.',
#  'Chinchow-Aigun',
#  'Chinese-American',
#  'Chinese-Japanese',
#  'Chinese-made',
#  'Christ-like',
#  'Civil-Service',
#  'Civil-service',
#  'Clayton-Bulwer',
#  'Clear-eyed',
#  'Co-operation',
#  'Coal-land',
#  'Coleman-Singleton',
#  'Columbia-it',
#  'Commander-in-Chief',
#  'Commissary-General',
#  'Commissioner-General',
#  'Communist-controlled',
#  'Communist-directed',
#  'Communist-dominated',
#  'Communist-inspired',
#  'Communist-supplied',
#  'Communist-supported',
#  'Conable-Hanee',
#  'Congo-Adoula',
#  'Congo-Kinshasa',
#  'Congress-and',
#  'Congress-by',
#  'Congress-through',
#  'Consul-General',
#  'Convention-my',
#  'Corps]-type',
#  'Cuban-Soviet',
#  'D-day',
#  'DECISION-MERELY',
#  'Dar-Es-Salaam',
#  'Day-inspector',
#  'Dead-Letter',
#  'Democratic-controlled',
#  'Director-General',
#  'Disarmament-Canada',
#  'Double-digit',
#  'Douglas-Home',
#  'Drug-Free',
#  'E-rate',
#  'EIGHT-HOUR',
#  'ELECTRICAL-POWER',
#  'Earth-based',
#  'East-West',
#  'East-mark',
#  'East-there',
#  'Egypt-Saudi',
#  'Egyptian-Israeli',
#  'Eisenhower-and',
#  'Eisenhower-they',
#  'Elizabeth-City',
#  'Empress-Queen',
#  'English-speaking',
#  'Entente-Allies',
#  'Establishment-this',
#  'Europe-the',
#  'Ex-Corporal',
#  'Export-Import',
#  'Eyre-Cragin',
#  'F-1',
#  'F-14',
#  'F-14s',
#  'F-15',
#  'F-35',
#  'F1a.-there',
#  'FBI-in',
#  'FELLOW-CITIZENS',
#  'FUR-SEAL',
#  'Fair-minded',
#  'Faith-Based',
#  'Faith-based',
#  'Far-reaching',
#  'Farmer-Labor',
#  'Federal-State',
#  'Federal-assisted',
#  'Federal-highway',
#  'Federally-funded',
#  'Fellow-Citizens',
#  'Fellow-Countrymen',
#  'Fellow-citizens',
#  'Fiat-Chrysler',
#  'Fifty-eighth',
#  'Fifty-fifth',
#  'Fifty-four-forty',
#  'Fish-Culture',
#  'Five-Year',
#  'Five-twenties',
#  'Fix-It-First',
#  'Flat-head',
#  'Follow-up',
#  'Foo-Choo-Foo',
#  'Food-for-Peace',
#  'Fordney-McCumber',
#  'Forty-fifth',
#  'Forty-ninth',
#  'Four-Power',
#  'Four-fifths',
#  'Franco-American',
#  'Frankfort-on-the-Main',
#  'Franklin-leaning',
#  'Free-Soilers',
#  'Free-State',
#  'Free-delivery',
#  'Free-market',
#  'G-20',
#  'G-8',
#  'GS-12',
#  'GS-18',
#  'Gall-lard',
#  'Garner-Rainey',
#  'Germany-the',
#  'Germany-voting',
#  'God-awful',
#  'God-blessed',
#  'God-fearing',
#  'God-given',
#  'God-imposed',
#  'Government-improved',
#  'Government-its',
#  'Government-led',
#  'Government-owned',
#  'Government-regulated',
#  'Government-the',
#  'Government-under',
#  'Government-wide',
#  'Governments-Germany',
#  'Governor-General',
#  'Governor-to',
#  'Gramm-Rudman',
#  'Gramm-Rudman-Hollings',
#  'Grant-in-aid',
#  'Greek-Turkish',
#  'H-43',
#  'H-bomb',
#  'HIV-positive',
#  'HOME-LOAN',
#  'Haitian-Americans',
#  'Haitian-Dominican',
#  'Half-hearted',
#  'Hard-headedness',
#  'Harley-Davidson',
#  'Harvard-trained',
#  'Hawaiian-Japanese',
#  'Hawley-Smoot',
#  'Hay-Herran',
#  'Hay-Pauncefote',
#  'Heaven-favored',
#  'Heavy-armed',
#  'Hesse-Darmstadt',
#  'High-ranking',
#  'High-wage',
#  'Hill-Burton',
#  'Hispanic-Americans',
#  'Hiss-Chambers',
#  'Hitler-dominated',
#  'Ho-si-woo',
#  'Hope-renewed',
#  'House-business',
#  'Hsiao-ping',
#  'Hudson-Fulton',
#  'Humphrey-Hawkins',
#  'IA-ECOSOC',
#  'II-has',
#  'III-C',
#  'INTER-AMERICAN',
#  'INTERSTATE-COMMERCE',
#  'Indian-school',
#  'Indo-China',
#  'Indo-Chinese',
#  'Indonesian-Malaysian',
#  'Inspector-General',
#  'Inter-American',
#  'Inter-Departmental',
#  'Intermediate-Range',
#  'Internal-Revenue',
#  'Internal-revenue',
#  'Iran-Iraq',
#  'Iraqi-led',
#  'Irish-American',
#  'Irish-Catholic',
#  'Irish-Protestant',
#  'Israeli-Jordanian',
#  'Israeli-Palestinian',
#  'Italian-Americans',
#  'J-58',
#  'Jackson-Vanik',
#  'Jaish-e-Mohammed',
#  'Japanese-American',
#  'Jefferson-like',
#  'Jewish-Americans',
#  'Job-killing',
#  'Johnson-Humphrey',
#  'Judas-like',
#  'Judge-Advocate-General',
#  'Judge-Advocates',
#  'Kassebaum-Kennedy',
#  'Kellogg-Briand',
#  'Kemp-Roth',
#  'Kennedy-Johnson',
#  'Kennedy-Kassebaum',
#  'Kennedy-McCarthy',
#  'Key-Stone',
#  'Kiao-chow',
#  'Klan-minded',
#  'LATIN-AMERICAN',
#  'LAW-THE',
#  'LIGHT-HOUSE',
#  'LIGHT-HOUSES',
#  'LONG-STANDING',
#  'Labor-Management',
#  'Lakes-St',
#  'Lao-tzu',
#  'Laos-regained',
#  'Large-scale',
#  'Latter-day',
#  'Law-abiding',
#  'Law-clerk',
#  'Lieutenant-Colonel',
#  'Lieutenant-Commander',
#  'Lieutenant-General',
#  'Life-Saving',
#  'Light-House',
#  'Light-houses',
#  'Lincoln\'s-"Let',
#  'Long-term',
#  'Low-income',
#  'Low-tax',
#  'M-1',
#  'MI-8',
#  'MS-13',
#  'Major-General',
#  'Man-of-war',
#  'Manila-Hongkong',
#  'Mansfield-Scott',
#  'Marine-Hospital',
#  'Marquez-Greene',
#  'Marxism-Leninism',
#  'Marxist-Leninism',
#  'Marxist-Leninist',
#  'Marxist-Leninists',
#  'Mason-Dixon',
#  'Mazar-e-Sharif',
#  'McCain-Feingold',
#  'Mecklenburg-Schwerin',
#  'Medicare-approved',
#  'Medicare-rarely',
#  'Meuse-Argonne',
#  'Mid-Atlantic',
#  'Middle-class',
#  'Middleton-Doctor',
#  'Mig-23',
#  'Mm-hmm',
#  'Modern-day',
#  'Money-Order',
#  'Moore-Brown',
#  'Muslim-majority',
#  'Mustering-out',
#  'NAVY-YARDS',
#  'Nation-wide',
#  'Nations-and',
#  'Nations-led',
#  'Navy-Yard',
#  'Nazi-dominated',
#  'Nazi-ism',
#  'Nebraska-Kansas',
#  'New-England',
#  'New-Jersey',
#  'New-Orleans',
#  'New-York',
#  'Night-inspector',
#  'Nine-eleven',
#  'Nixon-16',
#  'Nixon-Ford',
#  'Non-Discrimination',
#  'Non-Proliferation',
#  'Non-intervention',
#  'North-Carolina',
#  'North-South',
#  'North-West',
#  'North-Western',
#  'Nuclear-Test-Ban',
#  'OB-GYN',
#  'Oil-producing',
#  'Old-fashioned',
#  'On-site',
#  'Once-bitter',
#  'One-eighth',
#  'One-fourth',
#  'One-half',
#  'One-third',
#  'Ottoman-born',
#  'P-Tech',
#  'PANAMA-PACIFIC',
#  'POST-OFFICE',
#  'POSTAL-SAVINGS',
#  'PURE-FOOD',
#  'Pacific-cable',
#  'Pago-Pago',
#  'Pakistan-600',
#  'Pan-Amencan',
#  'Pan-American',
#  'Pan-Americanism',
#  'Panama-Pacific',
#  'Paper-covered',
#  'Paymaster-General',
#  'Paymaster-General.3',
#  'Payne-Aldrich',
#  'Pei-Ho',
#  'Peit-sang',
#  'Pent-up',
#  'Peru-Bolivian',
#  'Port-au-Prince',
#  'Post-9/11',
#  'Post-Dispatch',
#  'Post-Office',
#  'Post-OfficeDepartment',
#  'Post-Roads',
#  'Post-office',
#  'Post-offices',
#  'Post-roads',
#  'PostMaster-General',
#  'Postmaster-General',
#  'Postmaster-Generalagainst',
#  'Postmaster-Generals',
#  'Pre-K',
#  'President-Elect',
#  'President-and',
#  'President-as',
#  'President-some',
#  'President-that',
#  'President-to-be',
#  'President-tried',
#  'President-with',
#  'Presidents-President',
#  'Prize-winning',
#  'Provost-Marshal-General',
#  'Qaeda-Iraq',
#  'Quartermaster-General',
#  'R-U',
#  'R-e-g-a-n',
#  'RC-135',
#  'RICA-COLOMBIA',
#  'RS-70',
#  'Ranger-type',
#  'Re-Election',
#  'Re-employment',
#  'Re-enlistment',
#  'Reagan-Bush',
#  'Reagan-Kemp-Roth',
#  'Rear-Admiral',
#  'Revenue-Cutter',
#  'Richmond-based',
#  'Rip-Rap',
#  'Rush-Bagot',
#  'Russo-American',
#  'Russo-Japanese',
#  'SECOND-CLASS',
#  'SELF-DEFENSE',
#  'SEMI-CENTENNIAL',
#  'SLAVE-DEALER',
#  'SR-71',
#  'SR-7I',
#  'SS-18',
#  'SS-20',
#  'SS-20s',
#  'SS-21',
#  'SS-4',
#  'SS-4s',
#  'SS-5',
#  'STABT-Strategic',
#  'Sabbath-Sunday',
#  'Sai-shek',
#  'Sam-whoever',
#  'Saxe-Coburg',
#  'Schleswig-Holstein',
#  'Scotch-Irish',
#  'Scripps-Howard',
#  'Scud-type',
#  'Secret-Service',
#  'Secretary-General',
#  'Secretary-then-Regan',
#  'Self-defense',
#  'Self-determination',
#  'Self-governed',
#  'Self-government',
#  'Self-interest',
#  'Self-preservation',
#  'Self-reliance',
#  'Self-restraint',
#  'Seong-ho',
#  'September-immediately',
#  'Seventy-Fifth',
#  'Shan-tung',
#  'Sheppard-Towner',
#  'Short-term',
#  'Signal-Service',
#  'Simpson-Bowles',
#  'Simpson-Mazzoli',
#  'Sino-American',
#  'Sino-Soviet',
#  'Sixty-eighth',
#  'Slave-Code',
#  'Small-business',
#  'Smoot-Haw',
#  'Solicitor-General',
#  'South-Carolina',
#  'South-west',
#  'Soviet-American',
#  'Soviet-Chinese',
#  'Soviet-Cuban',
#  'Soviet-U.S.',
#  'Soviet-built',
#  'Soviet-made',
#  'Soviet-occupied',
#  'Soviet-sponsored',
#  'Soviet-supported',
#  'Spanish-American',
#  'Spanish-speaking',
#  'Speaker-elect',
#  'Star-Spangled',
#  'Star-Warring',
#  'State-administered',
#  'State-an',
#  'State-bank',
#  'State-controlled',
#  'State-directed',
#  'State-owned',
#  'State-sponsored',
#  'State-supported',
#  'States-Mexican',
#  'States-a',
#  'States-besides',
#  'Steamboat-Inspection',
#  'Sung-pu',
#  'Surgeon-General',
#  'Suz-ahn',
#  'Syrian-backed',
#  'Sze-chuen',
#  'TACNA-ARICA',
#  'Ta-lien-wan',
#  'Tacna-Arica',
#  'Taft-Ellender-Wagner',
#  'Tax-exempt',
#  'Ten-forties',
#  'The-world',
#  'Thirty-eighth',
#  'Thirty-fifth',
#  'Thirty-ninth',
#  'Thomas-Anita',
#  'Three-fourths',
#  'Three-quarters',
#  'Tien-Tsin',
#  'Tien-tsin',
#  'Ting-fang',
#  'To-day',
#  'To-morrow',
#  'Trans-Missouri',
#  'Trans-Pacific',
#  'Trenton-Princeton',
#  'Truman-Acheson',
#  'Trump-Pence',
#  'Tsai-Hsun',
#  'Tsai-tao',
#  'Tse-tung',
#  'Tsing-tao',
#  'Tsung-li',
#  'Twenty-fifth',
#  'Two-thirds',
#  'U-2',
#  'U-Boats',
#  'U-boats',
#  'U.S.-Canadian',
#  'U.S.-Japan',
#  'U.S.-Korea',
#  'U.S.-Mexico',
#  'U.S.-Mexico-Canada',
#  'U.S.-Panamanian',
#  'Ukrainian-Americans',
#  'Union-for',
#  'Union-loving',
#  'Union-men',
#  'Union-saving',
#  'Union-supporting',
#  'V-1',
#  'V-2',
#  'V-J',
#  'V-chip',
#  'Vice-Presidency',
#  'Vice-President',
#  'Vice-Presidential',
#  'Viet-Nam',
#  'Vietnam-and',
#  'Vietnam-apply',
#  'Vietnam-backed',
#  'W-GDP',
#  'Wage-workers',
#  'Wagner-Ellender-Taft',
#  'War-would',
#  'Washington-based',
#  'Web-feet',
#  'Wei-hai-wei',
#  'Well-considered',
#  'Well-founded',
#  'Well-trained',
#  'Western-proposed',
#  'Western-type',
#  'Wilkes-Barre',
#  'X-rated',
#  'Yang-Tse',
#  'Yen-hoon',
#  'Zero-Option',
#  'Zimbabwe-Rhodesia',
#  'across-the-board',
#  'act-$350,000,000',
#  'aid-to-democracies',
#  'air-to-air',
#  'al-Assad',
#  'al-Baghdadi',
#  "al-Qa'ida",
#  'al-Qaeda',
#  'al-Sabah',
#  'al-Suhail',
#  'all-American',
#  'all-Asian',
#  'all-German',
#  'all-Indochina',
#  'all-of-the-above',
#  'all-or-nothing',
#  'anti-American',
#  'anti-Catholic',
#  'anti-Communism',
#  'anti-Communist',
#  'anti-Fascist',
#  'anti-Nazi',
#  'anti-Semitic',
#  'anti-Semitism',
#  'anti-Somoza',
#  'anti-Soviet',
#  'anti-U.S.',
#  'anti-Vietnam',
#  'anti-Washington',
#  'anti-drug-trafficking',
#  'arm-in-arm',
#  'arms-Mother',
#  'attack,-dangers',
#  'back-and-forth',
#  'back-to-back',
#  'back-to-school',
#  'balance-of-payments',
#  'behind-the-scenes',
#  'black-and-white',
#  'brothers-in-arms',
#  "bull's-eye",
#  'business-I',
#  'cap-and-trade',
#  'case-by-case',
#  'catch-22',
#  'catch-and-release',
#  'cities-America',
#  'cities-Rome',
#  'co-States',
#  'coal-I',
#  'command-and-control',
#  'commander-in-chief',
#  'comrades-in-arms',
#  'cost-of-living',
#  'cost-plus-fixed',
#  'cross-Channel',
#  'cross-examination-type',
#  'cut-three-quarters',
#  'day-General',
#  'day-by-day',
#  'day-to-day',
#  "de-Ba'athification",
#  'de-Baathification',
#  'delegation-Admiral',
#  'devil-take-the-hind-most',
#  'dime-by-dime',
#  'do-gooders',
#  'do-it-yourself',
#  'do-or-die',
#  'door-to-door',
#  'down-the-middle',
#  'down-to-earth',
#  'eight-year-old',
#  'elbow-to-elbow',
#  "employer's-liability",
#  'end-of-the-year',
#  'every-4-year',
#  'ex-Bashaw',
#  'ex-Corporal',
#  'ex-GI',
#  'ex-President',
#  'ex-Senator',
#  'ex-Union',
#  'eye-and-a-half',
#  'face-to-face',
#  'faint-heartedly',
#  'farm-to-market',
#  'farnorth-west',
#  'fellow-citizensa',
#  'fellow-citizensin',
#  'fifteen-foldwithin',
#  'five-and-a-half',
#  'five-day-old',
#  'five-to-four',
#  'flat-to-deteriorating',
#  'follow-the-leader',
#  'four-and-a-half',
#  'four-year-old',
#  'fourteen-thousand-mile',
#  'fox-guarding-the-henhouse',
#  'free-for-all',
#  'get-11.4',
#  'get-rich-quick',
#  'girl-Tricia',
#  'give-and-take',
#  'good-for-nothing',
#  'grants-in-aid',
#  'ground-to-air',
#  'ground-to-ground',
#  'gur-reat',
#  'half-a-billion',
#  'half-an-eye',
#  'half-and-half',
#  'happy-go-lucky',
#  'hard-and-fast',
#  'history–-157',
#  'hit-and-run',
#  'holier-than-thou',
#  'horse-and-buggy',
#  'hour-by-hour',
#  'house-to-house',
#  "however-I'm",
#  'ibn-Khaldun',
#  'in-State',
#  'industry-by-industry',
#  'inter-American',
#  'inter-State',
#  'intra-German',
#  'involved-I',
#  'involved-Israel',
#  'item-by-item',
#  'killed-in-action',
#  'late-1970',
#  'life-and-death',
#  'line-by-line',
#  'line-of-battle',
#  'majority-Republican',
#  'man-at-arms',
#  'man-of-war',
#  'man-of-warsman',
#  'man-to-man',
#  'matter-of-course',
#  'men-of-war',
#  'merry-go-round',
#  "mid-'60s",
#  'mid-2030s',
#  'mid-April',
#  'mid-December',
#  'mid-July',
#  'mid-Pacific',
#  'military-Army',
#  'million-and-a-half-dollar',
#  'money,-expenditures',
#  'month-by-month',
#  'month-to-month',
#  'most-favored-nation',
#  'most-favored-nations',
#  'mother-in-law',
#  'mother-to-child',
#  'name-J.',
#  'navy-yards15,283,437.17For',
#  'navy-yards17,292,601.44For',
#  'navy-yards21,249,809.99For',
#  'navy-yards4,199,299.6912,300,700.31For',
#  'necessity-I',
#  'never-to-be-neglected',
#  'nice-to-have',
#  'nine-year-old',
#  'nominee-to-be',
#  'non-African-Americans',
#  'non-American',
#  'non-Arabs',
#  'non-British',
#  'non-Catholic',
#  'non-Catholics',
#  'non-Communist',
#  'non-European',
#  'non-Indian',
#  'non-Marxist',
#  ...]

# %% [markdown]
# >> #### 11.1 Problem: Some hyphen words are not valid words or contain extra words without space

# %%
pattern = '^[a-z]+-[^-A-Z0-9]+$'
hyphens_before = [re.search(pattern, token)[0] for token in hyphen_tokens if re.search(pattern, token)]
hyphens_before
# Out:
# ['do-gooders',
#  'faint-heartedly',
#  'farnorth-west',
#  'fellow-citizensa',
#  'fellow-citizensin',
#  'fifteen-foldwithin',
#  'gur-reat',
#  'one-hoss',
#  'post-poned',
#  'progress-alianza',
#  'pur-rinciple',
#  'self-goverment',
#  'self-governmentthroughout',
#  'self-sacrificingpatriotism',
#  'thirty-eightpopulous',
#  'twenty-fiveyears',
#  'war-makingpower',
#  'well-disciplinedand',
#  'well-informedpersons',
#  'whole-heartedly']

# %% [markdown]
# >> #### 11.2 Solution: Remove some words and update clean dictionary

# %%
# Update hyphen tokens
clean_dict['farnorth-west'] = 'far north-west'
clean_dict['fellow-citizensa'] = 'fellow-citizens a'
clean_dict['fellow-citizensin'] = 'fellow-citizens in'
clean_dict['fifteen-foldwithin'] = 'fifteen-fold within'
clean_dict['self-governmentthroughout'] = 'self-government throughout'
clean_dict['self-sacrificingpatriotism'] = 'self-sacrificing patriotism'
clean_dict['thirty-eightpopulous'] = 'thirty-eight populous'
clean_dict['twenty-fiveyears'] = 'twenty-five years'
clean_dict['war-makingpower'] = 'war-making power'
clean_dict['well-disciplinedand'] = 'well-disciplined and'
clean_dict['well-informedpersons'] = 'well-informed persons'

# %% [markdown]
# >> #### 11.3 Prepare token pairs

# %%
hyphen_tokens = sorted(list(set(hyphen_tokens).difference(set(hyphens_before))))
print(len(hyphen_tokens))
# Out:
# 1131

# %% [markdown]
# >> #### 12.1 Problem: Some tokens have hyphens between capitalized words and stopwords

# %%
pattern = '^[A-Z][a-z]+-[^-A-Z0-9]+$'
hyphens_before = [re.search(pattern, token)[0] for token in hyphen_tokens if re.search(pattern, token)]
hyphens_before
# Out:
# ['African-owned',
#  'All-merciful',
#  'All-powerful',
#  'All-time',
#  'Allies-in',
#  'America-in',
#  'America-the',
#  'American-born',
#  'American-built',
#  'American-made',
#  'American-mediated',
#  'American-owned',
#  'Americans-to',
#  'Americas-the',
#  'An-tung',
#  'As-salaamu',
#  'Asia-and',
#  'Asia-which',
#  'Assembly-have',
#  'Band-aid',
#  'Berlin-and',
#  'Big-hearted',
#  'Black-owned',
#  'Blue-collar',
#  'Bosnia-wide',
#  'Cabinet-level',
#  'Census-we',
#  'Chamber-the',
#  'Chi-li',
#  'Chinese-made',
#  'Christ-like',
#  'Civil-service',
#  'Clear-eyed',
#  'Co-operation',
#  'Coal-land',
#  'Columbia-it',
#  'Communist-controlled',
#  'Communist-directed',
#  'Communist-dominated',
#  'Communist-inspired',
#  'Communist-supplied',
#  'Communist-supported',
#  'Congress-and',
#  'Congress-by',
#  'Congress-through',
#  'Convention-my',
#  'Day-inspector',
#  'Democratic-controlled',
#  'Double-digit',
#  'Earth-based',
#  'East-mark',
#  'East-there',
#  'Eisenhower-and',
#  'Eisenhower-they',
#  'English-speaking',
#  'Establishment-this',
#  'Europe-the',
#  'Fair-minded',
#  'Faith-based',
#  'Far-reaching',
#  'Federal-assisted',
#  'Federal-highway',
#  'Federally-funded',
#  'Fellow-citizens',
#  'Fifty-eighth',
#  'Fifty-fifth',
#  'Five-twenties',
#  'Flat-head',
#  'Follow-up',
#  'Forty-fifth',
#  'Forty-ninth',
#  'Four-fifths',
#  'Franklin-leaning',
#  'Free-delivery',
#  'Free-market',
#  'Gall-lard',
#  'Germany-the',
#  'Germany-voting',
#  'God-awful',
#  'God-blessed',
#  'God-fearing',
#  'God-given',
#  'God-imposed',
#  'Government-improved',
#  'Government-its',
#  'Government-led',
#  'Government-owned',
#  'Government-regulated',
#  'Government-the',
#  'Government-under',
#  'Government-wide',
#  'Governor-to',
#  'Half-hearted',
#  'Hard-headedness',
#  'Harvard-trained',
#  'Heaven-favored',
#  'Heavy-armed',
#  'High-ranking',
#  'High-wage',
#  'Hitler-dominated',
#  'Hope-renewed',
#  'House-business',
#  'Hsiao-ping',
#  'Indian-school',
#  'Internal-revenue',
#  'Iraqi-led',
#  'Jefferson-like',
#  'Job-killing',
#  'Judas-like',
#  'Kiao-chow',
#  'Klan-minded',
#  'Lao-tzu',
#  'Laos-regained',
#  'Large-scale',
#  'Latter-day',
#  'Law-abiding',
#  'Law-clerk',
#  'Light-houses',
#  'Long-term',
#  'Low-income',
#  'Low-tax',
#  'Medicare-approved',
#  'Medicare-rarely',
#  'Middle-class',
#  'Mm-hmm',
#  'Modern-day',
#  'Muslim-majority',
#  'Mustering-out',
#  'Nation-wide',
#  'Nations-and',
#  'Nations-led',
#  'Nazi-dominated',
#  'Nazi-ism',
#  'Night-inspector',
#  'Nine-eleven',
#  'Non-intervention',
#  'Oil-producing',
#  'Old-fashioned',
#  'On-site',
#  'Once-bitter',
#  'One-eighth',
#  'One-fourth',
#  'One-half',
#  'One-third',
#  'Ottoman-born',
#  'Pacific-cable',
#  'Paper-covered',
#  'Peit-sang',
#  'Pent-up',
#  'Post-office',
#  'Post-offices',
#  'Post-roads',
#  'President-and',
#  'President-as',
#  'President-some',
#  'President-that',
#  'President-tried',
#  'President-with',
#  'Prize-winning',
#  'Ranger-type',
#  'Re-employment',
#  'Re-enlistment',
#  'Richmond-based',
#  'Sai-shek',
#  'Sam-whoever',
#  'Scud-type',
#  'Self-defense',
#  'Self-determination',
#  'Self-governed',
#  'Self-government',
#  'Self-interest',
#  'Self-preservation',
#  'Self-reliance',
#  'Self-restraint',
#  'Seong-ho',
#  'September-immediately',
#  'Shan-tung',
#  'Short-term',
#  'Sixty-eighth',
#  'Small-business',
#  'South-west',
#  'Soviet-built',
#  'Soviet-made',
#  'Soviet-occupied',
#  'Soviet-sponsored',
#  'Soviet-supported',
#  'Spanish-speaking',
#  'Speaker-elect',
#  'State-administered',
#  'State-an',
#  'State-bank',
#  'State-controlled',
#  'State-directed',
#  'State-owned',
#  'State-sponsored',
#  'State-supported',
#  'States-a',
#  'States-besides',
#  'Sung-pu',
#  'Suz-ahn',
#  'Syrian-backed',
#  'Sze-chuen',
#  'Tax-exempt',
#  'Ten-forties',
#  'The-world',
#  'Thirty-eighth',
#  'Thirty-fifth',
#  'Thirty-ninth',
#  'Three-fourths',
#  'Three-quarters',
#  'Tien-tsin',
#  'Ting-fang',
#  'To-day',
#  'To-morrow',
#  'Tsai-tao',
#  'Tse-tung',
#  'Tsing-tao',
#  'Tsung-li',
#  'Twenty-fifth',
#  'Two-thirds',
#  'Union-for',
#  'Union-loving',
#  'Union-men',
#  'Union-saving',
#  'Union-supporting',
#  'Vietnam-and',
#  'Vietnam-apply',
#  'Vietnam-backed',
#  'Wage-workers',
#  'War-would',
#  'Washington-based',
#  'Web-feet',
#  'Well-considered',
#  'Well-founded',
#  'Well-trained',
#  'Western-proposed',
#  'Western-type',
#  'Yen-hoon']

# %% [markdown]
# >> #### 12.2 Solution: Remove hyphens between capitalized words and stopwords

# %%
hyphens_after = [token.replace('-', ' ') for token in hyphens_before if token.split('-')[-1] in STOP_WORDS]
hyphens_after
# Out:
# ['Allies in',
#  'America in',
#  'America the',
#  'American made',
#  'Americans to',
#  'Americas the',
#  'Asia and',
#  'Asia which',
#  'Assembly have',
#  'Berlin and',
#  'Census we',
#  'Chamber the',
#  'Chinese made',
#  'Columbia it',
#  'Congress and',
#  'Congress by',
#  'Congress through',
#  'Convention my',
#  'East there',
#  'Eisenhower and',
#  'Eisenhower they',
#  'Establishment this',
#  'Europe the',
#  'Follow up',
#  'Germany the',
#  'Government its',
#  'Government the',
#  'Government under',
#  'Governor to',
#  'Mustering out',
#  'Nations and',
#  'Nine eleven',
#  'One third',
#  'Pent up',
#  'President and',
#  'President as',
#  'President some',
#  'President that',
#  'President with',
#  'Sam whoever',
#  'Soviet made',
#  'State an',
#  'States a',
#  'States besides',
#  'Union for',
#  'Vietnam and',
#  'War would']

# %% [markdown]
# >> #### 12.3 Prepare token pairs and update dictionary

# %%
# Zip pairs into before and after tuples
hyphens = list(zip(hyphens_before, hyphens_after))

# Update dictionary and hyphen tokens
clean_dict = update_dict(clean_dict, hyphens)
hyphen_tokens = [token for token in hyphen_tokens if token not in clean_dict]

# %%
len(hyphen_tokens)
# Out:
# 1084

# %% [markdown]
# >> #### 13.1 Problem: Some tokens both words capitalized are valid words while others are not

# %%
pattern = '^[A-Z][a-z]+-[A-Z][a-z]+$'
hyphens_before = [re.search(pattern, token)[0] for token in hyphen_tokens if re.search(pattern, token)]
hyphens_before
# Out:
# ['Adjutant-General',
#  'Administration-Mr',
#  'African-American',
#  'African-Americans',
#  'Aigner-Clark',
#  'Al-Azhar',
#  'Alsace-Lorraine',
#  'Amazon-Washington',
#  'Ambassador-Mr',
#  'American-British',
#  'American-Hellenic',
#  'American-Soviet',
#  'Anglo-Saxon',
#  'Anglo-Venezuelan',
#  'Anti-Trust',
#  'Antung-Mukden',
#  'Apollo-Gemini',
#  'Arab-Israeli',
#  'Armenian-Americans',
#  'Asia-Pacific',
#  'Asian-American',
#  'Asian-Americans',
#  'Atlantic-Mississippi',
#  'Attorney-General',
#  'Attorneys-General',
#  'Austro-Hungarian',
#  'Baltic-Americans',
#  'Band-Aid',
#  'Boutros-Ghali',
#  'Brest-Litovsk',
#  'Briand-Kellogg',
#  'Brigadier-General',
#  'British-American',
#  'Bunau-Varilla',
#  'Cambodian-Vietnam',
#  'Capper-Ketcham',
#  'Capper-Volstead',
#  'Captain-General',
#  'Captain-Generalto',
#  'Carter-Mondale',
#  'Chinchow-Aigun',
#  'Chinese-American',
#  'Chinese-Japanese',
#  'Civil-Service',
#  'Clayton-Bulwer',
#  'Coleman-Singleton',
#  'Commissary-General',
#  'Commissioner-General',
#  'Conable-Hanee',
#  'Congo-Adoula',
#  'Congo-Kinshasa',
#  'Consul-General',
#  'Cuban-Soviet',
#  'Dead-Letter',
#  'Director-General',
#  'Disarmament-Canada',
#  'Douglas-Home',
#  'Drug-Free',
#  'East-West',
#  'Egypt-Saudi',
#  'Egyptian-Israeli',
#  'Elizabeth-City',
#  'Empress-Queen',
#  'Entente-Allies',
#  'Ex-Corporal',
#  'Export-Import',
#  'Eyre-Cragin',
#  'Faith-Based',
#  'Farmer-Labor',
#  'Federal-State',
#  'Fellow-Citizens',
#  'Fellow-Countrymen',
#  'Fiat-Chrysler',
#  'Fish-Culture',
#  'Five-Year',
#  'Four-Power',
#  'Franco-American',
#  'Free-Soilers',
#  'Free-State',
#  'Garner-Rainey',
#  'Governments-Germany',
#  'Governor-General',
#  'Gramm-Rudman',
#  'Greek-Turkish',
#  'Haitian-Americans',
#  'Haitian-Dominican',
#  'Harley-Davidson',
#  'Hawaiian-Japanese',
#  'Hawley-Smoot',
#  'Hay-Herran',
#  'Hay-Pauncefote',
#  'Hesse-Darmstadt',
#  'Hill-Burton',
#  'Hispanic-Americans',
#  'Hiss-Chambers',
#  'Hudson-Fulton',
#  'Humphrey-Hawkins',
#  'Indo-China',
#  'Indo-Chinese',
#  'Indonesian-Malaysian',
#  'Inspector-General',
#  'Inter-American',
#  'Inter-Departmental',
#  'Intermediate-Range',
#  'Internal-Revenue',
#  'Iran-Iraq',
#  'Irish-American',
#  'Irish-Catholic',
#  'Irish-Protestant',
#  'Israeli-Jordanian',
#  'Israeli-Palestinian',
#  'Italian-Americans',
#  'Jackson-Vanik',
#  'Japanese-American',
#  'Jewish-Americans',
#  'Johnson-Humphrey',
#  'Judge-Advocates',
#  'Kassebaum-Kennedy',
#  'Kellogg-Briand',
#  'Kemp-Roth',
#  'Kennedy-Johnson',
#  'Kennedy-Kassebaum',
#  'Key-Stone',
#  'Labor-Management',
#  'Lakes-St',
#  'Lieutenant-Colonel',
#  'Lieutenant-Commander',
#  'Lieutenant-General',
#  'Life-Saving',
#  'Light-House',
#  'Major-General',
#  'Manila-Hongkong',
#  'Mansfield-Scott',
#  'Marine-Hospital',
#  'Marquez-Greene',
#  'Marxism-Leninism',
#  'Marxist-Leninism',
#  'Marxist-Leninist',
#  'Marxist-Leninists',
#  'Mason-Dixon',
#  'Mecklenburg-Schwerin',
#  'Meuse-Argonne',
#  'Mid-Atlantic',
#  'Middleton-Doctor',
#  'Money-Order',
#  'Moore-Brown',
#  'Navy-Yard',
#  'Nebraska-Kansas',
#  'New-England',
#  'New-Jersey',
#  'New-Orleans',
#  'New-York',
#  'Nixon-Ford',
#  'Non-Discrimination',
#  'Non-Proliferation',
#  'North-Carolina',
#  'North-South',
#  'North-West',
#  'North-Western',
#  'Pago-Pago',
#  'Pan-Amencan',
#  'Pan-American',
#  'Pan-Americanism',
#  'Panama-Pacific',
#  'Paymaster-General',
#  'Payne-Aldrich',
#  'Pei-Ho',
#  'Peru-Bolivian',
#  'Post-Dispatch',
#  'Post-Office',
#  'Post-Roads',
#  'Postmaster-General',
#  'Postmaster-Generalagainst',
#  'Postmaster-Generals',
#  'President-Elect',
#  'Presidents-President',
#  'Qaeda-Iraq',
#  'Quartermaster-General',
#  'Re-Election',
#  'Reagan-Bush',
#  'Rear-Admiral',
#  'Revenue-Cutter',
#  'Rip-Rap',
#  'Rush-Bagot',
#  'Russo-American',
#  'Russo-Japanese',
#  'Sabbath-Sunday',
#  'Saxe-Coburg',
#  'Schleswig-Holstein',
#  'Scotch-Irish',
#  'Scripps-Howard',
#  'Secret-Service',
#  'Secretary-General',
#  'Seventy-Fifth',
#  'Sheppard-Towner',
#  'Signal-Service',
#  'Simpson-Bowles',
#  'Simpson-Mazzoli',
#  'Sino-American',
#  'Sino-Soviet',
#  'Slave-Code',
#  'Smoot-Haw',
#  'Solicitor-General',
#  'South-Carolina',
#  'Soviet-American',
#  'Soviet-Chinese',
#  'Soviet-Cuban',
#  'Spanish-American',
#  'Star-Spangled',
#  'Star-Warring',
#  'States-Mexican',
#  'Steamboat-Inspection',
#  'Surgeon-General',
#  'Tacna-Arica',
#  'Thomas-Anita',
#  'Tien-Tsin',
#  'Trans-Missouri',
#  'Trans-Pacific',
#  'Trenton-Princeton',
#  'Truman-Acheson',
#  'Trump-Pence',
#  'Tsai-Hsun',
#  'Ukrainian-Americans',
#  'Vice-Presidency',
#  'Vice-President',
#  'Vice-Presidential',
#  'Viet-Nam',
#  'Wilkes-Barre',
#  'Yang-Tse',
#  'Zero-Option',
#  'Zimbabwe-Rhodesia']

# %% [markdown]
# >> #### 13.2 Solution: Remove invalid tokens with both words capitalized

# %%
tokens_to_clean_before = [token for token in hyphens_before if 'Mr' in token or 'Bob' in token]
tokens_to_clean_after = [token.replace('-', ' ') for token in tokens_to_clean_before]

# %% [markdown]
# >> #### 13.3 Prepare token pairs and update dictionary

# %%
# Update dictionary
for tup in list(zip(tokens_to_clean_before, tokens_to_clean_after)):
    clean_dict[tup[0]] = tup[1]
    
# Filter out cleaned tokens
hyphen_tokens = sorted(list(set(hyphen_tokens).difference(set(hyphens_before))))
print(len(hyphen_tokens))
# Out:
# 853

# %% [markdown]
# >> #### 14.1 Problem: Some tokens with first word capitalized have second word as stopwords

# %%
pattern = '^[A-Z][a-z]+-[a-z]+$'
hyphens_before = [re.search(pattern, token)[0] for token in hyphen_tokens if re.search(pattern, token)]
hyphens_before
# Out:
# ['Democratic-controlled',
#  'Double-digit',
#  'Earth-based',
#  'East-mark',
#  'East-there',
#  'Eisenhower-and',
#  'Eisenhower-they',
#  'English-speaking',
#  'Establishment-this',
#  'Europe-the',
#  'Fair-minded',
#  'Faith-based',
#  'Far-reaching',
#  'Federal-assisted',
#  'Federal-highway',
#  'Federally-funded',
#  'Fellow-citizens',
#  'Fifty-eighth',
#  'Fifty-fifth',
#  'Five-twenties',
#  'Flat-head',
#  'Follow-up',
#  'Forty-fifth',
#  'Forty-ninth',
#  'Four-fifths',
#  'Franklin-leaning',
#  'Free-delivery',
#  'Free-market',
#  'Gall-lard',
#  'Germany-the',
#  'Germany-voting',
#  'God-awful',
#  'God-blessed',
#  'God-fearing',
#  'God-given',
#  'God-imposed',
#  'Government-improved',
#  'Government-its',
#  'Government-led',
#  'Government-owned',
#  'Government-regulated',
#  'Government-the',
#  'Government-under',
#  'Government-wide',
#  'Governor-to',
#  'Half-hearted',
#  'Hard-headedness',
#  'Harvard-trained',
#  'Heaven-favored',
#  'Heavy-armed',
#  'High-ranking',
#  'High-wage',
#  'Hitler-dominated',
#  'Hope-renewed',
#  'House-business',
#  'Hsiao-ping',
#  'Indian-school',
#  'Internal-revenue',
#  'Iraqi-led',
#  'Jefferson-like',
#  'Job-killing',
#  'Judas-like',
#  'Kiao-chow',
#  'Klan-minded',
#  'Lao-tzu',
#  'Laos-regained',
#  'Large-scale',
#  'Latter-day',
#  'Law-abiding',
#  'Law-clerk',
#  'Light-houses',
#  'Long-term',
#  'Low-income',
#  'Low-tax',
#  'Medicare-approved',
#  'Medicare-rarely',
#  'Middle-class',
#  'Mm-hmm',
#  'Modern-day',
#  'Muslim-majority',
#  'Mustering-out',
#  'Nation-wide',
#  'Nations-and',
#  'Nations-led',
#  'Nazi-dominated',
#  'Nazi-ism',
#  'Night-inspector',
#  'Nine-eleven',
#  'Non-intervention',
#  'Oil-producing',
#  'Old-fashioned',
#  'On-site',
#  'Once-bitter',
#  'One-eighth',
#  'One-fourth',
#  'One-half',
#  'One-third',
#  'Ottoman-born',
#  'Pacific-cable',
#  'Paper-covered',
#  'Peit-sang',
#  'Pent-up',
#  'Post-office',
#  'Post-offices',
#  'Post-roads',
#  'President-and',
#  'President-as',
#  'President-some',
#  'President-that',
#  'President-tried',
#  'President-with',
#  'Prize-winning',
#  'Ranger-type',
#  'Re-employment',
#  'Re-enlistment',
#  'Richmond-based',
#  'Sai-shek',
#  'Sam-whoever',
#  'Scud-type',
#  'Self-defense',
#  'Self-determination',
#  'Self-governed',
#  'Self-government',
#  'Self-interest',
#  'Self-preservation',
#  'Self-reliance',
#  'Self-restraint',
#  'Seong-ho',
#  'September-immediately',
#  'Shan-tung',
#  'Short-term',
#  'Sixty-eighth',
#  'Small-business',
#  'South-west',
#  'Soviet-built',
#  'Soviet-made',
#  'Soviet-occupied',
#  'Soviet-sponsored',
#  'Soviet-supported',
#  'Spanish-speaking',
#  'Speaker-elect',
#  'State-administered',
#  'State-an',
#  'State-bank',
#  'State-controlled',
#  'State-directed',
#  'State-owned',
#  'State-sponsored',
#  'State-supported',
#  'States-a',
#  'States-besides',
#  'Sung-pu',
#  'Suz-ahn',
#  'Syrian-backed',
#  'Sze-chuen',
#  'Tax-exempt',
#  'Ten-forties',
#  'The-world',
#  'Thirty-eighth',
#  'Thirty-fifth',
#  'Thirty-ninth',
#  'Three-fourths',
#  'Three-quarters',
#  'Tien-tsin',
#  'Ting-fang',
#  'To-day',
#  'To-morrow',
#  'Tsai-tao',
#  'Tse-tung',
#  'Tsing-tao',
#  'Tsung-li',
#  'Twenty-fifth',
#  'Two-thirds',
#  'Union-for',
#  'Union-loving',
#  'Union-men',
#  'Union-saving',
#  'Union-supporting',
#  'Vietnam-and',
#  'Vietnam-apply',
#  'Vietnam-backed',
#  'Wage-workers',
#  'War-would',
#  'Washington-based',
#  'Web-feet',
#  'Well-considered',
#  'Well-founded',
#  'Well-trained',
#  'Western-proposed',
#  'Western-type',
#  'Yen-hoon']

# %%
hyphens_before = [token for token in hyphens_before if token.split('-')[-1] in STOP_WORDS]
hyphens_before
# Out:
# ['East-there',
#  'Eisenhower-and',
#  'Eisenhower-they',
#  'Establishment-this',
#  'Europe-the',
#  'Follow-up',
#  'Germany-the',
#  'Government-its',
#  'Government-the',
#  'Government-under',
#  'Governor-to',
#  'Mustering-out',
#  'Nations-and',
#  'Nine-eleven',
#  'One-third',
#  'Pent-up',
#  'President-and',
#  'President-as',
#  'President-some',
#  'President-that',
#  'President-with',
#  'Sam-whoever',
#  'Soviet-made',
#  'State-an',
#  'States-a',
#  'States-besides',
#  'Union-for',
#  'Vietnam-and',
#  'War-would']

# %% [markdown]
# >> #### 14.2 Solution: Remove tokens with first word capitalized have second word as stopwords

# %%
hyphens_after = [token.replace('-', ' ') for token in hyphens_before]
hyphens_after
# Out:
# ['East there',
#  'Eisenhower and',
#  'Eisenhower they',
#  'Establishment this',
#  'Europe the',
#  'Follow up',
#  'Germany the',
#  'Government its',
#  'Government the',
#  'Government under',
#  'Governor to',
#  'Mustering out',
#  'Nations and',
#  'Nine eleven',
#  'One third',
#  'Pent up',
#  'President and',
#  'President as',
#  'President some',
#  'President that',
#  'President with',
#  'Sam whoever',
#  'Soviet made',
#  'State an',
#  'States a',
#  'States besides',
#  'Union for',
#  'Vietnam and',
#  'War would']

# %% [markdown]
# >> #### 14.3 Prepare token pairs and update dictionary

# %%
# Zip pairs into before and after tuples
hyphens = list(zip(hyphens_before, hyphens_after))

# Update dictionary and hyphen tokens
clean_dict = update_dict(clean_dict, hyphens)
hyphen_tokens = [token for token in hyphen_tokens if token not in clean_dict]

# %% [markdown]
# >> #### 15.1 Problem: Some hyphen tokens with first word capitalized are not valid sayings

# %%
pattern = '^[A-Z][a-z]+-[a-z]+$'
hyphens_before = [re.search(pattern, token)[0] for token in hyphen_tokens if re.search(pattern, token)]
hyphens_before
# Out:
# ['Democratic-controlled',
#  'Double-digit',
#  'Earth-based',
#  'East-mark',
#  'English-speaking',
#  'Fair-minded',
#  'Faith-based',
#  'Far-reaching',
#  'Federal-assisted',
#  'Federal-highway',
#  'Federally-funded',
#  'Fellow-citizens',
#  'Fifty-eighth',
#  'Fifty-fifth',
#  'Five-twenties',
#  'Flat-head',
#  'Forty-fifth',
#  'Forty-ninth',
#  'Four-fifths',
#  'Franklin-leaning',
#  'Free-delivery',
#  'Free-market',
#  'Gall-lard',
#  'Germany-voting',
#  'God-awful',
#  'God-blessed',
#  'God-fearing',
#  'God-given',
#  'God-imposed',
#  'Government-improved',
#  'Government-led',
#  'Government-owned',
#  'Government-regulated',
#  'Government-wide',
#  'Half-hearted',
#  'Hard-headedness',
#  'Harvard-trained',
#  'Heaven-favored',
#  'Heavy-armed',
#  'High-ranking',
#  'High-wage',
#  'Hitler-dominated',
#  'Hope-renewed',
#  'House-business',
#  'Hsiao-ping',
#  'Indian-school',
#  'Internal-revenue',
#  'Iraqi-led',
#  'Jefferson-like',
#  'Job-killing',
#  'Judas-like',
#  'Kiao-chow',
#  'Klan-minded',
#  'Lao-tzu',
#  'Laos-regained',
#  'Large-scale',
#  'Latter-day',
#  'Law-abiding',
#  'Law-clerk',
#  'Light-houses',
#  'Long-term',
#  'Low-income',
#  'Low-tax',
#  'Medicare-approved',
#  'Medicare-rarely',
#  'Middle-class',
#  'Mm-hmm',
#  'Modern-day',
#  'Muslim-majority',
#  'Nation-wide',
#  'Nations-led',
#  'Nazi-dominated',
#  'Nazi-ism',
#  'Night-inspector',
#  'Non-intervention',
#  'Oil-producing',
#  'Old-fashioned',
#  'On-site',
#  'Once-bitter',
#  'One-eighth',
#  'One-fourth',
#  'One-half',
#  'Ottoman-born',
#  'Pacific-cable',
#  'Paper-covered',
#  'Peit-sang',
#  'Post-office',
#  'Post-offices',
#  'Post-roads',
#  'President-tried',
#  'Prize-winning',
#  'Ranger-type',
#  'Re-employment',
#  'Re-enlistment',
#  'Richmond-based',
#  'Sai-shek',
#  'Scud-type',
#  'Self-defense',
#  'Self-determination',
#  'Self-governed',
#  'Self-government',
#  'Self-interest',
#  'Self-preservation',
#  'Self-reliance',
#  'Self-restraint',
#  'Seong-ho',
#  'September-immediately',
#  'Shan-tung',
#  'Short-term',
#  'Sixty-eighth',
#  'Small-business',
#  'South-west',
#  'Soviet-built',
#  'Soviet-occupied',
#  'Soviet-sponsored',
#  'Soviet-supported',
#  'Spanish-speaking',
#  'Speaker-elect',
#  'State-administered',
#  'State-bank',
#  'State-controlled',
#  'State-directed',
#  'State-owned',
#  'State-sponsored',
#  'State-supported',
#  'Sung-pu',
#  'Suz-ahn',
#  'Syrian-backed',
#  'Sze-chuen',
#  'Tax-exempt',
#  'Ten-forties',
#  'The-world',
#  'Thirty-eighth',
#  'Thirty-fifth',
#  'Thirty-ninth',
#  'Three-fourths',
#  'Three-quarters',
#  'Tien-tsin',
#  'Ting-fang',
#  'To-day',
#  'To-morrow',
#  'Tsai-tao',
#  'Tse-tung',
#  'Tsing-tao',
#  'Tsung-li',
#  'Twenty-fifth',
#  'Two-thirds',
#  'Union-loving',
#  'Union-men',
#  'Union-saving',
#  'Union-supporting',
#  'Vietnam-apply',
#  'Vietnam-backed',
#  'Wage-workers',
#  'Washington-based',
#  'Web-feet',
#  'Well-considered',
#  'Well-founded',
#  'Well-trained',
#  'Western-proposed',
#  'Western-type',
#  'Yen-hoon']

# %% [markdown]
# >> #### 15.2 Solution: Remove hyphen tokens with first word capitalized that are not valid sayings

# %%
clean_dict['Germany-voting'] = 'Germany, voting'
clean_dict['Medicare-rarely'] = 'Medicare, rarely'
clean_dict['President-tried'] = 'President, tried'
clean_dict['September-immediately'] = 'September, immediately'
clean_dict['The-world'] = 'The world'
clean_dict['To-day'] = 'Today'
clean_dict['To-morrow'] = 'Tomorrow'
clean_dict['Vietnam-apply'] = 'Vietnam, apply'

# %% [markdown]
# >> #### 15.3 Prepare token pairs and update dictionary

# %%
# Update dictionary
for tup in list(zip(tokens_to_clean_before, tokens_to_clean_after)):
    clean_dict[tup[0]] = tup[1]
    
# Filter out cleaned tokens
hyphen_tokens = sorted(list(set(hyphen_tokens).difference(set(hyphens_before))))
print(len(hyphen_tokens))
# Out:
# 662

# %% [markdown]
# >> #### 16.1 Problem: Some tokens with multiple hyphens do not need hyphens

# %%
pattern = '^([a-z]+-)*[a-z]+$'
hyphens_before = [re.search(pattern, token)[0] for token in hyphen_tokens if re.search(pattern, token)]
hyphens_before
# Out:
# ['across-the-board',
#  'aid-to-democracies',
#  'air-to-air',
#  'all-of-the-above',
#  'all-or-nothing',
#  'anti-drug-trafficking',
#  'arm-in-arm',
#  'back-and-forth',
#  'back-to-back',
#  'back-to-school',
#  'balance-of-payments',
#  'behind-the-scenes',
#  'black-and-white',
#  'brothers-in-arms',
#  'cap-and-trade',
#  'case-by-case',
#  'catch-and-release',
#  'command-and-control',
#  'commander-in-chief',
#  'comrades-in-arms',
#  'cost-of-living',
#  'cost-plus-fixed',
#  'cross-examination-type',
#  'cut-three-quarters',
#  'day-by-day',
#  'day-to-day',
#  'devil-take-the-hind-most',
#  'dime-by-dime',
#  'do-it-yourself',
#  'do-or-die',
#  'door-to-door',
#  'down-the-middle',
#  'down-to-earth',
#  'eight-year-old',
#  'elbow-to-elbow',
#  'end-of-the-year',
#  'eye-and-a-half',
#  'face-to-face',
#  'farm-to-market',
#  'five-and-a-half',
#  'five-day-old',
#  'five-to-four',
#  'flat-to-deteriorating',
#  'follow-the-leader',
#  'four-and-a-half',
#  'four-year-old',
#  'fourteen-thousand-mile',
#  'fox-guarding-the-henhouse',
#  'free-for-all',
#  'get-rich-quick',
#  'give-and-take',
#  'good-for-nothing',
#  'grants-in-aid',
#  'ground-to-air',
#  'ground-to-ground',
#  'half-a-billion',
#  'half-an-eye',
#  'half-and-half',
#  'happy-go-lucky',
#  'hard-and-fast',
#  'hit-and-run',
#  'holier-than-thou',
#  'horse-and-buggy',
#  'hour-by-hour',
#  'house-to-house',
#  'industry-by-industry',
#  'item-by-item',
#  'killed-in-action',
#  'life-and-death',
#  'line-by-line',
#  'line-of-battle',
#  'man-at-arms',
#  'man-of-war',
#  'man-of-warsman',
#  'man-to-man',
#  'matter-of-course',
#  'men-of-war',
#  'merry-go-round',
#  'million-and-a-half-dollar',
#  'month-by-month',
#  'month-to-month',
#  'most-favored-nation',
#  'most-favored-nations',
#  'mother-in-law',
#  'mother-to-child',
#  'never-to-be-neglected',
#  'nice-to-have',
#  'nine-year-old',
#  'nominee-to-be',
#  'non-interest-bearing',
#  'non-service-connected',
#  'non-slave-holding',
#  'non-war-connected',
#  'not-at-all-fragile',
#  'not-for-profit',
#  'not-so-young',
#  'not-too-distant',
#  'off-the-record',
#  'oil-for-food',
#  'on-the-job',
#  'on-the-record',
#  'on-the-spot',
#  'one-for-one',
#  'one-on-one',
#  'one-universal-interest',
#  'one-year-old',
#  'out-of-control',
#  'out-of-date',
#  'out-of-pocket',
#  'out-of-wedlock',
#  'over-the-top',
#  'pay-as-you-go',
#  'payment-in-kind',
#  'people-to-people',
#  'person-to-person',
#  'post-cold-war',
#  'prisoner-of-war',
#  'prisoners-of-war',
#  'provost-marshal-general',
#  'rank-and-file',
#  'ready-to-be-filled',
#  'ready-to-work',
#  'right-to-know',
#  'right-to-work',
#  'rock-and-roll',
#  'round-the-clock',
#  'senator-to-be',
#  'seven-billion-dollar',
#  'ships-of-the-line',
#  'shoot-to-kill',
#  'side-by-side',
#  'slash-and-burn',
#  'sleight-of-hand',
#  'small-busi-ness',
#  'soak-the-rich',
#  'son-in-law',
#  'spend-and-tax',
#  'state-by-state',
#  'state-of-the',
#  'state-of-the-art',
#  'stay-at-home',
#  'step-by-step',
#  'straight-down-the',
#  'such-and-such',
#  'surface-to-surface',
#  'take-it-or-leave-it',
#  'take-the-hindermost',
#  'tax-and-spend',
#  'tenure-of-office',
#  'three-and-a-half',
#  'top-to-bottom',
#  'trick-or-treat',
#  'truth-in-lending',
#  'twenty-thousand-ton',
#  'two-and-a-half',
#  'two-month-old',
#  'two-to-one',
#  'umbilical-cord-blood',
#  'up-or-down',
#  'up-to-date',
#  'vis-a-vis',
#  'weapons-of-mass-destruction-related',
#  'week-by-week',
#  'welfare-to-work',
#  'well-to-do',
#  'win-the-war',
#  'winner-take-all',
#  'work-in-progress',
#  'would-be-masters',
#  'year-by-year',
#  'year-to-year',
#  'yes-or-no']

# %% [markdown]
# >> #### 16.2 Solution: Clean invalid tokens with multiple hyphens

# %%
tokens_to_clean_before = [
    'borne-successfully-a',
    'hurry-anything-even',
    'in-between-more',
    'leadership-yes-but',
    'self-determination-requires',
    'self-determination-that',
    'self-government-that',
    'self-government-with',
    'self-interest-of',
    'self-interest-then',
    'self-preservation-as',
    'small-busi-ness',
    'something-anything-to',
    'straight-down-the',
    'teachers-listen-with',
    'tonight-laughter-but',
]

tokens_to_clean_after = [
    'borne-successfully a',
    'hurry anything even',
    'in-between more',
    'leadership, yes, but',
    'self-determination requires',
    'self-determination that',
    'self-government that',
    'self-government with',
    'self-interest of',
    'self-interest then',
    'self-preservation as',
    'small-business',
    'something, anything, to',
    'straight down the',
    'teachers listen with',
    'tonight but',
]

# %% [markdown]
# >> #### 16.3 Prepare token pairs and update dictionary

# %%
# Update dictionary
for tup in list(zip(tokens_to_clean_before, tokens_to_clean_after)):
    clean_dict[tup[0]] = tup[1]
    
# Filter out cleaned tokens
hyphen_tokens = sorted(list(set(hyphen_tokens).difference(set(hyphens_before))))

# Filter out additional tokens
pattern = '^([a-z]+-)*[A-Z][a-z]+$'
additional_tokens = [re.search(pattern, token)[0] for token in hyphen_tokens if re.search(pattern, token)]
hyphen_tokens = sorted(list(set(hyphen_tokens).difference(set(additional_tokens))))

# %% [markdown]
# >> #### 17.1 Problem: The remaining tokens have few pattern similiarities

# %%
hyphen_tokens
# Out:
# ['1,500-a-year',
#  '1-day',
#  '1-in-20',
#  '1-yard',
#  '1-year',
#  '1-year-old',
#  '1/2-inch',
#  '1/2-percent',
#  '10,000-foot',
#  '10,000-page',
#  '10,000-ton',
#  '10-day',
#  '10-inch',
#  '10-man',
#  '10-minute',
#  '10-percent',
#  '10-round',
#  '10-to-1',
#  '10-year',
#  '10-year-old',
#  '100-cent',
#  '11-year-old',
#  '12-hour',
#  '12-inch',
#  '12-month',
#  '12-year-old',
#  '122-foot',
#  '122-percent',
#  '13-year-old',
#  '13Ѕ-inch',
#  '14-percent',
#  '14-point',
#  '14-to-1',
#  '14-year',
#  '14-year-old',
#  '15-percent',
#  '15-year-olds',
#  '152-millimeter',
#  '16-inch',
#  '16-inch-type',
#  '16-year-old',
#  '167-page',
#  '17-year',
#  '17-year-low',
#  '17-year-old',
#  '18-hour',
#  '18-nation',
#  '18-percent',
#  '18-wheelers',
#  '18-year-old',
#  '18-year-olds',
#  '180-odd',
#  '19-foot',
#  '19-year-old',
#  '19-year-olds',
#  '190-year',
#  '1970s-era',
#  '19th-century',
#  '2,000-foot',
#  '2,000-mile',
#  '2-in-3',
#  '2-is',
#  '2-minute',
#  '2-percent',
#  '2-year',
#  '2-year-old',
#  '2-year-olds',
#  '20-knot',
#  '20-percent',
#  '20-point',
#  '20-year',
#  '20-year-old',
#  '200-mile',
#  '200-year',
#  '200-year-old',
#  '21st-century',
#  '22,000-word',
#  '22-month',
#  '22-percent',
#  '23-knot',
#  '24-hour',
#  '24-knot',
#  '24-year',
#  '25-percent',
#  '25-year',
#  '250-bed',
#  '26-year-old',
#  '28-minute',
#  '28-percent',
#  '28-square-mile',
#  '3-day',
#  '3-inch',
#  '3-mile',
#  '3-minute',
#  '3-point',
#  '3-to-1',
#  '3-year',
#  '3/4-year',
#  '30-cent',
#  '30-day',
#  '30-minute',
#  '30-odd',
#  '30-percent',
#  '30-second',
#  '30-year',
#  '35-day',
#  '35-hour',
#  '35-percent',
#  '36-percent',
#  '37-point',
#  '3D-print',
#  '3rd-grade',
#  '4-or',
#  '4-percent',
#  '4-point',
#  '4-something',
#  '4-star',
#  '4-year',
#  '4-year-old',
#  '4.8-percent',
#  '40,000-odd',
#  '40-nation',
#  '40-percent',
#  '40-some',
#  '40-yard',
#  '40-year',
#  '45-second',
#  '45-year',
#  '47-year-old',
#  '48-story',
#  '49-year-old',
#  '5-ambulatory',
#  '5-day',
#  '5-letter',
#  '5-percent',
#  '5-power',
#  '5-year',
#  '5-year-old',
#  '50,000-a-year',
#  '50-cent',
#  '50-cent-a-gallon',
#  '50-hour',
#  '50-percent',
#  '50-year',
#  '500-billion',
#  '500-million',
#  '500-per-child',
#  '500-year',
#  '55-mile',
#  '5?-percent',
#  '6-day',
#  '6-inch',
#  '6-month',
#  '6-months',
#  '6-percent',
#  '6-point',
#  '6-pounder',
#  '6-year',
#  '60,000-plus',
#  '60-day',
#  '60-second',
#  '600,000-man',
#  '600-page',
#  '600-percent',
#  '600-ship',
#  '62-year-olders',
#  '65-year',
#  '650-billion-a-year',
#  '7-day',
#  '7-percent',
#  '7-year',
#  '7-year-long',
#  '70-million',
#  '70-percent',
#  '73-percent',
#  '75-bed',
#  '75-page',
#  '75-year-old',
#  '77-percent',
#  '8-inch',
#  '8-year',
#  '8-year-old',
#  '8-year-olds',
#  '800-HELPNOW',
#  '800-some',
#  '81-which',
#  '85-foot',
#  '88-year-old',
#  '9,000-men',
#  '9-foot',
#  '9-hour',
#  '9-millimeter',
#  '9-year-olds',
#  '9.2-percent',
#  '90-day',
#  '90-minute',
#  '90-second',
#  '900,000-$900,000',
#  '91-to-1',
#  '960-acre',
#  'A-11',
#  'A-6F',
#  'A-grade',
#  'A-plus',
#  'ACT-UP',
#  'ADJUTANT-GENERAL',
#  'AIDS-free',
#  'AK-47s',
#  'AMERICA-HONDURAS',
#  'ANTI-TRUST',
#  'ARBITRATIONS-PANAMA',
#  'Ah-h-h',
#  'Aix-la-Chapelle',
#  'Alaskan-Yukon-Pacific',
#  'B-1',
#  'B-1B',
#  'B-2',
#  'B-22',
#  'B-29',
#  'B-47',
#  'B-52',
#  'B-l',
#  'BUNAU-VARILLA',
#  'Big-Brother-is-watching-you',
#  'Boo-o-o',
#  'Bush-McCain',
#  'C-1',
#  'C-SPAN',
#  'C-minus',
#  'CAPITAL-GAINS',
#  'CIVIL-SERVICE',
#  'CONFERENCE-UNFORTUNATE',
#  'CONSULATE-GENERAL',
#  'Catch-and-release',
#  'Cha-Cha-Cha',
#  'China-U.S.',
#  'Commander-in-Chief',
#  'Corps]-type',
#  'D-day',
#  'DECISION-MERELY',
#  'Dar-Es-Salaam',
#  'E-rate',
#  'EIGHT-HOUR',
#  'ELECTRICAL-POWER',
#  'F-1',
#  'F-14',
#  'F-14s',
#  'F-15',
#  'F-35',
#  'F1a.-there',
#  'FBI-in',
#  'FELLOW-CITIZENS',
#  'FUR-SEAL',
#  'Fifty-four-forty',
#  'Fix-It-First',
#  'Foo-Choo-Foo',
#  'Food-for-Peace',
#  'Fordney-McCumber',
#  'Frankfort-on-the-Main',
#  'G-20',
#  'G-8',
#  'GS-12',
#  'GS-18',
#  'Gramm-Rudman-Hollings',
#  'Grant-in-aid',
#  'H-43',
#  'H-bomb',
#  'HIV-positive',
#  'HOME-LOAN',
#  'Ho-si-woo',
#  'IA-ECOSOC',
#  'II-has',
#  'III-C',
#  'INTER-AMERICAN',
#  'INTERSTATE-COMMERCE',
#  'J-58',
#  'Jaish-e-Mohammed',
#  'Judge-Advocate-General',
#  'Kennedy-McCarthy',
#  'LATIN-AMERICAN',
#  'LAW-THE',
#  'LIGHT-HOUSE',
#  'LIGHT-HOUSES',
#  'LONG-STANDING',
#  'Lincoln\'s-"Let',
#  'M-1',
#  'MI-8',
#  'MS-13',
#  'Man-of-war',
#  'Mazar-e-Sharif',
#  'McCain-Feingold',
#  'Mig-23',
#  'NAVY-YARDS',
#  'Nixon-16',
#  'Nuclear-Test-Ban',
#  'OB-GYN',
#  'P-Tech',
#  'PANAMA-PACIFIC',
#  'POST-OFFICE',
#  'POSTAL-SAVINGS',
#  'PURE-FOOD',
#  'Pakistan-600',
#  'Paymaster-General.3',
#  'Port-au-Prince',
#  'Post-9/11',
#  'Post-OfficeDepartment',
#  'PostMaster-General',
#  'Pre-K',
#  'President-to-be',
#  'Provost-Marshal-General',
#  'R-U',
#  'R-e-g-a-n',
#  'RC-135',
#  'RICA-COLOMBIA',
#  'RS-70',
#  'Reagan-Kemp-Roth',
#  'SECOND-CLASS',
#  'SELF-DEFENSE',
#  'SEMI-CENTENNIAL',
#  'SLAVE-DEALER',
#  'SR-71',
#  'SR-7I',
#  'SS-18',
#  'SS-20',
#  'SS-20s',
#  'SS-21',
#  'SS-4',
#  'SS-4s',
#  'SS-5',
#  'STABT-Strategic',
#  'Secretary-then-Regan',
#  'Soviet-U.S.',
#  'TACNA-ARICA',
#  'Ta-lien-wan',
#  'Taft-Ellender-Wagner',
#  'U-2',
#  'U-Boats',
#  'U-boats',
#  'U.S.-Canadian',
#  'U.S.-Japan',
#  'U.S.-Korea',
#  'U.S.-Mexico',
#  'U.S.-Mexico-Canada',
#  'U.S.-Panamanian',
#  'V-1',
#  'V-2',
#  'V-J',
#  'V-chip',
#  'W-GDP',
#  'Wagner-Ellender-Taft',
#  'Wei-hai-wei',
#  'X-rated',
#  'act-$350,000,000',
#  "al-Qa'ida",
#  'anti-U.S.',
#  'attack,-dangers',
#  "bull's-eye",
#  'business-I',
#  'catch-22',
#  'coal-I',
#  "de-Ba'athification",
#  "employer's-liability",
#  'every-4-year',
#  'ex-GI',
#  'get-11.4',
#  'history–-157',
#  "however-I'm",
#  'involved-I',
#  'late-1970',
#  "mid-'60s",
#  'mid-2030s',
#  'money,-expenditures',
#  'name-J.',
#  'navy-yards15,283,437.17For',
#  'navy-yards17,292,601.44For',
#  'navy-yards21,249,809.99For',
#  'navy-yards4,199,299.6912,300,700.31For',
#  'necessity-I',
#  'non-African-Americans',
#  'non-NATO',
#  'now-7.9',
#  'on-14(b',
#  'only."Attorney-General',
#  'percent-53',
#  'percent-I',
#  'politics-I',
#  'post-Cold-War',
#  'pre-1967',
#  'pre-K',
#  'problems-I',
#  "reorganization-I'd",
#  'run,-especially',
#  'self-government---that',
#  'slave-trade---that',
#  'struggle,-turn',
#  'that-I',
#  'theVice-President',
#  'to-day."Acting',
#  'to-morrow,-the',
#  "will-o'-the-wisp",
#  'words-"We',
#  'world-I',
#  'years-50']

# %% [markdown]
# >> #### 17.2 Solution: Clean remaining tokens have few pattern similiarities

# %%
# Update clean dict
clean_dict['2-is'] = '2 is'
clean_dict['4-or'] = '4- or'
clean_dict['5?-percent'] = '5-percent'
clean_dict['81-which'] = '81, which'
clean_dict['F1a.-there'] = 'F1a., there'
clean_dict['FBI-in'] = 'FBI, in'
clean_dict['II-has'] = 'II, has'
clean_dict['Paymaster-General.3'] = 'Paymaster-General. 3'
clean_dict['Post-OfficeDepartment'] = 'Post-Office Department'
clean_dict['Postmaster-General'] = 'Postmaster-General'
clean_dict['act-$350,000,000'] = 'act, $350,000,000'
clean_dict['attack,-dangers'] = 'attack, dangers'
clean_dict['business-I'] = 'business, I'
clean_dict['coal-I'] = 'coal, I'
clean_dict['however-I'] = 'however, I'
clean_dict['involved-I'] = 'involved, I'
clean_dict['percent-I'] = 'percent, I'
clean_dict['politics-I'] = 'politics, I'
clean_dict['problems-I'] = 'problems, I'
clean_dict['that-I'] = 'that, I'
clean_dict['reorganization-I'] = 'reorganization, I'
clean_dict['world-I'] = 'world, I'
clean_dict['theVice-President'] = 'the Vice President'
clean_dict['(Applause.)'] = ''
clean_dict['(applause.)'] = ''
clean_dict['(laughter)'] = ''
clean_dict['(Laughter)'] = ''
clean_dict['Nixon-16 years ago-was'] = 'Nixon, 16 years ago, was'
clean_dict['to-morrow,-the'] = 'tomorrow, the'
clean_dict['to-day."Acting'] = 'today."Acting'
clean_dict['self-government---that'] = 'self-government, that'
clean_dict['slave-trade---that'] = 'slave-trade, that'
clean_dict['only."Attorney-General'] = 'only. "Attorney-General'
clean_dict['theVice-President'] = 'the Vice President'
clean_dict['struggle,-turn'] = 'struggle, turn'
clean_dict['run,-especially'] = 'run, especially'
clean_dict['words-"We'] = 'words, "We'
clean_dict["reorganization-I'd"] = "reorganization, I'd"
clean_dict['necessity-I'] = 'necessity, I'
clean_dict['money,-expenditures'] = 'money, expenditures'
clean_dict['name-J.'] = 'name, J.'
clean_dict['get-11.4'] = 'get, 11.4'
clean_dict['history–-157'] = 'history, 157'

# Patterns to match tokens
patterns = [
    '^[0-9]+-(seconds?|millimeter|knot|minutes?|hours?|days?)$',
    '^[0-9]+-(weeks?|months?|years?|page|percent|point|mile)$',
    '^[0-9]+-(power|pounder|acre|some|billion|nation|star|something)$',
    '^[0-9]+-(odd|inch|yard|bed|million|percent|foot|year-olds?)$',
    '^[0-9]/[0-9]-[a-z]+$',
    '^U.S.-[A-Za-z]+$',
    '^[A-Z]+-[0-9]+$'
]

# Remove all tokens that match the given patterns
for pattern in patterns:
    token_matches =[re.search(pattern, token)[0] for token in hyphen_tokens if re.search(pattern, token)]
    hyphen_tokens = sorted(list(set(hyphen_tokens).difference(set(token_matches))))

# Update hyphen_tokens
hyphen_tokens = [token for token in hyphen_tokens if token not in clean_dict]
hyphen_tokens
# Out:
# ['1,500-a-year',
#  '1-in-20',
#  '10,000-foot',
#  '10,000-page',
#  '10,000-ton',
#  '10-man',
#  '10-round',
#  '10-to-1',
#  '100-cent',
#  '13Ѕ-inch',
#  '14-to-1',
#  '16-inch-type',
#  '17-year-low',
#  '18-wheelers',
#  '1970s-era',
#  '19th-century',
#  '2,000-foot',
#  '2,000-mile',
#  '2-in-3',
#  '21st-century',
#  '22,000-word',
#  '28-square-mile',
#  '3-to-1',
#  '30-cent',
#  '3D-print',
#  '3rd-grade',
#  '4.8-percent',
#  '40,000-odd',
#  '48-story',
#  '5-ambulatory',
#  '5-letter',
#  '50,000-a-year',
#  '50-cent',
#  '50-cent-a-gallon',
#  '500-per-child',
#  '60,000-plus',
#  '600,000-man',
#  '600-ship',
#  '62-year-olders',
#  '650-billion-a-year',
#  '7-year-long',
#  '800-HELPNOW',
#  '9,000-men',
#  '9.2-percent',
#  '900,000-$900,000',
#  '91-to-1',
#  'A-6F',
#  'A-grade',
#  'A-plus',
#  'ACT-UP',
#  'ADJUTANT-GENERAL',
#  'AIDS-free',
#  'AK-47s',
#  'AMERICA-HONDURAS',
#  'ANTI-TRUST',
#  'ARBITRATIONS-PANAMA',
#  'Ah-h-h',
#  'Aix-la-Chapelle',
#  'Alaskan-Yukon-Pacific',
#  'B-1B',
#  'B-l',
#  'BUNAU-VARILLA',
#  'Big-Brother-is-watching-you',
#  'Boo-o-o',
#  'Bush-McCain',
#  'C-SPAN',
#  'C-minus',
#  'CAPITAL-GAINS',
#  'CIVIL-SERVICE',
#  'CONFERENCE-UNFORTUNATE',
#  'CONSULATE-GENERAL',
#  'Catch-and-release',
#  'Cha-Cha-Cha',
#  'China-U.S.',
#  'Commander-in-Chief',
#  'Corps]-type',
#  'D-day',
#  'DECISION-MERELY',
#  'Dar-Es-Salaam',
#  'E-rate',
#  'EIGHT-HOUR',
#  'ELECTRICAL-POWER',
#  'F-14s',
#  'FELLOW-CITIZENS',
#  'FUR-SEAL',
#  'Fifty-four-forty',
#  'Fix-It-First',
#  'Foo-Choo-Foo',
#  'Food-for-Peace',
#  'Fordney-McCumber',
#  'Frankfort-on-the-Main',
#  'Gramm-Rudman-Hollings',
#  'Grant-in-aid',
#  'H-bomb',
#  'HIV-positive',
#  'HOME-LOAN',
#  'Ho-si-woo',
#  'IA-ECOSOC',
#  'III-C',
#  'INTER-AMERICAN',
#  'INTERSTATE-COMMERCE',
#  'Jaish-e-Mohammed',
#  'Judge-Advocate-General',
#  'Kennedy-McCarthy',
#  'LATIN-AMERICAN',
#  'LAW-THE',
#  'LIGHT-HOUSE',
#  'LIGHT-HOUSES',
#  'LONG-STANDING',
#  'Lincoln\'s-"Let',
#  'Man-of-war',
#  'Mazar-e-Sharif',
#  'McCain-Feingold',
#  'Mig-23',
#  'NAVY-YARDS',
#  'Nixon-16',
#  'Nuclear-Test-Ban',
#  'OB-GYN',
#  'P-Tech',
#  'PANAMA-PACIFIC',
#  'POST-OFFICE',
#  'POSTAL-SAVINGS',
#  'PURE-FOOD',
#  'Pakistan-600',
#  'Port-au-Prince',
#  'Post-9/11',
#  'PostMaster-General',
#  'Pre-K',
#  'President-to-be',
#  'Provost-Marshal-General',
#  'R-U',
#  'R-e-g-a-n',
#  'RICA-COLOMBIA',
#  'Reagan-Kemp-Roth',
#  'SECOND-CLASS',
#  'SELF-DEFENSE',
#  'SEMI-CENTENNIAL',
#  'SLAVE-DEALER',
#  'SR-7I',
#  'SS-20s',
#  'SS-4s',
#  'STABT-Strategic',
#  'Secretary-then-Regan',
#  'Soviet-U.S.',
#  'TACNA-ARICA',
#  'Ta-lien-wan',
#  'Taft-Ellender-Wagner',
#  'U-Boats',
#  'U-boats',
#  'U.S.-Mexico-Canada',
#  'V-J',
#  'V-chip',
#  'W-GDP',
#  'Wagner-Ellender-Taft',
#  'Wei-hai-wei',
#  'X-rated',
#  "al-Qa'ida",
#  'anti-U.S.',
#  "bull's-eye",
#  'catch-22',
#  "de-Ba'athification",
#  "employer's-liability",
#  'every-4-year',
#  'ex-GI',
#  "however-I'm",
#  'late-1970',
#  "mid-'60s",
#  'mid-2030s',
#  'navy-yards15,283,437.17For',
#  'navy-yards17,292,601.44For',
#  'navy-yards21,249,809.99For',
#  'navy-yards4,199,299.6912,300,700.31For',
#  'non-African-Americans',
#  'non-NATO',
#  'now-7.9',
#  'on-14(b',
#  'percent-53',
#  'post-Cold-War',
#  'pre-1967',
#  'pre-K',
#  "will-o'-the-wisp",
#  'years-50']

# %% [markdown]
# >> #### 17.3 Clean hyphen_tokens and then update transcript_tokens to remove all hyphen_tokens

# %%
# Filter hyphen_tokens out of transcript_tokens
transcript_tokens = sorted(list(set(transcript_tokens).difference(set(hyphen_tokens_list))))

# %% [markdown]
# >> #### 18.1 Problem: Some tokens have no space between two sentences

# %%
pattern = '[0-9]+\.[A-Z]?[a-z][a-z]+'
pattern_before = [re.search(pattern, token)[0] for token in transcript_tokens if re.search(pattern, token) and re.search(pattern, token)[0]==token]
pattern_before
# Out:
# ['11.Each',
#  '15.All',
#  '1800.Again',
#  '1812.The',
#  '1818.New',
#  '1820.The',
#  '1824.During',
#  '1827.Coinciding',
#  '1827.The',
#  '1842.The',
#  '1846.His',
#  '1849.But',
#  '1850.Preceding',
#  '1860.After',
#  '1860.Besides',
#  '1860.The',
#  '1861.Our',
#  '1861.The',
#  '1863.Hon',
#  '1864.Again',
#  '1864.The',
#  '1866.There',
#  '1868.The',
#  '1871.Other',
#  '1876.This',
#  '1878.The',
#  '1881.The',
#  '1883.Our',
#  '1884.The',
#  '1885.Inasmuch',
#  '1885.The',
#  '1886.Our',
#  '1889.The',
#  '1890.Under',
#  '1891.The',
#  '1892.The',
#  '1893.During',
#  '1893.From',
#  '1893.The',
#  '1893.There',
#  '1893.When',
#  '1894.Again',
#  '1894.The',
#  '1898.Having',
#  '1898.The',
#  '1899.Government',
#  '1899.Our',
#  '1899.The',
#  '1899.This',
#  '1908.The',
#  '1909.Many',
#  '1909.Philippine',
#  '1909.The',
#  '1910.The',
#  '1911.Therefore',
#  '1911.These',
#  '22.For',
#  '23.Our',
#  '30.The',
#  '5.The',
#  '78.The',
#  '83.From']

# %% [markdown]
# >> #### 18.2 Solution: Add space between two sentences

# %%
pattern_after = [token.replace('.', '. ') for token in pattern_before]
pattern_after
# Out:
# ['11. Each',
#  '15. All',
#  '1800. Again',
#  '1812. The',
#  '1818. New',
#  '1820. The',
#  '1824. During',
#  '1827. Coinciding',
#  '1827. The',
#  '1842. The',
#  '1846. His',
#  '1849. But',
#  '1850. Preceding',
#  '1860. After',
#  '1860. Besides',
#  '1860. The',
#  '1861. Our',
#  '1861. The',
#  '1863. Hon',
#  '1864. Again',
#  '1864. The',
#  '1866. There',
#  '1868. The',
#  '1871. Other',
#  '1876. This',
#  '1878. The',
#  '1881. The',
#  '1883. Our',
#  '1884. The',
#  '1885. Inasmuch',
#  '1885. The',
#  '1886. Our',
#  '1889. The',
#  '1890. Under',
#  '1891. The',
#  '1892. The',
#  '1893. During',
#  '1893. From',
#  '1893. The',
#  '1893. There',
#  '1893. When',
#  '1894. Again',
#  '1894. The',
#  '1898. Having',
#  '1898. The',
#  '1899. Government',
#  '1899. Our',
#  '1899. The',
#  '1899. This',
#  '1908. The',
#  '1909. Many',
#  '1909. Philippine',
#  '1909. The',
#  '1910. The',
#  '1911. Therefore',
#  '1911. These',
#  '22. For',
#  '23. Our',
#  '30. The',
#  '5. The',
#  '78. The',
#  '83. From']

# %% [markdown]
# >> #### 18.3 Prepare tokens and update dictionary

# %%
# Zip pairs into before and after tuples
patterns = list(zip(pattern_before, pattern_after))

# Update dictionary and hyphen tokens
clean_dict = update_dict(clean_dict, patterns)
transcript_tokens = [token for token in transcript_tokens if token not in clean_dict]

# %% [markdown]
# >> #### 19.1 Problem: Some tokens have no space between period and double quotes

# %%
pattern = "[A-Z]?[a-z]+\.\"[A-Za-z][a-z]+"
pattern_before = [re.search(pattern, token)[0] for token in list(set(transcript_tokens)) if re.search(pattern, token) and re.search(pattern, token)[0]==token]
pattern_before
# Out:
# ['Empire."Faithful',
#  'man."In',
#  'admission."Did',
#  'Government."These',
#  'violence."In',
#  'thereof."Such',
#  'restriction."In',
#  'Samoa."Arrangements',
#  'expedient."But',
#  'enterprise."The',
#  'independent."That',
#  'Corps."An',
#  'means."That',
#  'country."The',
#  'jurisdiction."In',
#  'Congress."In',
#  'aphorism."This',
#  'means."In',
#  'use."Seven',
#  'Court."The',
#  'kind."During',
#  'use."Under',
#  'States."If',
#  'present."In',
#  'Indians."The',
#  'view."This',
#  'America."It',
#  'origin."This',
#  'cargo."This',
#  'charge."Violent',
#  'banks."But',
#  'avail."Afterwards',
#  'happiness."Now',
#  'together."Yet',
#  'prescribe."An',
#  'consideration."Cheap',
#  'incorporation."Before',
#  'war."These',
#  'fetters."The',
#  'law."No',
#  'case."In',
#  'Honduras."Upon',
#  'people."To',
#  'thereof."In',
#  'States."Then',
#  'jail."The',
#  'improvements."The',
#  'color."Moreover',
#  'bondage."The',
#  'it."As',
#  'embarrassed."The',
#  'company."If',
#  'statute."Generally',
#  'reform."Action',
#  'governments."For',
#  'altogether."With',
#  'vindication."There',
#  'nation."It',
#  'prosperity."Serious',
#  'monopolies."If',
#  'insurance."Recent',
#  'successors."With',
#  'circulation."It',
#  'merit."In',
#  'employer."The',
#  'States."Secondly',
#  'safety."As',
#  'islands."To',
#  'evils."The',
#  'encouragement."The',
#  'power."Publicity',
#  'man."The',
#  'States."Thus',
#  'subject."Last',
#  'affixed."Done',
#  'exists."In',
#  'Constitution."Why',
#  'there."This',
#  'made."The',
#  'relationship."But',
#  'Union."But',
#  'year."There',
#  'another."Article',
#  'indemnities."Just',
#  'wars."When',
#  'standpoint."The',
#  'cruelty."To',
#  'action."This',
#  'all."These',
#  'enter."Not',
#  'States."The',
#  'control."The',
#  'Europe."It',
#  'it."The',
#  'Britain."When',
#  'Salvador."This',
#  'debts."However',
#  'Territory."The',
#  'numbers."At',
#  'country."Every',
#  'expenditures."The',
#  'Constitution."In',
#  'matter."The',
#  'rendered."It',
#  'nations."In',
#  'resumption."Unlimited',
#  'ended."Under',
#  'other."Mr',
#  'serve."On',
#  'justice."The',
#  'gerrymander."These',
#  'associations."This',
#  'class."It',
#  'therein."Had']

# %% [markdown]
# >> #### 19.2 Solution: Add space between some tokens and double quotes

# %%
pattern_after = [token.replace('.', '. ') for token in pattern_before]
pattern_after
# Out:
# ['Empire. "Faithful',
#  'man. "In',
#  'admission. "Did',
#  'Government. "These',
#  'violence. "In',
#  'thereof. "Such',
#  'restriction. "In',
#  'Samoa. "Arrangements',
#  'expedient. "But',
#  'enterprise. "The',
#  'independent. "That',
#  'Corps. "An',
#  'means. "That',
#  'country. "The',
#  'jurisdiction. "In',
#  'Congress. "In',
#  'aphorism. "This',
#  'means. "In',
#  'use. "Seven',
#  'Court. "The',
#  'kind. "During',
#  'use. "Under',
#  'States. "If',
#  'present. "In',
#  'Indians. "The',
#  'view. "This',
#  'America. "It',
#  'origin. "This',
#  'cargo. "This',
#  'charge. "Violent',
#  'banks. "But',
#  'avail. "Afterwards',
#  'happiness. "Now',
#  'together. "Yet',
#  'prescribe. "An',
#  'consideration. "Cheap',
#  'incorporation. "Before',
#  'war. "These',
#  'fetters. "The',
#  'law. "No',
#  'case. "In',
#  'Honduras. "Upon',
#  'people. "To',
#  'thereof. "In',
#  'States. "Then',
#  'jail. "The',
#  'improvements. "The',
#  'color. "Moreover',
#  'bondage. "The',
#  'it. "As',
#  'embarrassed. "The',
#  'company. "If',
#  'statute. "Generally',
#  'reform. "Action',
#  'governments. "For',
#  'altogether. "With',
#  'vindication. "There',
#  'nation. "It',
#  'prosperity. "Serious',
#  'monopolies. "If',
#  'insurance. "Recent',
#  'successors. "With',
#  'circulation. "It',
#  'merit. "In',
#  'employer. "The',
#  'States. "Secondly',
#  'safety. "As',
#  'islands. "To',
#  'evils. "The',
#  'encouragement. "The',
#  'power. "Publicity',
#  'man. "The',
#  'States. "Thus',
#  'subject. "Last',
#  'affixed. "Done',
#  'exists. "In',
#  'Constitution. "Why',
#  'there. "This',
#  'made. "The',
#  'relationship. "But',
#  'Union. "But',
#  'year. "There',
#  'another. "Article',
#  'indemnities. "Just',
#  'wars. "When',
#  'standpoint. "The',
#  'cruelty. "To',
#  'action. "This',
#  'all. "These',
#  'enter. "Not',
#  'States. "The',
#  'control. "The',
#  'Europe. "It',
#  'it. "The',
#  'Britain. "When',
#  'Salvador. "This',
#  'debts. "However',
#  'Territory. "The',
#  'numbers. "At',
#  'country. "Every',
#  'expenditures. "The',
#  'Constitution. "In',
#  'matter. "The',
#  'rendered. "It',
#  'nations. "In',
#  'resumption. "Unlimited',
#  'ended. "Under',
#  'other. "Mr',
#  'serve. "On',
#  'justice. "The',
#  'gerrymander. "These',
#  'associations. "This',
#  'class. "It',
#  'therein. "Had']

# %% [markdown]
# >> #### 19.3 Prepare tokens and update dictionary

# %%
# Zip pairs into before and after tuples
patterns = list(zip(pattern_before, pattern_after))

# Update dictionary and hyphen tokens
clean_dict = update_dict(clean_dict, patterns)
transcript_tokens = [token for token in transcript_tokens if token not in clean_dict]

# %% [markdown]
# >> #### 20.1 Problem: No space between end of sentence and a number

# %%
pattern = "[A-Z]?[a-z]+\.[0-9]"
pattern_before = [re.search(pattern, token)[0] for token in list(set(transcript_tokens)) if re.search(pattern, token) and re.search(pattern, token)[0]==token]
pattern_before
# Out:
# ['them.1',
#  'prescribe.3',
#  'Service.3',
#  'each.2',
#  'posts.5',
#  'war.2',
#  'each.3',
#  'each.4',
#  'disease.2',
#  'fever.7',
#  'requires.6',
#  'purpose.4',
#  'loans.1',
#  'nations.1',
#  'Bundy.6',
#  'exist.2']

# %% [markdown]
# >> #### 20.2 Solution: Add space between end of sentence and number

# %%
pattern_after = [token.replace('.', '. ') for token in pattern_before]
pattern_after
# Out:
# ['them. 1',
#  'prescribe. 3',
#  'Service. 3',
#  'each. 2',
#  'posts. 5',
#  'war. 2',
#  'each. 3',
#  'each. 4',
#  'disease. 2',
#  'fever. 7',
#  'requires. 6',
#  'purpose. 4',
#  'loans. 1',
#  'nations. 1',
#  'Bundy. 6',
#  'exist. 2']

# %% [markdown]
# >> #### 20.3 Prepare tokens and update dictionary

# %%
# Zip pairs into before and after tuples
patterns = list(zip(pattern_before, pattern_after))

# Update dictionary and hyphen tokens
clean_dict = update_dict(clean_dict, patterns)
transcript_tokens = [token for token in transcript_tokens if token not in clean_dict]

# %% [markdown]
# >> #### 21.1 Problem: Some tokens have no space between semicolon and word

# %%
pattern = "[A-Z]?[a-z]+;[a-z]+"
pattern_before = [re.search(pattern, token)[0] for token in list(set(transcript_tokens)) if re.search(pattern, token) and re.search(pattern, token)[0]==token]
pattern_before
# Out:
# ['flag;that',
#  'basis;to',
#  'Federal;and',
#  'producer;to',
#  'aggression;we',
#  'States;and',
#  'office;the',
#  'reservations;that',
#  'war;it',
#  'nations;and',
#  'unforeseen;many',
#  'secure;and',
#  'elected;that',
#  'latitude;but',
#  'circulation;but',
#  'exercised;and',
#  'intimate;the',
#  'learning;that',
#  'power;and',
#  'race;and',
#  'welfare;it',
#  'example;but',
#  'legislation;and',
#  'numbers;the',
#  'experiment;today',
#  'duty;and',
#  'future;many',
#  'beauty;filled',
#  'monopolies;the',
#  'he;d',
#  'settlements;to',
#  'frontier;to',
#  'Randall;that',
#  'disruption;it']

# %% [markdown]
# >> #### 21.2 Solution: Add space between semicolon and word

# %%
pattern_after = [token.replace(';', '; ') for token in pattern_before]
#pattern_after[-1] = 'held'
pattern_after
# Out:
# ['flag; that',
#  'basis; to',
#  'Federal; and',
#  'producer; to',
#  'aggression; we',
#  'States; and',
#  'office; the',
#  'reservations; that',
#  'war; it',
#  'nations; and',
#  'unforeseen; many',
#  'secure; and',
#  'elected; that',
#  'latitude; but',
#  'circulation; but',
#  'exercised; and',
#  'intimate; the',
#  'learning; that',
#  'power; and',
#  'race; and',
#  'welfare; it',
#  'example; but',
#  'legislation; and',
#  'numbers; the',
#  'experiment; today',
#  'duty; and',
#  'future; many',
#  'beauty; filled',
#  'monopolies; the',
#  'he; d',
#  'settlements; to',
#  'frontier; to',
#  'Randall; that',
#  'disruption; it']

# %% [markdown]
# >> #### 21.3 Prepare tokens and update dictionary

# %%
# Zip pairs into before and after tuples
patterns = list(zip(pattern_before, pattern_after))

# Update dictionary and hyphen tokens
clean_dict = update_dict(clean_dict, patterns)
transcript_tokens = [token for token in transcript_tokens if token not in clean_dict]

# %% [markdown]
# >> #### 22.1 Problem: Some tokens have no space between colon and word

# %%
pattern = "[A-Z]?[a-z]+:\"[A-Za-z]+"
pattern_before = [re.search(pattern, token)[0] for token in list(set(transcript_tokens)) if re.search(pattern, token) and re.search(pattern, token)[0]==token]
pattern_before
# Out:
# ['said:"If',
#  'said:"Our',
#  'wrote:"I',
#  'paragraph:"Such',
#  'action:"That',
#  'follows:"Whereas',
#  'follows:"The',
#  'action:"We',
#  'further:"I',
#  'said:"We',
#  'following:"The',
#  'Beaupre:"The',
#  'instructions:"It',
#  'stated:"In',
#  'said:"But',
#  'declared:"That',
#  'recommendation:"The',
#  'follows:"Article',
#  'said:"Interest',
#  'position:"The',
#  'said:"The',
#  'president:"Congress',
#  'follows:"From',
#  'Ehrman:"The',
#  'said:"It',
#  'follows:"Knowing',
#  'follows:"It',
#  'words:"This',
#  'America:"Among',
#  'said:"I',
#  'currency:"I']

# %% [markdown]
# >> #### 22.2 Solution: Add space between colon and word

# %%
pattern_after = [token.replace(':', ': ') for token in pattern_before]
pattern_after
# Out:
# ['said: "If',
#  'said: "Our',
#  'wrote: "I',
#  'paragraph: "Such',
#  'action: "That',
#  'follows: "Whereas',
#  'follows: "The',
#  'action: "We',
#  'further: "I',
#  'said: "We',
#  'following: "The',
#  'Beaupre: "The',
#  'instructions: "It',
#  'stated: "In',
#  'said: "But',
#  'declared: "That',
#  'recommendation: "The',
#  'follows: "Article',
#  'said: "Interest',
#  'position: "The',
#  'said: "The',
#  'president: "Congress',
#  'follows: "From',
#  'Ehrman: "The',
#  'said: "It',
#  'follows: "Knowing',
#  'follows: "It',
#  'words: "This',
#  'America: "Among',
#  'said: "I',
#  'currency: "I']

# %% [markdown]
# >> #### 22.3 Prepare tokens and update dictionary

# %%
# Zip pairs into before and after tuples
patterns = list(zip(pattern_before, pattern_after))

# Update dictionary and hyphen tokens
clean_dict = update_dict(clean_dict, patterns)
transcript_tokens = [token for token in transcript_tokens if token not in clean_dict]

# %% [markdown]
# >> #### 23.1 Problem: Tokens like dates or cardinal numbers we can ignore

# %%
patterns = [
    "([A-Z]\.)*",
    "[0-9]+(th|nd|rd|st)",
    "[0-9]{1,2}:[0-9]{2}",
    '[A-Za-z]+\'s',
    "[A-Za-z]+\.$",
    "[0-9]{4}s$",
    "^[OM]'$",
    "^p.[0-9]+",
    "^[A-Za-z]+'(d|re|ll|ve|t)$",
    "^[0-9]+d$",
    "^G[0-9]+$",
    "^d'[A-Za-z]+$",
    "^ma'[A-Za-z]+$",
    "^[Oo]'[A-Za-z]+$"
]

# %% [markdown]
# >> #### 23.2 Solution: Remove tokens from consideration of being cleaned

# %%
for pattern in patterns:
    pattern_match = [re.search(pattern, token)[0] for token in list(set(transcript_tokens)) if re.search(pattern, token) and re.search(pattern, token)[0]==token]
    transcript_tokens = sorted(list(set(transcript_tokens).difference(set(pattern_match))))

# %% [markdown]
# >> #### 24.1 Problem: There is not space between large numbers and words

# %%
pattern = "([0-9]{1,3},)*[0-9]{1,3}\.([0-9]{2}\.)?[A-Za-z]+"
pattern_before = [re.search(pattern, token)[0] for token in list(set(transcript_tokens)) if re.search(pattern, token) and re.search(pattern, token)[0]==token]
pattern_before
# Out:
# ['75,000,000.The',
#  '273,437,161.51.For',
#  '66,818,292.38.The',
#  '80,606,808.40.The',
#  '4,557,462.71.The',
#  '12,929,690.33.The',
#  '560,000.The',
#  '57,470,129.59.For',
#  '37,951.Among',
#  '247,131,549.The',
#  '24,175,000,000.There',
#  '104,000,000.The',
#  '7,063,298.57.The',
#  '2,226,876.The',
#  '101,000,000.It',
#  '196,778,017.The',
#  '934,123.11.There',
#  '63,000,000.During',
#  '101,232,511.66.The',
#  '31,414,788.04.Our',
#  '40,000,000.For',
#  '79,085.On',
#  '451,963,981.On',
#  '90,000.With',
#  '14,381,808.40.The',
#  '2,000.I',
#  '300,000,000.FACILITIES',
#  '218,196.The',
#  '2,033,053.09.It',
#  '5,125,638.14.The',
#  '2,740,854,750.Every',
#  '51,576,706.I',
#  '58,579,780.08.It',
#  '1,285,118.08.From',
#  '300,000.The',
#  '828,474.43.The',
#  '4,140,211,139.There',
#  '501,965,778.In',
#  '33,801,378.78.The',
#  '91.It',
#  '290,712.07.The',
#  '94,480,189.If',
#  '427,834.62.The',
#  '86,856,710.If',
#  '16,838,240.There',
#  '70,000,000.The',
#  '70,129,195.56.The',
#  '18,420.There',
#  '6,398,316.10.The',
#  '93,047,373.15.It',
#  '1,417,554.07.To',
#  '8,000,000.The',
#  '90,000,000.The',
#  '87,983,983.86.The',
#  '3,500,000.If',
#  '7.By',
#  '10,361,683.Should',
#  '43,678,883.01.During',
#  '6,879,300.93.The',
#  '71,902,000.The',
#  '570,749,155.If',
#  '99,960,253.54.The',
#  '172,314.65.The',
#  '98,072,420.30.Besides',
#  '165,235,129.35.The',
#  '130,140.85.It',
#  '23,150,617.39.The',
#  '112,000,000.On',
#  '387,131.95.The',
#  '500,000,000.These',
#  '114,000,000.ADVANTAGE',
#  '4,292,776.18.Estimates',
#  '126,758,218.Our',
#  '11,984,518.08.The',
#  '15,623,863.41.In',
#  '13,418,065.74.Because',
#  '6,000.The',
#  '82,487.30.The',
#  '28,000,000.On',
#  '9,844,528.The',
#  '356,000,000.The',
#  '6,400,000.The',
#  '80,976.59.The',
#  '324,656,458.I',
#  '4,000,000.The',
#  '50,451,265.The',
#  '391,994.59.These',
#  '7,862,797.10.The',
#  '2,426,753.36.Independent',
#  '87,500,000.Between',
#  '2,251,134.In',
#  '12,776,390.On',
#  '100,000,000.The',
#  '55,567,849.54.The',
#  '80,000.During',
#  '3,530,196.61.I',
#  '132,528,469.The',
#  '50,000,000.A',
#  '20,000,000.On',
#  '88,090,787.11.The',
#  '924,650.64.About',
#  '500,000.Owing',
#  '47,234,377.10.The',
#  '88,532,839.12.The',
#  '156,822,348.24.The',
#  '4,075,848.89.In',
#  '150,498.41.By',
#  '40,000,000.The',
#  '202,282,933.33.The',
#  '126,261,553.The',
#  '9,155,144.64.The',
#  '25,155,977.66.During',
#  '60,476,000.The',
#  '220,000,000.The',
#  '808,624,811.57.The',
#  '40,000.The',
#  '163,710.30.The',
#  '25,000.I',
#  '140,000,000.The',
#  '10,000,000.It',
#  '154.At',
#  '29,060,386.90.The',
#  '5,308,483.It',
#  '9,106,166.Another',
#  '4,528,676.87.It',
#  '74,989,900.It',
#  '16,000.I',
#  '381,999,073.Immediately',
#  '110,304.While',
#  '305,000,000.The',
#  '81,000,000.By',
#  '4,819,781.In',
#  '778,770.The',
#  '58,362,135.78.That',
#  '1,303,984,937.69.The',
#  '24,212,067.The',
#  '45,850,999.54.Besides',
#  '12,903,076.73.During',
#  '30,000,000.During',
#  '5,950,000.The',
#  '375,000,000.Press',
#  '137,000,000.It',
#  '100,000.A',
#  '1,047,271.35.New',
#  '16,619,047.42.This',
#  '37,239,762.57.The',
#  '140,000,000.There',
#  '97,011,330.In',
#  '2,711,579,899.In',
#  '10,000,000.The',
#  '40,000,000.From',
#  '25,165,154.51.The',
#  '100,544,491.28.The',
#  '52,318,629.55.The',
#  '1,221,170,454.In',
#  '36,886,972.The',
#  '9,383,000.The',
#  '7,710,900.The',
#  '9,000,000.Under',
#  '426,875.67.The',
#  '17.It',
#  '2,275,000.This',
#  '700,000.The',
#  '80,213.The',
#  '37,285.The',
#  '4,151,988.66.Estimated',
#  '1,301,388.In',
#  '75,000.Under',
#  '582,735.38.The',
#  '7,597,708.68.The',
#  '39,000,000.The',
#  '32,675,972.81.The',
#  '53,289,465.I',
#  '55,760,000.This',
#  '1,084,371.Your',
#  '16,191,836.A',
#  '47,103,248.During',
#  '65,000,000.This',
#  '350,000,000.There',
#  '3,584,537.91.The',
#  '5,000,000.The',
#  '84,324,414.15.The',
#  '12,000,000.The',
#  '288,000,000.The',
#  '346,681,016.The',
#  '6,078,267.43.The',
#  '211,412,620.The',
#  '17,508,613.08.The',
#  '27,165,000.At',
#  '13,000,000.The',
#  '44,551,043.36.During',
#  '119,612,116.09.The',
#  '2,727.The',
#  '77,400.96.Since',
#  '1,027,020.97.The',
#  '4,242.35.The',
#  '511,876,144.The',
#  '107.48.The',
#  '2,840,140.During',
#  '156,740,467.14.The',
#  '459,155.The',
#  '4,860,286,837.I',
#  '17,710,114.27.The',
#  '6,303,000.Believing',
#  '12,649,094.55.During',
#  '25,205,712.65.The',
#  '36,723,432.43.Estimated',
#  '35,931,000.In',
#  '7,921,995.99.As',
#  '30,492,817.29.The',
#  '19,700,000.Notwithstanding',
#  '138,502,545.The',
#  '89,111,559.67.The',
#  '441,300,093.Under',
#  '44,495,378.The',
#  '4,410,070.81.There',
#  '17,513,754.The',
#  '93,000,000.Every',
#  '94,094.83.From',
#  '1,232,839,670.In',
#  '2,900,735,884.In',
#  '77,889,570.The']

# %% [markdown]
# >> #### 24.2 Solution: Add space between large numbers and words

# %%
pattern_after = []
for token in pattern_before:
    decimals = len(token.replace('.', '. ').split()) == 3
    if decimals:
        tokens = token.split('.')
        token_cleaned = '.'.join(tokens[:-1]) + '. ' + tokens[-1]
    else:
        token_cleaned = token.replace('.', '. ')
    pattern_after += [token_cleaned]
pattern_after
# Out:
# ['75,000,000. The',
#  '273,437,161.51. For',
#  '66,818,292.38. The',
#  '80,606,808.40. The',
#  '4,557,462.71. The',
#  '12,929,690.33. The',
#  '560,000. The',
#  '57,470,129.59. For',
#  '37,951. Among',
#  '247,131,549. The',
#  '24,175,000,000. There',
#  '104,000,000. The',
#  '7,063,298.57. The',
#  '2,226,876. The',
#  '101,000,000. It',
#  '196,778,017. The',
#  '934,123.11. There',
#  '63,000,000. During',
#  '101,232,511.66. The',
#  '31,414,788.04. Our',
#  '40,000,000. For',
#  '79,085. On',
#  '451,963,981. On',
#  '90,000. With',
#  '14,381,808.40. The',
#  '2,000. I',
#  '300,000,000. FACILITIES',
#  '218,196. The',
#  '2,033,053.09. It',
#  '5,125,638.14. The',
#  '2,740,854,750. Every',
#  '51,576,706. I',
#  '58,579,780.08. It',
#  '1,285,118.08. From',
#  '300,000. The',
#  '828,474.43. The',
#  '4,140,211,139. There',
#  '501,965,778. In',
#  '33,801,378.78. The',
#  '91. It',
#  '290,712.07. The',
#  '94,480,189. If',
#  '427,834.62. The',
#  '86,856,710. If',
#  '16,838,240. There',
#  '70,000,000. The',
#  '70,129,195.56. The',
#  '18,420. There',
#  '6,398,316.10. The',
#  '93,047,373.15. It',
#  '1,417,554.07. To',
#  '8,000,000. The',
#  '90,000,000. The',
#  '87,983,983.86. The',
#  '3,500,000. If',
#  '7. By',
#  '10,361,683. Should',
#  '43,678,883.01. During',
#  '6,879,300.93. The',
#  '71,902,000. The',
#  '570,749,155. If',
#  '99,960,253.54. The',
#  '172,314.65. The',
#  '98,072,420.30. Besides',
#  '165,235,129.35. The',
#  '130,140.85. It',
#  '23,150,617.39. The',
#  '112,000,000. On',
#  '387,131.95. The',
#  '500,000,000. These',
#  '114,000,000. ADVANTAGE',
#  '4,292,776.18. Estimates',
#  '126,758,218. Our',
#  '11,984,518.08. The',
#  '15,623,863.41. In',
#  '13,418,065.74. Because',
#  '6,000. The',
#  '82,487.30. The',
#  '28,000,000. On',
#  '9,844,528. The',
#  '356,000,000. The',
#  '6,400,000. The',
#  '80,976.59. The',
#  '324,656,458. I',
#  '4,000,000. The',
#  '50,451,265. The',
#  '391,994.59. These',
#  '7,862,797.10. The',
#  '2,426,753.36. Independent',
#  '87,500,000. Between',
#  '2,251,134. In',
#  '12,776,390. On',
#  '100,000,000. The',
#  '55,567,849.54. The',
#  '80,000. During',
#  '3,530,196.61. I',
#  '132,528,469. The',
#  '50,000,000. A',
#  '20,000,000. On',
#  '88,090,787.11. The',
#  '924,650.64. About',
#  '500,000. Owing',
#  '47,234,377.10. The',
#  '88,532,839.12. The',
#  '156,822,348.24. The',
#  '4,075,848.89. In',
#  '150,498.41. By',
#  '40,000,000. The',
#  '202,282,933.33. The',
#  '126,261,553. The',
#  '9,155,144.64. The',
#  '25,155,977.66. During',
#  '60,476,000. The',
#  '220,000,000. The',
#  '808,624,811.57. The',
#  '40,000. The',
#  '163,710.30. The',
#  '25,000. I',
#  '140,000,000. The',
#  '10,000,000. It',
#  '154. At',
#  '29,060,386.90. The',
#  '5,308,483. It',
#  '9,106,166. Another',
#  '4,528,676.87. It',
#  '74,989,900. It',
#  '16,000. I',
#  '381,999,073. Immediately',
#  '110,304. While',
#  '305,000,000. The',
#  '81,000,000. By',
#  '4,819,781. In',
#  '778,770. The',
#  '58,362,135.78. That',
#  '1,303,984,937.69. The',
#  '24,212,067. The',
#  '45,850,999.54. Besides',
#  '12,903,076.73. During',
#  '30,000,000. During',
#  '5,950,000. The',
#  '375,000,000. Press',
#  '137,000,000. It',
#  '100,000. A',
#  '1,047,271.35. New',
#  '16,619,047.42. This',
#  '37,239,762.57. The',
#  '140,000,000. There',
#  '97,011,330. In',
#  '2,711,579,899. In',
#  '10,000,000. The',
#  '40,000,000. From',
#  '25,165,154.51. The',
#  '100,544,491.28. The',
#  '52,318,629.55. The',
#  '1,221,170,454. In',
#  '36,886,972. The',
#  '9,383,000. The',
#  '7,710,900. The',
#  '9,000,000. Under',
#  '426,875.67. The',
#  '17. It',
#  '2,275,000. This',
#  '700,000. The',
#  '80,213. The',
#  '37,285. The',
#  '4,151,988.66. Estimated',
#  '1,301,388. In',
#  '75,000. Under',
#  '582,735.38. The',
#  '7,597,708.68. The',
#  '39,000,000. The',
#  '32,675,972.81. The',
#  '53,289,465. I',
#  '55,760,000. This',
#  '1,084,371. Your',
#  '16,191,836. A',
#  '47,103,248. During',
#  '65,000,000. This',
#  '350,000,000. There',
#  '3,584,537.91. The',
#  '5,000,000. The',
#  '84,324,414.15. The',
#  '12,000,000. The',
#  '288,000,000. The',
#  '346,681,016. The',
#  '6,078,267.43. The',
#  '211,412,620. The',
#  '17,508,613.08. The',
#  '27,165,000. At',
#  '13,000,000. The',
#  '44,551,043.36. During',
#  '119,612,116.09. The',
#  '2,727. The',
#  '77,400.96. Since',
#  '1,027,020.97. The',
#  '4,242.35. The',
#  '511,876,144. The',
#  '107.48. The',
#  '2,840,140. During',
#  '156,740,467.14. The',
#  '459,155. The',
#  '4,860,286,837. I',
#  '17,710,114.27. The',
#  '6,303,000. Believing',
#  '12,649,094.55. During',
#  '25,205,712.65. The',
#  '36,723,432.43. Estimated',
#  '35,931,000. In',
#  '7,921,995.99. As',
#  '30,492,817.29. The',
#  '19,700,000. Notwithstanding',
#  '138,502,545. The',
#  '89,111,559.67. The',
#  '441,300,093. Under',
#  '44,495,378. The',
#  '4,410,070.81. There',
#  '17,513,754. The',
#  '93,000,000. Every',
#  '94,094.83. From',
#  '1,232,839,670. In',
#  '2,900,735,884. In',
#  '77,889,570. The']

# %% [markdown]
# >> #### 24.3 Prepare tokens and update dictionary

# %%
# Zip pairs into before and after tuples
patterns = list(zip(pattern_before, pattern_after))

# Update dictionary and hyphen tokens
clean_dict = update_dict(clean_dict, patterns)
transcript_tokens = [token for token in transcript_tokens if token not in clean_dict]

# %% [markdown]
# >> #### 25.1 Problem: Some tokens have a question mark following a comma

# %%
pattern_before = [token for token in transcript_tokens if ',?' in token]
pattern_before
# Out:
# ['everywhere,?the',
#  'happiness,?15,000,000',
#  'hostile,?all',
#  'indispensable,?because',
#  'it,?and',
#  'moreover,?who',
#  'power,?the',
#  'privileges,?for',
#  'resources,?some',
#  'return,?unless',
#  'seeking,?blindly',
#  'vision,?the',
#  'will,?any']

# %% [markdown]
# >> #### 25.2 Solution: Remove question mark

# %%
pattern_after = [token.replace(',?', ', ') for token in pattern_before]
pattern_after
# Out:
# ['everywhere, the',
#  'happiness, 15,000,000',
#  'hostile, all',
#  'indispensable, because',
#  'it, and',
#  'moreover, who',
#  'power, the',
#  'privileges, for',
#  'resources, some',
#  'return, unless',
#  'seeking, blindly',
#  'vision, the',
#  'will, any']

# %% [markdown]
# >> #### 25.3 Prepare tokens and update dictionary

# %%
# Zip pairs into before and after tuples
patterns = list(zip(pattern_before, pattern_after))

# Update dictionary and hyphen tokens
clean_dict = update_dict(clean_dict, patterns)
transcript_tokens = [token for token in transcript_tokens if token not in clean_dict]

# %% [markdown]
# >> #### 26.1 Problem: There needs to be a space between periods and Capitals or remove period

# %%
pattern = "^\.(.*?)"
pattern_before = [token for token in list(set(transcript_tokens)) if re.search(pattern, token)]
pattern_before
# Out:
# ['.decisions',
#  '.If',
#  '.limited',
#  '.He',
#  '.enhancement',
#  '.I',
#  '.The',
#  '.Affairs',
#  '.Our',
#  '.Negotiations',
#  '.outside',
#  '.position',
#  '.power',
#  '.recovery',
#  '.place',
#  '.As',
#  '.knowledge',
#  '.promoted',
#  '.nuclear',
#  '.every',
#  '.A',
#  '.important',
#  '.that',
#  '.and',
#  '.for',
#  '.expenditures',
#  '.with',
#  '.at',
#  '.pause',
#  '.merely',
#  '.In',
#  '.own',
#  '.By',
#  '.past',
#  '.the',
#  '.There',
#  '.upon',
#  '.America',
#  '.put',
#  '.commends',
#  '.is',
#  '.With',
#  '.Pursuant',
#  '.by',
#  '.During',
#  '.this']

# %% [markdown]
# >> #### 26.2 Solution: Insert space between periods and capitals or remove

# %%
pattern_after = [token.replace('.', '. ') if token[1].isupper() else token[1:] for token in pattern_before]
pattern_after
# Out:
# ['decisions',
#  '. If',
#  'limited',
#  '. He',
#  'enhancement',
#  '. I',
#  '. The',
#  '. Affairs',
#  '. Our',
#  '. Negotiations',
#  'outside',
#  'position',
#  'power',
#  'recovery',
#  'place',
#  '. As',
#  'knowledge',
#  'promoted',
#  'nuclear',
#  'every',
#  '. A',
#  'important',
#  'that',
#  'and',
#  'for',
#  'expenditures',
#  'with',
#  'at',
#  'pause',
#  'merely',
#  '. In',
#  'own',
#  '. By',
#  'past',
#  'the',
#  '. There',
#  'upon',
#  '. America',
#  'put',
#  'commends',
#  'is',
#  '. With',
#  '. Pursuant',
#  'by',
#  '. During',
#  'this']

# %% [markdown]
# >> #### 26.3 Prepare tokens and update dictionary

# %%
# Zip pairs into before and after tuples
patterns = list(zip(pattern_before, pattern_after))

# Update dictionary and hyphen tokens
clean_dict = update_dict(clean_dict, patterns)
transcript_tokens = [token for token in transcript_tokens if token not in clean_dict]

# %% [markdown]
# >> #### 27.1 Problem: Some specified token patterns need to be cleaned

# %%
pattern_before = []
pattern_after = []

pattern = "^[0-9]{4}[.]"
pattern_before += [token for token in list(set(transcript_tokens)) if re.search(pattern, token)]
pattern_after += [token.replace('.', '. ') for token in list(set(transcript_tokens)) if re.search(pattern, token)]

pattern = "^[0-9]{4}[,]"
pattern_before += [token for token in list(set(transcript_tokens)) if re.search(pattern, token)]
pattern_after += [token.replace(',', ', ') for token in list(set(transcript_tokens)) if re.search(pattern, token)]

pattern_before += [token for token in transcript_tokens if '\\' in token]
pattern_after += [token.replace('\\', '') for token in transcript_tokens if '\\' in token]

pattern_before
# Out:
# ['1858.It',
#  '1921.DEPARTMENT',
#  '1888.A',
#  '1911.To',
#  '1896.I',
#  '1894.As',
#  '1908.In',
#  '1874.I',
#  '1812.JAMES',
#  '1912.CIVIL',
#  '1818.In',
#  '1897.I',
#  '1812.I',
#  '1912.To',
#  '1876.It',
#  '1872.It',
#  '1827."We',
#  '1890.I',
#  '1890.In',
#  '1808.As',
#  '1898.In',
#  '1833.I',
#  '1813.JAMES',
#  '1888.In',
#  '1916.As',
#  '1877.In',
#  '1832.At',
#  '1889.I',
#  '1909.PORTO',
#  '1884,as',
#  '1928,"And',
#  '1926,Amendments',
#  '1850,providing',
#  '1865,numbered',
#  '1855,and']

# %% [markdown]
# >> #### 27.2 Solution: Clean specified token patterns

# %%
pattern_after
# Out:
# ['1858. It',
#  '1921. DEPARTMENT',
#  '1888. A',
#  '1911. To',
#  '1896. I',
#  '1894. As',
#  '1908. In',
#  '1874. I',
#  '1812. JAMES',
#  '1912. CIVIL',
#  '1818. In',
#  '1897. I',
#  '1812. I',
#  '1912. To',
#  '1876. It',
#  '1872. It',
#  '1827. "We',
#  '1890. I',
#  '1890. In',
#  '1808. As',
#  '1898. In',
#  '1833. I',
#  '1813. JAMES',
#  '1888. In',
#  '1916. As',
#  '1877. In',
#  '1832. At',
#  '1889. I',
#  '1909. PORTO',
#  '1884, as',
#  '1928, "And',
#  '1926, Amendments',
#  '1850, providing',
#  '1865, numbered',
#  '1855, and']

# %% [markdown]
# >> #### 27.3 Prepare tokens and update dictionary

# %%
# Zip pairs into before and after tuples
patterns = list(zip(pattern_before, pattern_after))

# Update dictionary and hyphen tokens
clean_dict = update_dict(clean_dict, patterns)
transcript_tokens = [token for token in transcript_tokens if token not in clean_dict]

# %% [markdown]
# >> #### 28.1 Problem: Remaining tokens need to be cleaned

# %%
pattern_before = transcript_tokens[5:]
pattern_before
# Out:
# ['0.9244.The',
#  '001,856Schedule',
#  '1,114,382,while',
#  '1,150Attempts',
#  '1.95M.',
#  '1/2per',
#  '100,000,000In',
#  '104,706,922,but',
#  '106,742,646M',
#  '106D',
#  '107,gig',
#  '11,105,820B',
#  '11,105,820H.',
#  '11.4M.',
#  '110,400.77The',
#  '110M.',
#  '111juries',
#  '112C',
#  '11⁄2',
#  '129B',
#  '14(b',
#  '148,480.00State',
#  '14E',
#  '154H',
#  '15A',
#  '16,000,000which',
#  '166,281,505.55The',
#  '16o,657',
#  '17,134,944It',
#  '178,672miles',
#  '17M.',
#  '1819–20',
#  '1825–07',
#  '186118,000.00Of',
#  '1861266,600.00Of',
#  '186210,300.00Of',
#  '1863116,850.00Of',
#  '1864133,550.00Of',
#  '18647,050.00Of',
#  '186540,800.00Of',
#  '18659,600.00Of',
#  '1867235,700.00Of',
#  '1868154,650.00Of',
#  '186J',
#  '1870$87,134,782.84From',
#  '1871117,619,630.25From',
#  '1872106,564,356.94Total',
#  '187294,895,348.94From',
#  '1874$8,883,940.933.65',
#  '18742,088,168.73Certificates',
#  '1881719,150.00Of',
#  '188247,650.00Of',
#  '1882were',
#  '1895:"The',
#  '1899:I',
#  '18gi',
#  '19,038,665.81on',
#  '1900;(2',
#  '19071,418,850.00Of',
#  '1911To',
#  '1913OUR',
#  '191:2',
#  '1925=100',
#  '1929;"Now',
#  '193,000)could',
#  '198,159,676.02,an',
#  '19M.',
#  '19ii',
#  '19li',
#  '19o8',
#  '1>e',
#  '1See',
#  '1a',
#  '1ongitudes',
#  '1⁄2',
#  '2,71o',
#  '20s',
#  '22].I',
#  '231,631.70Executive998,170.00472,270.00722,270.00870,750.00',
#  '23M.',
#  '25,902,683During',
#  '25,902,683This',
#  '257,981,439.57Leaving',
#  '25By',
#  '25M.',
#  '26M',
#  '26M.',
#  '2M.',
#  '2Secretary',
#  '2o,000',
#  '2oo',
#  '2oth',
#  '300million',
#  '30s',
#  '33,05o',
#  '35–$40',
#  '36F',
#  '39,applied',
#  '39N',
#  '3D',
#  '3oth',
#  '4,345,521;of',
#  '4,380,043H',
#  '400,000,000and',
#  '401(k)s',
#  '401k',
#  '401ks',
#  '403,525,250.28The',
#  '40s',
#  '41)1,406The',
#  '41,622,024J',
#  '45пїЅ',
#  '45пїЅ.',
#  '462,001,856I',
#  '46пїЅ',
#  '484,042,573.15From',
#  '4years',
#  '5,000,000people',
#  '50?”For',
#  '50s',
#  '51,000men',
#  '512,977,32677,044,257The',
#  '516,240,131to',
#  '579,850,322This',
#  '5M.',
#  '5s',
#  '6,038,091;and',
#  '60s',
#  '63K',
#  '675clerks',
#  '6:8',
#  '6I',
#  '6e',
#  '6oo',
#  '6rst',
#  '70s',
#  '712,882.20,an',
#  '74,480,20l.05',
#  '741.69From',
#  '75,000,0W',
#  '757s',
#  '75L',
#  '767,111,964Excess',
#  '799,959,736Imports',
#  '7M.',
#  '8)',
#  '804,445K',
#  '80s',
#  '81,486,466N',
#  '878,756,074Of',
#  '8G',
#  '90,786,064.02,which',
#  '90s',
#  '915,353,igo',
#  '91odily',
#  '9M.',
#  '=',
#  '>',
#  'A&M',
#  'A&M.',
#  'A.:Your',
#  'A.By',
#  'AT&T',
#  'Army."I',
#  'BUREN.By',
#  "Ba'athist",
#  'Ball,10',
#  'Builders,7',
#  'C3,100,060,000',
#  'COMMUNIQUÉ',
#  'Clinton/Gore',
#  'Coast190The',
#  'Columbia1,138,836.412,611,163.59For',
#  'Columbia256,017.991,643,982.01From',
#  'Columbia2Total',
#  'Columbia3,407,049.62For',
#  'Columbia3,817,028.48For',
#  'Communiqué',
#  'Congress."6',
#  'CrisisNextDoor.gov',
#  "D'AFFAIRES",
#  "D'Alesandro",
#  "D'Avino",
#  "Dara'a",
#  'Department:4,875,576.414,875,301.414,749,801.415,046,701.41',
#  'Doré',
#  'E.Lee',
#  'E1',
#  'Europe/Radio',
#  'FARLEY.It',
#  'February,1899',
#  'GOVERNED.”I',
#  'Gardner14',
#  'GeorgeWBush.com',
#  'Gove2rnment',
#  'Government."A',
#  'Government."I',
#  'Guaidó',
#  'Guantánamo',
#  'Harriman,1',
#  "I'm",
#  'I,_________,do',
#  'In1870',
#  'Indians2,623,390.544,126,609.46For',
#  'Indians6,475,999.29For',
#  'Indians7,061,728.82For',
#  'Indians7,362,590.34For',
#  'J1,307',
#  'JEFFERSON.By',
#  'José',
#  'June30',
#  'Kaléo',
#  "Ku'damm",
#  "L'Enfant",
#  'Legislature$13,426,805.73$13,169,679.70$13,169,679.70$12,938,048.00',
#  'López',
#  "M'Henry",
#  'MADISON.By',
#  'MacNeil/Lehrer',
#  'Medicare/prescription',
#  'Merchandise$667,697,693Gold',
#  'Moyers11',
#  "Mu'ammar",
#  'NECESSITY.But',
#  'Northwest435District',
#  'OB/GYNS',
#  'PIERCE.By',
#  'Pensions66,012,573.64For',
#  'Ph.D.',
#  "Presqu'isle",
#  'R&D',
#  'Recovery.gov',
#  'RedCross.org',
#  'SCHEDULES.Items',
#  'SS20',
#  "Sana'a",
#  'Schlesinger,2',
#  "Shi'a",
#  'Solomon,12',
#  'States."COMMON',
#  'States."I',
#  'States181Southern',
#  'T903',
#  "Ty'Sheoma",
#  'U.S',
#  'U.S.A',
#  'U235',
#  'VII.Since',
#  'Vaughn,6',
#  'WASHINGTON.By',
#  'Washington,"And',
#  'Y2',
#  '[America',
#  '`',
#  'a)round',
#  'a.m.',
#  'a14',
#  'account$99,960,003.54Reduction',
#  'account3,330,952.96Reduction',
#  'act.”Now',
#  'adaptation.“It',
#  'air)planes',
#  'and$38,336,450',
#  'and$4,575,397.97',
#  'and$6,469,643.04',
#  'and(3',
#  'and)to',
#  "aphorism.''This",
#  'appropria.ltions',
#  'approval:1',
#  'argument."I',
#  'arsenals13,512,204.3326,487,795.67For',
#  'arsenals35,372,157.20For',
#  'arsenals39,429,603.36For',
#  'arsenals48,911,382.93For',
#  'asociations.\'"This',
#  'assays4,460,205.17From',
#  'assesments(chargeable',
#  'assessments$1,614,054.37Less',
#  'assets13,994,613.24In',
#  'assurance(s',
#  'at/east',
#  'audit4,770,558.4515,742,667.61Less',
#  'aw.12',
#  'awards."I',
#  'a–work',
#  'banker."I',
#  'banks1,557,800.881,542,199.12From',
#  'banks9,111,008.85From',
#  'bar(re',
#  'be7crigspeculiarly',
#  'be:(1',
#  "beii4'forced",
#  'believe??that',
#  "bondage.''The",
#  'bonds59,000.00In',
#  'bonds75,000.00And',
#  'both/and',
#  'by$58,485,517.The',
#  'cal1ed',
#  'cash$58,448,223.75Kansas',
#  'cash11,798,314.14Notes',
#  'cash484,042,573.15The',
#  'cash6,303,000.00Central',
#  'cash821,897.70Making',
#  'celebrat(e)ing',
#  'cent20,594,600.00Of',
#  'cent65,380,250.00Of',
#  'cents13.1From',
#  'cents93.0From',
#  'certificates109,150.00Of',
#  'claims,227,040',
#  'coin9,412,637.65Total',
#  'committee1',
#  'committees."I',
#  'companies521,059.511,478,940.49From',
#  'companies749,861.87From',
#  'competition."I',
#  'con.structively',
#  'cotton30,454,476Hides',
#  'crops.(2',
#  'crops.(3',
#  'customs$195,067,489.76From',
#  'customs$214,706,496.93From',
#  'customs$216,370,286.77From',
#  'customs$223',
#  'customs$57,402,975.67$137,597,024.33From',
#  'day!"What',
#  'debt117,357,839.72Total',
#  'debt14,797,297.9639,702,702.04Total',
#  'debt270,559,695.91For',
#  'debt270,559,695.91Leaving',
#  'debt5,450.00Of',
#  'debt54,578,378.48For',
#  'debt59,160,131.25Total',
#  'debt99,960,253.54106,918,520.30Total',
#  "didn'the",
#  'die,\'"To',
#  'disbursements377,478,216.21Balance',
#  'disturb.”I',
#  'do15.6Of',
#  'duty;2',
#  'effect.||',
#  'either/or',
#  'equal.\'"This',
#  'estimated$343,000,000.00Total',
#  'estimated258,000,000.0085,000,000.00Estimated',
#  'etc,"a',
#  'etc1,136,442.34From',
#  'etc2,284,095.92From',
#  'etc298,696.78901,303.22From',
#  'etc6,523,396.39From',
#  'etc65,337,343$60,624,4642',
#  'etc950,229.463,149,770.54From',
#  'execution.(Signed',
#  'expenditures290,926,473.83Leaving',
#  'expenses$16,187,059.20For',
#  'expenses$22,312,907.71For',
#  'expenses$22,343,285.76For',
#  'fiancée',
#  "folks'pensions",
#  "follows:'The",
#  'follows:(I',
#  'follows:(i',
#  'follows::"In',
#  'follows;"It',
#  'fund$44,850,700.00Of',
#  'fund1,748,054.37Leaving',
#  'fund45,816,741.07Leaving',
#  'fund46,556.96Of',
#  'fund46,790,229.50Total',
#  'gathering(ed',
#  'government.""But',
#  'granted."I',
#  'great‐granddaughter',
#  'hand103,290,956.502,746,465.22100,544,491.28On',
#  'him!"While',
#  "him!''While",
#  'hom6',
#  'i.e',
#  'i5,000',
#  'i8go',
#  'improvemen4',
#  'in1881',
#  'injury."A',
#  'instance(s',
#  'intercourse1,260,766.37For',
#  'intercourse1,839,369.14For',
#  'intercourse2,419,275.24For',
#  "it'[s",
#  'it."I',
#  'it.”It',
#  'it1s',
#  'it:“The',
#  'job‐crushing',
#  'justice(s',
#  'l500',
#  'l7y',
#  'l933',
#  'labor(s',
#  'lands172,461.31327,538.69From',
#  'lands2,575,714.19From',
#  'lands2,932,635.175,067,634.83From',
#  'lands7,955,864.42From',
#  'lands863,209.802,436,790.20From',
#  'length3,949',
#  'libertyunites.org',
#  'loyalt(y)ies',
#  'manufactures49,949,128Coffee49,686,705Iron',
#  'manufactures53,842,292Silk',
#  'manufactures;$21,462,534.34',
#  'mechanical)double',
#  'merchandise$724,964,852Foreign',
#  'merchandise15,548,757Total',
#  'merchandise740,513,609Specie67,133,383Total',
#  'mills8.5From',
#  'miscellaneous412,254.71Total',
#  'molasses$103,884,274Wool',
#  'months)64,047,237.84Total',
#  'naïve',
#  'negroes!!”Well',
#  'not."SUBSTITUTE',
#  'notes13,300.00Total',
#  'o/the',
#  'of$425,000',
#  'of250',
#  'of39,183,258.93If',
#  'of57,603,396.09As',
#  'of____for',
#  'office."I',
#  'ones)are',
#  'orphans."DEPARTMENT',
#  "other.''Mr",
#  'out./p',
#  'overtures92',
#  'p.m.',
#  'parent/teacher',
#  'passed."A',
#  'pay)that',
#  'pensions16,285,261.9853,714,738.02For',
#  'pensions28,533,402.76For',
#  'pensions55,429,228.06For',
#  'people;"And',
#  'points:1',
#  'pound19,950,1873,129,321Total',
#  'pound348,988,6482,996,4033',
#  'pound78,701,14810,324,0694',
#  'powers."I',
#  'present45',
#  'proof7',
#  'property112,562.23167,437.77From',
#  'protect(ion',
#  'purchased$6,958,266.76For',
#  'purchased2,454,370.89Add',
#  'rates)G',
#  'rati6ed',
#  're)sources',
#  'receipts$112,194,947',
#  'recovery.gov',
#  'revenue$15,385,799.42$51,114,200.58For',
#  'revenue121,586,072.51From',
#  'revenue130,642,177.72From',
#  'revenue130,881,513.92From',
#  'revenue144,720,368.98From',
#  'revenue29,662,078.6090,337,921.40From',
#  'revenue40,098,432.73For',
#  'revenue42,958,329.08For',
#  'revenue43,939,710.00For',
#  'revenue94,134,534.00Add',
#  'revita1ize',
#  'régime',
#  'résumé',
#  'runni110',
#  'said,"About',
#  'said,"Sammy',
#  "said:'All",
#  'says:“We',
#  'seas."I',
#  'secured47,050,172.36Kansas',
#  'silver.]Fiscal',
#  'silver37,426,262Total',
#  'since1860',
#  'skins22,350,906I',
#  'slavery.”This',
#  'sources1,237,189.632,382,810.37Total',
#  'sources17,333,637.60Total',
#  'sources31,866,307.65Total',
#  'sources32,335,803.23The',
#  'stand."I',
#  'stringency."I',
#  'subject."I',
#  'supplies.]Fiscal',
#  't1he',
#  't1literests',
#  'tax‐cut',
#  'the1st',
#  'there"?if',
#  'thereof33,463,398Cotton',
#  'thereof41,464,599Chemicals38,464,965Flax',
#  'through(out',
#  'time.\'"Henry',
#  'time;I',
#  'to$25,013,650',
#  'to$443,889,495.88',
#  'to7the',
#  'trade."MAINE',
#  'tread.”At',
#  'trying???with',
#  'unavailable")109,935,705.59Total',
#  'up)on',
#  'usafreedomcorps.gov',
#  'vessels."A',
#  'w1,11',
#  'wage/pricing',
#  'war."I',
#  'war]1',
#  'well‐being',
#  "wisdom'sno",
#  "world'speace",
#  'wrote:``I',
#  'x897',
#  'x8go',
#  'x8th',
#  'year$364,694,229.91Net',
#  'year3,371,348.65Total',
#  'z898',
#  '~~To',
#  '~~more',
#  '¤oes',
#  '°']

# %% [markdown]
# >> #### 28.2 Solution: Clean tokens

# %%
pattern_after = [
'0.9244. The',
'1,114,382, while',
'1.95M.',
'1/2 per',
'100,000,000 In',
'104,706,922, but',
'11.4M.',
'110,400.77 The',
'110M.',
'11⁄2',
'14(b',
'15A',
'16,000,000 which',
'166,281,505.55 The',
'160,657',
'17,134,944 It',
'178,672 miles',
'17M.',
'1819–20',
'1825–07',
'1874 $8,883,940.933.65',
'1874 2,088,168.73 Certificates',
'1882 were',
'1895: "The',
'1899: I',
'19,038,665.81 on',
'1913 OUR',
'191:2',
'1925=100',
'1929; "Now',
'193,000) could',
'198,159,676.02, an',
'19M.',
'1908',
'1>e',
'See',
'1a',
'longitudes',
'1⁄2',
'20s',
'22]. I',
'23M.',
'25,902,683 During',
'25,902,683 This',
'257,981,439.57 Leaving',
'25 By',
'25M.',
'26M.',
'2M.',
'2 Secretary',
'20th',
'300 million',
'30s',
'35–$40',
'39, applied',
'3D',
'30th',
'4,345,521; of',
'400,000,000 and',
'401(k)s',
'401k',
'401ks',
'403,525,250.28 The',
'40s',
'41) 1,406 The',
'45пїЅ',
'45пїЅ.',
'46пїЅ',
'4 years',
'5,000,000 people',   
'50?” For',
'50s',
'51,000 men',
'512,977,32677,044,257 The',
'516,240,131 to',
'5M.',
'5s',
'6,038,091; and',
'60s',
'675 clerks',
'6:8',
'6e',
'6rst',
'70s',
'712,882.20, an',
'74,480,201.05',
'741.69 From',
'757s',
'767,111,964 Excess',
'799,959,736 Imports',
'7M.',
'8)',
'80s',
'90,786,064.02, which',
'90s',
'9M.',
'=',
'>',
'A&M',
'A&M.',
'A.: Your',
'A. By',
'AT&T',
'Army. "I',
'BUREN. By',
"Ba'athist",
'Ball, 10',
'Builders, 7',
'C3, 100,060,000',
'COMMUNIQUÉ',
'Clinton/Gore',
'Coast 190 The',
'Columbia 2 Total',
'Communiqué',
'Congress." 6',
'CrisisNextDoor.gov',
"D'AFFAIRES",
"D'Alesandro",
"D'Avino",
"Dara'a",
'Doré',
'E. Lee',
'E1',
'Europe and or Radio',
'FARLEY. It',
'February, 1899',
'GOVERNED.” I',
'Gardner',
'GeorgeWBush.com',
'Government. "A',
'Government. "I',
'Guaidó',
'Guantánamo',
'HIV/AIDS',
'Harriman, 1',
"I'm",
'I, do',
'JEFFERSON. By',
'José',
'June 30',
'Kaléo',
"Ku'damm",
"L'Enfant",
'López',
"M'Henry",
'MADISON. By',
'MacNeil and or Lehrer',
'Medicare and or prescription',
'Moyers',
"Mu'ammar",
'NECESSITY. But',
'Northwest 435 District',
'OB/GYNS',
'PIERCE. By',
'Ph.D.',
"Presqu'isle",
'R&D',
'Recovery.gov',
'RedCross.org',
'SS20',
"Sana'a",
'Schlesinger, 2',
"Shi'a",
'Solomon, 12',
'States. "I',
'States 181 Southern',
"Ty'Sheoma",
'U.S',
'U.S.A',
'U235',
'VII. Since',
'Vaughn, 6',
'Washington, "And',
'Y2',
'[America',
"'",
'a)round',
'a.m.',
'a14',
'act. ”Now',
'adaptation. “It',
'air)planes',
'and $38,336,450',
'and $4,575,397.97',
'and $6,469,643.04',
'and) to',
'and/or',
'aphorism. "This',
'approval: 1',
'argument. "I',
'asociations. "This',
'assesments (chargeable',
'assessments $1,614,054.37 Less',
'assets 13,994,613.24 In',
'assurance(s',
'at/east',
'audit 4,770,558.4515,742,667.61 Less',
'awards. "I',
'a–work',
'banker. "I',
'be: (1',
'believe that',
'bondage. "The',
'bonds 59,000.00 In',
'bonds 75,000.00 And',
'both/and',
'by $58,485,517. The',
'cal1ed',
'celebrat(e)ing',
'cents 13.1 From',
'cents 93.0 From',
'claims, 227,040',
'committee 1',
'committees. "I',
'competition. "I',
'constructively',
'crops. (2',
'crops. (3',
'customs $223',
'day! "What',
"didn't he",
'die, "To',
'disturb. ”I',
'do 15.6Of',
'duty; 2',
'effect.',
'either/or',
'equal. "This',
'etc, "a',
'etc 65,337,343$60,624,4642',
'execution. (Signed',
'fiancée',
"folks' pensions",
"follows: 'The",
'follows: "In',
'follows; "It',
'fund 1,748,054.37 Leaving',
'gathering(ed',
'government. But',
'granted. "I',
'great‐granddaughter',
'him! "While',
'him! "While',
'i.e',
'in 1881',
'injury. "A',
'instance(s',
"it'[s",
'it. "I',
'it. ”It',
"it's",
'it: “The',
'job‐crushing',
'justice(s',
'l500',
'l933',
'labor(s',
'length 3,949',
'libertyunites.org',
'loyalt(y)ies',
'manufactures; $21,462,534.34',
'mechanical) double',
'mills 8.5 From',
'naïve',
'negroes!! ”Well',
'not. "SUBSTITUTE',
'of the',
'of $425,000',
'of 250',
'of ____ for',
'office. "I',
'ones) are',
'orphans. "DEPARTMENT',
'other. "Mr',
'out.',
'overtures 92',
'p.m.',
'parent/teacher',
'passed. "A',
'pay) that',
'people; "And',
'points: 1',
'pound 19,950,1873,129,321 Total',
'pound 348,988,6482,996,4033',
'pound 78,701,14810,324,0694',
'powers. "I',
'present 45',
'proof 7',
'protect(ion',
're)sources',
'receipts $112,194,947',
'recovery.gov',
'revenue 130,881,513.92 From',
'revita1ize',
'régime',
'résumé',
'said, "About',
'said, "Sammy',
"said: 'All",
'says: “We',
'seas. "I',
'since 1860',
'slavery. ”This',
'sources 32,335,803.23 The',
'stand. "I',
'stringency. "I',
'subject. "I',
'the',
'tax‐cut',
'the 1st',
'there"? if',
'through(out',
'time.' "Henry'",
'time; I',
'to $25,013,650',
'to $443,889,495.88',
'tread. ”At',
'trying???with',
'up)on',
'usafreedomcorps.gov',
'vessels. "A',
'wage/pricing',
'war. "I',
'war] 1',
'well‐being',
"wisdom's no",
"world's peace",
'wrote: "I',
' To',
' more',
'does',
'°'
]

# %% [markdown]
# >> #### 28.3 Prepare tokens and update dictionary

# %%
# Zip pairs into before and after tuples
patterns = list(zip(pattern_before, pattern_after))

# Update dictionary and hyphen tokens
clean_dict = update_dict(clean_dict, patterns)
transcript_tokens = [token for token in transcript_tokens if token not in clean_dict]

# %% [markdown]
# ## Clean Tokens

# %%
speeches.Summary = speeches.Summary.apply(lambda x: clean_text_tokens(x, clean_dict))
speeches.Transcript = speeches.Transcript.apply(lambda x: clean_text_tokens(x, clean_dict))

# %%
# Add pipeline
nlp.add_pipe(remove_excess_spaces_component)

# Convert Transcripts to doc to create tokens with hyphens
speeches.Transcript = list(nlp.pipe(speeches.Transcript, batch_size = 50, n_process=-1,  disable=["tagger", "parser", "ner"]))
speeches.Transcript = speeches.Transcript.apply(lambda x: x.text.replace(' — ', '—'))

# Convert Transcripts again to clean transcripts into final form
speeches.Transcript = list(nlp.pipe(speeches.Transcript, batch_size = 50, n_process=-1,  disable=["tagger", "parser", "ner"]))
speeches.Transcript = speeches.Transcript.apply(lambda x: clean_transcript(x))
speeches.Transcript = speeches.Transcript.apply(lambda x: x.strip())

# %% [markdown]
# ## 4.6 Add Political Party

# %%
# Poltical Parties
president_party = {}
president_party['Abraham Lincoln'] = 'Republican'
president_party['Andrew Jackson'] = 'Democratic'
president_party['Andrew Johnson'] = 'Democratic'
president_party['Barack Obama'] = 'Democratic'
president_party['Benjamin Harrison'] = 'Republican'
president_party['Bill Clinton'] = 'Democratic'
president_party['Calvin Coolidge'] = 'Republican'
president_party['Chester A. Arthur'] = 'Republican'
president_party['Donald Trump'] = 'Republican'
president_party['Dwight D. Eisenhower'] = 'Republican'
president_party['Franklin D. Roosevelt'] = 'Democratic'
president_party['Franklin Pierce'] = 'Democratic'
president_party['George H. W. Bush'] = 'Republican'
president_party['George W. Bush'] = 'Republican'
president_party['George Washington'] = 'Unaffiliated'
president_party['Gerald Ford'] = 'Republican'
president_party['Grover Cleveland'] = 'Democratic'
president_party['Harry S. Truman'] = 'Democratic'
president_party['Herbert Hoover'] = 'Republican'
president_party['James A. Garfield'] = 'Republican'
president_party['James Buchanan'] = 'Democratic'
president_party['James K. Polk'] = 'Democratic'
president_party['James Madison'] = 'Democratic-Republican'
president_party['James Monroe'] = 'Democratic-Republican'
president_party['Jimmy Carter'] = 'Democratic'
president_party[ 'John Adams'] = 'Federalist'
president_party['John F. Kennedy'] = 'Democratic'
president_party['John Quincy Adams'] = 'Democratic-Republican'
president_party['John Tyler'] = 'Unaffiliated'
president_party['Lyndon B. Johnson'] = 'Democratic'
president_party[ 'Martin Van Buren'] = 'Democratic'
president_party['Millard Fillmore'] = 'Whig'
president_party['Richard M. Nixon'] = 'Republican'
president_party['Ronald Reagan'] = 'Republican'
president_party['Rutherford B. Hayes'] = 'Republican'
president_party[ 'Theodore Roosevelt'] = 'Republican'
president_party['Thomas Jefferson'] = 'Democratic-Republican'
president_party['Ulysses S. Grant'] = 'Republican'
president_party['Warren G. Harding'] = 'Republican'
president_party['William Harrison'] = 'Whig'
president_party['William McKinley'] = 'Republican'
president_party['William Taft'] = 'Republican'
president_party['Woodrow Wilson'] = 'Democratic'
president_party['Zachary Taylor'] = 'Whig'

# %%
# Add political party to speeches and rearrange column order
speeches['Party'] = speeches.President.apply(lambda x: president_party[x])
speeches = speeches[['Date', 'President', 'Party', 'Speech Title', 'Summary', 'Transcript', 'URL']]

# Reverse index ordering 
speeches = speeches.iloc[::-1]
speeches = speeches.reset_index(drop=True)

# %%
# Chester A. Arthur's date for his speech if off by a century so it must be corrected
speeches.iloc[774, speeches.columns.get_loc('Date')] = pd.Timestamp(1881, 12, 6)

# %%
# Save Speeches
pickle.dump(speeches, open('pickles/speeches.p', "wb" ))
